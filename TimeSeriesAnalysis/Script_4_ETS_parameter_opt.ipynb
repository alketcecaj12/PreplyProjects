# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
from random import random
import matplotlib.pyplot as plt 
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
import pandas as pd
import numpy as np
from pandas import datetime
from random import random
from pandas.plotting import lag_plot
from pandas.plotting import autocorrelation_plot
from statsmodels.graphics.tsaplots import plot_acf
from sklearn.metrics import mean_squared_error
from math import sqrt
from statsmodels.tsa.ar_model import AR
import warnings
warnings.filterwarnings('ignore')

# grid search ets hyperparameters for monthly mean temp dataset
from math import sqrt
from multiprocessing import cpu_count
from joblib import Parallel
from joblib import delayed
from warnings import catch_warnings
from warnings import filterwarnings
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error
from pandas import read_csv
from numpy import array


# one-step Holt Winters Exponential Smoothing forecast
def exp_smoothing_forecast(history, config):
    t,d,s,p,b,r = config
    # define model
    history = array(history)
    model = ExponentialSmoothing(history, trend=t, damped=d, seasonal=s, seasonal_periods=p)
    # fit model
    model_fit = model.fit(optimized=True, use_boxcox=b, remove_bias=r)
    # make one step forecast
    yhat = model_fit.predict(len(history), len(history))
    return yhat[0]

# root mean squared error or rmse
def measure_rmse(actual, predicted):
    return sqrt(mean_squared_error(actual, predicted))

# split a univariate dataset into train/test sets
def train_test_split(data, n_test):
    return data[:-n_test], data[-n_test:]


# walk-forward validation for univariate data
def walk_forward_validation(data, n_test, cfg):
    predictions = list()
    # split dataset
    train, test = train_test_split(data, n_test)
    # seed history with training dataset
    history = [x for x in train]
    # step over each time-step in the test set
    for i in range(len(test)):
        # fit model and make forecast for history
        yhat = exp_smoothing_forecast(history, cfg)
        # store forecast in list of predictions
        predictions.append(yhat)
        # add actual observation to history for the next loop
        history.append(test[i])
    # estimate prediction error
    error = measure_rmse(test, predictions)
    return error



# score a model, return None on failure
def score_model(data, n_test, cfg, debug=False):
    result = None
    # convert config to a key
    key = str(cfg)
    # show all warnings and fail on exception if debugging
    if debug:
        result = walk_forward_validation(data, n_test, cfg)
    else:
        # one failure during model validation suggests an unstable config
        try:
            # never show warnings when grid searching, too noisy
            with catch_warnings():
                filterwarnings("ignore")
                result = walk_forward_validation(data, n_test, cfg)
        except:
             error = None
    # check for an interesting result
    #if result is not None:
    #     print(' > Model[%s] %.3f' % (key, result))
    return (key, result)


# grid search configs
def grid_search(data, cfg_list, n_test, parallel=True):
    scores = None
    if parallel:
    # execute configs in parallel
    
        executor = Parallel(n_jobs=cpu_count(), backend='multiprocessing') 
        tasks = (delayed(score_model)(data, n_test, cfg) for cfg in cfg_list) 
        scores = executor(tasks)
    else:
        scores = [score_model(data, n_test, cfg) for cfg in cfg_list]
    # remove empty results
    scores = [r for r in scores if r[1] != None]
    # sort configs by error, asc
    scores.sort(key=lambda tup: tup[1])
    return scores  

# create a set of exponential smoothing configs to try
def exp_smoothing_configs(seasonal=[None]): 
    models = list()
    # define config lists
    t_params = ['add', 'mul', None]
    d_params = [True, False] 
    s_params = ['add', 'mul', None] 
    p_params = seasonal
    b_params = [True, False] 
    r_params = [True, False]
    # create config instances
    for t in t_params:
        for d in d_params:
            for s in s_params:
                for p in p_params:
                    for b in b_params:
                        for r in r_params:
                            cfg = [t,d,s,p,b,r]
                            models.append(cfg)
    return models

# %%
if __name__ == '__main__':


    count = 0
    data2dict = {}

    data = pd.read_csv('/Users/alket/Desktop/dati/new_data_backfill_forwfill.csv',index_col = 0)
    gbc = data.groupby(by = data['cell_num'])  


    for cell_i, df_i in gbc:
        
        week = df_i
        print('week = ', len(week))
        
        week_red = week.iloc[::4, :]
        print('week reduced = ', len(week_red))
        week_red = week_red[:168]
        final_series = week_red['nr_people'].values
        print('final length ', len(final_series))
        #data = df_i['nr_people'].to_frame()
        #data = data[:96]
        print(len(data))
        #print(type(data))

        #data = data.values
        # data split
        n_test = 12
        cell_num = cell_i
        
        # model configs
        cfg_list = exp_smoothing_configs()

        # grid search
        scores = grid_search(final_series, cfg_list, n_test)
        
        #print(scores)
        # list top 3 configs
        for cfg, error in scores[:1]:
            configuration = cfg+','+str(error)
            print(cell_num, configuration)
            data2dict[cell_num]= configuration


# trend, damped, seasonal='add', seasonal_per = 96, Box-Cox, bias
# 486-1252:[None, False, None, 0, False, False],0.8660254037844386
with open('BestETS_config_parametres.csv', 'w') as f:
    for key, value in data2dict.items():
        f.write('%s:%s\n' % (key, value))

print('done')
# Out:
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 486-1252 ['mul', True, None, None, False, True],2.915592748982327
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 486-1253 ['mul', True, None, None, True, True],3.2107662668349994
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 486-1254 ['mul', True, None, None, True, True],3.4101502458130963
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 486-1255 ['mul', True, None, None, True, True],3.1682062881637596
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 486-1256 ['mul', True, None, None, True, True],3.4381780287105923
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 486-1257 ['add', True, None, None, True, True],2.92318285562195
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 486-1258 ['add', True, None, None, True, True],2.9317843425449666
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 486-1259 ['add', True, None, None, False, False],3.2512734209688126
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 486-1260 ['add', True, None, None, True, True],3.2425218932575506
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 486-1261 ['add', True, None, None, True, True],3.112835778355397
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 486-1262 ['add', True, None, None, False, False],3.231777153043523
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 486-1263 ['add', True, None, None, False, False],35.63774396076711
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 486-1264 ['add', True, None, None, False, False],32.72818589908084
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 486-1265 ['add', True, None, None, True, False],17.611576805556094
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 486-1266 ['add', True, None, None, True, False],6.500342938967796
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 486-1267 ['add', True, None, None, False, False],1.3929775390613728
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 486-1268 ['add', True, None, None, True, False],1.3279126695639154
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 487-1252 ['mul', True, None, None, True, True],3.3330214111675756
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 487-1253 ['mul', True, None, None, True, True],3.3892622317408603
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 487-1254 ['mul', True, None, None, True, True],3.2251602772372117
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 487-1255 ['mul', True, None, None, True, True],3.2697657891978804
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 487-1256 ['mul', True, None, None, True, True],3.248316854432207
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 487-1257 ['add', True, None, None, True, True],3.334422845719613
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 487-1258 ['add', True, None, None, False, False],3.5956394796344284
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 487-1259 ['add', True, None, None, False, False],3.4649830946700524
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 487-1260 ['add', True, None, None, True, True],2.5844005051697083
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 487-1261 ['add', True, None, None, True, True],3.1945010084582792
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 487-1262 ['add', True, None, None, False, False],5.595658971877361
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 487-1263 ['add', True, None, None, False, False],40.325824255380745
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 487-1264 ['add', True, None, None, False, False],31.034679880974995
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 487-1265 ['add', True, None, None, True, False],20.82955647639673
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 487-1266 ['add', True, None, None, True, False],9.396586454136783
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 487-1267 ['mul', True, None, None, False, False],1.3069884555909494
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 487-1268 ['add', True, None, None, False, False],5.583072945803851
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 488-1252 ['mul', True, None, None, True, True],16.11388415977313
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 488-1253 ['mul', True, None, None, True, True],16.779716445772646
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 488-1254 ['mul', True, None, None, True, True],6.4921909018843165
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 488-1255 ['mul', True, None, None, True, True],3.330284811079138
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 488-1256 ['mul', True, None, None, True, True],3.2978662114907884
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 488-1257 ['mul', True, None, None, True, True],3.222292554975241
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 488-1258 ['add', True, None, None, True, True],4.732514175319126
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 488-1259 ['add', True, None, None, False, False],4.324506509958289
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 488-1260 ['add', True, None, None, False, False],4.046567650448196
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 488-1261 ['add', True, None, None, False, False],3.991713811209863
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 488-1262 ['add', True, None, None, False, False],3.8612902904576027
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 488-1263 ['add', True, None, None, False, False],25.746225248174856
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 488-1264 ['add', True, None, None, False, False],29.44024291929755
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 488-1265 ['add', True, None, None, False, False],27.540467371743148
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 488-1266 ['add', True, None, None, False, False],13.912266709108659
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 488-1267 ['add', True, None, None, False, False],4.8766503495668365
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 488-1268 ['mul', True, None, None, False, False],6.891934640608136
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 489-1252 ['mul', True, None, None, True, True],27.327639543445397
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 489-1253 ['mul', True, None, None, True, True],27.514590743678156
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 489-1254 ['mul', True, None, None, True, True],16.273272962984908
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 489-1255 ['mul', True, None, None, True, True],13.783154976320336
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 489-1256 ['mul', True, None, None, True, True],5.198651175233606
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 489-1257 ['mul', True, None, None, True, True],3.4902556692858724
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 489-1258 ['add', True, None, None, True, True],4.405888779024244
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 489-1259 ['add', True, None, None, False, False],4.4669972257112915
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 489-1260 ['add', True, None, None, False, False],4.153485297765563
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 489-1261 ['add', True, None, None, False, False],4.467081622879376
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 489-1262 ['add', True, None, None, False, False],4.04766386242124
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 489-1263 ['add', True, None, None, False, False],3.1641186064344677
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 489-1264 ['add', True, None, None, False, False],5.700687037937769
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 489-1265 ['add', True, None, None, True, False],10.049706412215379
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 489-1266 ['add', True, None, None, False, False],14.813955385937623
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 489-1267 ['add', True, None, None, False, False],5.316371660629688
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 489-1268 ['mul', True, None, None, False, False],7.114156114522284
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 490-1252 ['add', True, None, None, False, False],14.778690331927434
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 490-1253 ['mul', True, None, None, True, True],6.221357925504476
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 490-1254 ['mul', True, None, None, True, True],28.089440632400482
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 490-1255 ['mul', True, None, None, True, True],8.07875881296418
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 490-1256 ['mul', True, None, None, True, True],26.87109020552698
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 490-1257 ['mul', True, None, None, True, True],9.499543727153288
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 490-1258 ['add', True, None, None, True, True],4.425140624902081
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 490-1259 ['add', True, None, None, False, False],4.037253383807271
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 490-1260 ['add', True, None, None, False, False],4.153079560023463
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 490-1261 ['add', True, None, None, False, False],3.984024142417952
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 490-1262 ['add', True, None, None, False, False],3.7205402906996863
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 490-1263 ['add', True, None, None, False, False],3.2585974428866478
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 490-1264 ['mul', True, None, None, True, True],2.2152777878467957
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 490-1265 ['add', True, None, None, True, False],1.433662058916454
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 490-1266 ['mul', True, None, None, False, False],1.9471142635249759
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 490-1267 [None, False, None, None, False, False],2.661453237111885
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 490-1268 ['mul', True, None, None, False, False],6.04596474163928
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 491-1252 ['add', True, None, None, True, True],3.8597000827756847
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 491-1253 ['add', True, None, None, True, True],3.336970131243873
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 491-1254 ['add', False, None, None, True, True],7.0233165701421045
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 491-1255 ['mul', True, None, None, True, True],17.296770505737666
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 491-1256 ['mul', True, None, None, True, True],12.163400433642813
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 491-1257 ['mul', True, None, None, True, True],13.920213016429866
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 491-1258 ['add', True, None, None, True, True],76.36204991066865
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 491-1259 ['add', True, None, None, False, False],99.85581124247105
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 491-1260 ['add', True, None, None, False, False],24.906802851889868
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 491-1261 ['mul', True, None, None, True, True],2.7322791769962893
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 491-1262 ['mul', True, None, None, True, True],4.3075436911997
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 491-1263 ['mul', True, None, None, True, True],2.131364536704087
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 491-1264 ['mul', True, None, None, True, True],1.5165880901147852
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 491-1265 ['add', True, None, None, True, True],1.2043477259953241
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 491-1266 ['mul', True, None, None, False, False],0.7342719520985774
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 491-1267 [None, False, None, None, False, False],0.5773502691896257
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 491-1268 ['add', True, None, None, True, False],7.489440655227227
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 492-1252 ['add', True, None, None, False, False],4.935141741537261
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 492-1253 ['add', True, None, None, False, False],5.307340063436514
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 492-1254 ['add', False, None, None, True, True],12.533215350899257
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 492-1255 ['mul', True, None, None, True, True],17.437835815057152
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 492-1256 ['mul', True, None, None, True, True],17.68034998281752
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 492-1257 ['add', False, None, None, True, True],9.933012899007526
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 492-1258 ['add', True, None, None, True, True],38.78426888016689
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 492-1259 ['add', True, None, None, False, False],14.204101527207868
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 492-1260 ['add', True, None, None, False, False],25.045178494725718
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 492-1261 [None, False, None, None, False, False],16.92384904998466
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 492-1262 [None, False, None, None, False, False],2.6770630673681683
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 492-1263 [None, False, None, None, False, False],1.3844373104863459
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 492-1264 [None, False, None, None, False, False],1.1902380714238083
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 492-1265 ['add', True, None, None, True, True],0.9066007005972622
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 492-1266 ['add', True, None, None, False, False],0.9105655249324519
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 492-1267 ['mul', True, None, None, False, False],1.4277576315267462
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 492-1268 [None, False, None, None, False, True],6.581835804739836
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 493-1252 ['add', True, None, None, False, True],1.060468555287699
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 493-1253 ['add', True, None, None, False, False],5.261193574728024
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 493-1254 ['add', True, None, None, False, False],20.59705630323245
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 493-1255 ['mul', True, None, None, True, True],7.949350273166032
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 493-1256 ['mul', True, None, None, True, True],6.703651282001768
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 493-1257 ['add', False, None, None, True, True],3.6057061885517885
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 493-1258 ['add', False, None, None, True, True],12.02614708314675
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 493-1259 [None, False, None, None, True, False],6.204836822995419
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 493-1260 [None, False, None, None, True, False],37.015762408285816
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 493-1261 [None, False, None, None, True, False],12.051970793193917
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 493-1262 [None, False, None, None, False, False],1.3228756555322954
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 493-1263 [None, False, None, None, True, False],1.2909944487358023
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 493-1264 [None, False, None, None, True, False],1.1902380714237975
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 493-1265 [None, False, None, None, True, False],1.1902380714238079
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 493-1266 ['mul', False, None, None, True, True],0.40762783895988736
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 493-1267 ['add', True, None, None, False, False],2.173791167812808
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 493-1268 [None, False, None, None, True, False],3.5118845842842363
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 494-1252 ['mul', False, None, None, False, False],1.8455773035690777
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 494-1253 ['add', True, None, None, False, False],2.3142344416557745
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 494-1254 ['add', True, None, None, False, False],10.514033809277608
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 494-1255 ['add', True, None, None, False, False],16.632037906180926
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 494-1256 ['mul', False, None, None, False, True],7.090330612182214
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 494-1257 ['add', False, None, None, True, True],6.915469138345569
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 494-1258 ['mul', True, None, None, False, True],2.2031362920622706
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 494-1259 [None, False, None, None, False, False],4.795831523312719
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 494-1260 [None, False, None, None, False, False],2.70801280154532
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 494-1261 [None, False, None, None, True, False],1.4999999999999931
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 494-1262 [None, False, None, None, True, False],1.3228756555322922
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 494-1263 [None, False, None, None, False, False],1.3228756555322954
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 494-1264 [None, False, None, None, True, False],1.3228756555322894
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 494-1265 [None, False, None, None, True, False],0.8164965809277257
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 494-1266 ['mul', False, None, None, True, False],0.4968192108767124
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 494-1267 ['add', False, None, None, False, False],2.803935517006137
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 494-1268 [None, False, None, None, False, True],8.54292118540119
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 495-1252 ['mul', True, None, None, False, True],0.7945422554410677
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 495-1253 ['mul', True, None, None, False, True],0.696972680585874
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 495-1254 ['mul', True, None, None, False, False],1.44717471328792
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 495-1255 ['add', True, None, None, False, False],4.129886284858571
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 495-1256 ['add', True, None, None, False, False],11.069006798479315
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 495-1257 ['mul', True, None, None, False, True],11.708553357049961
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 495-1258 ['mul', True, None, None, False, True],9.459265888169288
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 495-1259 ['mul', True, None, None, False, True],5.2855352455861375
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 495-1260 ['mul', True, None, None, False, True],5.295011973807974
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 495-1261 [None, False, None, None, False, False],17.73884626086676
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 495-1262 [None, False, None, None, False, False],22.088835792469162
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 495-1263 [None, False, None, None, False, False],21.73323108360405
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 495-1264 [None, False, None, None, True, False],19.063490411429516
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 495-1265 [None, False, None, None, True, False],10.87428158546575
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 495-1266 ['mul', True, None, None, False, True],8.40896717626713
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 495-1267 ['add', False, None, None, False, False],7.922786051864797
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 495-1268 ['mul', True, None, None, True, False],3.391031423221676
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 496-1252 ['mul', False, None, None, False, False],6.46333308142924
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 496-1253 [None, False, None, None, False, False],7.621242243449117
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 496-1254 ['mul', False, None, None, False, False],6.595031396064694
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 496-1255 [None, False, None, None, True, False],10.923687424004918
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 496-1256 ['add', True, None, None, False, False],11.145305206610375
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 496-1257 ['mul', True, None, None, False, True],8.360610586415083
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 496-1258 ['mul', True, None, None, False, True],7.204959939718132
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 496-1259 ['mul', False, None, None, False, False],7.295849330449506
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 496-1260 ['mul', False, None, None, False, False],4.16005749547035
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 496-1261 [None, False, None, None, False, False],0.5823697927404944
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 496-1262 ['mul', True, None, None, False, True],0.55715457401606
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 496-1263 [None, False, None, None, False, False],0.7071067811865476
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 496-1264 ['mul', True, None, None, False, True],0.6454418760927219
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 496-1265 ['mul', True, None, None, False, False],0.6750419105972039
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 496-1266 ['mul', True, None, None, True, False],0.6459139514706856
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 496-1267 ['mul', False, None, None, True, False],0.6175034500871708
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 496-1268 [None, False, None, None, False, False],0.8324277264959197
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 497-1252 ['add', True, None, None, False, False],0.9450838835192877
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 497-1253 ['mul', True, None, None, False, True],0.378312619532246
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 497-1254 ['mul', True, None, None, False, True],7.844916215137131
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 497-1255 [None, False, None, None, True, False],6.551637462749267
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 497-1256 [None, False, None, None, True, False],1.6606664335671326
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 497-1257 [None, False, None, None, False, False],3.4544833399983816
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 497-1258 ['add', True, None, None, False, True],3.0568452641988584
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 497-1259 ['mul', False, None, None, False, False],4.7159997450213735
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 497-1260 ['mul', True, None, None, False, False],2.5684915516264826
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 497-1261 [None, False, None, None, True, False],0.5807431085828582
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 497-1262 ['add', True, None, None, False, True],0.6439873758816783
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 497-1263 ['mul', False, None, None, True, False],0.6859224534332449
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 497-1264 ['mul', True, None, None, False, True],0.48763914455805174
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 497-1265 [None, False, None, None, True, False],0.40561399763649153
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 497-1266 [None, False, None, None, False, False],0.7057807129820142
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 497-1267 ['add', True, None, None, False, True],0.5787363977080527
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 497-1268 ['add', False, None, None, True, False],3.0422952695759307
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 498-1252 [None, False, None, None, True, False],2.6299556396765715
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 498-1253 [None, False, None, None, False, False],4.102844541697057
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 498-1254 [None, False, None, None, True, False],5.537749241945324
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 498-1255 ['mul', True, None, None, True, False],0.4676180260148464
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 498-1256 ['add', True, None, None, True, False],1.895680302491747
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 498-1257 ['mul', True, None, None, False, False],3.1649526189997608
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 498-1258 ['mul', False, None, None, True, False],3.5605844673117337
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 498-1259 ['mul', True, None, None, False, True],3.709056805288011
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 498-1260 ['mul', True, None, None, False, True],4.5817560392011965
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 498-1261 ['mul', True, None, None, False, True],2.4659586279766676
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 498-1262 [None, False, None, None, False, False],0.7015617265653947
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 498-1263 ['mul', True, None, None, False, True],0.5201051724100262
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 498-1264 ['add', True, None, None, False, False],0.47079606121936113
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 498-1265 ['mul', True, None, None, False, True],0.6423552711028317
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 498-1266 ['mul', False, None, None, True, False],0.6484632209812361
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 498-1267 [None, False, None, None, True, False],3.5472994422987854
# week =  11808
# week reduced =  2952
# final length  168
# 2609568
# 498-1268 [None, False, None, None, True, False],1.499980417130619
# done
