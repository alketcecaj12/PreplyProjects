# %% [markdown]
# ### Forecasting pollution with ARIMA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
from statsmodels.tsa.arima.model import ARIMA
warnings.filterwarnings('ignore')
from sklearn.metrics import mean_squared_error
import os

# %%
os.getcwd()
# Out:
# '/Users/alket/Desktop/TimeseriesPollution'

# %%
no2 = pd.read_csv('CleanData_PM10.csv')
no2
# Out:
#                 datetime  PM10
# 0    2020-01-01 00:00:00  42.0
# 1    2020-01-02 00:00:00  39.0
# 2    2020-01-03 00:00:00  49.0
# 3    2020-01-04 00:00:00  44.0
# 4    2020-01-05 00:00:00  27.0
# ..                   ...   ...
# 287  2020-10-14 00:00:00   9.0
# 288  2020-10-15 00:00:00  14.0
# 289  2020-10-16 00:00:00   9.0
# 290  2020-10-17 00:00:00  10.0
# 291  2020-10-18 00:00:00  14.0
#
# [292 rows x 2 columns]

# %%
series = no2['PM10']
type(series)
# Out:
# pandas.core.series.Series

# %%
plt.figure(figsize = (20, 4))
plt.plot(series)
plt.show()

# %% [markdown]
# ### Forecasting with ARIMA method

# %%
# split into train and test sets
X = series.values
size = int(len(X) * 0.80)
print('-------------------- Size = ',size)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
print(size)
# Out:
# -------------------- Size =  233
# 233

# %%
# walk-forward validation
counter = 0
for t in range(len(test)):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    counter += 1
    print(counter)
    print('predicted=%f, expected=%f' % (yhat, obs))
# Out:
# 1
# predicted=16.454392, expected=16.000000
# 2
# predicted=17.692928, expected=17.000000
# 3
# predicted=17.142813, expected=12.000000
# 4
# predicted=11.141171, expected=15.000000
# 5
# predicted=17.634801, expected=15.000000
# 6
# predicted=15.421130, expected=14.000000
# 7
# predicted=13.359901, expected=14.000000
# 8
# predicted=15.319855, expected=19.000000
# 9
# predicted=18.701538, expected=13.000000
# 10
# predicted=11.140945, expected=16.000000
# 11
# predicted=16.882170, expected=10.000000
# 12
# predicted=10.051838, expected=14.000000
# 13
# predicted=14.653160, expected=11.000000
# 14
# predicted=12.713747, expected=12.000000
# 15
# predicted=11.709797, expected=14.000000
# 16
# predicted=15.817010, expected=14.000000
# 17
# predicted=12.271749, expected=11.000000
# 18
# predicted=10.939562, expected=6.000000
# 19
# predicted=6.358376, expected=17.000000
# 20
# predicted=19.532730, expected=19.000000
# 21
# predicted=17.216969, expected=22.000000
# 22
# predicted=19.253973, expected=25.000000
# 23
# predicted=23.372730, expected=23.000000
# 24
# predicted=17.702085, expected=23.000000
# 25
# predicted=21.814588, expected=30.000000
# 26
# predicted=29.698656, expected=32.000000
# 27
# predicted=29.087737, expected=28.000000
# 28
# predicted=25.454994, expected=29.000000
# 29
# predicted=28.906248, expected=28.000000
# 30
# predicted=26.783501, expected=28.000000
# 31
# predicted=27.993643, expected=21.000000
# 32
# predicted=22.032112, expected=19.000000
# 33
# predicted=21.215685, expected=15.000000
# 34
# predicted=18.065951, expected=15.000000
# 35
# predicted=17.883793, expected=7.000000
# 36
# predicted=10.091139, expected=6.000000
# 37
# predicted=9.713934, expected=6.000000
# 38
# predicted=9.948718, expected=5.000000
# 39
# predicted=6.233914, expected=6.000000
# 40
# predicted=8.600976, expected=13.000000
# 41
# predicted=13.508202, expected=16.000000
# 42
# predicted=13.524096, expected=17.000000
# 43
# predicted=13.937510, expected=10.000000
# 44
# predicted=7.332889, expected=14.000000
# 45
# predicted=14.017987, expected=8.000000
# 46
# predicted=7.744030, expected=7.000000
# 47
# predicted=8.290655, expected=12.000000
# 48
# predicted=15.810565, expected=15.000000
# 49
# predicted=13.382373, expected=15.000000
# 50
# predicted=14.093989, expected=21.000000
# 51
# predicted=19.930889, expected=29.000000
# 52
# predicted=25.587547, expected=28.000000
# 53
# predicted=22.550043, expected=6.000000
# 54
# predicted=2.212984, expected=6.000000
# 55
# predicted=11.340305, expected=9.000000
# 56
# predicted=14.103222, expected=14.000000
# 57
# predicted=16.027709, expected=9.000000
# 58
# predicted=12.066075, expected=10.000000
# 59
# predicted=9.809872, expected=14.000000

# %%
# evaluate forecasts
import math
rmse = math.sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)

# plot forecasts against actual outcomes
plt.figure(figsize = (20, 4))
plt.plot(test, label='real data')
plt.plot(predictions, color='red', label='forecasted')
plt.legend(prop={'size': 15})
plt.show()
# Out:
# Test RMSE: 4.958

# %%
diff = test - predictions

# %%
diff
# Out:
# array([ -0.45439169,  -0.69292792,  -5.14281283,   3.858829  ,
#         -2.63480117,  -1.42113045,   0.64009927,   3.68014494,
#         -5.70153785,   4.85905493,  -6.88216992,   3.94816221,
#         -3.65315965,  -0.71374665,   2.29020259,  -1.81700993,
#         -1.27174865,  -4.93956191,  10.6416244 ,  -0.5327303 ,
#          4.78303146,   5.74602744,  -0.37272968,   5.29791532,
#          8.18541165,   2.30134384,  -1.0877368 ,   3.54500558,
#         -0.90624786,   1.216499  ,  -6.99364287,  -3.03211235,
#         -6.21568504,  -3.06595066, -10.8837934 ,  -4.09113871,
#         -3.71393371,  -4.94871826,  -0.2339139 ,   4.39902356,
#          2.49179817,   3.47590372,  -3.93751037,   6.66711134,
#         -6.01798718,  -0.74403016,   3.70934526,  -0.81056462,
#          1.61762725,   6.90601137,   9.06911098,   2.41245261,
#        -16.55004268,   3.78701632,  -2.34030504,  -0.10322241,
#         -7.02770941,  -2.06607497,   4.19012762])

# %%
# compute the mean absolute error
mae = np.mean(abs(diff))
mae
# Out:
# 3.910502692366197

# %%
plt.figure(figsize = (20, 1))
plt.boxplot(diff, vert = False)
#plt.plot(test[0])
plt.show()

# %%
plt.figure(figsize = (4, 5))
plt.hist(diff)
#plt.plot(test[0])
plt.show()
