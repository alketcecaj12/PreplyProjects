# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("data/Caudais-2021.xlsx")

# %%
data.head(20)
# Out:
#              Data Hora  Caudal (m3/h)
# 0  2021-01-01 00:00:33         6.0340
# 1  2021-01-01 00:00:33         6.0340
# 2  2021-01-01 00:00:33         6.0340
# 3  2021-01-01 00:05:59         3.8180
# 4  2021-01-01 00:05:59         3.8180
# 5  2021-01-01 00:10:27         2.4630
# 6  2021-01-01 00:10:27         2.4630
# 7  2021-01-01 00:15:06         5.2960
# 8  2021-01-01 00:15:06         5.2960
# 9  2021-01-01 00:15:06         5.2960
# 10 2021-01-01 00:20:42         3.6950
# 11 2021-01-01 00:20:42         3.6950
# 12 2021-01-01 00:25:21         4.4330
# 13 2021-01-01 00:25:21         4.4330
# 14 2021-01-01 00:25:21         4.4330
# 15 2021-01-01 00:30:45         6.6500
# 16 2021-01-01 00:30:45         6.6500
# 17 2021-01-01 00:35:28         4.6800
# 18 2021-01-01 00:35:28         4.6800
# 19 2021-01-01 00:40:06         0.9852

# %%
data.shape
# Out:
# (258624, 2)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258624 entries, 0 to 258623
# Data columns (total 2 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Data Hora      258624 non-null  datetime64[ns]
#  1   Caudal (m3/h)  258624 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 3.9 MB

# %%
#data.set_index(['Data Hora'], inplace = True)

# %%
data
# Out:
#                  Data Hora  Caudal (m3/h)
# 0      2021-01-01 00:00:33          6.034
# 1      2021-01-01 00:00:33          6.034
# 2      2021-01-01 00:00:33          6.034
# 3      2021-01-01 00:05:59          3.818
# 4      2021-01-01 00:05:59          3.818
# ...                    ...            ...
# 258619 2021-12-31 23:52:00          8.342
# 258620 2021-12-31 23:54:00          9.526
# 258621 2021-12-31 23:56:00          9.445
# 258622 2021-12-31 23:58:00          8.541
# 258623 2022-01-01 00:00:00          9.133
#
# [258624 rows x 2 columns]

# %%
plt.figure(figsize = (20, 5))
plt.plot(data['Caudal (m3/h)'])
plt.show()

# %% [markdown]
# ### Too much data - better take a subset of it.

# %%
subset_data = data[:5000]

# %%
plt.figure(figsize = (20, 5))
plt.plot(subset_data['Caudal (m3/h)'])
plt.show()

# %%
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (219345, 2)

# %%
subset_data = data[:2000]

# %%
plt.figure(figsize = (20, 5))
plt.plot(subset_data['Caudal (m3/h)'])
plt.show()

# %%
subset_data.set_index(['Data Hora'], inplace = True)

# %%
plt.figure(figsize = (20, 5))
plt.plot(subset_data['Caudal (m3/h)'])
plt.xlabel("Time")
plt.ylabel('Observations')
plt.show()
