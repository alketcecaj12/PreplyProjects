# %% [markdown]
# ## Project: Unsupervised Learning
# ----------------------------------------
# **Marks: 30**
# -----------------------------------------
#
# Welcome to the project on Unsupervised Learning. We will be using the Credit Card Customer Data for this project.
#
# ----------------------------
# ## Context:
# -----------------------------
# AllLife Bank wants to focus on its credit card customer base in the next financial year. They have been advised by their marketing research team, that the penetration in the market can be improved. Based on this input, the Marketing team proposes to run personalized campaigns to target new customers as well as upsell to existing customers. Another insight from the market research was that the customers perceive the support services of the back poorly. Based on this, the Operations team wants to upgrade the service delivery model, to ensure that customers queries are resolved faster. Head of Marketing and Head of Delivery both decide to reach out to the Data Science team for help.
#
#
# ----------------------------
# ## Objective:
# -----------------------------
#
# Identify different segments in the existing customer based on their spending patterns as well as past interaction with the bank.
#
# --------------------------
# ## About the data:
# --------------------------
# Data is of various customers of a bank with their credit limit, the total number of credit cards the customer has, and different channels through which customer has contacted the bank for any queries, different channels include visiting the bank, online and through a call centre.
#
# - Sl_no - Customer Serial Number
# - Customer Key - Customer identification
# - Avg_Credit_Limit	- Average credit limit (currency is not specified, you can make an assumption around this)
# - Total_Credit_Cards	- Total number of credit cards
# - Total_visits_bank	- Total bank visits
# - Total_visits_online -	 Total online visits
# - Total_calls_made - Total calls made

# %% [markdown]
# ## Importing libraries and overview of the dataset

# %%
#Import all the necessary packages

import pandas as pd
import numpy as np

import matplotlib.pylab as plt
import seaborn as sns

#to scale the data using z-score 
from sklearn.preprocessing import StandardScaler

#importing clustering algorithms
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture


#if the below line of code gives an error, then uncomment the following code to install the sklearn_extra library
#!pip install scikit-learn-extra
from sklearn_extra.cluster import KMedoids

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Loading data

# %%
data = pd.read_excel('Credit_Card_Customer_Data.xlsx')
data.head()
# Out:
#    Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 0      1         87073            100000                   2
# 1      2         38414             50000                   3
# 2      3         17341             50000                   7
# 3      4         40496             30000                   5
# 4      5         47437            100000                   6
#
#    Total_visits_bank  Total_visits_online  Total_calls_made
# 0                  1                    1                 0
# 1                  0                   10                 9
# 2                  1                    3                 4
# 3                  1                    1                 4
# 4                  0                   12                 3

# %%
data.shape
# Out:
# (660, 7)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data['Customer Key']
# Out:
# 0      87073
# 1      38414
# 2      17341
# 3      40496
# 4      47437
#        ...
# 655    51108
# 656    60732
# 657    53834
# 658    80655
# 659    80150
# Name: Customer Key, Length: 660, dtype: int64

# %%
data['Customer Key'].nunique()
# Out:
# 655

# %%
ckgb = data.groupby(['Customer Key'])

# %%
for i, k in ckgb: 
    print(i, k)
# Out:
# 11265      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 450    451         11265             51000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 450                  3                    2                 0
# 11398      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 378    379         11398             12000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 378                  5                    2                 1
# 11412      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 179    180         11412             19000                   2
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 179                  2                    3                 4
# 11466      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 321    322         11466              9000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 321                  5                    0                 0
# 11562      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 609    610         11562             38000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 609                  3                    2                 0
# 11596      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 316    317         11596             18000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 316                  4                    0                 2
# 11602      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 128    129         11602              8000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 128                  1                    5                 4
# 11698      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 292    293         11698             17000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 292                  3                    0                 4
# 11734      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 561    562         11734             29000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 561                  5                    0                 2
# 11799      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 349    350         11799             11000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 349                  3                    2                 3
# 11937     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 96     97         11937             18000                   3
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 96                  2                    3                 6
# 12026     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 79     80         12026             15000                   1
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 79                  1                    2                 7
# 12122      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 217    218         12122             11000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 217                  0                    2                 5
# 12456      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 476    477         12456             70000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 476                  5                    0                 4
# 12663      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 439    440         12663             66000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 439                  4                    0                 3
# 13140      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 519    520         13140             57000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 519                  2                    0                 0
# 13215      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 201    202         13215             11000                   1
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 201                  0                    3                 8
# 13315      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 648    649         13315            111000                   8
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 648                  1                    7                 0
# 13720      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 598    599         13720             64000                   5
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 598                  4                    1                 2
# 13999     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 30     31         13999             16000                   3
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 30                  1                    5                 4
# 14248      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 133    134         14248             10000                   3
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 133                  1                    5                 9
# 14263      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 239    240         14263             16000                   5
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 239                  2                    0                 0
# 14309     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 19     20         14309             19000                   4
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 19                  1                    5                 8
# 14377      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 571    572         14377             36000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 571                  2                    0                 4
# 14398      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 194    195         14398             12000                   2
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 194                  0                    4                 4
# 14439      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 442    443         14439             51000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 442                  3                    0                 3
# 14816      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 449    450         14816             36000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 449                  3                    2                 3
# 14854     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 27     28         14854              9000                   2
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 27                  2                    2                10
# 14916      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 631    632         14916            195000                   8
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 631                  0                   15                 0
# 14946      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 106    107         14946             20000                   2
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 106                  1                    5                 5
# 15086      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 516    517         15086             32000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 516                  4                    0                 3
# 15129      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 234    235         15129             16000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 234                  5                    0                 4
# 15310      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 115    116         15310              7000                   2
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 115                  2                    3                 7
# 15318      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 360    361         15318             14000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 360                  3                    0                 1
# 15546      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 198    199         15546             19000                   1
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 198                  1                    4                 7
# 15585      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 626    627         15585            156000                   9
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 626                  1                   10                 2
# 15798      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 466    467         15798             70000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 466                  2                    0                 3
# 16180      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 633    634         16180            163000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 633                  1                   10                 1
# 16253      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 610    611         16253             39000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 610                  2                    1                 0
# 16374      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 307    308         16374              8000                   5
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 307                  3                    2                 1
# 16418      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 385    386         16418              8000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 385                  4                    2                 0
# 16577      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 120    121         16577             10000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 120                  2                    4                 6
# 16676      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 207    208         16676             19000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 207                  2                    4                 4
# 16715      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 199    200         16715              7000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 199                  2                    4                 9
# 17036      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 265    266         17036              9000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 265                  4                    2                 1
# 17165      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 259    260         17165              6000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 259                  4                    1                 4
# 17325      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 456    457         17325             41000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 456                  5                    2                 3
# 17341    Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 2      3         17341             50000                   7
#
#    Total_visits_bank  Total_visits_online  Total_calls_made
# 2                  1                    3                 4
# 17377      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 533    534         17377             36000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 533                  3                    0                 3
# 17382      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 507    508         17382             42000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 507                  3                    2                 0
# 17538      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 638    639         17538            153000                   8
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 638                  1                    7                 1
# 17565      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 347    348         17565              5000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 347                  2                    0                 3
# 17649      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 371    372         17649              6000                   5
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 371                  2                    2                 1
# 17703      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 407    408         17703             50000                   5
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 407                  4                    0                 1
# 17933      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 330    331         17933             19000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 330                  3                    1                 2
# 17937     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 57     58         17937              6000                   2
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 57                  0                    2                10
# 18007     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 90     91         18007             13000                   2
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 90                  1                    4                 6
# 18086      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 113    114         18086              7000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 113                  1                    2                 4
# 18145      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 193    194         18145              6000                   2
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 193                  2                    5                 8
# 18397      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 483    484         18397             30000                   5
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 483                  4                    1                 1
# 18514      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 274    275         18514             10000                   5
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 274                  5                    1                 3
# 18519      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 644    645         18519            127000                  10
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 644                  1                   15                 1
# 18564      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 156    157         18564             12000                   3
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 156                  2                    5                 7
# 18595      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 247    248         18595             19000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 247                  3                    1                 2
# 18609      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 215    216         18609              8000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 215                  0                    4                 7
# 18821     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 73     74         18821             19000                   3
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 73                  1                    3                 6
# 18916     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 99    100         18916              5000                   2
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 99                  1                    4                 6
# 19137      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 339    340         19137             10000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 339                  3                    1                 1
# 19215      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 383    384         19215             18000                   5
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 383                  3                    1                 3
# 19785      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 305    306         19785             19000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 305                  5                    1                 4
# 20043      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 493    494         20043             35000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 493                  2                    1                 4
# 20072      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 261    262         20072             18000                   5
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 261                  3                    0                 4
# 20119     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 41     42         20119             10000                   1
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 41                  1                    2                 7
# 20337      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 625    626         20337             91000                   8
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 625                  1                    6                 1
# 20524      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 175    176         20524              6000                   1
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 175                  0                    2                 5
# 20570      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 448    449         20570             31000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 448                  4                    2                 1
# 20593      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 202    203         20593              5000                   1
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 202                  0                    3                 8
# 20620      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 627    628         20620            146000                  10
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 627                  0                   12                 1
# 21233      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 281    282         21233             14000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 281                  2                    0                 0
# 21531      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 257    258         21531             10000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 257                  4                    2                 3
# 21717      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 510    511         21717             33000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 510                  2                    2                 2
# 21976     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 70     71         21976             14000                   1
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 70                  2                    4                 7
# 22348      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 365    366         22348             13000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 365                  5                    0                 2
# 22610      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 333    334         22610             15000                   5
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 333                  4                    2                 2
# 22824      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 326    327         22824              6000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 326                  4                    2                 3
# 22842      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 498    499         22842             31000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 498                  4                    1                 0
# 22919      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 280    281         22919              7000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 280                  4                    1                 2
# 23102      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 490    491         23102             65000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 490                  2                    0                 0
# 23110      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 429    430         23110             41000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 429                  4                    1                 0
# 23302      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 254    255         23302             16000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 254                  3                    1                 0
# 23409      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 384    385         23409              8000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 384                  4                    0                 0
# 23743      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 138    139         23743             15000                   1
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 138                  1                    5                 9
# 23768      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 149    150         23768             14000                   2
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 149                  1                    2                 7
# 23881      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 322    323         23881              8000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 322                  3                    1                 2
# 24001     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 24     25         24001              8000                   2
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 24                  0                    2                10
# 24054      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 158    159         24054             10000                   3
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 158                  2                    5                 9
# 24702      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 379    380         24702              6000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 379                  2                    0                 3
# 24748      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 575    576         24748             73000                   5
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 575                  3                    0                 4
# 24808      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 264    265         24808             17000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 264                  4                    1                 2
# 24980      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 451    452         24980             36000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 451                  4                    2                 2
# 24998      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 314    315         24998             12000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 314                  3                    1                 2
# 25084     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 13     14         25084              9000                   1
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 13                  1                    5                 6
# 25321      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 416    417         25321             46000                   5
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 416                  2                    2                 3
# 25330      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 177    178         25330             14000                   3
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 177                  0                    4                 8
# 25440      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 121    122         25440             13000                   3
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 121                  0                    5                10
# 25742     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 95     96         25742              5000                   1
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 95                  2                    5                 7
# 26063      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 565    566         26063             69000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 565                  5                    0                 1
# 26089      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 105    106         26089             12000                   2
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 105                  1                    4                 9
# 26334      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 531    532         26334             32000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 531                  3                    2                 2
# 26493      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 553    554         26493             41000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 553                  4                    1                 3
# 26599      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 102    103         26599             10000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 102                  1                    5                10
# 26604      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 435    436         26604             74000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 435                  5                    0                 3
# 26678      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 328    329         26678             14000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 328                  4                    2                 1
# 26767      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 327    328         26767             11000                   5
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 327                  5                    1                 1
# 27101      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 251    252         27101             18000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 251                  2                    1                 2
# 27117      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 508    509         27117             59000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 508                  2                    0                 3
# 27120     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 72     73         27120             11000                   3
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 72                  1                    2                 6
# 27212      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 641    642         27212            144000                  10
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 641                  0                   10                 2
# 27408      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 255    256         27408              7000                   5
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 255                  5                    2                 3
# 27476      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 515    516         27476             37000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 515                  4                    2                 2
# 27824      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 380    381         27824             13000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 380                  2                    0                 4
# 28208      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 218    219         28208             19000                   3
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 218                  1                    5                 7
# 28254     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 34     35         28254              8000                   4
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 34                  1                    3                10
# 28408      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 431    432         28408             72000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 431                  5                    2                 3
# 28414      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 318    319         28414             14000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 318                  4                    0                 3
# 28525      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 652    653         28525            156000                   8
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 652                  1                    8                 0
# 28701      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 130    131         28701             18000                   3
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 130                  1                    5                 6
# 28842      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 172    173         28842             20000                   2
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 172                  0                    5                 6
# 29058      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 197    198         29058             12000                   1
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 197                  1                    2                 7
# 29102      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 484    485         29102             28000                   5
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 484                  4                    1                 1
# 29112     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 29     30         29112              8000                   4
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 29                  0                    4                 7
# 29176      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 535    536         29176             28000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 535                  5                    1                 3
# 29759     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 60     61         29759             20000                   4
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 60                  1                    4                 7
# 29794     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 20     21         29794              5000                   3
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 20                  2                    5                 5
# 29864      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 402    403         29864             56000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 402                  2                    0                 2
# 29886      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 356    357         29886             16000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 356                  5                    1                 1
# 29919      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 474    475         29919             38000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 474                  3                    1                 4
# 30256      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 530    531         30256             38000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 530                  3                    0                 0
# 30507     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 22     23         30507              6000                   4
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 22                  1                    4                 6
# 30570      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 649    650         30570            112000                  10
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 649                  1                    8                 1
# 30712      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 304    305         30712             16000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 304                  4                    2                 4
# 30888     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 35     36         30888             19000                   2
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 35                  0                    4                 4
# 31113      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 390    391         31113             11000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 390                  2                    0                 4
# 31256      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 134    135         31256             13000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 134                  1                    5                 7
# 31384      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 306    307         31384             19000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 306                  3                    0                 0
# 31515      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 395    396         31515              5000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 395                  5                    0                 1
# 31551      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 400    401         31551             75000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 400                  3                    2                 4
# 31870      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 574    575         31870             70000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 574                  3                    2                 0
# 31903      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 237    238         31903              8000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 237                  4                    0                 4
# 31948      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 606    607         31948             63000                   5
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 606                  3                    1                 3
# 31950      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 428    429         31950             56000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 428                  4                    0                 3
# 32107      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 620    621         32107            108000                  10
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 620                  0                   15                 1
# 32352      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 249    250         32352              9000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 249                  5                    2                 0
# 32374      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 165    166         32374             14000                   1
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 165                  0                    4                 9
# 32550     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 31     32         32550             11000                   3
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 31                  1                    5                 6
# 32584      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 623    624         32584            166000                  10
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 623                  0                    7                 0
# 32828     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 56     57         32828              6000                   1
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 56                  0                    2                 5
# 33110      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 167    168         33110             15000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 167                  2                    3                 6
# 33187     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 74     75         33187              7000                   2
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 74                  0                    5                 8
# 33240      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 320    321         33240             12000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 320                  5                    2                 1
# 33295      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 551    552         33295             37000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 551                  2                    1                 1
# 33317      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 204    205         33317             17000                   2
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 204                  2                    5                 5
# 33369      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 114    115         33369             18000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 114                  0                    3                 6
# 33457      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 252    253         33457              9000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 252                  5                    0                 4
# 33790      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 354    355         33790              9000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 354                  4                    0                 2
# 33837      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 630    631         33837            200000                  10
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 630                  0                   13                 0
# 33991      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 408    409         33991             49000                   5
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 408                  3                    0                 1
# 34103      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 132    133         34103             12000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 132                  0                    2                 6
# 34423      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 267    268         34423             15000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 267                  4                    0                 1
# 34495      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 331    332         34495             18000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 331                  5                    2                 0
# 34677      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 293    294         34677              6000                   5
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 293                  2                    1                 0
# 34775      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 543    544         34775             60000                   5
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 543                  2                    1                 0
# 35103      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 155    156         35103             19000                   1
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 155                  1                    4                 5
# 35149     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 71     72         35149              6000                   3
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 71                  2                    2                 7
# 35254      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 229    230         35254              8000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 229                  2                    1                 4
# 35256      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 117    118         35256             17000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 117                  0                    4                 7
# 35268      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 560    561         35268             46000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 560                  3                    1                 0
# 35421      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 584    585         35421             34000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 584                  4                    1                 3
# 35483      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 233    234         35483             13000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 233                  2                    1                 0
# 35549      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 242    243         35549              8000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 242                  3                    2                 4
# ...
# 92503     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 12     13         92503             11000                   1
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 12                  2                    5                 9
# 92522      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 373    374         92522              6000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 373                  5                    0                 1
# 92782      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 325    326         92782             14000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 325                  4                    2                 3
# 92933      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 463    464         92933             38000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 463                  5                    1                 4
# 92956      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 300    301         92956             15000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 300                  5                    0                 0
# 93310      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 587    588         93310             70000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 587                  3                    0                 4
# 93381      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 594    595         93381             60000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 594                  2                    1                 4
# 93482     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 75     76         93482             16000                   3
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 75                  1                    4                 6
# 93496      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 426    427         93496             71000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 426                  2                    0                 2
# 93997      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 119    120         93997              9000                   3
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 119                  0                    4                 9
# 94251      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 212    213         94251             10000                   3
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 212                  1                    3                 4
# 94391      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 612    613         94391            157000                   9
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 612                  1                   14                 1
# 94437      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 353    354         94437              9000                   5
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 353                  4                    1                 3
# 94529      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 509    510         94529             30000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 509                  4                    2                 1
# 94595      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 460    461         94595             26000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 460                  4                    2                 3
# 94666      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 291    292         94666              5000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 291                  3                    2                 2
# 94700      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 590    591         94700             36000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 590                  2                    2                 3
# 95147      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 486    487         95147             64000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 486                  2                    2                 2
# 95489      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 147    148         95489              5000                   2
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 147                  2                    5                 6
# 95495      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 181    182         95495             13000                   3
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 181                  0                    2                10
# 95507      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 137    138         95507             15000                   2
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 137                  0                    5                 8
# 95610      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 294    295         95610              7000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 294                  5                    2                 3
# 95925      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 278    279         95925             10000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 278                  4                    2                 4
# 96163      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 224    225         96163             12000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 224                  1                    5                 9
# 96186      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 364    365         96186             13000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 364                  4                    2                 3
# 96213      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 101    102         96213             11000                   1
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 101                  1                    5                 9
# 96269      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 563    564         96269             69000                   5
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 563                  4                    1                 0
# 96297      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 430    431         96297             71000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 430                  4                    0                 0
# 96386     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 52     53         96386             17000                   2
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 52                  1                    5                 8
# 96463     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 17     18         96463              8000                   2
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 17                  0                    3                 4
# 96534      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 573    574         96534             66000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 573                  2                    2                 3
# 96548      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 338    339         96548             20000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 338                  2                    0                 1
# 96929      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 391    392         96929             13000                   4
# 398    399         96929             67000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 391                  5                    0                 0
# 398                  2                    2                 2
# 97011      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 154    155         97011              8000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 154                  2                    3                10
# 97109      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 268    269         97109             17000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 268                  5                    0                 0
# 97285      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 624    625         97285            178000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 624                  0                   11                 0
# 97463      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 192    193         97463             20000                   3
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 192                  0                    3                 5
# 97530      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 419    420         97530             58000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 419                  4                    0                 1
# 97536      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 166    167         97536             13000                   4
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 166                  0                    4                 7
# 97687      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 171    172         97687              6000                   2
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 171                  2                    3                 7
# 97825      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 231    232         97825             19000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 231                  3                    2                 3
# 97850      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 554    555         97850             33000                   5
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 554                  2                    2                 0
# 97935      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 104    105         97935             17000                   2
# 632    633         97935            187000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 104                  1                    2                10
# 632                  1                    7                 0
# 97951      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 152    153         97951             15000                   3
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 152                  2                    2                 6
# 97954      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 404    405         97954             70000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 404                  2                    0                 4
# 98126      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 369    370         98126             19000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 369                  4                    1                 3
# 98216      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 617    618         98216            136000                   8
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 617                  0                   13                 0
# 98288      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 195    196         98288              8000                   2
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 195                  1                    4                 8
# 98499      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 116    117         98499             18000                   1
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 116                  0                    2                 7
# 98602      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 170    171         98602              7000                   2
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 170                  1                    2                 8
# 98969      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 185    186         98969             18000                   3
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 185                  0                    4                 4
# 99026     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 45     46         99026             14000                   4
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 45                  1                    4                 9
# 99131      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 518    519         99131             36000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 518                  4                    0                 2
# 99284      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 600    601         99284             68000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 600                  5                    0                 0
# 99437      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 520    521         99437             39000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 520                  4                    0                 4
# 99473      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 592    593         99473             54000                   5
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 592                  4                    2                 1
# 99589     Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 80     81         99589             20000                   2
#
#     Total_visits_bank  Total_visits_online  Total_calls_made
# 80                  2                    4                 8
# 99596      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 205    206         99596             17000                   1
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 205                  0                    5                 5
# 99843      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 640    641         99843            123000                   8
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 640                  1                   15                 2

# %% [markdown]
# #### Check the info of the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660 entries, 0 to 659
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sl_No                660 non-null    int64
#  1   Customer Key         660 non-null    int64
#  2   Avg_Credit_Limit     660 non-null    int64
#  3   Total_Credit_Cards   660 non-null    int64
#  4   Total_visits_bank    660 non-null    int64
#  5   Total_visits_online  660 non-null    int64
#  6   Total_calls_made     660 non-null    int64
# dtypes: int64(7)
# memory usage: 36.2 KB

# %% [markdown]
# **Observations:**
#
# - There are 660 observations and 7 columns in the dataset.
# - All columns have 660 non-null values i.e. there are no missing values.
# - All columns are of int64 data type.

# %% [markdown]
# **There are no missing values. Let us now figure out the uniques in each column.**

# %%
data.nunique()
# Out:
# Sl_No                  660
# Customer Key           655
# Avg_Credit_Limit       110
# Total_Credit_Cards      10
# Total_visits_bank        6
# Total_visits_online     16
# Total_calls_made        11
# dtype: int64

# %% [markdown]
# - Customer key, which is an identifier, has repeated values. We should treat the same accordingly before applying any algorithm.

# %% [markdown]
# ## Data Preprocessing and Exploratory Data Analysis

# %% [markdown]
# #### **Question 1: Identify and drop the rows with duplicated customer keys (2 Marks)**

# %%
# Identify the duplicated customer keys
duplicate_keys = data.duplicated(subset=['Customer Key'])

# %%
duplicate_keys
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 655    False
# 656    False
# 657    False
# 658    False
# 659    False
# Length: 660, dtype: bool

# %%
# Drop duplicated keys

data = data.drop_duplicates(subset='Customer Key')

# %%
data.shape
# Out:
# (655, 7)

# %% [markdown]
# We have done some basic checks. Now, let's drop the variables that are not required for our analysis.

# %%
data.drop(columns = ['Sl_No', 'Customer Key'], inplace = True)

# %%
data
# Out:
#      Avg_Credit_Limit  Total_Credit_Cards  Total_visits_bank  \
# 0              100000                   2                  1
# 1               50000                   3                  0
# 2               50000                   7                  1
# 3               30000                   5                  1
# 4              100000                   6                  0
# ..                ...                 ...                ...
# 655             99000                  10                  1
# 656             84000                  10                  1
# 657            145000                   8                  1
# 658            172000                  10                  1
# 659            167000                   9                  0
#
#      Total_visits_online  Total_calls_made
# 0                      1                 0
# 1                     10                 9
# 2                      3                 4
# 3                      1                 4
# 4                     12                 3
# ..                   ...               ...
# 655                   10                 0
# 656                   13                 2
# 657                    9                 1
# 658                   15                 0
# 659                   12                 2
#
# [655 rows x 5 columns]

# %% [markdown]
# Now that we have dropped unnecessary column. We can again check for duplicates. Duplicates would mean customers with identical features.

# %%
data[data.duplicated()]
# Out:
#      Avg_Credit_Limit  Total_Credit_Cards  Total_visits_bank  \
# 162              8000                   2                  0
# 175              6000                   1                  0
# 215              8000                   4                  0
# 295             10000                   6                  4
# 324              9000                   4                  5
# 361             18000                   6                  3
# 378             12000                   6                  5
# 385              8000                   7                  4
# 395              5000                   4                  5
# 455             47000                   6                  2
# 497             52000                   4                  2
#
#      Total_visits_online  Total_calls_made
# 162                    3                 4
# 175                    2                 5
# 215                    4                 7
# 295                    2                 3
# 324                    0                 4
# 361                    1                 4
# 378                    2                 1
# 385                    2                 0
# 395                    0                 1
# 455                    0                 4
# 497                    1                 2

# %% [markdown]
# We can drop these duplicated rows from the data

# %%
data=data[~data.duplicated()]

# %%
data.shape
# Out:
# (644, 5)

# %% [markdown]
# - After removing duplicated keys and rows and unnecessary columns, there are 644 unique observations and 5 columns in our data.

# %% [markdown]
# #### Summary Statistics

# %% [markdown]
# #### **Question 2: Write your observations on the summary statistics of the data (1 Mark)**

# %%
data.describe().T
# Out:
#                      count          mean           std     min      25%  \
# Avg_Credit_Limit     644.0  34543.478261  37428.704286  3000.0  11000.0
# Total_Credit_Cards   644.0      4.694099      2.175338     1.0      3.0
# Total_visits_bank    644.0      2.395963      1.626964     0.0      1.0
# Total_visits_online  644.0      2.624224      2.957728     0.0      1.0
# Total_calls_made     644.0      3.608696      2.880025     0.0      1.0
#
#                          50%       75%       max
# Avg_Credit_Limit     18000.0  48000.00  200000.0
# Total_Credit_Cards       5.0      6.00      10.0
# Total_visits_bank        2.0      4.00       5.0
# Total_visits_online      2.0      4.00      15.0
# Total_calls_made         3.0      5.25      10.0

# %%
plt.figure()
plt.hist(data['Avg_Credit_Limit'], bins = 20)
plt.show()

# %%
plt.boxplot(data['Avg_Credit_Limit'])
plt.show()

# %% [markdown]
# **Observations:___________**

# %% [markdown]
# #### Now let's go ahead with the exploring each variable at hand. We will check the distribution and outliers for each variable in the data.

# %% [markdown]
# #### Question 3:
# - **Check the distribution of all variables (use .hist() attribute) (2 Marks)**
# - **Check outliers for all variables (use sns.boxplot()) (2 Mark)**
# - **Write your observations (1 Marks)**

# %%
# Uncomment and complete the code by filling the blanks 

# for col in data.columns:
#     print(col)
#     print('Skew :',round(data[col].skew(),2))
#     plt.figure(figsize=(15,4))
#     plt.subplot(1,2,1)
#     data[col].______________
#     plt.ylabel('count')
#     plt.subplot(1,2,2)
#     sns.boxplot(x=___________)
#     plt.show()

# %% [markdown]
# **Observation:______________**

# %% [markdown]
# **Now, let's check the correlation among different variables.**

# %%
plt.figure(figsize=(8,8))
sns.heatmap(data.corr(), annot=True, fmt='0.2f')
plt.show()

# %% [markdown]
# **Observation:**
#
# - Avg_Credit_Limit is positively correlated with Total_Credit_Cards Total_visits_online which can makes sense.
# - Avg_Credit_Limit is negatively correlated with Total_calls_made and Total_visits_bank.
# - Total_visits_bank, Total_visits_online, Total_calls_made are negatively correlated which implies that majority of customers use only one of these channels to contact the bank.

# %% [markdown]
# #### Scaling the data

# %%
scaler=StandardScaler()
data_scaled=pd.DataFrame(scaler.fit_transform(data), columns=data.columns)

# %%
data_scaled.head()
# Out:
#    Avg_Credit_Limit  Total_Credit_Cards  Total_visits_bank  \
# 0          1.750192           -1.239437          -0.858684
# 1          0.413280           -0.779381          -1.473803
# 2          0.413280            1.060843          -0.858684
# 3         -0.121485            0.140731          -0.858684
# 4          1.750192            0.600787          -1.473803
#
#    Total_visits_online  Total_calls_made
# 0            -0.549573         -1.253982
# 1             2.495669          1.873420
# 2             0.127148          0.135974
# 3            -0.549573          0.135974
# 4             3.172390         -0.211515

# %%
#Creating copy of the data to store labels from each algorithm
data_scaled_copy = data_scaled.copy(deep=True)

# %% [markdown]
# ## K-Means

# %% [markdown]
# Let us now fit k-means algorithm on our scaled data and find out the optimum number of clusters to use.
#
# We will do this in 3 steps:
# 1. Initialize a dictionary to store the SSE for each k
# 2. Run for a range of Ks and store SSE for each run
# 3. Plot the SSE vs K and find the elbow

# %%
# step 1
sse = {} 

# step 2 - iterate for a range of Ks and fit the scaled data to the algorithm. Use inertia attribute from the clustering object and 
# store the inertia value for that k 
for k in range(1, 10):
    kmeans = KMeans(n_clusters=k, max_iter=1000, random_state=1).fit(data_scaled)
    sse[k] = kmeans.inertia_

# step 3
plt.figure()
plt.plot(list(sse.keys()), list(sse.values()), 'bx-')
plt.xlabel("Number of cluster")
plt.ylabel("SSE")
plt.show()

# %% [markdown]
# - Looking at the plot, we can say that elbow point is achieved for k=3.
# - We will fit the k-means again with k=3 to get the labels.

# %% [markdown]
# #### Question 4:
#
# - **From the above elbow plot, state the reason for choosing k=3 and with random_state=1(1 Mark)**
# - **Fit the K-means algorithms on the scaled data with number of cluster equal to 3 (2 Mark)**
# - **Store the predictions as 'Labels' to the 'data_scaled_copy' and 'data' dataframes (2 Marks)**

# %%
kmeans = _______________ #Apply the K-Means algorithm
__________________ #Fit the kmeans function on the scaled data

#Adding predicted labels to the original data and scaled data 
data_scaled_copy['Labels'] = ___________ #Save the predictions on the scaled data from K-Means
data['Labels'] = _______________ #Save the predictions on the scaled data from K-Means

# %% [markdown]
# We have generated the labels with k-means. Let us look at the various features based on the labels.

# %% [markdown]
# #### **Question 5: Create cluster profiles using the below summary statistics and box plots for each label (6 Marks)**

# %%
#Number of observations in each cluster
data.Labels.value_counts()
# Out:
# 1    374
# 0    221
# 2     49
# Name: Labels, dtype: int64

# %%
#Calculating summary statistics of the original data for each label
mean = data.groupby('Labels').mean()
median = data.groupby('Labels').median()
df_kmeans = pd.concat([mean, median], axis=0)
df_kmeans.index = ['group_0 Mean', 'group_1 Mean', 'group_2 Mean', 'group_0 Median', 'group_1 Median', 'group_2 Median']
df_kmeans.T
# Out:
#                      group_0 Mean  group_1 Mean   group_2 Mean  \
# Avg_Credit_Limit     12239.819005  33893.048128  140102.040816
# Total_Credit_Cards       2.411765      5.508021       8.775510
# Total_visits_bank        0.945701      3.489305       0.591837
# Total_visits_online      3.561086      0.975936      10.979592
# Total_calls_made         6.891403      1.997326       1.102041
#
#                      group_0 Median  group_1 Median  group_2 Median
# Avg_Credit_Limit            12000.0         31500.0        145000.0
# Total_Credit_Cards              2.0             6.0             9.0
# Total_visits_bank               1.0             3.0             1.0
# Total_visits_online             4.0             1.0            11.0
# Total_calls_made                7.0             2.0             1.0

# %%
#Visualizing different features w.r.t K-means labels
data_scaled_copy.boxplot(by = 'Labels', layout = (1,5),figsize=(20,7))
plt.show()

# %% [markdown]
# **Cluster Profiles:_______________**

# %% [markdown]
# ## Gaussian Mixture

# %% [markdown]
# Let's create clusters using Gaussian Mixture Models

# %% [markdown]
# #### Question 6:
#
# - **Apply the Gaussian Mixture algorithm on the scaled data with random_state=1 (2 Marks)**
# - **Create cluster profiles using the below summary statistics and box plots for each label (2 Marks)**
# - **Compare the clusters from both algorithms - K-means and Gaussian Mixture (1 Mark)**

# %%
gmm = __________________ #Apply the Gaussian Mixture algorithm
___________ #Fit the gmm function on the scaled data

data_scaled_copy['GmmLabels'] = gmm.predict(data_scaled)
data['GmmLabels'] = gmm.predict(data_scaled)

# %%
#Number of observations in each cluster
data.GmmLabels.value_counts()
# Out:
# 1    374
# 0    221
# 2     49
# Name: GmmLabels, dtype: int64

# %%
#Calculating summary statistics of the original data for each label
original_features = ["Avg_Credit_Limit","Total_Credit_Cards","Total_visits_bank","Total_visits_online","Total_calls_made"]

mean = data.groupby('GmmLabels').mean()
median = data.groupby('GmmLabels').median()
df_gmm = pd.concat([mean, median], axis=0)
df_gmm.index = ['group_0 Mean', 'group_1 Mean', 'group_2 Mean', 'group_0 Median', 'group_1 Median', 'group_2 Median']
df_gmm[original_features].T
# Out:
#                      group_0 Mean  group_1 Mean   group_2 Mean  \
# Avg_Credit_Limit     12239.819005  33893.048128  140102.040816
# Total_Credit_Cards       2.411765      5.508021       8.775510
# Total_visits_bank        0.945701      3.489305       0.591837
# Total_visits_online      3.561086      0.975936      10.979592
# Total_calls_made         6.891403      1.997326       1.102041
#
#                      group_0 Median  group_1 Median  group_2 Median
# Avg_Credit_Limit            12000.0         31500.0        145000.0
# Total_Credit_Cards              2.0             6.0             9.0
# Total_visits_bank               1.0             3.0             1.0
# Total_visits_online             4.0             1.0            11.0
# Total_calls_made                7.0             2.0             1.0

# %%
# plotting boxplots with the new GMM based labels

features_with_lables = ["Avg_Credit_Limit","Total_Credit_Cards","Total_visits_bank","Total_visits_online","Total_calls_made","GmmLabels"]

data_scaled_copy[features_with_lables].boxplot(by = 'GmmLabels', layout = (1,5),figsize=(20,7))
plt.show()

# %% [markdown]
# **Cluster Profiles:____________**
#
# **Comparing Clusters:____________**

# %% [markdown]
# ## K-Medoids

# %% [markdown]
# #### Question 7:
#
# - **Apply the K-Mediods on the scaled data with random_state=1 (2 Marks)**
# - **Create cluster profiles using the below summary statistics and box plots for each label (2 Marks)**
# - **Compare the clusters from both algorithms - K-Means and K-Medoids (2 Marks)**

# %%
kmedo = _____________ #Apply the K-Medoids algorithm
_____________ #Fit the kmedo function on the scaled data

data_scaled_copy['kmedoLabels'] = kmedo.predict(data_scaled)
data['kmedoLabels'] = kmedo.predict(data_scaled)

# %%
#Number of observations in each cluster
data.kmedoLabels.value_counts()
# Out:
# 2    289
# 0    222
# 1    133
# Name: kmedoLabels, dtype: int64

# %%
#Calculating summary statistics of the original data for each label
mean = data.groupby('kmedoLabels').mean()
median = data.groupby('kmedoLabels').median()
df_kmedoids = pd.concat([mean, median], axis=0)
df_kmedoids.index = ['group_0 Mean', 'group_1 Mean', 'group_2 Mean', 'group_0 Median', 'group_1 Median', 'group_2 Median']
df_kmedoids[original_features].T
# Out:
#                      group_0 Mean  group_1 Mean  group_2 Mean  group_0 Median  \
# Avg_Credit_Limit     12216.216216  85052.631579  28449.826990         12000.0
# Total_Credit_Cards       2.423423      7.030075      5.363322             2.0
# Total_visits_bank        0.950450      1.691729      3.830450             1.0
# Total_visits_online      3.554054      4.639098      0.982699             4.0
# Total_calls_made         6.878378      1.969925      1.851211             7.0
#
#                      group_1 Median  group_2 Median
# Avg_Credit_Limit            68000.0         20000.0
# Total_Credit_Cards              7.0             5.0
# Total_visits_bank               2.0             4.0
# Total_visits_online             2.0             1.0
# Total_calls_made                2.0             2.0

# %%
#plotting boxplots with the new K-Medoids based labels

features_with_lables = ["Avg_Credit_Limit",	"Total_Credit_Cards","Total_visits_bank","Total_visits_online","Total_calls_made","kmedoLabels"]

data_scaled_copy[features_with_lables].boxplot(by = 'kmedoLabels', layout = (1,5),figsize=(20,7))
plt.show()

# %% [markdown]
# Let's compare the clusters from K-Means and K-Medoids

# %%
comparison = pd.concat([df_kmedoids, df_kmeans], axis=1)[original_features]
comparison
# Out:
#                 Avg_Credit_Limit  Avg_Credit_Limit  Total_Credit_Cards  \
# group_0 Mean        12216.216216      12239.819005            2.423423
# group_1 Mean        85052.631579      33893.048128            7.030075
# group_2 Mean        28449.826990     140102.040816            5.363322
# group_0 Median      12000.000000      12000.000000            2.000000
# group_1 Median      68000.000000      31500.000000            7.000000
# group_2 Median      20000.000000     145000.000000            5.000000
#
#                 Total_Credit_Cards  Total_visits_bank  Total_visits_bank  \
# group_0 Mean              2.411765           0.950450           0.945701
# group_1 Mean              5.508021           1.691729           3.489305
# group_2 Mean              8.775510           3.830450           0.591837
# group_0 Median            2.000000           1.000000           1.000000
# group_1 Median            6.000000           2.000000           3.000000
# group_2 Median            9.000000           4.000000           1.000000
#
#                 Total_visits_online  Total_visits_online  Total_calls_made  \
# group_0 Mean               3.554054             3.561086          6.878378
# group_1 Mean               4.639098             0.975936          1.969925
# group_2 Mean               0.982699            10.979592          1.851211
# group_0 Median             4.000000             4.000000          7.000000
# group_1 Median             2.000000             1.000000          2.000000
# group_2 Median             1.000000            11.000000          2.000000
#
#                 Total_calls_made
# group_0 Mean            6.891403
# group_1 Mean            1.997326
# group_2 Mean            1.102041
# group_0 Median          7.000000
# group_1 Median          2.000000
# group_2 Median          1.000000

# %% [markdown]
# **Cluster Profiles:____________**
#
# **Comparing Clusters:___________________**
