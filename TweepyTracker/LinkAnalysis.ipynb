# %%
import pandas as pd

# %%
data = pd.read_excel("Classgap_Doc.xlsx")

# %%
data
# Out:
#       TESTATA              DATA  \
# 0        Rai1  13/11/2020 07:20
# 1       Rete4  13/11/2020 07:20
# 2       Rete4  13/11/2020 08:00
# 3        Rai3  13/11/2020 06:40
# 4     Italia1  13/11/2020 12:40
# ...       ...               ...
# 3720  Canale5  31/10/2021 19:40
# 3721    Rete4  31/10/2021 21:40
# 3722    Rete4  31/10/2021 21:20
# 3723    Rete4  31/10/2021 21:00
# 3724        v               NaN
#
#                                               CONTENUTO  \
# 0     questo virus ancora per alcuni mesi fa anche v...
# 1     da di ritratti di grandi sportivi e di grandi ...
# 2     secondo alcuni scienziati e il visone potrebbe...
# 3     diamo i numeri della pandemia nel mondo oltre ...
# 4     caro la racchetta e ancora una volta sulle bar...
# ...                                                 ...
# 3720  Nobel per la chimica nel diciannove tre scienz...
# 3721  dopodiché il problema è che quando tutti ci st...
# 3722  Lare della religione a partire da un corso di ...
# ...

# %%
data.columns
# Out:
# Index(['TESTATA', 'DATA', 'CONTENUTO', 'TITOLO', 'LINK', 'DURATA', 'corpus',
#        'Categoria', 'Categoria Agenzia', 'Nazioni', 'Regioni', 'Province',
#        'Aziende', 'Localizzazione fonte', 'Imprenditori', 'Politici', 'Leader',
#        'Università', 'Banche', 'Partiti', 'Autore', 'Hashtag', 'UserMentions',
#        'Speaker'],
#       dtype='object')

# %%
lista = []

# %%
for i, row in data.iterrows(): 
    corpus_i = row['corpus']
    lista.append(corpus_i)
    lista.append('\n')

# %%
import csv 

with open('corpus.csv', 'w') as f: 
    write = csv.writer(f) 
    write.writerow(lista)
