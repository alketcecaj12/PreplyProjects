# %%
import string
import re
from wordcloud import WordCloud
import matplotlib.pyplot as plt
def remove_punct(text):
    text_nopunct = "".join([char for char in text if char not in string.punctuation])
    return text_nopunct.lower()

def tokenize(text):
    tokens = re.split('\W+', text)
    return tokens
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-85-b65dfc956254> in <module>
#       1 import string
#       2 import re
# ----> 3 from wordcloud import WordCloud
#       4 import matplotlib.pyplot as plt
#       5 def remove_punct(text):
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
# !conda install -c conda-forge wordcloud
# Out:
# ^C

# %%
lista = []
with open('2022-01-12 09_05_17_tweets.txt', 'r', encoding='cp850' ) as file: 
    
    line = file.read()
    lista.append(line)

# %%
lista
# Out:
# ['RT @PSchioppa: Con il 50% dei delegati regionali scelti a grandi elettori per il #Quirinale viste le appartenenze, mai come stiamo facendoÔÇª\n-----------------------\nRT @siamonoitv2000: Corsa al #Quirinale, speciale di #SiamoNoi alle 15.15 su @TV2000it con @giuspaterniti, @PaoloGraldi e @FrancoBechis.\n\n#ÔÇª\n-----------------------\nÔ×í´©Å #SiamoNoi\nÔÅ░ 15.15\n\xadƒô║ @TV2000it \n\n#Quirinale #12gennaio #canale28 #siamonoitv2000 @FrancoBechis @giuspaterniti @PaoloGraldi @ilmessaggeroit @tempoweb @GabriFacondo https://t.co/RXCDpGCiY0\n-----------------------\nDopo che per mesi #Mattarella ha detto che non ci pensava nemmeno ora ripropongono Mattarella per un secondo incarico.\nCos├¼, tranquillamente e come se fosse la cosa pi├╣ fattibile del mondo.\n#Quirinale\n-----------------------\nRT @smenichini: Non ci sar├á purtroppo alcun effetto #Sassoli sul voto per il #Quirinale, che non ├¿ un momento per la politica gentile. Per├▓ÔÇª\n-----------------------\nRT @DinoGiarrusso: Immaginatevi se @GiuseppeConteIT fosse andato in #CONFERENZASTAMPA con tre giorni di ritardo, escludendo un quotidiano eÔÇª\n-----------------------\nE\' fissata per le 16 di oggi pomeriggio la seduta d\'Aula dell\'Assemblea Regionale Siciliana che elegger├á i tre grandi elettori che dal 24 gennaio prossimo voteranno per il nuovo Presidente della Repubblica.  \n #Ars #Palermo #Quirinale\n\nhttps://t.co/kOTsCdHde5 https://t.co/elAayM8EYC\n-----------------------\nRT @CCKKI: Dice #Berlusconi: "Se va #Draghi al #Quirinale si va al voto".\nProbabilmente #Mattarella sar├á costretto a disfare i bagagli e feÔÇª\n-----------------------\nIl Corriere stila i possibili nomi per il #Quirinale, ma i vari #noQUIRISILVIO, Prodi, Casini e Cartabia mi fanno venire voglia di andare sotto la finestra di #Mattarella a piangere e gridare non ci lasciare ti prego\n-----------------------\nRT @fattoquotidiano: #Quirinale, Cinque Stelle e Pd pensano di non scrivere nulla sulla scheda per le prime tre chiame, per poi andare sulÔÇª\n-----------------------\nStefano Folli su @repubblica, quello che molti cittadini pensano #Quirinale https://t.co/iaH4AUDOGT\n-----------------------\nPerle di cinismo &amp; saggezza #Quirinale https://t.co/MfGj7xD0x7\n-----------------------\nDi cose strane sul #totoquirinale ne ho lette parecchie, ma quella secondo cui il centrosinistra non potrebbe dire no a Letizia Moratti, "perch├® figlia di un partigiano" (La Stampa, oggi) le batte davvero tutte #quirinale #elezioniquirinale #presidentedellarepubblica\n-----------------------\nRT @CCKKI: Dice #Berlusconi: "Se va #Draghi al #Quirinale si va al voto".\nProbabilmente #Mattarella sar├á costretto a disfare i bagagli e feÔÇª\n-----------------------\nRT @Murandrea1: Il #Quirinale ├¿ perno istituzionale, geopolitico, strategico dello Stato italiano.  La forza del Quirinale ├¿ quella di poteÔÇª\n-----------------------\n16 arresti a #catania per pizzo e usura. \nAddio a #sassoli. Delirio #novax sui social. \n#Bassetti ÔÇ£Non pubblichiamo pi├╣ il dato dei contagiÔÇØ. \nLÔÇÖARS scegli i grandi elettori per il #quirinale. \nPronta la task force regionale per il #PNRR \n\n#edicola #primapagina #12gennaio https://t.co/osymboONnD\n-----------------------\nRT @DinoGiarrusso: Immaginatevi se @GiuseppeConteIT fosse andato in #CONFERENZASTAMPA con tre giorni di ritardo, escludendo un quotidiano eÔÇª\n-----------------------\n#Berlusconi ├¿ improponibile al #Quirinale. Un condannato in via definitiva e ancora sotto processo come pu├▓ diventare Presidente della Repubblica? Andr├á alla sbarra da imputato come presidente del Consiglio Superiore della Magistratura?\n-----------------------\nQuirinale, da oggi Berlusconi ha un voto in pi├╣, Toma: ┬½Per me Silvio Berlusconi sarebbe perfetto┬╗ #Quirinale #Berlusconi #toma https://t.co/GG8McaE19i via @MoliseWeb\n-----------------------\nRT @fuskiko: Se la notizia ├¿ vera. Domani alla cara avvocatessa, una querela non gliela toglie nessuno. #quirinale chiediamo scuse im ...

# %%
text = "\n-----------------------\n".join(lista)

# %%
tweets = text.split("\n-----------------------\n")

# %%
tweets_number = {}
count = 1
for i in tweets: 
    tweets_number[count] = i 
    count+=1

# %%
tweets_number
# Out:
# {1: 'RT @PSchioppa: Con il 50% dei delegati regionali scelti a grandi elettori per il #Quirinale viste le appartenenze, mai come stiamo facendoÔÇª',
#  2: 'RT @siamonoitv2000: Corsa al #Quirinale, speciale di #SiamoNoi alle 15.15 su @TV2000it con @giuspaterniti, @PaoloGraldi e @FrancoBechis.\n\n#ÔÇª',
#  3: 'Ô×í´©Å #SiamoNoi\nÔÅ░ 15.15\n\xadƒô║ @TV2000it \n\n#Quirinale #12gennaio #canale28 #siamonoitv2000 @FrancoBechis @giuspaterniti @PaoloGraldi @ilmessaggeroit @tempoweb @GabriFacondo https://t.co/RXCDpGCiY0',
#  4: 'Dopo che per mesi #Mattarella ha detto che non ci pensava nemmeno ora ripropongono Mattarella per un secondo incarico.\nCos├¼, tranquillamente e come se fosse la cosa pi├╣ fattibile del mondo.\n#Quirinale',
#  5: 'RT @smenichini: Non ci sar├á purtroppo alcun effetto #Sassoli sul voto per il #Quirinale, che non ├¿ un momento per la politica gentile. Per├▓ÔÇª',
#  6: 'RT @DinoGiarrusso: Immaginatevi se @GiuseppeConteIT fosse andato in #CONFERENZASTAMPA con tre giorni di ritardo, escludendo un quotidiano eÔÇª',
#  7: "E' fissata per le 16 di oggi pomeriggio la seduta d'Aula dell'Assemblea Regionale Siciliana che elegger├á i tre grandi elettori che dal 24 gennaio prossimo voteranno per il nuovo Presidente della Repubblica.  \n #Ars #Palermo #Quirinale\n\nhttps://t.co/kOTsCdHde5 https://t.co/elAayM8EYC",
#  8: 'RT @CCKKI: Dice #Berlusconi: "Se va #Draghi al #Quirinale si va al voto".\nProbabilmente #Mattarella sar├á costretto a disfare i bagagli e feÔÇª',
#  9: 'Il Corriere stila i possibili nomi per il #Quirinale, ma i vari #noQUIRISILVIO, Prodi, Casini e Cartabia mi fanno venire voglia di andare sotto la finestra di #Mattarella a piangere e gridare non ci lasciare ti prego',
#  10: 'RT @fattoquotidiano: #Quirinale, Cinque Stelle e Pd pensano di non scrivere nulla sulla scheda per le prime tre chiame, per poi andare sulÔÇª',
#  11: 'Stefano Folli su @repubblica, quello che molti cittadini pensano #Quirinale https://t.co/iaH4AUDOGT',
#  12: 'Perle di cinismo &amp; saggezza #Quirinale https://t.co/MfGj7xD0x7',
#  13: 'Di cose strane sul #totoquirinale ne ho lette parecchie, ma quella secondo cui il centrosinistra non potrebbe dire no a Letizia Moratti, "perch├® figlia di un partigiano" (La Stampa, oggi) le batte davvero tutte #quirinale #elezioniquirinale #presidentedellarepubblica',
#  14: 'RT @CCKKI: Dice #Berlusconi: "Se va #Draghi al #Quirinale si va al voto".\nProbabilmente #Mattarella sar├á costretto a disfare i bagagli e feÔÇª',
#  15: 'RT @Murandrea1: Il #Quirinale ├¿ perno istituzionale, geopolitico, strategico dello Stato italiano.  La forza del Quirinale ├¿ quella di poteÔÇª',
#  16: '16 arresti a #catania per pizzo e usura. \nAddio a #sassoli. Delirio #novax sui social. \n#Bassetti ÔÇ£Non pubblichiamo pi├╣ il dato dei contagiÔÇØ. \nLÔÇÖARS scegli i grandi elettori per il #quirinale. \nPronta la task force regionale per il #PNRR \n\n#edicola #primapagina #12gennaio https://t.co/osymboONnD',
#  17: 'RT @DinoGiarrusso: Immaginatevi se @GiuseppeConteIT fosse andato in #CONFERENZASTAMPA con tre giorni di ritardo, escludendo un quotidiano eÔÇª',
#  18: '#Berlusconi ├¿ improponibile al #Quirinale. Un condannato in via definitiva e ancora sotto processo come pu├▓ diventare Presidente della Repubblica? Andr├á alla sbarra da imputato come presidente del Consiglio Superiore della Magistratura?',
#  19: 'Quirinale, da oggi Berlusconi ha un voto in pi├╣, Toma: ┬½Per me Silvio Berlusconi sarebbe perfetto┬╗ #Quirinale #Berlusconi #toma https://t.co/GG8McaE19i via @MoliseWeb',
#  20: 'RT @fuskiko: Se la notizia ├¿ vera. Domani alla cara avvocatessa, una querela non gliela toglie nessuno. #quirinale chiediamo scuse imm├®diatÔÇª',
#  21: 'RT @fattoquotidiano: #Quirinale, Cinque Stelle e Pd pensano di non scrivere nulla sulla scheda per le prime tre chiame, per poi andare sulÔÇª',
#  22: 'RT @CosoSono: #noQUIRISILVIO \xadƒö┤\n\nCosa si fa per danaro?\n\nAnche eleggere un pregiudicato al #Quirinale \xadƒñ¼',
#  23: 'RT @fuskiko: Se la notizia ├¿ vera. Domani alla cara avvocatessa, una querela non gliela toglie nessuno. #quirinale chiediamo scuse imm├®diatÔÇª',
#  24: 'RT @CCKKI: Dice #Berlusconi: "Se va #Draghi al #Quirinale si va al voto".\nProbabilmente #Mattarella sar├á costretto a disfare i bagagli e feÔÇª',
#  25: 'RT @fuskiko: Se la notizia ├¿ vera. Domani alla cara avvocatessa, una querela non gliela toglie nessuno. #quirinale chiediamo scuse imm├®diatÔÇª',
#  26: 'RT @fattoquotidiano: #Quirinale, Cinque Stelle e Pd pensano di non scrivere nulla sulla scheda per le prime tre chiame, per poi andare sulÔÇª',
#  27: '#Quirinale, Cinque Stelle e Pd pensano di non scrivere nulla sulla scheda per le prime tre chiame, per poi andare sul ÔÇ£bisÔÇØ o su Draghi. Conte incontrer├á Salvini [di @lucadecarolis e @WandaMarra] https://t.co/WM4donPLb7',
#  28: 'RT @armanduplessis: Considerando anche alcune bizzarre ipotesi in campo per il #Quirinale, scrive Folli che "il Paese potrebbe aver bisognoÔÇª',
#  29: 'RT @smenichini: Non ci sar├á purtroppo alcun effetto #Sassoli sul voto per il #Quirinale, che non ├¿ un momento per la politica gentile. Per├▓ÔÇª',
#  30: 'RT @maurobiani: #PresidenteDellaRepubblica #Quirinale #Covid \nCorsa.\nOggi su @repubblica https://t.co/wXMlZQLaoo',
#  31: 'RT @LaNotiziaTweet: Draghi sogna il #Quirinale. Ma a Palazzo Chigi ha fallito quasi tutto. A partire da Recovery plan e campagna vaccinale.ÔÇª',
#  32: 'RT @maurobiani: #PresidenteDellaRepubblica #Quirinale #Covid \nCorsa.\nOggi su @repubblica https://t.co/wXMlZQLaoo',
#  33: '12 giorni allÔÇÖalba. #Quirinale',
#  34: 'RT @LaNotiziaTweet: Draghi sogna il #Quirinale. Ma a Palazzo Chigi ha fallito quasi tutto. A partire da Recovery plan e campagna vaccinale.ÔÇª',
#  35: 'RT @maurobiani: #PresidenteDellaRepubblica #Quirinale #Covid \nCorsa.\nOggi su @repubblica https://t.co/wXMlZQLaoo',
#  36: "RT @thebrightside0: #buonoasapersi\xadƒÆí\n\nLa buona ed utile informazione ├¿ quella di @DavideGiac su @rtl1025 quando ricorda e sottolinea come l'ÔÇª",
#  37: '#Quirinale Un Mattarella-bis unico, estremo tentativo per un centrosinistra in empasse sul candidato anti-Berlusconi. @domanigiornale illustra il piano Pd-M5S, per @ilfoglio_it Letta non sarebbe troppo entusiasta.\n\n#primapagina  #12gennaio  #FrontPage https://t.co/w4abCq9jmQ',
#  38: '@MartaGrande87 si legge sui giornali che una parte dei parlamentari 5stelle, te in primis, appoggia #casini al #Quirinale...spero siano solo fantasie della mente deviata dei giornalisti.....',
#  39: 'RT @maurobiani: #PresidenteDellaRepubblica #Quirinale #Covid \nCorsa.\nOggi su @repubblica https://t.co/wXMlZQLaoo',
#  40: 'RT @qn_lanazione: #Quirinale - Grandi elettori toscani, la Lega non cede il posto https://t.co/wHfZUVkAZx via @qn_lanazione',
#  41: '\xadƒöÁ ÔÇ£Orientarsi in questa fase non ├¿ semplice, sul #Quirinale ci sono poche certezze e molte incertezze. #Draghi vuole andare al #Colle al 100%ÔÇØ\n\n@claudiocerasa \xadƒÄÖ´©Å\n#nonstopnews\n\xadƒö┤ LIVE ÔûÂ´©Å https://t.co/iDld1y40ul https://t.co/DQK1XtDZAi',
#  42: 'RT @CCKKI: Dice #Berlusconi: "Se va #Draghi al #Quirinale si va al voto".\nProbabilmente #Mattarella sar├á costretto a disfare i bagagli e feÔÇª',
#  43: 'Rosy Bindi al #Quirinale? ... Io credo ai miracoli. https://t.co/sGg51ffGFP',
#  44: '#Quirinale Sembra che il Pd si appresti ad affossare il buon senso, come per il DdlZan. Alta politica',
#  45: 'RT @Lombard5stelle: #Quirinale @dariovioli: "LÔÇÖipotesi che io possa votare Berlusconi non ├¿ semplicemente ridicola fantapolitica, ma unÔÇÖoffÔÇª',
#  46: 'RT @LaNotiziaTweet: Draghi sogna il #Quirinale. Ma a Palazzo Chigi ha fallito quasi tutto. A partire da Recovery plan e campagna vaccinale.ÔÇª',
#  47: 'RT @DinoGiarrusso: Immaginatevi se @GiuseppeConteIT fosse andato in #CONFERENZASTAMPA con tre giorni di ritardo, escludendo un quotidiano eÔÇª',
#  48: 'RT @GiampieroBiglia: ÔÇ£Lo stop di #Berlusconi a #Draghi :con lui al Colle noi fuori dal governoÔÇØ in una frase lÔÇÖarroganza, spregiudicatezzaÔÇª',
#  49: '.@paolomieli: "Vi pare questo il modo di discutere sul Capo dello Stato a 10 giorni dalle votazioni? Proporre di richiamare Mattarella?" #Quirinale',
#  50: 'RT @CosoSono: #noQUIRISILVIO \xadƒö┤\n\nCosa si fa per danaro?\n\nAnche eleggere un pregiudicato al #Quirinale \xadƒñ¼',
#  51: 'ÔÇ£Sgarbi chiama i parlamentari uno a uno, poi gli passa Berlusconi che augura buon anno e chiede il voto per il #QuirinaleÔÇØ\nE ve la siete presa con Montanari perch├® diceva Repubblica delle Banane',
#  52: "@elio_vito Elio, battute a parte, sei uno dei pochi che in questo paese riuscirebbe a mettere  d'accordo dx e sx, ma non hai fatto un pensiero per il #Quirinale. Stanotte ho sognato che diventava presidente della Repubblica Pillon \xadƒÿ¡\xadƒÿ¡",
#  53: '.@paolomieli: "Dibattito sul #Quirinale svilente, si vede ricomparire il sempre uguale, ora chiedono a #Mattarella di restare ma c\'├¿ un solo precedente quello di Napolitano che accett├▓ un secondo mandato ma solo dopo il patatrac delle prime votazioni".',
#  54: 'ÔÇ£Immaginate se #mattarella dicesse ho scherzato ├¿ impossibile potrebbe tornare in campo solo di fronte a un disastro conclamato ÔÇ£\n@paolomieli @24Mattino #Quirinale',
#  55: "RT @OrioliAlberto: Se la #Meloni desidera un patriota al #Quirinale dovrebbe leggere di piu` @AnpiPatria, rivista dell'#ANPI fondata nel 19ÔÇª",
#  56: "Ci mancava #Bersani e la sua lungimiranza!! Vorrei #MarioDraghi come  #PdR  per i prossimi sette anni (e non fino al 2023, sempre che ci si arrivi). Cio' darebbe peso,  credibilita' e stabilita' al ns Paese! .@matteorenzi  @AzioneCesena  #facciamorete #Quirinale @GiorgiaMeloni https://t.co/i85BInr7wL",
#  57: 'Negli episodi precedenti....(musichetta) #Quirinale https://t.co/kYI0x6vnCl',
#  58: '#dimartedi Il segretario del Partito democratico Enrico Letta sul #Quirinale: ÔÇ£Ho notizie di parlamentari del nostro gruppo che hanno ricevuto una telefonata di Berlusconi in questi giorniÔÇØ\n\nOcchio alle sporche manovre.',
#  59: 'Il #Quirinale ├¿ perno istituzionale, geopolitico, strategico dello Stato italiano.  La forza del Quirinale ├¿ quella di poter disegnare la cornice entro cui la vita politico-istituzionale pu├▓ muoversi.\n@diss_ipatio\n\nhttps://t.co/v0lLp7c8Om',
#  60: 'Vi aspettiamo a #Studio24, alle 10:00 su @RaiNews, con i nostri ospiti per parlare di:\n\n#OMS #VarianteOmicron #COVID19 #scuola #universit├á #ricerca #Draghi #Mattarella #Berlusconi #Quirinale #PresidenteDellaRepubblica #Sassoli #Europa\n\nConduce @GiorgiaRomb https://t.co/dlKuuaKpu6',
#  61: '#URBANI: ÔÇ£SUL #QUIRINALE #BERLUSCONI APRA GLI OCCHI, NON CI SONO LE ÔÇØ\n\nÔÇ£DRAGHI MEGLIO A PALAZZO CHIGIÔÇØ\nhttps://t.co/wyu50PJcUP https://t.co/eB6kQFq6vV',
#  62: '\xadƒç«\xadƒç╣ Elezioni #Quirinale 2022: 12 possibili scenari. Da Mattarella bis a Draghi, da Berlusconi a Prodi, da Cartabia fino a Moratti. Chi sar├á il prossimo #presidente della Repubblica?https://t.co/s6cZyYzDua',
#  63: 'Spero veramente che #Mattarella ci ripensi. #elezionipresidente #Quirinale',
#  64: 'RT @gladiatoremassi: Nel nome del popolo Italiano chiedo a #meloni e #salvini: ma una persona perbene come #Gratteri al #Quirinale NO? MeglÔÇª',
#  65: 'RT @fabvix1971: La sola idea che il centrodestra possa effettivamente proporre #Berlusconi per il #Quirinale ├¿ raccapricciante. Mi auguro cÔÇª',
#  66: '#Juorno #Quirinale #Sgambetti tra #alleati su delegati regionali, ├¿ caos\nhttps://t.co/c8rdFXmDbe',
#  67: '#Juorno #Quirinale #Sgambetti tra #alleati su delegati regionali, ├¿ caos\nhttps://t.co/0sXK4CW7Uh',
#  68: 'Il bollettino covid deve essere giornaliero o settimanale? I fatti di Capodanno di Milano entrano nel dibattito politico; sul #Quirinale torna la voglia di bis di #Mattarella; riaprire i pozzi di gas italiani?\n\nLa giornata in 24 minuti #12gennaio\nhttps://t.co/qE5U9Of6Mh',
#  69: '#lanota del gianka\nIl modus operandi della sinistra...porre veti sugli altri e scommettere su una candidatura femminile per il Colle, ma solo se appartiene al fronte rosso.\n#Quirinale https://t.co/BUXc4aCBsq',
#  70: '#Quirinale Volevo avvisare #Berlusconi che si ├¿ liberato un posto da #Presidente del #ParlamentoEuropeo.\n#12gennaio #Europa #UE #EuroParlamento #Sassoli #DavidSassoli #AddioDavid #RIPDavidSassoli #PresidenteDellaRepubblica #noQUIRISILVIO #Buongiorno #unTemaAlGiorno',
#  71: 'RT @armanduplessis: Considerando anche alcune bizzarre ipotesi in campo per il #Quirinale, scrive Folli che "il Paese potrebbe aver bisognoÔÇª',
#  72: 'Il #Quirinale ├¿ perno istituzionale, geopolitico, strategico dello Stato italiano.  La forza del Quirinale ├¿ quella di poter disegnare la cornice entro cui la vita politico-istituzionale pu├▓ muoversi. Con potere informali di nominaÔÇªhttps://t.co/MSS06urHRO https://t.co/IAINhsutO7',
#  73: 'RT @armanduplessis: Considerando anche alcune bizzarre ipotesi in campo per il #Quirinale, scrive Folli che "il Paese potrebbe aver bisognoÔÇª',
#  74: 'Considerando anche alcune bizzarre ipotesi in campo per il #Quirinale, scrive Folli che "il Paese potrebbe aver bisogno ancora di #Mattarella, nonostante il suo personale desiderio di tornare alla vita privata".  @repubblica',
#  75: 'RT @DinoGiarrusso: Immaginatevi se @GiuseppeConteIT fosse andato in #CONFERENZASTAMPA con tre giorni di ritardo, escludendo un quotidiano eÔÇª',
#  76: 'RT @DinoGiarrusso: Immaginatevi se @GiuseppeConteIT fosse andato in #CONFERENZASTAMPA con tre giorni di ritardo, escludendo un quotidiano eÔÇª',
#  77: 'La sola idea che il centrodestra possa effettivamente proporre #Berlusconi per il #Quirinale ├¿ raccapricciante. Mi auguro che quel nome venga fatto solo per dargli il contentino ma che poi ci si concentri su qualcuno pi├╣ presentabile.',
#  78: 'Elezione del Presidente. La politica trovi unit├á nellÔÇÖinteresse del Paese - di Pasquale Episcopo\n\n#Quirinale #PresidentedellaRepubblica #politica\n\nhttps://t.co/dyrvRI5JzM',
#  79: 'RT @LaNotiziaTweet: Draghi sogna il #Quirinale. Ma a Palazzo Chigi ha fallito quasi tutto. A partire da Recovery plan e campagna vaccinale.ÔÇª',
#  80: 'RT @fuskiko: Se la notizia ├¿ vera. Domani alla cara avvocatessa, una querela non gliela toglie nessuno. #quirinale chiediamo scuse imm├®diatÔÇª',
#  81: 'Ma invece un Napolitano-ter no?#quirinale #romanzoquirinale #PresidenteDellaRepubblica',
#  82: "RT @AlbertoLetizia2: Dopo avere ascoltato #Letta, l'ipotesi agghiacciante di #Berlusconi al #Quirinale diventa improvvisamente realistica.",
#  83: 'RT @ilfaccendiere_: Voci sempre pi├╣ fitte tra i cronisti parlamentari: "Almeno #Conte le domande se le faceva fare".                      #ÔÇª',
#  84: 'Corsa al #Quirinale, speciale di #SiamoNoi alle 15.15 su @TV2000it con @giuspaterniti, @PaoloGraldi e @FrancoBechis.\n\n#12gennaio #Mattarella #canale28 @tempoweb @ilmessaggeroit https://t.co/ydexO5cr0m',
#  85: 'Colle, Berlusconi rompe gli indugi e spariglia subito le carte - https://t.co/X58Rl5PVmQ\n#MarioDraghi #PensioniDeiParlamentari #PresidenteDellaRepubblica #Quirinale #SergioMattarella #SilvioBerlusconi https://t.co/MjW8om0vV8',
#  86: 'Credo che alla fine ci salveremo (anche se per poco) grazie agli inciuci partitocratici italioti. L"elezione del #PdR sta per creare un terremoto sia che #Draghi vada al #Quirinale sia che possa restare a #PalazzoChigi. E non ├¿ escluso nemmeno che si dimetta come terza opzione',
#  87: 'RT @sallisbeth: cinque figure femminili is the new "una donna al #Quirinale"',
#  88: 'RT @c_briguglio: CÔÇÖ├¿ chi spinge #Letta alla ÔÇ£chiamata allÔÇÖemergenza democratica, la denuncia del Caimano che vuole diventare capo dei magisÔÇª',
#  89: "RT @VanessaEffect: Era l'uno gennaio e su @DomaniGiornale scrivevamo che il #PD non si rassegna. E si sa, chi non si rassegna a Capodanno..ÔÇª",
#  90: 'RT @radioanchio: Tra poco #Radioanchio con @giorgiozanchini #12gennaio @Radio1Rai\n7:30 Gestione #pandemia in #europa: Eva Polverino, @giorgÔÇª',
#  91: 'Comunque non ├¿ vero che il segretario di un partito non ├¿ mai stato candidato al #Quirinale.\nLo fu #Spadolini',
#  92: 'Il fatto che al #Quirinale non sia mai andato un capo di un partito non significa che questo sia vietato dalla #Costituzione \n#Berlusconi',
#  93: 'RT @dukana2: #Travaglio: ÔÇ£No di #Draghi a domande su #Quirinale? Roba da Corea del Nord. Avrebbe fatto meglio a non fare la conferenza stamÔÇª',
#  94: '#Quirinale - Grandi elettori toscani, la Lega non cede il posto https://t.co/wHfZUVkAZx via @qn_lanazione',
#  95: 'ma mi pare proprio il minimo \n\n#noQUIRISILVIO #Quirinale #Berlusconi #Conte #Letta #pd #M5S https://t.co/fOr0OlukUl',
#  96: 'RT @XMERIDIO78: Il Segnale del delirio di Onnipotenza.\n#Draghidimettiti \n#DRAGHIVATTENEINGALERA \n#Quirinale #Bassetti #RenziFaiSchifo httpsÔÇª',
#  97: "Negli ultimi 6 mesi abbiamo perso uomini giusti,di valore, il dott. @GinoStrada @DavidSassoli \nUomini perbene,capaci, uomini di cuore e grande forza morale. \nNon mi rassegno al pensiero di un farabutto al #Quirinale e dei suoi scagnozzi al potere. \nL'umanit├á deve vincere. Sempre",
#  98: 'RT @radioanchio: Tra poco #Radioanchio con @giorgiozanchini #12gennaio @Radio1Rai\n7:30 Gestione #pandemia in #europa: Eva Polverino, @giorgÔÇª',
#  99: '#Letta non ├¿ in grado di porre condizioni per il #Quirinale, tanto meno su #Berlusconi. Se ne faccia una ragione.',
#  100: '#Quirinale ventuno votazioni per eleggere Saragat. \n#lasceltadelpresudente\n@IlMattinoFoggia \n#12gennaio #PresidenteDellaRepubblica https://t.co/GapzRAS8lV',
#  101: 'RT @Barbapapoo: D\'Alema non sarebbe male come giudice del Talent Show " Chi vuol essere Presidente della Repubblica"\n\n#Quirinale https://t.ÔÇª',
#  102: 'RT @Storace: #CONFERENZASTAMPA #Draghi #Quirinale https://t.co/L6BqrhGd0g',
#  103: 'RT @maurobiani: #PresidenteDellaRepubblica #Quirinale #Covid \nCorsa.\nOggi su @repubblica https://t.co/wXMlZQLaoo',
#  104: '#M5s, assemblea dei deputati sul #Quirinale: ÔÇ£Dare pieno mandato a #ConteÔÇØ. Ma anche a Montecitorio cÔÇÖ├¿ chi chiede il #Mattarella-bis https://t.co/TzGW4p0jyh',
#  105: '#Quirinale, scintille nelle Regioni ┬ásui delegati. #Pd beffato in #Lombardia https://t.co/TpcAY9Gdub',
#  106: '#Quirinale #Salvini: ┬½#Berlusconi adesso sciolga la riserva┬╗. Ed evoca un governo con i leader politici https://t.co/gLWQYvRkDH',
#  107: 'RT @maurobiani: #PresidenteDellaRepubblica #Quirinale #Covid \nCorsa.\nOggi su @repubblica https://t.co/wXMlZQLaoo',
#  108: 'RT @maurobiani: #PresidenteDellaRepubblica #Quirinale #Covid \nCorsa.\nOggi su @repubblica https://t.co/wXMlZQLaoo',
#  109: '#Quirinale, il piano segreto di #Pd e #M5S per il #Mattarella bis https://t.co/nvSKNBRlix',
#  110: 'RT @maurobiani: #PresidenteDellaRepubblica #Quirinale #Covid \nCorsa.\nOggi su @repubblica https://t.co/wXMlZQLaoo',
#  111: 'RT @LaNotiziaTweet: Draghi sogna il #Quirinale. Ma a Palazzo Chigi ha fallito quasi tutto. A partire da Recovery plan e campagna vaccinale.ÔÇª',
#  112: 'RT @ilfaccendiere_: Voci sempre pi├╣ fitte tra i cronisti parlamentari: "Almeno #Conte le domande se le faceva fare".                      #ÔÇª',
#  113: '#Quirinale #Letta: ┬½#Mattarella bis? Sarebbe il massimo┬╗. Sbarramento anti-#Berlusconi https://t.co/74SGb2Z6wE',
#  114: 'RT @LaNotiziaTweet: Draghi sogna il #Quirinale. Ma a Palazzo Chigi ha fallito quasi tutto. A partire da Recovery plan e campagna vaccinale.ÔÇª',
#  115: 'RT @ManLanTuit: #Letta a #DiMaterd├¼ bolla come "improbabile" \'maggioranza Ursula\'.\n#Salvini a #portaaporta esclude fuga #Lega da #Governo.ÔÇª',
#  116: 'RT @Libero_official: #MarioDraghi per traghettare il Paese fuori dalla pandemia potrebbe sfilarsi dalla corsa al #Quirinale e spingere perÔÇª',
#  117: 'RT @dukana2: #Travaglio: ÔÇ£No di #Draghi a domande su #Quirinale? Roba da Corea del Nord. Avrebbe fatto meglio a non fare la conferenza stamÔÇª',
#  118: 'RT @c_briguglio: CÔÇÖ├¿ chi spinge #Letta alla ÔÇ£chiamata allÔÇÖemergenza democratica, la denuncia del Caimano che vuole diventare capo dei magisÔÇª',
#  119: 'RT @dukana2: #Travaglio: ÔÇ£No di #Draghi a domande su #Quirinale? Roba da Corea del Nord. Avrebbe fatto meglio a non fare la conferenza stamÔÇª',
#  120: 'RT @maurobiani: #PresidenteDellaRepubblica #Quirinale #Covid \nCorsa.\nOggi su @repubblica https://t.co/wXMlZQLaoo',
#  121: 'RT @malgradotutto: ÔÇ£Non esiste la storia muta. Per quanto le diano fuoco, per quanto la frantumino, per quanto la falsifichino, la storia uÔÇª',
#  122: 'Il Cav. armato sul Quirinale. A Villa Grande si fanno i conti Salvini sbuffa -  #armato #Quirinale. #Villa #Grande  https://t.co/fRU02ArzQX',
#  123: 'RT @CosoSono: #noQUIRISILVIO \xadƒö┤\n\nCosa si fa per danaro?\n\nAnche eleggere un pregiudicato al #Quirinale \xadƒñ¼',
#  124: '#noQUIRISILVIO \xadƒö┤\n\nCosa si fa per danaro?\n\nAnche eleggere un pregiudicato al #Quirinale \xadƒñ¼ https://t.co/3uUJEJFDl5',
#  125: 'RT @maurobiani: #PresidenteDellaRepubblica #Quirinale #Covid \nCorsa.\nOggi su @repubblica https://t.co/wXMlZQLaoo',
#  126: "RT @AlbertoLetizia2: Dopo avere ascoltato #Letta, l'ipotesi agghiacciante di #Berlusconi al #Quirinale diventa improvvisamente realistica.",
#  127: 'RT @ilfaccendiere_: Voci sempre pi├╣ fitte tra i cronisti parlamentari: "Almeno #Conte le domande se le faceva fare".                      #ÔÇª',
#  128: '#Mattarella #Quirinale https://t.co/Y2RShLGlRE',
#  129: "RT @AlbertoLetizia2: Dopo avere ascoltato #Letta, l'ipotesi agghiacciante di #Berlusconi al #Quirinale diventa improvvisamente realistica.",
#  130: 'RT @ilfaccendiere_: Voci sempre pi├╣ fitte tra i cronisti parlamentari: "Almeno #Conte le domande se le faceva fare".                      #ÔÇª',
#  131: '#Quirinale, #Sorgi su #LaStampa attacca #Berlusconi e avverte: "Occhio alle torbide manovre sull\'elezione del presidente"  https://t.co/5M1CXTZTxi https://t.co/aKZyzjOCGQ',
#  132: 'RT @dukana2: #Travaglio: ÔÇ£No di #Draghi a domande su #Quirinale? Roba da Corea del Nord. Avrebbe fatto meglio a non fare la conferenza stamÔÇª',
#  133: 'RT @lucianoghelfi: #Salvini: #Amato non ├¿ nel parterre che ho in testa per il #Quirinale. Non forzerei #Mattarella a fare quel che non vuolÔÇª',
#  134: 'RT @CarlaGommy: #Quirinale\nNessun #evasore amico di evasori pu├▓ aspirare a ricoprire la massima carica dello Stato. ├ê un dato di fatto.\n#noÔÇª',
#  135: 'RT @malgradotutto: ÔÇ£Non esiste la storia muta. Per quanto le diano fuoco, per quanto la frantumino, per quanto la falsifichino, la storia uÔÇª',
#  136: 'RT @radioanchio: Tra poco #Radioanchio con @giorgiozanchini #12gennaio @Radio1Rai\n7:30 Gestione #pandemia in #europa: Eva Polverino, @giorgÔÇª',
#  137: 'RT @malgradotutto: ÔÇ£Non esiste la storia muta. Per quanto le diano fuoco, per quanto la frantumino, per quanto la falsifichino, la storia uÔÇª',
#  138: 'RT @Lombard5stelle: #Quirinale @dariovioli: "LÔÇÖipotesi che io possa votare Berlusconi non ├¿ semplicemente ridicola fantapolitica, ma unÔÇÖoffÔÇª',
#  139: 'RT @dukana2: #Travaglio: ÔÇ£No di #Draghi a domande su #Quirinale? Roba da Corea del Nord. Avrebbe fatto meglio a non fare la conferenza stamÔÇª',
#  140: 'RT @maurobiani: #PresidenteDellaRepubblica #Quirinale #Covid \nCorsa.\nOggi su @repubblica https://t.co/wXMlZQLaoo',
#  141: '#Travaglio: ÔÇ£No di #Draghi a domande su #Quirinale? Roba da Corea del Nord. Avrebbe fatto meglio a non fare la conferenza stampaÔÇØ.  https://t.co/v75Iv9zyTf',
#  142: 'Tra poco #Radioanchio con @giorgiozanchini #12gennaio @Radio1Rai\n7:30 Gestione #pandemia in #europa: Eva Polverino, @giorgiogilestro\n8:30 #politica e #quirinale:@crippa5stelle @EnricoBorghi1 @mandelli_andrea @MolinariRik\n9:05 Caso #Djokovic:@AdrianoPanatta @giorgiamecca https://t.co/WG9sOYIpre',
#  143: 'RT @PSchioppa: Con il 50% dei delegati regionali scelti a grandi elettori per il #Quirinale viste le appartenenze, mai come stiamo facendoÔÇª',
#  144: 'Le grand jeu du #Quirinale. #Berlusconi y croit mais Salvini &amp; Meloni cherchent des alternatives. #MarioDraghi reste le plus qualifi├® de tous. PD &amp; M5S travaillent ├á un maintien de Sergio Mattarella malgr├® le refus du Pr├®sident sortant. https://t.co/lPdMYubfQm',
#  145: 'RT @Apndp: Ma i conduttori #tv (di una qualsiasi tv) contro #Draghi perch├¿ si ├¿ rifiutato di parlare di #quirinale son gli stessi che concoÔÇª',
#  146: 'RT @lucianoghelfi: #Letta: se il centrodestra davvero presentasse #Berlusconi per il #Quirinale non escludo che il #PD rimanga fuori dallÔÇÖaÔÇª',
#  147: "RT @AlbertoLetizia2: Dopo avere ascoltato #Letta, l'ipotesi agghiacciante di #Berlusconi al #Quirinale diventa improvvisamente realistica.",
#  148: 'RT @malgradotutto: ÔÇ£Non esiste la storia muta. Per quanto le diano fuoco, per quanto la frantumino, per quanto la falsifichino, la storia uÔÇª',
#  149: 'Voi cazzeggiate sui social e intanto @berlusconi va a caccia di voti #Quirinale',
#  150: 'RT @maurobiani: #PresidenteDellaRepubblica #Quirinale #Covid \nCorsa.\nOggi su @repubblica https://t.co/wXMlZQLaoo',
#  151: 'RT @valy_s: A #Crisanti viene chiesto un parere su #Draghi e #Quirinale: \nÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á dÔÇª',
#  152: 'RT @DinoGiarrusso: Immaginatevi se @GiuseppeConteIT fosse andato in #CONFERENZASTAMPA con tre giorni di ritardo, escludendo un quotidiano eÔÇª',
#  153: 'RT @maurobiani: #PresidenteDellaRepubblica #Quirinale #Covid \nCorsa.\nOggi su @repubblica https://t.co/wXMlZQLaoo',
#  154: 'RT @fuskiko: Se la notizia ├¿ vera. Domani alla cara avvocatessa, una querela non gliela toglie nessuno. #quirinale chiediamo scuse imm├®diatÔÇª',
#  155: '#Juorno #Quirinale: tensione in #assemblea #M5s su indicazioni senatori\nhttps://t.co/oy2yViWM3T',
#  156: '#Juorno #Quirinale: tensione in #assemblea #M5s su indicazioni senatori\nhttps://t.co/S6fyAg8DrP',
#  157: 'RT @lucianoghelfi: #Letta: se il centrodestra davvero presentasse #Berlusconi per il #Quirinale non escludo che il #PD rimanga fuori dallÔÇÖaÔÇª',
#  158: 'RT @Lombard5stelle: #Quirinale @dariovioli: "LÔÇÖipotesi che io possa votare Berlusconi non ├¿ semplicemente ridicola fantapolitica, ma unÔÇÖoffÔÇª',
#  159: 'RT @maurobiani: #PresidenteDellaRepubblica #Quirinale #Covid \nCorsa.\nOggi su @repubblica https://t.co/wXMlZQLaoo',
#  160: 'Quirinale Dario Violi tra i delegati regionali: ÔÇ£Non voter├▓ BerlusconiÔÇØ -  #Quirinale #Dario #Violi #delegati  https://t.co/9QtXayYi4C',
#  161: "RT @AlbertoLetizia2: Dopo avere ascoltato #Letta, l'ipotesi agghiacciante di #Berlusconi al #Quirinale diventa improvvisamente realistica.",
#  162: 'RT @Apndp: Ma i conduttori #tv (di una qualsiasi tv) contro #Draghi perch├¿ si ├¿ rifiutato di parlare di #quirinale son gli stessi che concoÔÇª',
#  163: 'RT @Lombard5stelle: #Quirinale @dariovioli: "LÔÇÖipotesi che io possa votare Berlusconi non ├¿ semplicemente ridicola fantapolitica, ma unÔÇÖoffÔÇª',
#  164: 'RT @DinoGiarrusso: Immaginatevi se @GiuseppeConteIT fosse andato in #CONFERENZASTAMPA con tre giorni di ritardo, escludendo un quotidiano eÔÇª',
#  165: 'Sto cercando la procedura con cui ci si candida al #quirinale (o si rifiutano "candidature") nella costituzione italiana ma non la trovo.',
#  166: 'RT @sabrina_qwerty: Tra questi NON POLITICI chi sceglieresti come Presidente della Repubblica ? #fantasia #Quirinale',
#  167: 'RT @Storace: #CONFERENZASTAMPA #Draghi #Quirinale https://t.co/L6BqrhGd0g',
#  168: 'STUPRANDO IL #QUIRINALE, IL PEDOFILO STRAGISTA #SILVIOBERLUSCONI E LA LESBICA NAZISTA #MARINABERLUSCONI VOGLION FAR TORNARE I METODI KILLER DEI GOVERNI 2001/2006 E 2008/2011 (QUANDO L\'ASSASSINO SILVIO BERLUSCONI ORDINAVA "DI DISARTICOLARE A MORTE CHI NON LO LECCAVA")! PAURA ZERO! https://t.co/RhYD5vJtRZ',
#  169: 'RT @you_trend: #Quirinale: Abruzzo, Liguria, Lombardia e Umbria hanno gi├á eletto i rispettivi delegati in vista del 24 gennaio. Su 58 delegÔÇª',
#  170: 'Quirinale Letta: ÔÇ£Mattarella bis sarebbe il massimoÔÇØ - #Quirinale #Letta: #ÔÇ£Mattarella https://t.co/pXypIx3LX5 https://t.co/XPsI5xOuFw',
#  171: "RT @IL_IGNORANTE: TROPPO REPENTINO\nquesto cambio di narrazione. Che c'entri il Quirinale da sistemare come vuole Zio Bill?\n@Musso___ @fdragÔÇª",
#  172: "RT @AlbertoLetizia2: Dopo avere ascoltato #Letta, l'ipotesi agghiacciante di #Berlusconi al #Quirinale diventa improvvisamente realistica.",
#  173: 'KILLERS #MARINABERLUSCONI &amp; #SILVIOBERLUSCONI ARE ON TRIALS/INVESTIGATIONS X THEIR MURDER OF #IMANEFADIL, X CORRUPTING WITNESSES, X MAFIA Ôé¼ LAUNDERING DONE TO SELL #ACMILAN, X BUTCHERING HEROES FALCONE &amp; BORSELLINO! THEREFORE WANT TO SODOMIZE #QUIRINALE TO BURY JUSTICE! IN JAIL! https://t.co/pFc3UP0ely',
#  174: 'RT @LaNotiziaTweet: Il Paese ├¿ in piena emergenza Covid ma per #Draghi e #Berlusconi lÔÇÖunico pensiero sono i giochi per il #Quirinale. UltiÔÇª',
#  175: 'RT @ilfaccendiere_: Voci sempre pi├╣ fitte tra i cronisti parlamentari: "Almeno #Conte le domande se le faceva fare".                      #ÔÇª',
#  176: 'RT @DinoGiarrusso: Immaginatevi se @GiuseppeConteIT fosse andato in #CONFERENZASTAMPA con tre giorni di ritardo, escludendo un quotidiano eÔÇª',
#  177: 'RT @catirafaella: Comunque finir├á questo Romanzo #Quirinale, nessuno mi toglier├á dalla testa che #DavidSassoli sarebbe stato un grande PresÔÇª',
#  178: "RT @AlbertoLetizia2: Dopo avere ascoltato #Letta, l'ipotesi agghiacciante di #Berlusconi al #Quirinale diventa improvvisamente realistica.",
#  179: 'Come si chiama il problema di quelli che danno #burioni come possibile al #Quirinale ?',
#  180: 'RT @Apndp: Ma i conduttori #tv (di una qualsiasi tv) contro #Draghi perch├¿ si ├¿ rifiutato di parlare di #quirinale son gli stessi che concoÔÇª',
#  181: 'RT @fuskiko: Se la notizia ├¿ vera. Domani alla cara avvocatessa, una querela non gliela toglie nessuno. #quirinale chiediamo scuse imm├®diatÔÇª',
#  182: 'RT @LanfrancoPalazz: Berlusconi a #Roma #Quirinale @RadioRadicale con @gasparripdl #opencamera @FI_NewSs @SenatoStampa #opensenato https://ÔÇª',
#  183: 'RT @Apndp: Ma i conduttori #tv (di una qualsiasi tv) contro #Draghi perch├¿ si ├¿ rifiutato di parlare di #quirinale son gli stessi che concoÔÇª',
#  184: 'RT @Apndp: Ma i conduttori #tv (di una qualsiasi tv) contro #Draghi perch├¿ si ├¿ rifiutato di parlare di #quirinale son gli stessi che concoÔÇª',
#  185: 'RT @dariosci1: Questi ultimi dieci giorni credo siano stati cruciali per Governo, Draghi e Quirinale.\nCovid, contagi, provvedimenti (scuolaÔÇª',
#  186: 'RT @fuskiko: Se la notizia ├¿ vera. Domani alla cara avvocatessa, una querela non gliela toglie nessuno. #quirinale chiediamo scuse imm├®diatÔÇª',
#  187: 'RT @Lombard5stelle: #Quirinale @dariovioli: "LÔÇÖipotesi che io possa votare Berlusconi non ├¿ semplicemente ridicola fantapolitica, ma unÔÇÖoffÔÇª',
#  188: 'Se la notizia ├¿ vera. Domani alla cara avvocatessa, una querela non gliela toglie nessuno. #quirinale chiediamo scuse imm├®diate e ritiro di questa affermazione #alessiamorani, #poliziapostale https://t.co/va7i9hNMjM',
#  189: 'RT @ManLanTuit: #Letta a #DiMaterd├¼ bolla come "improbabile" \'maggioranza Ursula\'.\n#Salvini a #portaaporta esclude fuga #Lega da #Governo.ÔÇª',
#  190: 'RT @ilfaccendiere_: Voci sempre pi├╣ fitte tra i cronisti parlamentari: "Almeno #Conte le domande se le faceva fare".                      #ÔÇª',
#  191: '2001/2006. A CHIGI, L\'ASSASSINO #SILVIOBERLUSCONI! INCITATO DALLA KILLER #MARINABERLUSCONI, FA UCCIDERE "VIA DISARTICOLAZIONI TRAUMATICHE". 2008/2011. A CHIGI LO STRAGISTA #BERLUSCONI, ESPLODON GLI OMICIDI DI STATO (#ALDROVANDI, #CUCCHI) SE ANDR├ü AL #QUIRINALE, UCCIDER├ü MIGLIAIA! https://t.co/T3yzfpZGDD',
#  192: 'RT @Lombard5stelle: #Quirinale @dariovioli: "LÔÇÖipotesi che io possa votare Berlusconi non ├¿ semplicemente ridicola fantapolitica, ma unÔÇÖoffÔÇª',
#  193: 'RT @DinoGiarrusso: Immaginatevi se @GiuseppeConteIT fosse andato in #CONFERENZASTAMPA con tre giorni di ritardo, escludendo un quotidiano eÔÇª',
#  194: 'ÔÇ£Non esiste la storia muta. Per quanto le diano fuoco, per quanto la frantumino, per quanto la falsifichino, la storia umana si rifiuta di tacereÔÇØ\n[#EdoardoGaleano] #12gennaio\n\n #Falcone #Borsellino #Quirinale #Berlusconi https://t.co/AckXTmHV0S',
#  195: "RT @AlbertoLetizia2: Dopo avere ascoltato #Letta, l'ipotesi agghiacciante di #Berlusconi al #Quirinale diventa improvvisamente realistica.",
#  196: 'dai che con un piccolo sforzo ce la fate anche per il #quirinale.\n\n#unadonna #Sanremo2022 https://t.co/4PHvSnePmF',
#  197: 'Dice #Berlusconi: "Se va #Draghi al #Quirinale si va al voto".\nProbabilmente #Mattarella sar├á costretto a disfare i bagagli e fermarsi per altri due anni al Quirinale, tanto ormai lo strappo alla Costituzione c\'├¿ stato, chi si preoccupa pi├╣?.',
#  198: '#Letta a #DiMaterd├¼ bolla come "improbabile" \'maggioranza Ursula\'.\n#Salvini a #portaaporta esclude fuga #Lega da #Governo.\nLetta usa formula "patto di #governo", Salvini "natura del #governo" \nIn disaccordo su #Quirinale".\nSintonia sul dopo. https://t.co/TMP3SsDP2e',
#  199: 'RT @dariosci1: Questi ultimi dieci giorni credo siano stati cruciali per Governo, Draghi e Quirinale.\nCovid, contagi, provvedimenti (scuolaÔÇª',
#  200: "E gi├á, la chiave dell'enigma ├¿ palazzo Chigi. \n#quirinale #PresidenteDellaRepubblica \n#PNRR \n#dimartedi",
#  201: 'Questi ultimi dieci giorni credo siano stati cruciali per Governo, Draghi e Quirinale.\nCovid, contagi, provvedimenti (scuola, trasporti, ospedali) non pervenuti, lotte nella maggioranza che riesplodono come i contagi.\nSar├á dura la scelta per il #Quirinale\n #lineanotte',
#  202: 'Diario Quirinale.6: Franco Frattini, lÔÇÖasso nella manica del centrodestra https://t.co/ntxQ2yM6Aq via @il_mio_giornale #Quirinale',
#  203: '#Draghi ieri ha arroccato ma oggi ├¿ partito il riposizionamento di stampa tigg├¼ virologi &amp; co.. LÔÇÖex re Mida ormai epigono di Giuseppi cambier├á registro solo dopo 24, se da #quirinale o #chigi vedremo. #DraghiVattene #speranzadimettiti',
#  204: 'RT @Apndp: Ma i conduttori #tv (di una qualsiasi tv) contro #Draghi perch├¿ si ├¿ rifiutato di parlare di #quirinale son gli stessi che concoÔÇª',
#  205: 'eccole 1 su 2 #italiani che ti trovi per strada no le ne frega niente del #Quirinale #Presidentielle2022 #PresidenteDellaRepubblica #Presidente in #Italia #Italy #Italie #Italien #Italian #italiano #italiana https://t.co/kdBl0zBudT',
#  206: 'RT @DinoGiarrusso: Immaginatevi se @GiuseppeConteIT fosse andato in #CONFERENZASTAMPA con tre giorni di ritardo, escludendo un quotidiano eÔÇª',
#  207: '@ClaraMutsc ma hai visto che al 51% no le ne frega niente in #Italia del tema #Quirinale',
#  208: 'Il lascito politico di #Sassoli, la Spagna che declassa #Covid da emergenza a influenza, i piani per il #Quirinale. La puntata di stasera di ÔÇ£├ê gi├á domaniÔÇØ, la rassegna stampa di Rai News @RaiNews Ô×í´©Å https://t.co/5C7uzlZp9y https://t.co/4YmiNgOTNh',
#  209: 'Ci spostiamo nella vicenda del #Quirinale #Floris #Dimarted├¼',
#  210: 'Berlusconi a #Roma #Quirinale @RadioRadicale con @gasparripdl #opencamera @FI_NewSs @SenatoStampa #opensenato https://t.co/GgvfIp01Kk',
#  211: 'RT @ilfaccendiere_: Voci sempre pi├╣ fitte tra i cronisti parlamentari: "Almeno #Conte le domande se le faceva fare".                      #ÔÇª',
#  212: 'RT @BlackOutTotale: Ma si!!!! Eleggiamolo PRESIDENTE DELLA REPUBBLICA questo miserabile buffone!!!!\n#quirinale #berlusconi https://t.co/7GYÔÇª',
#  213: '@GiulioMarini2 @Palazzo_Chigi Comunque articolo apologetico del grande decisore che farebbe benissimo ovunque. Mentre invece sta distruggendo il paese.  Divisivo come PdC, non oso immaginarlo al #Quirinale',
#  214: 'Pera, Frattini, Casellati, Moratti, Amato, Cartabia. Il "ricambio dopo anni di Presidenti con cultura di sinistra" sarebbe il declassamento del #Quirinale. Penosi. A sto punto sia Draghi.\n#Salvini #portaaporta',
#  215: 'RT @BlackOutTotale: Ma si!!!! Eleggiamolo PRESIDENTE DELLA REPUBBLICA questo miserabile buffone!!!!\n#quirinale #berlusconi https://t.co/7GYÔÇª',
#  216: 'RT @Lombard5stelle: #Quirinale @dariovioli: "LÔÇÖipotesi che io possa votare Berlusconi non ├¿ semplicemente ridicola fantapolitica, ma unÔÇÖoffÔÇª',
#  217: "RT @m_t_h_MWarrior: @La7tv E che c'├¿ di maleÔüë´©Å #PD e #ForzaItalia non sono forse alleati di #governoÔØô\xadƒÿü\nSe #Berlusconi chiede appoggio ├¿ perÔÇª",
#  218: '#Quirinale lo scontro sul delegato della #Lombardia il centrodestra vota per il candidato #M5s @RadioRadicale  con @rampi https://t.co/9lkXnA59OB',
#  219: 'RT @Apndp: Ma i conduttori #tv (di una qualsiasi tv) contro #Draghi perch├¿ si ├¿ rifiutato di parlare di #quirinale son gli stessi che concoÔÇª',
#  220: "@La7tv E che c'├¿ di maleÔüë´©Å #PD e #ForzaItalia non sono forse alleati di #governoÔØô\xadƒÿü\nSe #Berlusconi chiede appoggio ├¿ perch├® sa che pu├▓ ottenerlo\n\n#Quirinale",
#  221: 'RT @GerriLiu5: @nonsonpago1 @maurobiani @espressonline @BlobRai3 #Quirinale',
#  222: 'RT @plpetrillo: Sottoscrivo il pensiero di @ClementiF La permanente cultura del rinvio, tipica del nostro paese, non permei anche il voto pÔÇª',
#  223: 'RT @tempoweb: Il ritratto di Pietrangelo #Buttafuoco: #Draghi ├¿ il morto che insegna a piangere #quirinale #governo #rete4 #staseraitalia #ÔÇª',
#  224: '#PresidenteDellaRepubblica #Quirinale #Covid_19 @maurobiani https://t.co/tNmhByV4vo',
#  225: "ci vuole Berlusconi al #quirinale \nSarebbe l'ultimo tassello che manca alla distruzione! E io voglio godermela in diretta  #lounge \n\nhttps://t.co/TS7pmCdgnk",
#  226: '"Al #Quirinale candidato di #centrodestra di alto profilo" dice #salvini e dal cilindro per l\'ennesima volta tira fuori il nome di #berlusconi.\nE questo sarebbe il politico di "alto profilo"?\nChe spettacolo!\n#mamifacciailpiacere\n#portaaporta\n#noquirisilvio',
#  227: '@nonsonpago1 @maurobiani @espressonline @BlobRai3 #Quirinale',
#  228: "#dimartedi al 50% degli #italiani no le ne frega niente del #Quirinale #PresidenteDellaRepubblica #Presidente alla faccia della #democrazia e dopo parliamo si serve la #scuola aperte e perche c'├¿ il #supergreenpass #megagreenpass #greenpass senza se e senza ma in #Italia #Italy",
#  229: 'RT @nonsonpago1: @maurobiani: #taglioalto #PresidenteDellaRepubblica #Quirinale #Berlusconi \nScavare il baratro.\nQuesta settimana su @espreÔÇª',
#  230: '@is_amazon @jokervilma @SonoStefanoIT @IlConteIT @Gio2020Gio @NapolitanoIda @giuno55 @APatrignan @m_spagna @IdaNapolitano5 @Fabrix_l3ill @luca_bottazzi @ferrandomau @ApriGli2occhi @ANTEO17 @AntonioDiBari85 @Viv_Dany @gladiatoremassi @GianniMagini @primaopoitorna Parentesi: #Draghi Presidente del Consiglio piace a tutti ...\n====\n#M5S #Conte #Quirinale https://t.co/AmxXsmaa2E',
#  231: 'RT @ilfaccendiere_: Voci sempre pi├╣ fitte tra i cronisti parlamentari: "Almeno #Conte le domande se le faceva fare".                      #ÔÇª',
#  232: 'RT @Libero_official: Il #Pd fa credere a #MatteoSalvini di poter scegliere il prossimo Capo dello Stato: una trappola, i due tavoli del Pd.ÔÇª',
#  233: "@ierogamos @GiorgiaMeloni @Quirinale La #Meloni in questa fase non pu├▓ fare diversamente ben sapendo che tanto #Berlusconi non avr├á mai i voti necessari! Hai letto l'intervista a #UffPost di Urbani? Consiglia al Cav di ritirarsi dalla corsa al #Quirinale",
#  234: 'Draghi, Governo e Quirinale. Rebus senza soluzione? Forse no\n ##01 #5S #ForzaItalia #GiorgiaMeloni #governo #ItaliaViva #Lega #MarioDraghi #MatteoRenzi #MatteoSalvini #Pd #Quirinale #SilvioBerlusconi\n\nhttps://t.co/RgPSqDfp6R https://t.co/3VaoWOsir5',
#  235: 'Quirinale: il nodo Berlusconi complica la trattativa. Ma Salvini evoca un governo con dentro tutti i leader -  #Quirinale: #Berlusconi #complica  https://t.co/9zRFjceVI2',
#  236: 'RT @jacopoat: Qui per ricordarvi che Berlusconi al #Quirinale non ├¿ soltanto auspicabile.\n\n├ê ineluttabile. Accettatelo, sapete tutti che doÔÇª',
#  237: "RT @IL_IGNORANTE: TROPPO REPENTINO\nquesto cambio di narrazione. Che c'entri il Quirinale da sistemare come vuole Zio Bill?\n@Musso___ @fdragÔÇª",
#  238: 'LÔÇÖintervista su @La7tv ha dato lÔÇÖidea di un @EnricoLetta molto responsabile. Non per lÔÇÖaccenno - o lÔÇÖappello? - tuttavia alla ribellione dei parlamentari di @forza_italia  allÔÇÖipotesi di #Berlusconi candidato al #Quirinale. Cos├¼ÔÇªaltro che Vietnam! #PresidenteDellaRepubblica https://t.co/O8GFzTBVFm',
#  239: '#portaaporta questo PORCO politico:"... Berlusconi ha fatto 3 volte il premier. ├ê riconosciuto a livello internazionale! La Sinistra(sic!) non pu├▓ dire che non pu├▓ andare al #Quirinale!". https://t.co/D7GSCR5bak',
#  240: 'Romanzo #Quirinale, si comincia ad entrare nel vivo: ad oggi le carte, eccetto una, sono tutte coperte. Basandosi esclusivamente su percentuali in aula, poco - pochissimo - spazio per manovre partitiche e tema bipartisan esce fuori un sol nome: Pierferdinando #Casini. #dimartedi',
#  241: "RT @IL_IGNORANTE: TROPPO REPENTINO\nquesto cambio di narrazione. Che c'entri il Quirinale da sistemare come vuole Zio Bill?\n@Musso___ @fdragÔÇª",
#  242: 'RT @ilfaccendiere_: Voci sempre pi├╣ fitte tra i cronisti parlamentari: "Almeno #Conte le domande se le faceva fare".                      #ÔÇª',
#  243: 'Primo trapiantato con il cuore di un maiale.\nOra ├¿ candidato alla presidenza della Repubblica.\n#Quirinale #PresidenteDellaRepubblica',
#  244: 'RT @tempoweb: I timori che la formazione di un nuovo governo sia impossibile e che si vada a elezioni terrorizza il M5s: ecco perch├® voglioÔÇª',
#  245: 'RT @VincePastore: Sulla candidatura di Silvio #Berlusconi al #Quirinale ha detto tutto Ornella Vanoni al @fattoquotidiano intervistata da @ÔÇª',
#  246: 'RT @mostro15119736: Cose che i giornali spagnoli scrivono e che quelli italiani non hanno il coraggio di dire.\n\nEl Palacio del #Quirinale eÔÇª',
#  247: 'So che non fotte un cazzo a nessuno, ma siccome stanno iniziando a fare sul serio, in caso di #QUIRISILVIO sto gi├á programmando un trasloco in Spagna o Portogallo. Non scherzo, sarebbe intollerabile, mi vergognerei della mia nazione #DiMartedi #cartabianca #Berlusconi #Quirinale',
#  248: "RT @AlbertoLetizia2: Dopo avere ascoltato #Letta, l'ipotesi agghiacciante di #Berlusconi al #Quirinale diventa improvvisamente realistica.",
#  249: 'M5s assemblea dei deputati sul Quirinale: ÔÇ£Dare pieno mandato a ConteÔÇØ. Ma anche a Montecitorio cÔÇÖ├¿ chi chiede il Mattarella-bis -  #assemblea #deputati #Quirinale:  https://t.co/lwbW3TywEt',
#  250: '@TommyBrain #Quirinale #dimartedi #cartabianca #Fuoridalcoro Attenzione a non passare dalla padella #Draghi alla brace #Berlusconi!!! #noQUIRISILVIO https://t.co/Ojix2NLkWr',
#  251: 'RT @TgrRaiMolise: #quirinale: ecco i #grandielettori del #Molise\nhttps://t.co/odlj36co2y',
#  252: 'Quirinale, Salvini ÔÇ£Sarebbe meglio che Draghi continuasse come premierÔÇØ ÔÇô Libero Quotidiano #quirinale #salvini #draghi #continuasse #premier #libero #quotidiano  https://t.co/CD0c2qT2o9',
#  253: 'Quirinale, Meloni ÔÇ£Draghi chiarisca se candidato o noÔÇØ ÔÇô Libero Quotidiano #quirinale #meloni #draghi #chiarisca #candidato #libero #quotidiano  https://t.co/WGK168INme',
#  254: '@sole24ore #Berlusconi ├¿ un pregiudicato per #evasionefiscale, nonch├® amico di #corrotti e #mafiosi. Altroch├® #Quirinale!',
#  255: "Non se l'aspettava? Allora dai tempi di #Enricostaisereno non ha imparato nulla. #Letta #Berlusconi #Quirinale #Draghi #Mattarella https://t.co/OnSzRlqiPZ",
#  256: '@La7tv #Mattarella ha detto di noooooooo.\n\nSiete tonti, o cosa?\n\n#Quirinale #dimartedi',
#  257: 'RT @ilfaccendiere_: Voci sempre pi├╣ fitte tra i cronisti parlamentari: "Almeno #Conte le domande se le faceva fare".                      #ÔÇª',
#  258: "#Berlusconi ha le carte in regola per aspirare al #Quirinale. Al di l├á dell'esito finale: avr├á il diritto di farlo? L'agitazione espressa da taluni a #dimartedi ├¿ pi├╣ che altro un'insofferenza alla democrazia",
#  259: 'ÔÇ£LÔÇÖuscita di ieri di #Berlusconi ├¿ Totalmente sproporzionata ÔÇ£@EnricoLetta ÔÇ£non ci crede ├¿ una pistola scarica?ÔÇØ #belpietro ÔÇ£├¿ una brutta espressione ma lÔÇÖha detta leiÔÇØreplica segretario del #pd #dimartedi @diMartedi #Quirinale',
#  260: 'RT @alberoandronico: #ALBEROANDRONICO #FOTOGRAFIA #POESIA #NARRATIVA #CORTOMETRAGGI #PITTURA #DIALETTO #VIDEO #VIDEOPOESIE https://t.co/0qkÔÇª',
#  261: 'RT @alberoandronico: #ALBEROANDRONICO #FOTOGRAFIA #POESIA #NARRATIVA #CORTOMETRAGGI #PITTURA #DIALETTO #VIDEO #VIDEOPOESIE https://t.co/0qkÔÇª',
#  262: 'RT @alberoandronico: #ALBEROANDRONICO #FOTOGRAFIA #POESIA #NARRATIVA #CORTOMETRAGGI #PITTURA #DIALETTO #VIDEO #VIDEOPOESIE https://t.co/0qkÔÇª',
#  263: 'RT @alberoandronico: #ALBEROANDRONICO #SPORT #FOTOGRAFIA #POESIA #NARRATIVA #CORTOMETRAGGI #PITTURA #DIALETTO #VIDEO #alberoandronico.net \xadƒÅåÔÇª',
#  264: 'RT @alberoandronico: #ALBEROANDRONICO #FOTOGRAFIA #POESIA #NARRATIVA #CORTOMETRAGGI #PITTURA #DIALETTO #VIDEO #VIDEOPOESIE https://t.co/0qkÔÇª',
#  265: 'Mi sembra di aver capito che #forzaitalia #legasalvini e #fratellimeloni avallando lÔÇÖassurda ipotesi del #nano al #quirinale abbiano gi├á deciso di far cadere questo governo, per ritornare nella totale anarchia.\nNon fa una piega!\xadƒæÅ\xadƒæÅ\xadƒæÅ\xadƒæÅ\xadƒæÅ',
#  266: "RT @AlbertoLetizia2: Dopo avere ascoltato #Letta, l'ipotesi agghiacciante di #Berlusconi al #Quirinale diventa improvvisamente realistica.",
#  267: 'RT @Lombard5stelle: #Quirinale @dariovioli: "LÔÇÖipotesi che io possa votare Berlusconi non ├¿ semplicemente ridicola fantapolitica, ma unÔÇÖoffÔÇª',
#  268: "Dopo avere ascoltato #Letta, l'ipotesi agghiacciante di #Berlusconi al #Quirinale diventa improvvisamente realistica.",
#  269: 'RT @diMartedi: #Letta su #Quirinale: "Il massimo sarebbe un Mattarella bis, il Parlamento deve eleggere una persona come lui. La questioneÔÇª',
#  270: 'Io al Quirinale vedrei bene uno che ├¿ fuori dalle logiche politiche e che da sempre fa mangiare anche noi. Giovanni Rana.\n#Quirinale #DraghiVattene #rana \n@GiovanniRanaNYC #PresidenteDellaRepubblica',
#  271: 'ÔÇ£ ├¿ stato chiaro ma si ├¿ fermato  tutto ÔÇ£@EnricoLetta #Quirinale #centrodestra #Berlusconi #dimartedi @diMartedi',
#  272: "RT @IL_IGNORANTE: TROPPO REPENTINO\nquesto cambio di narrazione. Che c'entri il Quirinale da sistemare come vuole Zio Bill?\n@Musso___ @fdragÔÇª",
#  273: 'RT @LaNotiziaTweet: Il Paese ├¿ in piena emergenza Covid ma per #Draghi e #Berlusconi lÔÇÖunico pensiero sono i giochi per il #Quirinale. UltiÔÇª',
#  274: 'RT @diMartedi: #Letta su #Quirinale: "Il massimo sarebbe un Mattarella bis, il Parlamento deve eleggere una persona come lui. La questioneÔÇª',
#  275: 'RT @Ghigliottina: ÔÜá´©Å #Quirinale, si fa largo il nome di #Casini, dopo il semestre bianco, si profila un settennato grigio.\n\n\xadƒôó La satira ognÔÇª',
#  276: 'Rita Borsellino sarebbe stata un perfetto Presidente della Repubblica.\n#Quirinale #TotoNomi #PdR',
#  277: '#Quirinale, il Covid sceglier├á il Presidente della Repubblica? https://t.co/l99Tm7e8mY #Travaglio https://t.co/cWfo26QQss',
#  278: 'ÔÇ£La candidatura ├¿ l├¼ ed ├¿ seria non mi sembra che sia una vicenda chiusa ÔÇØ @EnricoLetta su #Berlusconi #dimartedi #Quirinale',
#  279: '@petergomezblog @fattoquotidiano Ecco, due voti persi per la mia proposta per il #Quirinale!\nhttps://t.co/Md0eeNRQIf',
#  280: 'RT @smenichini: Non ci sar├á purtroppo alcun effetto #Sassoli sul voto per il #Quirinale, che non ├¿ un momento per la politica gentile. Per├▓ÔÇª',
#  281: 'Quirinale Letta: ÔÇ£Mattarella bis sarebbe il massimoÔÇØ -  #Quirinale #Letta: #ÔÇ£Mattarella  https://t.co/pXypIwMb5x',
#  282: 'RT @moussedisalmone: #Fuoridalcoro trasmissione di oggi mi pare pi├╣ libera delle precedenti. Mi chiedo se #Berlusconi non stia allenando laÔÇª',
#  283: 'RT @PolScorr: Avevo "un sogno"\n\nVedevo i leader politici, in balia dei problemi di partito, in fila a piagnucolare sotto casa sua\n\n#DavidSaÔÇª',
#  284: '#Fuoridalcoro trasmissione di oggi mi pare pi├╣ libera delle precedenti. Mi chiedo se #Berlusconi non stia allenando la presa in vista della battaglia per il #Quirinale.\nComunque sia un piacere seguirla',
#  285: "Era l'uno gennaio e su @DomaniGiornale scrivevamo che il #PD non si rassegna. E si sa, chi non si rassegna a Capodanno... #Mattarella #Quirinale #Letta\n#dimartedi\n https://t.co/CfGzLAPDna",
#  286: 'RT @alberoandronico: #ALBEROANDRONICO #FOTOGRAFIA #POESIA #NARRATIVA #CORTOMETRAGGI #PITTURA #DIALETTO #VIDEO #VIDEOPOESIE https://t.co/0qkÔÇª',
#  287: 'ÔÇ£Tutto mi aspettavo tranne che esser qui a discutere di #Berlusconi ÔÇ£ @EnricoLetta #Quirinale @diMartedi #dimartedi',
# ...
#  397: 'ma che cazzo si ├¿ bevuto #maurocorona? vorrebbe un piduista al #quirinale? #cartabianca',
#  398: '@M_gabanelli Una Donna come Lei ci vorrebbe al #Quirinale',
#  399: 'Sbaglier├▓ ma uno dei maggiori sponsor della #Meloni a #PalazzoChigi si sta dimostrando  #Travaglio. \n\nE francamente non capisco. \n\n#ottoemezzo #Quirinale #dimartedi #Draghi #11gennaio #11gennaio2022 https://t.co/0ZIgFdLhZ9',
#  400: 'RT @lucianoghelfi: #Salvini: #Amato non ├¿ nel parterre che ho in testa per il #Quirinale. Non forzerei #Mattarella a fare quel che non vuolÔÇª',
#  401: 'Se il Presidente della Repubblica deve essere super partes, non divisivo, rispettoso delle Istituzioni, incensurato chi meglio di Berlusconi? \nVallanzasca? \n#Quirinale #Berlusconi #noQUIRISILVIO',
#  402: 'RT @thewatcherpost: \xadƒùô Largo Chigi, 12 gennaio ore 8.45 | Torna la rassegna stampa di #TheWatcherPost condotta da @PieroTatafiore. Luci puntÔÇª',
#  403: 'RT @maurobiani: #PresidenteDellaRepubblica #Quirinale #Covid \nCorsa.\nOggi su @repubblica https://t.co/wXMlZQLaoo',
#  404: 'RT @you_trend: #Quirinale: Abruzzo, Liguria, Lombardia e Umbria hanno gi├á eletto i rispettivi delegati in vista del 24 gennaio. Su 58 delegÔÇª',
#  405: '#dimartedi Travaglio: ÔÇ£#Draghi stia al governo per tenere insieme la sua larga maggioranza invece di tentare la fuga verso il #QuirinaleÔÇØ. Non vorremo mica privarci di un cotanto salvatore della Patria? #Draghi #governodeimigliori',
#  406: 'RT @Apndp: Ma i conduttori #tv (di una qualsiasi tv) contro #Draghi perch├¿ si ├¿ rifiutato di parlare di #quirinale son gli stessi che concoÔÇª',
#  407: 'RT @La7tv: #ottoemezzo Walter #Veltroni sulla candidatura di Silvio #Berlusconi al #Quirinale: "Soprattutto questa volta, vista la situazioÔÇª',
#  408: 'Il presidente della repubblica scelto in segreto a Enna, come la mafia. Questo ├¿ il metodo. #Quirinale',
#  409: 'RT @Libero_official: "#Quirinale, elezione non rinviabile ma non deve essere per foza in presenza": #SabinoCassese ci spiega come "dribblarÔÇª',
#  410: "TROPPO REPENTINO\nquesto cambio di narrazione. Che c'entri il Quirinale da sistemare come vuole Zio Bill?\n@Musso___ @fdragoni \n#Quirinale #draghibugiardo #speranzadimettiti https://t.co/gzP8ruLJ2W",
#  411: '#dimartedi #PresidenteDellaRepubblica #governodeipeggiori #novax #nogreenpassobbligatorio\n\nNon amo il #governodeimigliori ,  ma #Travaglio che cerca di demolire ad ogni costo  #Draghi porta dritti a #Berlusconi al #Quirinale. \n\nE poi ?',
#  412: 'RT @expoitalyonline: Calenda rilancia Cartabia\n\nLa nostra proposta ├¿ la ministra Cartabia, una persona di grande qualit├á, ex presidente delÔÇª',
#  413: 'Gli uomini che servono nei momenti di crisi per il #Quirinale lancio la sua candidatura #carcarlopravettonipresidente\nhttps://t.co/oxMdXB1E3K',
#  414: 'RT @Apndp: Ma i conduttori #tv (di una qualsiasi tv) contro #Draghi perch├¿ si ├¿ rifiutato di parlare di #quirinale son gli stessi che concoÔÇª',
#  415: 'RT @catirafaella: Comunque finir├á questo Romanzo #Quirinale, nessuno mi toglier├á dalla testa che #DavidSassoli sarebbe stato un grande PresÔÇª',
#  416: 'Il Segnale del delirio di Onnipotenza.\n#Draghidimettiti \n#DRAGHIVATTENEINGALERA \n#Quirinale #Bassetti #RenziFaiSchifo https://t.co/V0Z724xbNz',
#  417: 'RT @maurobiani: #PresidenteDellaRepubblica #Quirinale #Covid \nCorsa.\nOggi su @repubblica https://t.co/wXMlZQLaoo',
#  418: 'RT @lucianoghelfi: #Salvini: #Amato non ├¿ nel parterre che ho in testa per il #Quirinale. Non forzerei #Mattarella a fare quel che non vuolÔÇª',
#  419: 'RT @valy_s: A #Crisanti viene chiesto un parere su #Draghi e #Quirinale: \nÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á dÔÇª',
#  420: 'RT @Apndp: Ma i conduttori #tv (di una qualsiasi tv) contro #Draghi perch├¿ si ├¿ rifiutato di parlare di #quirinale son gli stessi che concoÔÇª',
#  421: 'RT @Apndp: Ma i conduttori #tv (di una qualsiasi tv) contro #Draghi perch├¿ si ├¿ rifiutato di parlare di #quirinale son gli stessi che concoÔÇª',
#  422: 'Marta Cartabia Presidente della Repubblica #quirinale https://t.co/mp0GvQNX7S',
#  423: 'RT @valy_s: A #Crisanti viene chiesto un parere su #Draghi e #Quirinale: \nÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á dÔÇª',
#  424: 'RT @Libero_official: "#Quirinale, elezione non rinviabile ma non deve essere per foza in presenza": #SabinoCassese ci spiega come "dribblarÔÇª',
#  425: 'RT @maurobiani: #PresidenteDellaRepubblica #Quirinale #Covid \nCorsa.\nOggi su @repubblica https://t.co/wXMlZQLaoo',
#  426: 'RT @valy_s: A #Crisanti viene chiesto un parere su #Draghi e #Quirinale: \nÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á dÔÇª',
#  427: 'RT @Eib63: @direpuntoit ÔÇ£La sola ipotesi di Berlusconi al Quirinale offende decine di milioni di italianiÔÇØ\nAntonio Scurati #Quirinale #BerlÔÇª',
#  428: 'RT @maurobiani: #PresidenteDellaRepubblica #Quirinale #Covid \nCorsa.\nOggi su @repubblica https://t.co/wXMlZQLaoo',
#  429: 'RT @valy_s: A #Crisanti viene chiesto un parere su #Draghi e #Quirinale: \nÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á dÔÇª',
#  430: 'RT @Libero_official: #MarioDraghi per traghettare il Paese fuori dalla pandemia potrebbe sfilarsi dalla corsa al #Quirinale e spingere perÔÇª',
#  431: 'RT @DinoGiarrusso: Immaginatevi se @GiuseppeConteIT fosse andato in #CONFERENZASTAMPA con tre giorni di ritardo, escludendo un quotidiano eÔÇª',
#  432: 'RT @La7tv: #ottoemezzo Walter Veltroni sulla prossima elezione del Capo dello Stato: "Non possiamo permetterci di perdere in un colpo soloÔÇª',
#  433: 'RT @maurobiani: #PresidenteDellaRepubblica #Quirinale #Covid \nCorsa.\nOggi su @repubblica https://t.co/wXMlZQLaoo',
#  434: 'RT @valy_s: A #Crisanti viene chiesto un parere su #Draghi e #Quirinale: \nÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á dÔÇª',
#  435: 'RT @valy_s: A #Crisanti viene chiesto un parere su #Draghi e #Quirinale: \nÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á dÔÇª',
#  436: 'Concordo con @EnricoLetta, il Mattarella Bis sarebbe il massimo, ma bisogna assolutamente rispettare la volont├á del Presidente. \n#dimartedi #Quirinale',
#  437: '@direpuntoit ÔÇ£La sola ipotesi di Berlusconi al Quirinale offende decine di milioni di italianiÔÇØ\nAntonio Scurati #Quirinale #Berlusconi',
#  438: 'RT @DinoGiarrusso: Immaginatevi se @GiuseppeConteIT fosse andato in #CONFERENZASTAMPA con tre giorni di ritardo, escludendo un quotidiano eÔÇª',
#  439: 'RT @lucianoghelfi: #Salvini: #Amato non ├¿ nel parterre che ho in testa per il #Quirinale. Non forzerei #Mattarella a fare quel che non vuolÔÇª',
#  440: '#Salvini: #Amato non ├¿ nel parterre che ho in testa per il #Quirinale. Non forzerei #Mattarella a fare quel che non vuole. Serve un tavolo di tutti i leader, ma senza veti',
#  441: 'RT @valy_s: A #Crisanti viene chiesto un parere su #Draghi e #Quirinale: \nÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á dÔÇª',
#  442: '@lercionotizie #BreakingNews #Quirinale: riunione segreta del centrodestra e del centrosinistra in una sala bingo alla Bufalotta, Roma.',
#  443: 'RT @LaNotiziaTweet: Il Paese ├¿ in piena emergenza Covid ma per #Draghi e #Berlusconi lÔÇÖunico pensiero sono i giochi per il #Quirinale. UltiÔÇª',
#  444: 'RT @Libero_official: "#Quirinale, elezione non rinviabile ma non deve essere per foza in presenza": #SabinoCassese ci spiega come "dribblarÔÇª',
#  445: '#ottoemezzo Walter #Veltroni sulla candidatura di Silvio #Berlusconi al #Quirinale: "Soprattutto questa volta, vista la situazione drammatica in cui versiamo, ├® necessario trovare una persona che abbia l\'autorevolezza internazionale" https://t.co/81h4TUOs6G',
#  446: 'RT @valy_s: A #Crisanti viene chiesto un parere su #Draghi e #Quirinale: \nÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á dÔÇª',
#  447: '"#Quirinale, elezione non rinviabile ma non deve essere per foza in presenza": #SabinoCassese ci spiega come "dribblare" il #Covid  https://t.co/IWSdtwL7Rz https://t.co/m9I3PGljI9',
#  448: '#Floris 2022 anno di #Berlusconi #Quirinale',
#  449: 'La vedo difficile @EnricoLetta sul #Berlusconi #Quirinale',
#  450: '#Berlusconi ,quando era pi├╣ giovane(meno rincoglionito)vedeva #comunisti dappertutto,chiss├á cosa vedr├á ora che ├¿ candidato al #Quirinale',
#  451: 'ÔÇ£Non era abituato a esser criticato contraddetto ÔÇ£ @PButtafuoco @StaseraItalia #staseraitalia #Draghi ÔÇ£dalle non risposte  ├¿ chiaro che il pensierino al #Quirinale lo stia facendo ÔÇ£',
#  452: '#Letta a @diMartedi : Vedo difficile #Berlusconi al #Quirinale . https://t.co/TDZKlMbOOe',
#  453: 'RT @maurobiani: #PresidenteDellaRepubblica #Quirinale #Covid \nCorsa.\nOggi su @repubblica https://t.co/wXMlZQLaoo',
#  454: 'RT @Apndp: Ma i conduttori #tv (di una qualsiasi tv) contro #Draghi perch├¿ si ├¿ rifiutato di parlare di #quirinale son gli stessi che concoÔÇª',
#  455: '@RegLiguria @GiovanniToti @CuoreEconomico @ESG89_Group #Quirinale https://t.co/y2OZl16j0d',
#  456: 'Se #Berlusconi sar├áÔÇÖ eletto al #Quirinale, quasi sicuramente daraÔÇÖ lÔÇÖamnistia a tutti i suoi amici #criminali: #DellUtri, #Previti, #FedeÔÇª\n\n#vergogna !',
#  457: 'RT @carta73: Qualche giorno fa si ragionava con gli amici, discutendo di politica, speravamo di vederti salire al Colle...\nSei salito moltoÔÇª',
#  458: 'RT @tempoweb: Colloquio #Draghi-#Salvini in Senato. La spinta dalla #Lega: ÔÇ£Resti al #governo, non cÔÇÖ├¿ bisogno di confusioneÔÇØ #quirinale #1ÔÇª',
#  459: 'RT @tempoweb: Colloquio #Draghi-#Salvini in Senato. La spinta dalla #Lega: ÔÇ£Resti al #governo, non cÔÇÖ├¿ bisogno di confusioneÔÇØ #quirinale #1ÔÇª',
#  460: 'Mica vero che Draghi diventando presidente della repubblica lascerebbe Palazzo Chigi. Lo smonterebbe pezzo per pezzo per poi ricostruirselo dentro il Quirinale\n#Quirinale',
#  461: 'RT @Apndp: Ma i conduttori #tv (di una qualsiasi tv) contro #Draghi perch├¿ si ├¿ rifiutato di parlare di #quirinale son gli stessi che concoÔÇª',
#  462: 'RT @LaNotiziaTweet: Il Paese ├¿ in piena emergenza Covid ma per #Draghi e #Berlusconi lÔÇÖunico pensiero sono i giochi per il #Quirinale. UltiÔÇª',
#  463: 'RT @maurobiani: #PresidenteDellaRepubblica #Quirinale #Covid \nCorsa.\nOggi su @repubblica https://t.co/wXMlZQLaoo',
#  464: '#ottoemezzo Walter Veltroni sulla possibile elezione di Draghi al #Quirinale: "La condizione per proseguire l\'azione dell\'esecutivo ├® una condizione politica, i partiti non si devono sfilare sulla base delle proprie convenienze" https://t.co/moDDvxRtH6',
#  465: 'RT @fabrizio19651: Una minaccia obliqua che  dimostra una volta di pi├╣ che non ha le caratteristiche per fare il #PresidenteDellaRepubblicaÔÇª',
#  466: 'Colloquio #Draghi-#Salvini in Senato. La spinta dalla #Lega: ÔÇ£Resti al #governo, non cÔÇÖ├¿ bisogno di confusioneÔÇØ #quirinale #11gennaio #iltempoquotidiano  https://t.co/ueb5MLVEcT https://t.co/ZdC6TGCDht',
#  467: 'RT @ivanscalfarotto: Riflessioni.\n#Quirinale https://t.co/xLzfOv8f3O',
#  468: 'RT @LaNotiziaTweet: Draghi sogna il #Quirinale. Ma a Palazzo Chigi ha fallito quasi tutto. A partire da Recovery plan e campagna vaccinale.ÔÇª',
#  469: 'Ricordo del Primo #Presidente della Repubblica \xadƒç«\xadƒç╣ Enrico De Nicola  ÔÇªche non si comanda mai cosi bene che quando si obbedisce alla propria coscienza #Leadership #Quirinale https://t.co/sPiowjr9HL',
#  470: 'RT @Apndp: Ma i conduttori #tv (di una qualsiasi tv) contro #Draghi perch├¿ si ├¿ rifiutato di parlare di #quirinale son gli stessi che concoÔÇª',
#  471: '\xadƒæÇ\n#Quirinale #PresidenteDellaRepubblica #donnaalquirinale #toscana #siena #bohemien #radicalchic #cattocomunisti #cattocomunismo https://t.co/c5yrlqIfhe https://t.co/SxGBlkAcQT',
#  472: 'RT @DinoGiarrusso: Immaginatevi se @GiuseppeConteIT fosse andato in #CONFERENZASTAMPA con tre giorni di ritardo, escludendo un quotidiano eÔÇª',
#  473: 'RT @valy_s: A #Crisanti viene chiesto un parere su #Draghi e #Quirinale: \nÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á dÔÇª',
#  474: 'RT @ivanscalfarotto: Riflessioni.\n#Quirinale https://t.co/xLzfOv8f3O',
#  475: 'A me piacerebbe che #Draghi decidesse di levarsi dai piedi, altro che #Quirinale! #ottoemezzo',
#  476: 'RT @Apndp: Ma i conduttori #tv (di una qualsiasi tv) contro #Draghi perch├¿ si ├¿ rifiutato di parlare di #quirinale son gli stessi che concoÔÇª',
#  477: 'RT @il_vetero: Finalmente una candidatura in grado di mettere dÔÇÖaccordo tutti gli italiani e tutte le italiane!\n#CristinaPresidente Subito!ÔÇª',
#  478: 'RT @valy_s: A #Crisanti viene chiesto un parere su #Draghi e #Quirinale: \nÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á dÔÇª',
#  479: 'RT @DinoGiarrusso: Immaginatevi se @GiuseppeConteIT fosse andato in #CONFERENZASTAMPA con tre giorni di ritardo, escludendo un quotidiano eÔÇª',
#  480: 'RT @LucillaMasini: QUESITO DI GENNAIO \n\nFra avere Berlusconi Presidente della Repubblica e mangiare un chilo di mÔé¼rda, preferite il guano dÔÇª',
#  481: 'RT @DomaniGiornale: #Berlusconi ├¿ arrivato a #Roma, da dove prover├á il salto al #Quirinale: nonostante i suoi consiglieri lo abbiano cautamÔÇª',
#  482: "Il #centrodestra ├¿ diviso su #Berlusconi al #Quirinale. #Draghi resta in pole ma prende quota l'ipotesi di un bis di #Mattarella.\n\nhttps://t.co/c5kOJPGJ34",
#  483: 'RT @NicoFuccaro: Qualcuno ha capito qualcosa di quello che in iperpolitichese sta sostenendo @VeltroniWalter sul #Quirinale? (non che sia dÔÇª',
#  484: 'RT @Lombard5stelle: #Quirinale @dariovioli: "LÔÇÖipotesi che io possa votare Berlusconi non ├¿ semplicemente ridicola fantapolitica, ma unÔÇÖoffÔÇª',
#  485: 'RT @fabrizio19651: Una minaccia obliqua che  dimostra una volta di pi├╣ che non ha le caratteristiche per fare il #PresidenteDellaRepubblicaÔÇª',
#  486: 'Lo smemorato di Cologno al #Quirinale lo voglio vedere solo in una puntata di @fratellicrozza',
#  487: 'RT @S_Giacomoni: #Quirinale. Saranno le regole della #democrazia a scegliere\xadƒù│ \n\n\xadƒöÁ Sono convinto che #Berlusconi al #Colle e #Draghi al #GovÔÇª',
#  488: 'RT @valy_s: A #Crisanti viene chiesto un parere su #Draghi e #Quirinale: \nÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á dÔÇª',
#  489: 'RT @valy_s: A #Crisanti viene chiesto un parere su #Draghi e #Quirinale: \nÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á dÔÇª',
#  490: 'Quirinale la segreteria Pd decide di non decidere. La candidatura di Berlusconi angoscia Letta -  #Quirinale #segreteria #decide  https://t.co/YHC1UzasAF',
#  491: 'Canditati per il #Quirinale -1 https://t.co/grTSJWHtTY',
#  492: 'RT @valy_s: A #Crisanti viene chiesto un parere su #Draghi e #Quirinale: \nÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á dÔÇª',
#  493: 'RT @valy_s: A #Crisanti viene chiesto un parere su #Draghi e #Quirinale: \nÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á dÔÇª',
#  494: 'RT @valy_s: A #Crisanti viene chiesto un parere su #Draghi e #Quirinale: \nÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á dÔÇª',
#  495: '#Quirinale #Berlusconi #Draghi #PresidenteDellaRepubblica  https://t.co/uoCuFPo59S',
#  496: '#ottoemezzo Walter Veltroni sulla prossima elezione del Capo dello Stato: "Non possiamo permetterci di perdere in un colpo solo sia #Draghi sia #Mattarella" @VeltroniWalter #quirinale https://t.co/VL1ETJJybt',
#  497: 'A #Crisanti viene chiesto un parere su #Draghi e #Quirinale: \nÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á di gregge, che il #greenpass ci avrebbe protetto dal contagio e poi ├¿ arrivata #Omicron. Per fortuna ├¿ pi├╣ ÔÇ£leggeraÔÇØÔÇØ\n#ottoemezzo',
#  498: 'RT @AdolfoTasinato: Per il giornale inglese The Guardian in Italia non vige un sistema democratico. #Draghi #Italy #Italia #democrazia #PolÔÇª',
#  499: "#ottoemezzo #quirinale\n#Crisanti scopri l'intruso",
#  500: 'Berlusconi al #Quirinale in questo periodo storico non si pu├▓ sopportare #ottoemezzo .',
#  501: ''}

# %%
for k, v in tweets_number.items(): 
    print(k, v)
    text_i = v
    print(type(text_i))
    text_i = remove_punct(text_i)
    print(text_i)
    l = tokenize(text_i)
    print(l)
    print('--------------------------------------------------')
# Out:
# 1 RT @PSchioppa: Con il 50% dei delegati regionali scelti a grandi elettori per il #Quirinale viste le appartenenze, mai come stiamo facendoÔÇª
# <class 'str'>
# rt pschioppa con il 50 dei delegati regionali scelti a grandi elettori per il quirinale viste le appartenenze mai come stiamo facendoôçª
# ['rt', 'pschioppa', 'con', 'il', '50', 'dei', 'delegati', 'regionali', 'scelti', 'a', 'grandi', 'elettori', 'per', 'il', 'quirinale', 'viste', 'le', 'appartenenze', 'mai', 'come', 'stiamo', 'facendoôçª']
# --------------------------------------------------
# 2 RT @siamonoitv2000: Corsa al #Quirinale, speciale di #SiamoNoi alle 15.15 su @TV2000it con @giuspaterniti, @PaoloGraldi e @FrancoBechis.
#
# #ÔÇª
# <class 'str'>
# rt siamonoitv2000 corsa al quirinale speciale di siamonoi alle 1515 su tv2000it con giuspaterniti paolograldi e francobechis
#
# ôçª
# ['rt', 'siamonoitv2000', 'corsa', 'al', 'quirinale', 'speciale', 'di', 'siamonoi', 'alle', '1515', 'su', 'tv2000it', 'con', 'giuspaterniti', 'paolograldi', 'e', 'francobechis', 'ôçª']
# --------------------------------------------------
# 3 Ô×í´©Å #SiamoNoi
# ÔÅ░ 15.15
# ­ƒô║ @TV2000it
#
# #Quirinale #12gennaio #canale28 #siamonoitv2000 @FrancoBechis @giuspaterniti @PaoloGraldi @ilmessaggeroit @tempoweb @GabriFacondo https://t.co/RXCDpGCiY0
# <class 'str'>
# ô×í´©å siamonoi
# ôå░ 1515
# ­ƒô║ tv2000it
#
# quirinale 12gennaio canale28 siamonoitv2000 francobechis giuspaterniti paolograldi ilmessaggeroit tempoweb gabrifacondo httpstcorxcdpgciy0
# ['ô', 'í', 'å', 'siamonoi', 'ôå', '1515', 'ƒô', 'tv2000it', 'quirinale', '12gennaio', 'canale28', 'siamonoitv2000', 'francobechis', 'giuspaterniti', 'paolograldi', 'ilmessaggeroit', 'tempoweb', 'gabrifacondo', 'httpstcorxcdpgciy0']
# --------------------------------------------------
# 4 Dopo che per mesi #Mattarella ha detto che non ci pensava nemmeno ora ripropongono Mattarella per un secondo incarico.
# Cos├¼, tranquillamente e come se fosse la cosa pi├╣ fattibile del mondo.
# #Quirinale
# <class 'str'>
# dopo che per mesi mattarella ha detto che non ci pensava nemmeno ora ripropongono mattarella per un secondo incarico
# cos├¼ tranquillamente e come se fosse la cosa pi├╣ fattibile del mondo
# quirinale
# ['dopo', 'che', 'per', 'mesi', 'mattarella', 'ha', 'detto', 'che', 'non', 'ci', 'pensava', 'nemmeno', 'ora', 'ripropongono', 'mattarella', 'per', 'un', 'secondo', 'incarico', 'cos', '¼', 'tranquillamente', 'e', 'come', 'se', 'fosse', 'la', 'cosa', 'pi', 'fattibile', 'del', 'mondo', 'quirinale']
# --------------------------------------------------
# 5 RT @smenichini: Non ci sar├á purtroppo alcun effetto #Sassoli sul voto per il #Quirinale, che non ├¿ un momento per la politica gentile. Per├▓ÔÇª
# <class 'str'>
# rt smenichini non ci sar├á purtroppo alcun effetto sassoli sul voto per il quirinale che non ├¿ un momento per la politica gentile per├▓ôçª
# ['rt', 'smenichini', 'non', 'ci', 'sar', 'á', 'purtroppo', 'alcun', 'effetto', 'sassoli', 'sul', 'voto', 'per', 'il', 'quirinale', 'che', 'non', 'un', 'momento', 'per', 'la', 'politica', 'gentile', 'per', 'ôçª']
# --------------------------------------------------
# 6 RT @DinoGiarrusso: Immaginatevi se @GiuseppeConteIT fosse andato in #CONFERENZASTAMPA con tre giorni di ritardo, escludendo un quotidiano eÔÇª
# <class 'str'>
# rt dinogiarrusso immaginatevi se giuseppeconteit fosse andato in conferenzastampa con tre giorni di ritardo escludendo un quotidiano eôçª
# ['rt', 'dinogiarrusso', 'immaginatevi', 'se', 'giuseppeconteit', 'fosse', 'andato', 'in', 'conferenzastampa', 'con', 'tre', 'giorni', 'di', 'ritardo', 'escludendo', 'un', 'quotidiano', 'eôçª']
# --------------------------------------------------
# 7 E' fissata per le 16 di oggi pomeriggio la seduta d'Aula dell'Assemblea Regionale Siciliana che elegger├á i tre grandi elettori che dal 24 gennaio prossimo voteranno per il nuovo Presidente della Repubblica.
#  #Ars #Palermo #Quirinale
#
# https://t.co/kOTsCdHde5 https://t.co/elAayM8EYC
# <class 'str'>
# e fissata per le 16 di oggi pomeriggio la seduta daula dellassemblea regionale siciliana che elegger├á i tre grandi elettori che dal 24 gennaio prossimo voteranno per il nuovo presidente della repubblica
#  ars palermo quirinale
#
# httpstcokotscdhde5 httpstcoelaaym8eyc
# ['e', 'fissata', 'per', 'le', '16', 'di', 'oggi', 'pomeriggio', 'la', 'seduta', 'daula', 'dellassemblea', 'regionale', 'siciliana', 'che', 'elegger', 'á', 'i', 'tre', 'grandi', 'elettori', 'che', 'dal', '24', 'gennaio', 'prossimo', 'voteranno', 'per', 'il', 'nuovo', 'presidente', 'della', 'repubblica', 'ars', 'palermo', 'quirinale', 'httpstcokotscdhde5', 'httpstcoelaaym8eyc']
# --------------------------------------------------
# 8 RT @CCKKI: Dice #Berlusconi: "Se va #Draghi al #Quirinale si va al voto".
# Probabilmente #Mattarella sar├á costretto a disfare i bagagli e feÔÇª
# <class 'str'>
# rt cckki dice berlusconi se va draghi al quirinale si va al voto
# probabilmente mattarella sar├á costretto a disfare i bagagli e feôçª
# ['rt', 'cckki', 'dice', 'berlusconi', 'se', 'va', 'draghi', 'al', 'quirinale', 'si', 'va', 'al', 'voto', 'probabilmente', 'mattarella', 'sar', 'á', 'costretto', 'a', 'disfare', 'i', 'bagagli', 'e', 'feôçª']
# --------------------------------------------------
# 9 Il Corriere stila i possibili nomi per il #Quirinale, ma i vari #noQUIRISILVIO, Prodi, Casini e Cartabia mi fanno venire voglia di andare sotto la finestra di #Mattarella a piangere e gridare non ci lasciare ti prego
# <class 'str'>
# il corriere stila i possibili nomi per il quirinale ma i vari noquirisilvio prodi casini e cartabia mi fanno venire voglia di andare sotto la finestra di mattarella a piangere e gridare non ci lasciare ti prego
# ['il', 'corriere', 'stila', 'i', 'possibili', 'nomi', 'per', 'il', 'quirinale', 'ma', 'i', 'vari', 'noquirisilvio', 'prodi', 'casini', 'e', 'cartabia', 'mi', 'fanno', 'venire', 'voglia', 'di', 'andare', 'sotto', 'la', 'finestra', 'di', 'mattarella', 'a', 'piangere', 'e', 'gridare', 'non', 'ci', 'lasciare', 'ti', 'prego']
# --------------------------------------------------
# 10 RT @fattoquotidiano: #Quirinale, Cinque Stelle e Pd pensano di non scrivere nulla sulla scheda per le prime tre chiame, per poi andare sulÔÇª
# <class 'str'>
# rt fattoquotidiano quirinale cinque stelle e pd pensano di non scrivere nulla sulla scheda per le prime tre chiame per poi andare sulôçª
# ['rt', 'fattoquotidiano', 'quirinale', 'cinque', 'stelle', 'e', 'pd', 'pensano', 'di', 'non', 'scrivere', 'nulla', 'sulla', 'scheda', 'per', 'le', 'prime', 'tre', 'chiame', 'per', 'poi', 'andare', 'sulôçª']
# --------------------------------------------------
# 11 Stefano Folli su @repubblica, quello che molti cittadini pensano #Quirinale https://t.co/iaH4AUDOGT
# <class 'str'>
# stefano folli su repubblica quello che molti cittadini pensano quirinale httpstcoiah4audogt
# ['stefano', 'folli', 'su', 'repubblica', 'quello', 'che', 'molti', 'cittadini', 'pensano', 'quirinale', 'httpstcoiah4audogt']
# --------------------------------------------------
# 12 Perle di cinismo &amp; saggezza #Quirinale https://t.co/MfGj7xD0x7
# <class 'str'>
# perle di cinismo amp saggezza quirinale httpstcomfgj7xd0x7
# ['perle', 'di', 'cinismo', 'amp', 'saggezza', 'quirinale', 'httpstcomfgj7xd0x7']
# --------------------------------------------------
# 13 Di cose strane sul #totoquirinale ne ho lette parecchie, ma quella secondo cui il centrosinistra non potrebbe dire no a Letizia Moratti, "perch├® figlia di un partigiano" (La Stampa, oggi) le batte davvero tutte #quirinale #elezioniquirinale #presidentedellarepubblica
# <class 'str'>
# di cose strane sul totoquirinale ne ho lette parecchie ma quella secondo cui il centrosinistra non potrebbe dire no a letizia moratti perch├® figlia di un partigiano la stampa oggi le batte davvero tutte quirinale elezioniquirinale presidentedellarepubblica
# ['di', 'cose', 'strane', 'sul', 'totoquirinale', 'ne', 'ho', 'lette', 'parecchie', 'ma', 'quella', 'secondo', 'cui', 'il', 'centrosinistra', 'non', 'potrebbe', 'dire', 'no', 'a', 'letizia', 'moratti', 'perch', 'figlia', 'di', 'un', 'partigiano', 'la', 'stampa', 'oggi', 'le', 'batte', 'davvero', 'tutte', 'quirinale', 'elezioniquirinale', 'presidentedellarepubblica']
# --------------------------------------------------
# 14 RT @CCKKI: Dice #Berlusconi: "Se va #Draghi al #Quirinale si va al voto".
# Probabilmente #Mattarella sar├á costretto a disfare i bagagli e feÔÇª
# <class 'str'>
# rt cckki dice berlusconi se va draghi al quirinale si va al voto
# probabilmente mattarella sar├á costretto a disfare i bagagli e feôçª
# ['rt', 'cckki', 'dice', 'berlusconi', 'se', 'va', 'draghi', 'al', 'quirinale', 'si', 'va', 'al', 'voto', 'probabilmente', 'mattarella', 'sar', 'á', 'costretto', 'a', 'disfare', 'i', 'bagagli', 'e', 'feôçª']
# --------------------------------------------------
# 15 RT @Murandrea1: Il #Quirinale ├¿ perno istituzionale, geopolitico, strategico dello Stato italiano.  La forza del Quirinale ├¿ quella di poteÔÇª
# <class 'str'>
# rt murandrea1 il quirinale ├¿ perno istituzionale geopolitico strategico dello stato italiano  la forza del quirinale ├¿ quella di poteôçª
# ['rt', 'murandrea1', 'il', 'quirinale', 'perno', 'istituzionale', 'geopolitico', 'strategico', 'dello', 'stato', 'italiano', 'la', 'forza', 'del', 'quirinale', 'quella', 'di', 'poteôçª']
# --------------------------------------------------
# 16 16 arresti a #catania per pizzo e usura.
# Addio a #sassoli. Delirio #novax sui social.
# #Bassetti ÔÇ£Non pubblichiamo pi├╣ il dato dei contagiÔÇØ.
# LÔÇÖARS scegli i grandi elettori per il #quirinale.
# Pronta la task force regionale per il #PNRR
#
# #edicola #primapagina #12gennaio https://t.co/osymboONnD
# <class 'str'>
# 16 arresti a catania per pizzo e usura
# addio a sassoli delirio novax sui social
# bassetti ôç£non pubblichiamo pi├╣ il dato dei contagiôçø
# lôçöars scegli i grandi elettori per il quirinale
# pronta la task force regionale per il pnrr
#
# edicola primapagina 12gennaio httpstcoosymboonnd
# ['16', 'arresti', 'a', 'catania', 'per', 'pizzo', 'e', 'usura', 'addio', 'a', 'sassoli', 'delirio', 'novax', 'sui', 'social', 'bassetti', 'ôç', 'non', 'pubblichiamo', 'pi', 'il', 'dato', 'dei', 'contagiôçø', 'lôçöars', 'scegli', 'i', 'grandi', 'elettori', 'per', 'il', 'quirinale', 'pronta', 'la', 'task', 'force', 'regionale', 'per', 'il', 'pnrr', 'edicola', 'primapagina', '12gennaio', 'httpstcoosymboonnd']
# --------------------------------------------------
# 17 RT @DinoGiarrusso: Immaginatevi se @GiuseppeConteIT fosse andato in #CONFERENZASTAMPA con tre giorni di ritardo, escludendo un quotidiano eÔÇª
# <class 'str'>
# rt dinogiarrusso immaginatevi se giuseppeconteit fosse andato in conferenzastampa con tre giorni di ritardo escludendo un quotidiano eôçª
# ['rt', 'dinogiarrusso', 'immaginatevi', 'se', 'giuseppeconteit', 'fosse', 'andato', 'in', 'conferenzastampa', 'con', 'tre', 'giorni', 'di', 'ritardo', 'escludendo', 'un', 'quotidiano', 'eôçª']
# --------------------------------------------------
# 18 #Berlusconi ├¿ improponibile al #Quirinale. Un condannato in via definitiva e ancora sotto processo come pu├▓ diventare Presidente della Repubblica? Andr├á alla sbarra da imputato come presidente del Consiglio Superiore della Magistratura?
# <class 'str'>
# berlusconi ├¿ improponibile al quirinale un condannato in via definitiva e ancora sotto processo come pu├▓ diventare presidente della repubblica andr├á alla sbarra da imputato come presidente del consiglio superiore della magistratura
# ['berlusconi', 'improponibile', 'al', 'quirinale', 'un', 'condannato', 'in', 'via', 'definitiva', 'e', 'ancora', 'sotto', 'processo', 'come', 'pu', 'diventare', 'presidente', 'della', 'repubblica', 'andr', 'á', 'alla', 'sbarra', 'da', 'imputato', 'come', 'presidente', 'del', 'consiglio', 'superiore', 'della', 'magistratura']
# --------------------------------------------------
# 19 Quirinale, da oggi Berlusconi ha un voto in pi├╣, Toma: ┬½Per me Silvio Berlusconi sarebbe perfetto┬╗ #Quirinale #Berlusconi #toma https://t.co/GG8McaE19i via @MoliseWeb
# <class 'str'>
# quirinale da oggi berlusconi ha un voto in pi├╣ toma ┬½per me silvio berlusconi sarebbe perfetto┬╗ quirinale berlusconi toma httpstcogg8mcae19i via moliseweb
# ['quirinale', 'da', 'oggi', 'berlusconi', 'ha', 'un', 'voto', 'in', 'pi', 'toma', '½per', 'me', 'silvio', 'berlusconi', 'sarebbe', 'perfetto', 'quirinale', 'berlusconi', 'toma', 'httpstcogg8mcae19i', 'via', 'moliseweb']
# --------------------------------------------------
# 20 RT @fuskiko: Se la notizia ├¿ vera. Domani alla cara avvocatessa, una querela non gliela toglie nessuno. #quirinale chiediamo scuse imm├®diatÔÇª
# <class 'str'>
# rt fuskiko se la notizia ├¿ vera domani alla cara avvocatessa una querela non gliela toglie nessuno quirinale chiediamo scuse imm├®diatôçª
# ['rt', 'fuskiko', 'se', 'la', 'notizia', 'vera', 'domani', 'alla', 'cara', 'avvocatessa', 'una', 'querela', 'non', 'gliela', 'toglie', 'nessuno', 'quirinale', 'chiediamo', 'scuse', 'imm', 'diatôçª']
# --------------------------------------------------
# 21 RT @fattoquotidiano: #Quirinale, Cinque Stelle e Pd pensano di non scrivere nulla sulla scheda per le prime tre chiame, per poi andare sulÔÇª
# <class 'str'>
# rt fattoquotidiano quirinale cinque stelle e pd pensano di non scrivere nulla sulla scheda per le prime tre chiame per poi andare sulôçª
# ['rt', 'fattoquotidiano', 'quirinale', 'cinque', 'stelle', 'e', 'pd', 'pensano', 'di', 'non', 'scrivere', 'nulla', 'sulla', 'scheda', 'per', 'le', 'prime', 'tre', 'chiame', 'per', 'poi', 'andare', 'sulôçª']
# --------------------------------------------------
# 22 RT @CosoSono: #noQUIRISILVIO ­ƒö┤
#
# Cosa si fa per danaro?
#
# Anche eleggere un pregiudicato al #Quirinale ­ƒñ¼
# <class 'str'>
# rt cososono noquirisilvio ­ƒö┤
#
# cosa si fa per danaro
#
# anche eleggere un pregiudicato al quirinale ­ƒñ¼
# ['rt', 'cososono', 'noquirisilvio', 'ƒö', 'cosa', 'si', 'fa', 'per', 'danaro', 'anche', 'eleggere', 'un', 'pregiudicato', 'al', 'quirinale', 'ƒñ¼']
# --------------------------------------------------
# 23 RT @fuskiko: Se la notizia ├¿ vera. Domani alla cara avvocatessa, una querela non gliela toglie nessuno. #quirinale chiediamo scuse imm├®diatÔÇª
# <class 'str'>
# rt fuskiko se la notizia ├¿ vera domani alla cara avvocatessa una querela non gliela toglie nessuno quirinale chiediamo scuse imm├®diatôçª
# ['rt', 'fuskiko', 'se', 'la', 'notizia', 'vera', 'domani', 'alla', 'cara', 'avvocatessa', 'una', 'querela', 'non', 'gliela', 'toglie', 'nessuno', 'quirinale', 'chiediamo', 'scuse', 'imm', 'diatôçª']
# --------------------------------------------------
# 24 RT @CCKKI: Dice #Berlusconi: "Se va #Draghi al #Quirinale si va al voto".
# Probabilmente #Mattarella sar├á costretto a disfare i bagagli e feÔÇª
# <class 'str'>
# rt cckki dice berlusconi se va draghi al quirinale si va al voto
# probabilmente mattarella sar├á costretto a disfare i bagagli e feôçª
# ['rt', 'cckki', 'dice', 'berlusconi', 'se', 'va', 'draghi', 'al', 'quirinale', 'si', 'va', 'al', 'voto', 'probabilmente', 'mattarella', 'sar', 'á', 'costretto', 'a', 'disfare', 'i', 'bagagli', 'e', 'feôçª']
# --------------------------------------------------
# 25 RT @fuskiko: Se la notizia ├¿ vera. Domani alla cara avvocatessa, una querela non gliela toglie nessuno. #quirinale chiediamo scuse imm├®diatÔÇª
# <class 'str'>
# rt fuskiko se la notizia ├¿ vera domani alla cara avvocatessa una querela non gliela toglie nessuno quirinale chiediamo scuse imm├®diatôçª
# ['rt', 'fuskiko', 'se', 'la', 'notizia', 'vera', 'domani', 'alla', 'cara', 'avvocatessa', 'una', 'querela', 'non', 'gliela', 'toglie', 'nessuno', 'quirinale', 'chiediamo', 'scuse', 'imm', 'diatôçª']
# --------------------------------------------------
# 26 RT @fattoquotidiano: #Quirinale, Cinque Stelle e Pd pensano di non scrivere nulla sulla scheda per le prime tre chiame, per poi andare sulÔÇª
# <class 'str'>
# rt fattoquotidiano quirinale cinque stelle e pd pensano di non scrivere nulla sulla scheda per le prime tre chiame per poi andare sulôçª
# ['rt', 'fattoquotidiano', 'quirinale', 'cinque', 'stelle', 'e', 'pd', 'pensano', 'di', 'non', 'scrivere', 'nulla', 'sulla', 'scheda', 'per', 'le', 'prime', 'tre', 'chiame', 'per', 'poi', 'andare', 'sulôçª']
# --------------------------------------------------
# 27 #Quirinale, Cinque Stelle e Pd pensano di non scrivere nulla sulla scheda per le prime tre chiame, per poi andare sul ÔÇ£bisÔÇØ o su Draghi. Conte incontrer├á Salvini [di @lucadecarolis e @WandaMarra] https://t.co/WM4donPLb7
# <class 'str'>
# quirinale cinque stelle e pd pensano di non scrivere nulla sulla scheda per le prime tre chiame per poi andare sul ôç£bisôçø o su draghi conte incontrer├á salvini di lucadecarolis e wandamarra httpstcowm4donplb7
# ['quirinale', 'cinque', 'stelle', 'e', 'pd', 'pensano', 'di', 'non', 'scrivere', 'nulla', 'sulla', 'scheda', 'per', 'le', 'prime', 'tre', 'chiame', 'per', 'poi', 'andare', 'sul', 'ôç', 'bisôçø', 'o', 'su', 'draghi', 'conte', 'incontrer', 'á', 'salvini', 'di', 'lucadecarolis', 'e', 'wandamarra', 'httpstcowm4donplb7']
# --------------------------------------------------
# 28 RT @armanduplessis: Considerando anche alcune bizzarre ipotesi in campo per il #Quirinale, scrive Folli che "il Paese potrebbe aver bisognoÔÇª
# <class 'str'>
# rt armanduplessis considerando anche alcune bizzarre ipotesi in campo per il quirinale scrive folli che il paese potrebbe aver bisognoôçª
# ['rt', 'armanduplessis', 'considerando', 'anche', 'alcune', 'bizzarre', 'ipotesi', 'in', 'campo', 'per', 'il', 'quirinale', 'scrive', 'folli', 'che', 'il', 'paese', 'potrebbe', 'aver', 'bisognoôçª']
# --------------------------------------------------
# 29 RT @smenichini: Non ci sar├á purtroppo alcun effetto #Sassoli sul voto per il #Quirinale, che non ├¿ un momento per la politica gentile. Per├▓ÔÇª
# <class 'str'>
# rt smenichini non ci sar├á purtroppo alcun effetto sassoli sul voto per il quirinale che non ├¿ un momento per la politica gentile per├▓ôçª
# ['rt', 'smenichini', 'non', 'ci', 'sar', 'á', 'purtroppo', 'alcun', 'effetto', 'sassoli', 'sul', 'voto', 'per', 'il', 'quirinale', 'che', 'non', 'un', 'momento', 'per', 'la', 'politica', 'gentile', 'per', 'ôçª']
# --------------------------------------------------
# 30 RT @maurobiani: #PresidenteDellaRepubblica #Quirinale #Covid
# Corsa.
# Oggi su @repubblica https://t.co/wXMlZQLaoo
# <class 'str'>
# rt maurobiani presidentedellarepubblica quirinale covid
# corsa
# oggi su repubblica httpstcowxmlzqlaoo
# ['rt', 'maurobiani', 'presidentedellarepubblica', 'quirinale', 'covid', 'corsa', 'oggi', 'su', 'repubblica', 'httpstcowxmlzqlaoo']
# --------------------------------------------------
# 31 RT @LaNotiziaTweet: Draghi sogna il #Quirinale. Ma a Palazzo Chigi ha fallito quasi tutto. A partire da Recovery plan e campagna vaccinale.ÔÇª
# <class 'str'>
# rt lanotiziatweet draghi sogna il quirinale ma a palazzo chigi ha fallito quasi tutto a partire da recovery plan e campagna vaccinaleôçª
# ['rt', 'lanotiziatweet', 'draghi', 'sogna', 'il', 'quirinale', 'ma', 'a', 'palazzo', 'chigi', 'ha', 'fallito', 'quasi', 'tutto', 'a', 'partire', 'da', 'recovery', 'plan', 'e', 'campagna', 'vaccinaleôçª']
# --------------------------------------------------
# 32 RT @maurobiani: #PresidenteDellaRepubblica #Quirinale #Covid
# Corsa.
# Oggi su @repubblica https://t.co/wXMlZQLaoo
# <class 'str'>
# rt maurobiani presidentedellarepubblica quirinale covid
# corsa
# oggi su repubblica httpstcowxmlzqlaoo
# ['rt', 'maurobiani', 'presidentedellarepubblica', 'quirinale', 'covid', 'corsa', 'oggi', 'su', 'repubblica', 'httpstcowxmlzqlaoo']
# --------------------------------------------------
# 33 12 giorni allÔÇÖalba. #Quirinale
# <class 'str'>
# 12 giorni allôçöalba quirinale
# ['12', 'giorni', 'allôçöalba', 'quirinale']
# --------------------------------------------------
# 34 RT @LaNotiziaTweet: Draghi sogna il #Quirinale. Ma a Palazzo Chigi ha fallito quasi tutto. A partire da Recovery plan e campagna vaccinale.ÔÇª
# <class 'str'>
# rt lanotiziatweet draghi sogna il quirinale ma a palazzo chigi ha fallito quasi tutto a partire da recovery plan e campagna vaccinaleôçª
# ['rt', 'lanotiziatweet', 'draghi', 'sogna', 'il', 'quirinale', 'ma', 'a', 'palazzo', 'chigi', 'ha', 'fallito', 'quasi', 'tutto', 'a', 'partire', 'da', 'recovery', 'plan', 'e', 'campagna', 'vaccinaleôçª']
# --------------------------------------------------
# 35 RT @maurobiani: #PresidenteDellaRepubblica #Quirinale #Covid
# Corsa.
# Oggi su @repubblica https://t.co/wXMlZQLaoo
# <class 'str'>
# rt maurobiani presidentedellarepubblica quirinale covid
# corsa
# oggi su repubblica httpstcowxmlzqlaoo
# ['rt', 'maurobiani', 'presidentedellarepubblica', 'quirinale', 'covid', 'corsa', 'oggi', 'su', 'repubblica', 'httpstcowxmlzqlaoo']
# --------------------------------------------------
# 36 RT @thebrightside0: #buonoasapersi­ƒÆí
#
# La buona ed utile informazione ├¿ quella di @DavideGiac su @rtl1025 quando ricorda e sottolinea come l'ÔÇª
# <class 'str'>
# rt thebrightside0 buonoasapersi­ƒæí
#
# la buona ed utile informazione ├¿ quella di davidegiac su rtl1025 quando ricorda e sottolinea come lôçª
# ['rt', 'thebrightside0', 'buonoasapersi', 'ƒæí', 'la', 'buona', 'ed', 'utile', 'informazione', 'quella', 'di', 'davidegiac', 'su', 'rtl1025', 'quando', 'ricorda', 'e', 'sottolinea', 'come', 'lôçª']
# --------------------------------------------------
# 37 #Quirinale Un Mattarella-bis unico, estremo tentativo per un centrosinistra in empasse sul candidato anti-Berlusconi. @domanigiornale illustra il piano Pd-M5S, per @ilfoglio_it Letta non sarebbe troppo entusiasta.
#
# #primapagina  #12gennaio  #FrontPage https://t.co/w4abCq9jmQ
# <class 'str'>
# quirinale un mattarellabis unico estremo tentativo per un centrosinistra in empasse sul candidato antiberlusconi domanigiornale illustra il piano pdm5s per ilfoglioit letta non sarebbe troppo entusiasta
#
# primapagina  12gennaio  frontpage httpstcow4abcq9jmq
# ['quirinale', 'un', 'mattarellabis', 'unico', 'estremo', 'tentativo', 'per', 'un', 'centrosinistra', 'in', 'empasse', 'sul', 'candidato', 'antiberlusconi', 'domanigiornale', 'illustra', 'il', 'piano', 'pdm5s', 'per', 'ilfoglioit', 'letta', 'non', 'sarebbe', 'troppo', 'entusiasta', 'primapagina', '12gennaio', 'frontpage', 'httpstcow4abcq9jmq']
# --------------------------------------------------
# 38 @MartaGrande87 si legge sui giornali che una parte dei parlamentari 5stelle, te in primis, appoggia #casini al #Quirinale...spero siano solo fantasie della mente deviata dei giornalisti.....
# <class 'str'>
# martagrande87 si legge sui giornali che una parte dei parlamentari 5stelle te in primis appoggia casini al quirinalespero siano solo fantasie della mente deviata dei giornalisti
# ['martagrande87', 'si', 'legge', 'sui', 'giornali', 'che', 'una', 'parte', 'dei', 'parlamentari', '5stelle', 'te', 'in', 'primis', 'appoggia', 'casini', 'al', 'quirinalespero', 'siano', 'solo', 'fantasie', 'della', 'mente', 'deviata', 'dei', 'giornalisti']
# --------------------------------------------------
# 39 RT @maurobiani: #PresidenteDellaRepubblica #Quirinale #Covid
# Corsa.
# Oggi su @repubblica https://t.co/wXMlZQLaoo
# <class 'str'>
# rt maurobiani presidentedellarepubblica quirinale covid
# corsa
# oggi su repubblica httpstcowxmlzqlaoo
# ['rt', 'maurobiani', 'presidentedellarepubblica', 'quirinale', 'covid', 'corsa', 'oggi', 'su', 'repubblica', 'httpstcowxmlzqlaoo']
# --------------------------------------------------
# 40 RT @qn_lanazione: #Quirinale - Grandi elettori toscani, la Lega non cede il posto https://t.co/wHfZUVkAZx via @qn_lanazione
# <class 'str'>
# rt qnlanazione quirinale  grandi elettori toscani la lega non cede il posto httpstcowhfzuvkazx via qnlanazione
# ['rt', 'qnlanazione', 'quirinale', 'grandi', 'elettori', 'toscani', 'la', 'lega', 'non', 'cede', 'il', 'posto', 'httpstcowhfzuvkazx', 'via', 'qnlanazione']
# --------------------------------------------------
# 41 ­ƒöÁ ÔÇ£Orientarsi in questa fase non ├¿ semplice, sul #Quirinale ci sono poche certezze e molte incertezze. #Draghi vuole andare al #Colle al 100%ÔÇØ
#
# @claudiocerasa ­ƒÄÖ´©Å
# #nonstopnews
# ­ƒö┤ LIVE ÔûÂ´©Å https://t.co/iDld1y40ul https://t.co/DQK1XtDZAi
# <class 'str'>
# ­ƒöá ôç£orientarsi in questa fase non ├¿ semplice sul quirinale ci sono poche certezze e molte incertezze draghi vuole andare al colle al 100ôçø
#
# claudiocerasa ­ƒäö´©å
# nonstopnews
# ­ƒö┤ live ôûâ´©å httpstcoidld1y40ul httpstcodqk1xtdzai
# ['', 'ƒöá', 'ôç', 'orientarsi', 'in', 'questa', 'fase', 'non', 'semplice', 'sul', 'quirinale', 'ci', 'sono', 'poche', 'certezze', 'e', 'molte', 'incertezze', 'draghi', 'vuole', 'andare', 'al', 'colle', 'al', '100ôçø', 'claudiocerasa', 'ƒäö', 'å', 'nonstopnews', 'ƒö', 'live', 'ôûâ', 'å', 'httpstcoidld1y40ul', 'httpstcodqk1xtdzai']
# --------------------------------------------------
# 42 RT @CCKKI: Dice #Berlusconi: "Se va #Draghi al #Quirinale si va al voto".
# Probabilmente #Mattarella sar├á costretto a disfare i bagagli e feÔÇª
# <class 'str'>
# rt cckki dice berlusconi se va draghi al quirinale si va al voto
# probabilmente mattarella sar├á costretto a disfare i bagagli e feôçª
# ['rt', 'cckki', 'dice', 'berlusconi', 'se', 'va', 'draghi', 'al', 'quirinale', 'si', 'va', 'al', 'voto', 'probabilmente', 'mattarella', 'sar', 'á', 'costretto', 'a', 'disfare', 'i', 'bagagli', 'e', 'feôçª']
# --------------------------------------------------
# 43 Rosy Bindi al #Quirinale? ... Io credo ai miracoli. https://t.co/sGg51ffGFP
# <class 'str'>
# rosy bindi al quirinale  io credo ai miracoli httpstcosgg51ffgfp
# ['rosy', 'bindi', 'al', 'quirinale', 'io', 'credo', 'ai', 'miracoli', 'httpstcosgg51ffgfp']
# --------------------------------------------------
# 44 #Quirinale Sembra che il Pd si appresti ad affossare il buon senso, come per il DdlZan. Alta politica
# <class 'str'>
# quirinale sembra che il pd si appresti ad affossare il buon senso come per il ddlzan alta politica
# ['quirinale', 'sembra', 'che', 'il', 'pd', 'si', 'appresti', 'ad', 'affossare', 'il', 'buon', 'senso', 'come', 'per', 'il', 'ddlzan', 'alta', 'politica']
# --------------------------------------------------
# 45 RT @Lombard5stelle: #Quirinale @dariovioli: "LÔÇÖipotesi che io possa votare Berlusconi non ├¿ semplicemente ridicola fantapolitica, ma unÔÇÖoffÔÇª
# <class 'str'>
# rt lombard5stelle quirinale dariovioli lôçöipotesi che io possa votare berlusconi non ├¿ semplicemente ridicola fantapolitica ma unôçöoffôçª
# ['rt', 'lombard5stelle', 'quirinale', 'dariovioli', 'lôçöipotesi', 'che', 'io', 'possa', 'votare', 'berlusconi', 'non', 'semplicemente', 'ridicola', 'fantapolitica', 'ma', 'unôçöoffôçª']
# --------------------------------------------------
# 46 RT @LaNotiziaTweet: Draghi sogna il #Quirinale. Ma a Palazzo Chigi ha fallito quasi tutto. A partire da Recovery plan e campagna vaccinale.ÔÇª
# <class 'str'>
# rt lanotiziatweet draghi sogna il quirinale ma a palazzo chigi ha fallito quasi tutto a partire da recovery plan e campagna vaccinaleôçª
# ['rt', 'lanotiziatweet', 'draghi', 'sogna', 'il', 'quirinale', 'ma', 'a', 'palazzo', 'chigi', 'ha', 'fallito', 'quasi', 'tutto', 'a', 'partire', 'da', 'recovery', 'plan', 'e', 'campagna', 'vaccinaleôçª']
# --------------------------------------------------
# 47 RT @DinoGiarrusso: Immaginatevi se @GiuseppeConteIT fosse andato in #CONFERENZASTAMPA con tre giorni di ritardo, escludendo un quotidiano eÔÇª
# <class 'str'>
# rt dinogiarrusso immaginatevi se giuseppeconteit fosse andato in conferenzastampa con tre giorni di ritardo escludendo un quotidiano eôçª
# ['rt', 'dinogiarrusso', 'immaginatevi', 'se', 'giuseppeconteit', 'fosse', 'andato', 'in', 'conferenzastampa', 'con', 'tre', 'giorni', 'di', 'ritardo', 'escludendo', 'un', 'quotidiano', 'eôçª']
# --------------------------------------------------
# 48 RT @GiampieroBiglia: ÔÇ£Lo stop di #Berlusconi a #Draghi :con lui al Colle noi fuori dal governoÔÇØ in una frase lÔÇÖarroganza, spregiudicatezzaÔÇª
# <class 'str'>
# rt giampierobiglia ôç£lo stop di berlusconi a draghi con lui al colle noi fuori dal governoôçø in una frase lôçöarroganza spregiudicatezzaôçª
# ['rt', 'giampierobiglia', 'ôç', 'lo', 'stop', 'di', 'berlusconi', 'a', 'draghi', 'con', 'lui', 'al', 'colle', 'noi', 'fuori', 'dal', 'governoôçø', 'in', 'una', 'frase', 'lôçöarroganza', 'spregiudicatezzaôçª']
# --------------------------------------------------
# 49 .@paolomieli: "Vi pare questo il modo di discutere sul Capo dello Stato a 10 giorni dalle votazioni? Proporre di richiamare Mattarella?" #Quirinale
# <class 'str'>
# paolomieli vi pare questo il modo di discutere sul capo dello stato a 10 giorni dalle votazioni proporre di richiamare mattarella quirinale
# ['paolomieli', 'vi', 'pare', 'questo', 'il', 'modo', 'di', 'discutere', 'sul', 'capo', 'dello', 'stato', 'a', '10', 'giorni', 'dalle', 'votazioni', 'proporre', 'di', 'richiamare', 'mattarella', 'quirinale']
# --------------------------------------------------
# 50 RT @CosoSono: #noQUIRISILVIO ­ƒö┤
#
# Cosa si fa per danaro?
#
# Anche eleggere un pregiudicato al #Quirinale ­ƒñ¼
# <class 'str'>
# rt cososono noquirisilvio ­ƒö┤
#
# cosa si fa per danaro
#
# anche eleggere un pregiudicato al quirinale ­ƒñ¼
# ['rt', 'cososono', 'noquirisilvio', 'ƒö', 'cosa', 'si', 'fa', 'per', 'danaro', 'anche', 'eleggere', 'un', 'pregiudicato', 'al', 'quirinale', 'ƒñ¼']
# --------------------------------------------------
# 51 ÔÇ£Sgarbi chiama i parlamentari uno a uno, poi gli passa Berlusconi che augura buon anno e chiede il voto per il #QuirinaleÔÇØ
# E ve la siete presa con Montanari perch├® diceva Repubblica delle Banane
# <class 'str'>
# ôç£sgarbi chiama i parlamentari uno a uno poi gli passa berlusconi che augura buon anno e chiede il voto per il quirinaleôçø
# e ve la siete presa con montanari perch├® diceva repubblica delle banane
# ['ôç', 'sgarbi', 'chiama', 'i', 'parlamentari', 'uno', 'a', 'uno', 'poi', 'gli', 'passa', 'berlusconi', 'che', 'augura', 'buon', 'anno', 'e', 'chiede', 'il', 'voto', 'per', 'il', 'quirinaleôçø', 'e', 've', 'la', 'siete', 'presa', 'con', 'montanari', 'perch', 'diceva', 'repubblica', 'delle', 'banane']
# --------------------------------------------------
# 52 @elio_vito Elio, battute a parte, sei uno dei pochi che in questo paese riuscirebbe a mettere  d'accordo dx e sx, ma non hai fatto un pensiero per il #Quirinale. Stanotte ho sognato che diventava presidente della Repubblica Pillon ­ƒÿ¡­ƒÿ¡
# <class 'str'>
# eliovito elio battute a parte sei uno dei pochi che in questo paese riuscirebbe a mettere  daccordo dx e sx ma non hai fatto un pensiero per il quirinale stanotte ho sognato che diventava presidente della repubblica pillon ­ƒÿ¡­ƒÿ¡
# ['eliovito', 'elio', 'battute', 'a', 'parte', 'sei', 'uno', 'dei', 'pochi', 'che', 'in', 'questo', 'paese', 'riuscirebbe', 'a', 'mettere', 'daccordo', 'dx', 'e', 'sx', 'ma', 'non', 'hai', 'fatto', 'un', 'pensiero', 'per', 'il', 'quirinale', 'stanotte', 'ho', 'sognato', 'che', 'diventava', 'presidente', 'della', 'repubblica', 'pillon', 'ƒÿ', 'ƒÿ', '']
# --------------------------------------------------
# 53 .@paolomieli: "Dibattito sul #Quirinale svilente, si vede ricomparire il sempre uguale, ora chiedono a #Mattarella di restare ma c'├¿ un solo precedente quello di Napolitano che accett├▓ un secondo mandato ma solo dopo il patatrac delle prime votazioni".
# <class 'str'>
# paolomieli dibattito sul quirinale svilente si vede ricomparire il sempre uguale ora chiedono a mattarella di restare ma c├¿ un solo precedente quello di napolitano che accett├▓ un secondo mandato ma solo dopo il patatrac delle prime votazioni
# ['paolomieli', 'dibattito', 'sul', 'quirinale', 'svilente', 'si', 'vede', 'ricomparire', 'il', 'sempre', 'uguale', 'ora', 'chiedono', 'a', 'mattarella', 'di', 'restare', 'ma', 'c', 'un', 'solo', 'precedente', 'quello', 'di', 'napolitano', 'che', 'accett', 'un', 'secondo', 'mandato', 'ma', 'solo', 'dopo', 'il', 'patatrac', 'delle', 'prime', 'votazioni']
# --------------------------------------------------
# 54 ÔÇ£Immaginate se #mattarella dicesse ho scherzato ├¿ impossibile potrebbe tornare in campo solo di fronte a un disastro conclamato ÔÇ£
# @paolomieli @24Mattino #Quirinale
# <class 'str'>
# ôç£immaginate se mattarella dicesse ho scherzato ├¿ impossibile potrebbe tornare in campo solo di fronte a un disastro conclamato ôç£
# paolomieli 24mattino quirinale
# ['ôç', 'immaginate', 'se', 'mattarella', 'dicesse', 'ho', 'scherzato', 'impossibile', 'potrebbe', 'tornare', 'in', 'campo', 'solo', 'di', 'fronte', 'a', 'un', 'disastro', 'conclamato', 'ôç', 'paolomieli', '24mattino', 'quirinale']
# --------------------------------------------------
# 55 RT @OrioliAlberto: Se la #Meloni desidera un patriota al #Quirinale dovrebbe leggere di piu` @AnpiPatria, rivista dell'#ANPI fondata nel 19ÔÇª
# <class 'str'>
# rt oriolialberto se la meloni desidera un patriota al quirinale dovrebbe leggere di piu anpipatria rivista dellanpi fondata nel 19ôçª
# ['rt', 'oriolialberto', 'se', 'la', 'meloni', 'desidera', 'un', 'patriota', 'al', 'quirinale', 'dovrebbe', 'leggere', 'di', 'piu', 'anpipatria', 'rivista', 'dellanpi', 'fondata', 'nel', '19ôçª']
# --------------------------------------------------
# 56 Ci mancava #Bersani e la sua lungimiranza!! Vorrei #MarioDraghi come  #PdR  per i prossimi sette anni (e non fino al 2023, sempre che ci si arrivi). Cio' darebbe peso,  credibilita' e stabilita' al ns Paese! .@matteorenzi  @AzioneCesena  #facciamorete #Quirinale @GiorgiaMeloni https://t.co/i85BInr7wL
# <class 'str'>
# ci mancava bersani e la sua lungimiranza vorrei mariodraghi come  pdr  per i prossimi sette anni e non fino al 2023 sempre che ci si arrivi cio darebbe peso  credibilita e stabilita al ns paese matteorenzi  azionecesena  facciamorete quirinale giorgiameloni httpstcoi85binr7wl
# ['ci', 'mancava', 'bersani', 'e', 'la', 'sua', 'lungimiranza', 'vorrei', 'mariodraghi', 'come', 'pdr', 'per', 'i', 'prossimi', 'sette', 'anni', 'e', 'non', 'fino', 'al', '2023', 'sempre', 'che', 'ci', 'si', 'arrivi', 'cio', 'darebbe', 'peso', 'credibilita', 'e', 'stabilita', 'al', 'ns', 'paese', 'matteorenzi', 'azionecesena', 'facciamorete', 'quirinale', 'giorgiameloni', 'httpstcoi85binr7wl']
# --------------------------------------------------
# 57 Negli episodi precedenti....(musichetta) #Quirinale https://t.co/kYI0x6vnCl
# <class 'str'>
# negli episodi precedentimusichetta quirinale httpstcokyi0x6vncl
# ['negli', 'episodi', 'precedentimusichetta', 'quirinale', 'httpstcokyi0x6vncl']
# --------------------------------------------------
# 58 #dimartedi Il segretario del Partito democratico Enrico Letta sul #Quirinale: ÔÇ£Ho notizie di parlamentari del nostro gruppo che hanno ricevuto una telefonata di Berlusconi in questi giorniÔÇØ
#
# Occhio alle sporche manovre.
# <class 'str'>
# dimartedi il segretario del partito democratico enrico letta sul quirinale ôç£ho notizie di parlamentari del nostro gruppo che hanno ricevuto una telefonata di berlusconi in questi giorniôçø
#
# occhio alle sporche manovre
# ['dimartedi', 'il', 'segretario', 'del', 'partito', 'democratico', 'enrico', 'letta', 'sul', 'quirinale', 'ôç', 'ho', 'notizie', 'di', 'parlamentari', 'del', 'nostro', 'gruppo', 'che', 'hanno', 'ricevuto', 'una', 'telefonata', 'di', 'berlusconi', 'in', 'questi', 'giorniôçø', 'occhio', 'alle', 'sporche', 'manovre']
# --------------------------------------------------
# 59 Il #Quirinale ├¿ perno istituzionale, geopolitico, strategico dello Stato italiano.  La forza del Quirinale ├¿ quella di poter disegnare la cornice entro cui la vita politico-istituzionale pu├▓ muoversi.
# @diss_ipatio
#
# https://t.co/v0lLp7c8Om
# <class 'str'>
# il quirinale ├¿ perno istituzionale geopolitico strategico dello stato italiano  la forza del quirinale ├¿ quella di poter disegnare la cornice entro cui la vita politicoistituzionale pu├▓ muoversi
# dissipatio
#
# httpstcov0llp7c8om
# ['il', 'quirinale', 'perno', 'istituzionale', 'geopolitico', 'strategico', 'dello', 'stato', 'italiano', 'la', 'forza', 'del', 'quirinale', 'quella', 'di', 'poter', 'disegnare', 'la', 'cornice', 'entro', 'cui', 'la', 'vita', 'politicoistituzionale', 'pu', 'muoversi', 'dissipatio', 'httpstcov0llp7c8om']
# --------------------------------------------------
# 60 Vi aspettiamo a #Studio24, alle 10:00 su @RaiNews, con i nostri ospiti per parlare di:
#
# #OMS #VarianteOmicron #COVID19 #scuola #universit├á #ricerca #Draghi #Mattarella #Berlusconi #Quirinale #PresidenteDellaRepubblica #Sassoli #Europa
#
# Conduce @GiorgiaRomb https://t.co/dlKuuaKpu6
# <class 'str'>
# vi aspettiamo a studio24 alle 1000 su rainews con i nostri ospiti per parlare di
#
# oms varianteomicron covid19 scuola universit├á ricerca draghi mattarella berlusconi quirinale presidentedellarepubblica sassoli europa
#
# conduce giorgiaromb httpstcodlkuuakpu6
# ['vi', 'aspettiamo', 'a', 'studio24', 'alle', '1000', 'su', 'rainews', 'con', 'i', 'nostri', 'ospiti', 'per', 'parlare', 'di', 'oms', 'varianteomicron', 'covid19', 'scuola', 'universit', 'á', 'ricerca', 'draghi', 'mattarella', 'berlusconi', 'quirinale', 'presidentedellarepubblica', 'sassoli', 'europa', 'conduce', 'giorgiaromb', 'httpstcodlkuuakpu6']
# --------------------------------------------------
# 61 #URBANI: ÔÇ£SUL #QUIRINALE #BERLUSCONI APRA GLI OCCHI, NON CI SONO LE ÔÇØ
#
# ÔÇ£DRAGHI MEGLIO A PALAZZO CHIGIÔÇØ
# https://t.co/wyu50PJcUP https://t.co/eB6kQFq6vV
# <class 'str'>
# urbani ôç£sul quirinale berlusconi apra gli occhi non ci sono le ôçø
#
# ôç£draghi meglio a palazzo chigiôçø
# httpstcowyu50pjcup httpstcoeb6kqfq6vv
# ['urbani', 'ôç', 'sul', 'quirinale', 'berlusconi', 'apra', 'gli', 'occhi', 'non', 'ci', 'sono', 'le', 'ôçø', 'ôç', 'draghi', 'meglio', 'a', 'palazzo', 'chigiôçø', 'httpstcowyu50pjcup', 'httpstcoeb6kqfq6vv']
# --------------------------------------------------
# 62 ­ƒç«­ƒç╣ Elezioni #Quirinale 2022: 12 possibili scenari. Da Mattarella bis a Draghi, da Berlusconi a Prodi, da Cartabia fino a Moratti. Chi sar├á il prossimo #presidente della Repubblica?https://t.co/s6cZyYzDua
# <class 'str'>
# ­ƒç«­ƒç╣ elezioni quirinale 2022 12 possibili scenari da mattarella bis a draghi da berlusconi a prodi da cartabia fino a moratti chi sar├á il prossimo presidente della repubblicahttpstcos6czyyzdua
# ['', 'ƒç', 'ƒç', 'elezioni', 'quirinale', '2022', '12', 'possibili', 'scenari', 'da', 'mattarella', 'bis', 'a', 'draghi', 'da', 'berlusconi', 'a', 'prodi', 'da', 'cartabia', 'fino', 'a', 'moratti', 'chi', 'sar', 'á', 'il', 'prossimo', 'presidente', 'della', 'repubblicahttpstcos6czyyzdua']
# --------------------------------------------------
# 63 Spero veramente che #Mattarella ci ripensi. #elezionipresidente #Quirinale
# <class 'str'>
# spero veramente che mattarella ci ripensi elezionipresidente quirinale
# ['spero', 'veramente', 'che', 'mattarella', 'ci', 'ripensi', 'elezionipresidente', 'quirinale']
# --------------------------------------------------
# 64 RT @gladiatoremassi: Nel nome del popolo Italiano chiedo a #meloni e #salvini: ma una persona perbene come #Gratteri al #Quirinale NO? MeglÔÇª
# <class 'str'>
# rt gladiatoremassi nel nome del popolo italiano chiedo a meloni e salvini ma una persona perbene come gratteri al quirinale no meglôçª
# ['rt', 'gladiatoremassi', 'nel', 'nome', 'del', 'popolo', 'italiano', 'chiedo', 'a', 'meloni', 'e', 'salvini', 'ma', 'una', 'persona', 'perbene', 'come', 'gratteri', 'al', 'quirinale', 'no', 'meglôçª']
# --------------------------------------------------
# 65 RT @fabvix1971: La sola idea che il centrodestra possa effettivamente proporre #Berlusconi per il #Quirinale ├¿ raccapricciante. Mi auguro cÔÇª
# <class 'str'>
# rt fabvix1971 la sola idea che il centrodestra possa effettivamente proporre berlusconi per il quirinale ├¿ raccapricciante mi auguro côçª
# ['rt', 'fabvix1971', 'la', 'sola', 'idea', 'che', 'il', 'centrodestra', 'possa', 'effettivamente', 'proporre', 'berlusconi', 'per', 'il', 'quirinale', 'raccapricciante', 'mi', 'auguro', 'côçª']
# --------------------------------------------------
# 66 #Juorno #Quirinale #Sgambetti tra #alleati su delegati regionali, ├¿ caos
# https://t.co/c8rdFXmDbe
# <class 'str'>
# juorno quirinale sgambetti tra alleati su delegati regionali ├¿ caos
# httpstcoc8rdfxmdbe
# ['juorno', 'quirinale', 'sgambetti', 'tra', 'alleati', 'su', 'delegati', 'regionali', 'caos', 'httpstcoc8rdfxmdbe']
# --------------------------------------------------
# 67 #Juorno #Quirinale #Sgambetti tra #alleati su delegati regionali, ├¿ caos
# https://t.co/0sXK4CW7Uh
# <class 'str'>
# juorno quirinale sgambetti tra alleati su delegati regionali ├¿ caos
# httpstco0sxk4cw7uh
# ['juorno', 'quirinale', 'sgambetti', 'tra', 'alleati', 'su', 'delegati', 'regionali', 'caos', 'httpstco0sxk4cw7uh']
# --------------------------------------------------
# 68 Il bollettino covid deve essere giornaliero o settimanale? I fatti di Capodanno di Milano entrano nel dibattito politico; sul #Quirinale torna la voglia di bis di #Mattarella; riaprire i pozzi di gas italiani?
#
# La giornata in 24 minuti #12gennaio
# https://t.co/qE5U9Of6Mh
# <class 'str'>
# il bollettino covid deve essere giornaliero o settimanale i fatti di capodanno di milano entrano nel dibattito politico sul quirinale torna la voglia di bis di mattarella riaprire i pozzi di gas italiani
#
# la giornata in 24 minuti 12gennaio
# httpstcoqe5u9of6mh
# ['il', 'bollettino', 'covid', 'deve', 'essere', 'giornaliero', 'o', 'settimanale', 'i', 'fatti', 'di', 'capodanno', 'di', 'milano', 'entrano', 'nel', 'dibattito', 'politico', 'sul', 'quirinale', 'torna', 'la', 'voglia', 'di', 'bis', 'di', 'mattarella', 'riaprire', 'i', 'pozzi', 'di', 'gas', 'italiani', 'la', 'giornata', 'in', '24', 'minuti', '12gennaio', 'httpstcoqe5u9of6mh']
# --------------------------------------------------
# 69 #lanota del gianka
# Il modus operandi della sinistra...porre veti sugli altri e scommettere su una candidatura femminile per il Colle, ma solo se appartiene al fronte rosso.
# #Quirinale https://t.co/BUXc4aCBsq
# <class 'str'>
# lanota del gianka
# il modus operandi della sinistraporre veti sugli altri e scommettere su una candidatura femminile per il colle ma solo se appartiene al fronte rosso
# quirinale httpstcobuxc4acbsq
# ['lanota', 'del', 'gianka', 'il', 'modus', 'operandi', 'della', 'sinistraporre', 'veti', 'sugli', 'altri', 'e', 'scommettere', 'su', 'una', 'candidatura', 'femminile', 'per', 'il', 'colle', 'ma', 'solo', 'se', 'appartiene', 'al', 'fronte', 'rosso', 'quirinale', 'httpstcobuxc4acbsq']
# --------------------------------------------------
# 70 #Quirinale Volevo avvisare #Berlusconi che si ├¿ liberato un posto da #Presidente del #ParlamentoEuropeo.
# #12gennaio #Europa #UE #EuroParlamento #Sassoli #DavidSassoli #AddioDavid #RIPDavidSassoli #PresidenteDellaRepubblica #noQUIRISILVIO #Buongiorno #unTemaAlGiorno
# <class 'str'>
# quirinale volevo avvisare berlusconi che si ├¿ liberato un posto da presidente del parlamentoeuropeo
# 12gennaio europa ue europarlamento sassoli davidsassoli addiodavid ripdavidsassoli presidentedellarepubblica noquirisilvio buongiorno untemaalgiorno
# ['quirinale', 'volevo', 'avvisare', 'berlusconi', 'che', 'si', 'liberato', 'un', 'posto', 'da', 'presidente', 'del', 'parlamentoeuropeo', '12gennaio', 'europa', 'ue', 'europarlamento', 'sassoli', 'davidsassoli', 'addiodavid', 'ripdavidsassoli', 'presidentedellarepubblica', 'noquirisilvio', 'buongiorno', 'untemaalgiorno']
# --------------------------------------------------
# 71 RT @armanduplessis: Considerando anche alcune bizzarre ipotesi in campo per il #Quirinale, scrive Folli che "il Paese potrebbe aver bisognoÔÇª
# <class 'str'>
# rt armanduplessis considerando anche alcune bizzarre ipotesi in campo per il quirinale scrive folli che il paese potrebbe aver bisognoôçª
# ['rt', 'armanduplessis', 'considerando', 'anche', 'alcune', 'bizzarre', 'ipotesi', 'in', 'campo', 'per', 'il', 'quirinale', 'scrive', 'folli', 'che', 'il', 'paese', 'potrebbe', 'aver', 'bisognoôçª']
# --------------------------------------------------
# 72 Il #Quirinale ├¿ perno istituzionale, geopolitico, strategico dello Stato italiano.  La forza del Quirinale ├¿ quella di poter disegnare la cornice entro cui la vita politico-istituzionale pu├▓ muoversi. Con potere informali di nominaÔÇªhttps://t.co/MSS06urHRO https://t.co/IAINhsutO7
# <class 'str'>
# il quirinale ├¿ perno istituzionale geopolitico strategico dello stato italiano  la forza del quirinale ├¿ quella di poter disegnare la cornice entro cui la vita politicoistituzionale pu├▓ muoversi con potere informali di nominaôçªhttpstcomss06urhro httpstcoiainhsuto7
# ['il', 'quirinale', 'perno', 'istituzionale', 'geopolitico', 'strategico', 'dello', 'stato', 'italiano', 'la', 'forza', 'del', 'quirinale', 'quella', 'di', 'poter', 'disegnare', 'la', 'cornice', 'entro', 'cui', 'la', 'vita', 'politicoistituzionale', 'pu', 'muoversi', 'con', 'potere', 'informali', 'di', 'nominaôçªhttpstcomss06urhro', 'httpstcoiainhsuto7']
# --------------------------------------------------
# 73 RT @armanduplessis: Considerando anche alcune bizzarre ipotesi in campo per il #Quirinale, scrive Folli che "il Paese potrebbe aver bisognoÔÇª
# <class 'str'>
# rt armanduplessis considerando anche alcune bizzarre ipotesi in campo per il quirinale scrive folli che il paese potrebbe aver bisognoôçª
# ['rt', 'armanduplessis', 'considerando', 'anche', 'alcune', 'bizzarre', 'ipotesi', 'in', 'campo', 'per', 'il', 'quirinale', 'scrive', 'folli', 'che', 'il', 'paese', 'potrebbe', 'aver', 'bisognoôçª']
# --------------------------------------------------
# 74 Considerando anche alcune bizzarre ipotesi in campo per il #Quirinale, scrive Folli che "il Paese potrebbe aver bisogno ancora di #Mattarella, nonostante il suo personale desiderio di tornare alla vita privata".  @repubblica
# <class 'str'>
# considerando anche alcune bizzarre ipotesi in campo per il quirinale scrive folli che il paese potrebbe aver bisogno ancora di mattarella nonostante il suo personale desiderio di tornare alla vita privata  repubblica
# ['considerando', 'anche', 'alcune', 'bizzarre', 'ipotesi', 'in', 'campo', 'per', 'il', 'quirinale', 'scrive', 'folli', 'che', 'il', 'paese', 'potrebbe', 'aver', 'bisogno', 'ancora', 'di', 'mattarella', 'nonostante', 'il', 'suo', 'personale', 'desiderio', 'di', 'tornare', 'alla', 'vita', 'privata', 'repubblica']
# --------------------------------------------------
# 75 RT @DinoGiarrusso: Immaginatevi se @GiuseppeConteIT fosse andato in #CONFERENZASTAMPA con tre giorni di ritardo, escludendo un quotidiano eÔÇª
# <class 'str'>
# rt dinogiarrusso immaginatevi se giuseppeconteit fosse andato in conferenzastampa con tre giorni di ritardo escludendo un quotidiano eôçª
# ['rt', 'dinogiarrusso', 'immaginatevi', 'se', 'giuseppeconteit', 'fosse', 'andato', 'in', 'conferenzastampa', 'con', 'tre', 'giorni', 'di', 'ritardo', 'escludendo', 'un', 'quotidiano', 'eôçª']
# --------------------------------------------------
# 76 RT @DinoGiarrusso: Immaginatevi se @GiuseppeConteIT fosse andato in #CONFERENZASTAMPA con tre giorni di ritardo, escludendo un quotidiano eÔÇª
# <class 'str'>
# rt dinogiarrusso immaginatevi se giuseppeconteit fosse andato in conferenzastampa con tre giorni di ritardo escludendo un quotidiano eôçª
# ['rt', 'dinogiarrusso', 'immaginatevi', 'se', 'giuseppeconteit', 'fosse', 'andato', 'in', 'conferenzastampa', 'con', 'tre', 'giorni', 'di', 'ritardo', 'escludendo', 'un', 'quotidiano', 'eôçª']
# --------------------------------------------------
# 77 La sola idea che il centrodestra possa effettivamente proporre #Berlusconi per il #Quirinale ├¿ raccapricciante. Mi auguro che quel nome venga fatto solo per dargli il contentino ma che poi ci si concentri su qualcuno pi├╣ presentabile.
# <class 'str'>
# la sola idea che il centrodestra possa effettivamente proporre berlusconi per il quirinale ├¿ raccapricciante mi auguro che quel nome venga fatto solo per dargli il contentino ma che poi ci si concentri su qualcuno pi├╣ presentabile
# ['la', 'sola', 'idea', 'che', 'il', 'centrodestra', 'possa', 'effettivamente', 'proporre', 'berlusconi', 'per', 'il', 'quirinale', 'raccapricciante', 'mi', 'auguro', 'che', 'quel', 'nome', 'venga', 'fatto', 'solo', 'per', 'dargli', 'il', 'contentino', 'ma', 'che', 'poi', 'ci', 'si', 'concentri', 'su', 'qualcuno', 'pi', 'presentabile']
# --------------------------------------------------
# 78 Elezione del Presidente. La politica trovi unit├á nellÔÇÖinteresse del Paese - di Pasquale Episcopo
#
# #Quirinale #PresidentedellaRepubblica #politica
#
# https://t.co/dyrvRI5JzM
# <class 'str'>
# elezione del presidente la politica trovi unit├á nellôçöinteresse del paese  di pasquale episcopo
#
# ...
# --------------------------------------------------
# 471 ­ƒæÇ
# #Quirinale #PresidenteDellaRepubblica #donnaalquirinale #toscana #siena #bohemien #radicalchic #cattocomunisti #cattocomunismo https://t.co/c5yrlqIfhe https://t.co/SxGBlkAcQT
# <class 'str'>
# ­ƒæç
# quirinale presidentedellarepubblica donnaalquirinale toscana siena bohemien radicalchic cattocomunisti cattocomunismo httpstcoc5yrlqifhe httpstcosxgblkacqt
# ['', 'ƒæç', 'quirinale', 'presidentedellarepubblica', 'donnaalquirinale', 'toscana', 'siena', 'bohemien', 'radicalchic', 'cattocomunisti', 'cattocomunismo', 'httpstcoc5yrlqifhe', 'httpstcosxgblkacqt']
# --------------------------------------------------
# 472 RT @DinoGiarrusso: Immaginatevi se @GiuseppeConteIT fosse andato in #CONFERENZASTAMPA con tre giorni di ritardo, escludendo un quotidiano eÔÇª
# <class 'str'>
# rt dinogiarrusso immaginatevi se giuseppeconteit fosse andato in conferenzastampa con tre giorni di ritardo escludendo un quotidiano eôçª
# ['rt', 'dinogiarrusso', 'immaginatevi', 'se', 'giuseppeconteit', 'fosse', 'andato', 'in', 'conferenzastampa', 'con', 'tre', 'giorni', 'di', 'ritardo', 'escludendo', 'un', 'quotidiano', 'eôçª']
# --------------------------------------------------
# 473 RT @valy_s: A #Crisanti viene chiesto un parere su #Draghi e #Quirinale:
# ÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á dÔÇª
# <class 'str'>
# rt valys a crisanti viene chiesto un parere su draghi e quirinale
# ôç£├ê stato ôçÿsfortunatoôçö ci ha detto che avremmo avuto lôçöimmunit├á dôçª
# ['rt', 'valys', 'a', 'crisanti', 'viene', 'chiesto', 'un', 'parere', 'su', 'draghi', 'e', 'quirinale', 'ôç', 'ê', 'stato', 'ôçÿsfortunatoôçö', 'ci', 'ha', 'detto', 'che', 'avremmo', 'avuto', 'lôçöimmunit', 'á', 'dôçª']
# --------------------------------------------------
# 474 RT @ivanscalfarotto: Riflessioni.
# #Quirinale https://t.co/xLzfOv8f3O
# <class 'str'>
# rt ivanscalfarotto riflessioni
# quirinale httpstcoxlzfov8f3o
# ['rt', 'ivanscalfarotto', 'riflessioni', 'quirinale', 'httpstcoxlzfov8f3o']
# --------------------------------------------------
# 475 A me piacerebbe che #Draghi decidesse di levarsi dai piedi, altro che #Quirinale! #ottoemezzo
# <class 'str'>
# a me piacerebbe che draghi decidesse di levarsi dai piedi altro che quirinale ottoemezzo
# ['a', 'me', 'piacerebbe', 'che', 'draghi', 'decidesse', 'di', 'levarsi', 'dai', 'piedi', 'altro', 'che', 'quirinale', 'ottoemezzo']
# --------------------------------------------------
# 476 RT @Apndp: Ma i conduttori #tv (di una qualsiasi tv) contro #Draghi perch├¿ si ├¿ rifiutato di parlare di #quirinale son gli stessi che concoÔÇª
# <class 'str'>
# rt apndp ma i conduttori tv di una qualsiasi tv contro draghi perch├¿ si ├¿ rifiutato di parlare di quirinale son gli stessi che concoôçª
# ['rt', 'apndp', 'ma', 'i', 'conduttori', 'tv', 'di', 'una', 'qualsiasi', 'tv', 'contro', 'draghi', 'perch', 'si', 'rifiutato', 'di', 'parlare', 'di', 'quirinale', 'son', 'gli', 'stessi', 'che', 'concoôçª']
# --------------------------------------------------
# 477 RT @il_vetero: Finalmente una candidatura in grado di mettere dÔÇÖaccordo tutti gli italiani e tutte le italiane!
# #CristinaPresidente Subito!ÔÇª
# <class 'str'>
# rt ilvetero finalmente una candidatura in grado di mettere dôçöaccordo tutti gli italiani e tutte le italiane
# cristinapresidente subitoôçª
# ['rt', 'ilvetero', 'finalmente', 'una', 'candidatura', 'in', 'grado', 'di', 'mettere', 'dôçöaccordo', 'tutti', 'gli', 'italiani', 'e', 'tutte', 'le', 'italiane', 'cristinapresidente', 'subitoôçª']
# --------------------------------------------------
# 478 RT @valy_s: A #Crisanti viene chiesto un parere su #Draghi e #Quirinale:
# ÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á dÔÇª
# <class 'str'>
# rt valys a crisanti viene chiesto un parere su draghi e quirinale
# ôç£├ê stato ôçÿsfortunatoôçö ci ha detto che avremmo avuto lôçöimmunit├á dôçª
# ['rt', 'valys', 'a', 'crisanti', 'viene', 'chiesto', 'un', 'parere', 'su', 'draghi', 'e', 'quirinale', 'ôç', 'ê', 'stato', 'ôçÿsfortunatoôçö', 'ci', 'ha', 'detto', 'che', 'avremmo', 'avuto', 'lôçöimmunit', 'á', 'dôçª']
# --------------------------------------------------
# 479 RT @DinoGiarrusso: Immaginatevi se @GiuseppeConteIT fosse andato in #CONFERENZASTAMPA con tre giorni di ritardo, escludendo un quotidiano eÔÇª
# <class 'str'>
# rt dinogiarrusso immaginatevi se giuseppeconteit fosse andato in conferenzastampa con tre giorni di ritardo escludendo un quotidiano eôçª
# ['rt', 'dinogiarrusso', 'immaginatevi', 'se', 'giuseppeconteit', 'fosse', 'andato', 'in', 'conferenzastampa', 'con', 'tre', 'giorni', 'di', 'ritardo', 'escludendo', 'un', 'quotidiano', 'eôçª']
# --------------------------------------------------
# 480 RT @LucillaMasini: QUESITO DI GENNAIO
#
# Fra avere Berlusconi Presidente della Repubblica e mangiare un chilo di mÔé¼rda, preferite il guano dÔÇª
# <class 'str'>
# rt lucillamasini quesito di gennaio
#
# fra avere berlusconi presidente della repubblica e mangiare un chilo di môé¼rda preferite il guano dôçª
# ['rt', 'lucillamasini', 'quesito', 'di', 'gennaio', 'fra', 'avere', 'berlusconi', 'presidente', 'della', 'repubblica', 'e', 'mangiare', 'un', 'chilo', 'di', 'môé¼rda', 'preferite', 'il', 'guano', 'dôçª']
# --------------------------------------------------
# 481 RT @DomaniGiornale: #Berlusconi ├¿ arrivato a #Roma, da dove prover├á il salto al #Quirinale: nonostante i suoi consiglieri lo abbiano cautamÔÇª
# <class 'str'>
# rt domanigiornale berlusconi ├¿ arrivato a roma da dove prover├á il salto al quirinale nonostante i suoi consiglieri lo abbiano cautamôçª
# ['rt', 'domanigiornale', 'berlusconi', 'arrivato', 'a', 'roma', 'da', 'dove', 'prover', 'á', 'il', 'salto', 'al', 'quirinale', 'nonostante', 'i', 'suoi', 'consiglieri', 'lo', 'abbiano', 'cautamôçª']
# --------------------------------------------------
# 482 Il #centrodestra ├¿ diviso su #Berlusconi al #Quirinale. #Draghi resta in pole ma prende quota l'ipotesi di un bis di #Mattarella.
#
# https://t.co/c5kOJPGJ34
# <class 'str'>
# il centrodestra ├¿ diviso su berlusconi al quirinale draghi resta in pole ma prende quota lipotesi di un bis di mattarella
#
# httpstcoc5kojpgj34
# ['il', 'centrodestra', 'diviso', 'su', 'berlusconi', 'al', 'quirinale', 'draghi', 'resta', 'in', 'pole', 'ma', 'prende', 'quota', 'lipotesi', 'di', 'un', 'bis', 'di', 'mattarella', 'httpstcoc5kojpgj34']
# --------------------------------------------------
# 483 RT @NicoFuccaro: Qualcuno ha capito qualcosa di quello che in iperpolitichese sta sostenendo @VeltroniWalter sul #Quirinale? (non che sia dÔÇª
# <class 'str'>
# rt nicofuccaro qualcuno ha capito qualcosa di quello che in iperpolitichese sta sostenendo veltroniwalter sul quirinale non che sia dôçª
# ['rt', 'nicofuccaro', 'qualcuno', 'ha', 'capito', 'qualcosa', 'di', 'quello', 'che', 'in', 'iperpolitichese', 'sta', 'sostenendo', 'veltroniwalter', 'sul', 'quirinale', 'non', 'che', 'sia', 'dôçª']
# --------------------------------------------------
# 484 RT @Lombard5stelle: #Quirinale @dariovioli: "LÔÇÖipotesi che io possa votare Berlusconi non ├¿ semplicemente ridicola fantapolitica, ma unÔÇÖoffÔÇª
# <class 'str'>
# rt lombard5stelle quirinale dariovioli lôçöipotesi che io possa votare berlusconi non ├¿ semplicemente ridicola fantapolitica ma unôçöoffôçª
# ['rt', 'lombard5stelle', 'quirinale', 'dariovioli', 'lôçöipotesi', 'che', 'io', 'possa', 'votare', 'berlusconi', 'non', 'semplicemente', 'ridicola', 'fantapolitica', 'ma', 'unôçöoffôçª']
# --------------------------------------------------
# 485 RT @fabrizio19651: Una minaccia obliqua che  dimostra una volta di pi├╣ che non ha le caratteristiche per fare il #PresidenteDellaRepubblicaÔÇª
# <class 'str'>
# rt fabrizio19651 una minaccia obliqua che  dimostra una volta di pi├╣ che non ha le caratteristiche per fare il presidentedellarepubblicaôçª
# ['rt', 'fabrizio19651', 'una', 'minaccia', 'obliqua', 'che', 'dimostra', 'una', 'volta', 'di', 'pi', 'che', 'non', 'ha', 'le', 'caratteristiche', 'per', 'fare', 'il', 'presidentedellarepubblicaôçª']
# --------------------------------------------------
# 486 Lo smemorato di Cologno al #Quirinale lo voglio vedere solo in una puntata di @fratellicrozza
# <class 'str'>
# lo smemorato di cologno al quirinale lo voglio vedere solo in una puntata di fratellicrozza
# ['lo', 'smemorato', 'di', 'cologno', 'al', 'quirinale', 'lo', 'voglio', 'vedere', 'solo', 'in', 'una', 'puntata', 'di', 'fratellicrozza']
# --------------------------------------------------
# 487 RT @S_Giacomoni: #Quirinale. Saranno le regole della #democrazia a scegliere­ƒù│
#
# ­ƒöÁ Sono convinto che #Berlusconi al #Colle e #Draghi al #GovÔÇª
# <class 'str'>
# rt sgiacomoni quirinale saranno le regole della democrazia a scegliere­ƒù│
#
# ­ƒöá sono convinto che berlusconi al colle e draghi al govôçª
# ['rt', 'sgiacomoni', 'quirinale', 'saranno', 'le', 'regole', 'della', 'democrazia', 'a', 'scegliere', 'ƒù', 'ƒöá', 'sono', 'convinto', 'che', 'berlusconi', 'al', 'colle', 'e', 'draghi', 'al', 'govôçª']
# --------------------------------------------------
# 488 RT @valy_s: A #Crisanti viene chiesto un parere su #Draghi e #Quirinale:
# ÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á dÔÇª
# <class 'str'>
# rt valys a crisanti viene chiesto un parere su draghi e quirinale
# ôç£├ê stato ôçÿsfortunatoôçö ci ha detto che avremmo avuto lôçöimmunit├á dôçª
# ['rt', 'valys', 'a', 'crisanti', 'viene', 'chiesto', 'un', 'parere', 'su', 'draghi', 'e', 'quirinale', 'ôç', 'ê', 'stato', 'ôçÿsfortunatoôçö', 'ci', 'ha', 'detto', 'che', 'avremmo', 'avuto', 'lôçöimmunit', 'á', 'dôçª']
# --------------------------------------------------
# 489 RT @valy_s: A #Crisanti viene chiesto un parere su #Draghi e #Quirinale:
# ÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á dÔÇª
# <class 'str'>
# rt valys a crisanti viene chiesto un parere su draghi e quirinale
# ôç£├ê stato ôçÿsfortunatoôçö ci ha detto che avremmo avuto lôçöimmunit├á dôçª
# ['rt', 'valys', 'a', 'crisanti', 'viene', 'chiesto', 'un', 'parere', 'su', 'draghi', 'e', 'quirinale', 'ôç', 'ê', 'stato', 'ôçÿsfortunatoôçö', 'ci', 'ha', 'detto', 'che', 'avremmo', 'avuto', 'lôçöimmunit', 'á', 'dôçª']
# --------------------------------------------------
# 490 Quirinale la segreteria Pd decide di non decidere. La candidatura di Berlusconi angoscia Letta -  #Quirinale #segreteria #decide  https://t.co/YHC1UzasAF
# <class 'str'>
# quirinale la segreteria pd decide di non decidere la candidatura di berlusconi angoscia letta   quirinale segreteria decide  httpstcoyhc1uzasaf
# ['quirinale', 'la', 'segreteria', 'pd', 'decide', 'di', 'non', 'decidere', 'la', 'candidatura', 'di', 'berlusconi', 'angoscia', 'letta', 'quirinale', 'segreteria', 'decide', 'httpstcoyhc1uzasaf']
# --------------------------------------------------
# 491 Canditati per il #Quirinale -1 https://t.co/grTSJWHtTY
# <class 'str'>
# canditati per il quirinale 1 httpstcogrtsjwhtty
# ['canditati', 'per', 'il', 'quirinale', '1', 'httpstcogrtsjwhtty']
# --------------------------------------------------
# 492 RT @valy_s: A #Crisanti viene chiesto un parere su #Draghi e #Quirinale:
# ÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á dÔÇª
# <class 'str'>
# rt valys a crisanti viene chiesto un parere su draghi e quirinale
# ôç£├ê stato ôçÿsfortunatoôçö ci ha detto che avremmo avuto lôçöimmunit├á dôçª
# ['rt', 'valys', 'a', 'crisanti', 'viene', 'chiesto', 'un', 'parere', 'su', 'draghi', 'e', 'quirinale', 'ôç', 'ê', 'stato', 'ôçÿsfortunatoôçö', 'ci', 'ha', 'detto', 'che', 'avremmo', 'avuto', 'lôçöimmunit', 'á', 'dôçª']
# --------------------------------------------------
# 493 RT @valy_s: A #Crisanti viene chiesto un parere su #Draghi e #Quirinale:
# ÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á dÔÇª
# <class 'str'>
# rt valys a crisanti viene chiesto un parere su draghi e quirinale
# ôç£├ê stato ôçÿsfortunatoôçö ci ha detto che avremmo avuto lôçöimmunit├á dôçª
# ['rt', 'valys', 'a', 'crisanti', 'viene', 'chiesto', 'un', 'parere', 'su', 'draghi', 'e', 'quirinale', 'ôç', 'ê', 'stato', 'ôçÿsfortunatoôçö', 'ci', 'ha', 'detto', 'che', 'avremmo', 'avuto', 'lôçöimmunit', 'á', 'dôçª']
# --------------------------------------------------
# 494 RT @valy_s: A #Crisanti viene chiesto un parere su #Draghi e #Quirinale:
# ÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á dÔÇª
# <class 'str'>
# rt valys a crisanti viene chiesto un parere su draghi e quirinale
# ôç£├ê stato ôçÿsfortunatoôçö ci ha detto che avremmo avuto lôçöimmunit├á dôçª
# ['rt', 'valys', 'a', 'crisanti', 'viene', 'chiesto', 'un', 'parere', 'su', 'draghi', 'e', 'quirinale', 'ôç', 'ê', 'stato', 'ôçÿsfortunatoôçö', 'ci', 'ha', 'detto', 'che', 'avremmo', 'avuto', 'lôçöimmunit', 'á', 'dôçª']
# --------------------------------------------------
# 495 #Quirinale #Berlusconi #Draghi #PresidenteDellaRepubblica  https://t.co/uoCuFPo59S
# <class 'str'>
# quirinale berlusconi draghi presidentedellarepubblica  httpstcouocufpo59s
# ['quirinale', 'berlusconi', 'draghi', 'presidentedellarepubblica', 'httpstcouocufpo59s']
# --------------------------------------------------
# 496 #ottoemezzo Walter Veltroni sulla prossima elezione del Capo dello Stato: "Non possiamo permetterci di perdere in un colpo solo sia #Draghi sia #Mattarella" @VeltroniWalter #quirinale https://t.co/VL1ETJJybt
# <class 'str'>
# ottoemezzo walter veltroni sulla prossima elezione del capo dello stato non possiamo permetterci di perdere in un colpo solo sia draghi sia mattarella veltroniwalter quirinale httpstcovl1etjjybt
# ['ottoemezzo', 'walter', 'veltroni', 'sulla', 'prossima', 'elezione', 'del', 'capo', 'dello', 'stato', 'non', 'possiamo', 'permetterci', 'di', 'perdere', 'in', 'un', 'colpo', 'solo', 'sia', 'draghi', 'sia', 'mattarella', 'veltroniwalter', 'quirinale', 'httpstcovl1etjjybt']
# --------------------------------------------------
# 497 A #Crisanti viene chiesto un parere su #Draghi e #Quirinale:
# ÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á di gregge, che il #greenpass ci avrebbe protetto dal contagio e poi ├¿ arrivata #Omicron. Per fortuna ├¿ pi├╣ ÔÇ£leggeraÔÇØÔÇØ
# #ottoemezzo
# <class 'str'>
# a crisanti viene chiesto un parere su draghi e quirinale
# ôç£├ê stato ôçÿsfortunatoôçö ci ha detto che avremmo avuto lôçöimmunit├á di gregge che il greenpass ci avrebbe protetto dal contagio e poi ├¿ arrivata omicron per fortuna ├¿ pi├╣ ôç£leggeraôçøôçø
# ottoemezzo
# ['a', 'crisanti', 'viene', 'chiesto', 'un', 'parere', 'su', 'draghi', 'e', 'quirinale', 'ôç', 'ê', 'stato', 'ôçÿsfortunatoôçö', 'ci', 'ha', 'detto', 'che', 'avremmo', 'avuto', 'lôçöimmunit', 'á', 'di', 'gregge', 'che', 'il', 'greenpass', 'ci', 'avrebbe', 'protetto', 'dal', 'contagio', 'e', 'poi', 'arrivata', 'omicron', 'per', 'fortuna', 'pi', 'ôç', 'leggeraôçøôçø', 'ottoemezzo']
# --------------------------------------------------
# 498 RT @AdolfoTasinato: Per il giornale inglese The Guardian in Italia non vige un sistema democratico. #Draghi #Italy #Italia #democrazia #PolÔÇª
# <class 'str'>
# rt adolfotasinato per il giornale inglese the guardian in italia non vige un sistema democratico draghi italy italia democrazia polôçª
# ['rt', 'adolfotasinato', 'per', 'il', 'giornale', 'inglese', 'the', 'guardian', 'in', 'italia', 'non', 'vige', 'un', 'sistema', 'democratico', 'draghi', 'italy', 'italia', 'democrazia', 'polôçª']
# --------------------------------------------------
# 499 #ottoemezzo #quirinale
# #Crisanti scopri l'intruso
# <class 'str'>
# ottoemezzo quirinale
# crisanti scopri lintruso
# ['ottoemezzo', 'quirinale', 'crisanti', 'scopri', 'lintruso']
# --------------------------------------------------
# 500 Berlusconi al #Quirinale in questo periodo storico non si pu├▓ sopportare #ottoemezzo .
# <class 'str'>
# berlusconi al quirinale in questo periodo storico non si pu├▓ sopportare ottoemezzo
# ['berlusconi', 'al', 'quirinale', 'in', 'questo', 'periodo', 'storico', 'non', 'si', 'pu', 'sopportare', 'ottoemezzo', '']
# --------------------------------------------------
# 501
# <class 'str'>
#
# ['']
# --------------------------------------------------

# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.6.7-py3-none-any.whl (1.5 MB)
# Requirement already satisfied: click in c:\users\alket\anaconda3\envs\ds10\lib\site-packages (from nltk) (7.1.2)
# Requirement already satisfied: tqdm in c:\users\alket\anaconda3\envs\ds10\lib\site-packages (from nltk) (4.61.2)
# Requirement already satisfied: joblib in c:\users\alket\anaconda3\envs\ds10\lib\site-packages (from nltk) (1.0.1)
# Collecting regex>=2021.8.3
#   Downloading regex-2021.11.10-cp39-cp39-win_amd64.whl (273 kB)
# Requirement already satisfied: colorama in c:\users\alket\anaconda3\envs\ds10\lib\site-packages (from tqdm->nltk) (0.4.4)
# Installing collected packages: regex, nltk
# Successfully installed nltk-3.6.7 regex-2021.11.10

# %%
import nltk

stopword = nltk.corpus.stopwords.words('italian')

# %%
def remove_stopwords(tokenized_list):
    text = [word for word in tokenized_list if word not in stopword]
    return text

# %%
token_list = []
for k, v in tweets_number.items(): 
    print(k, v)
    text_i = v
    print(type(text_i))
    text_i = remove_punct(text_i)
    print(text_i)
    l = tokenize(text_i)
    print(l)
    l2 = remove_stopwords(l)
    token_list.append(l2)
    print(l2)
    print('--------------------------------------------------')
# Out:
# 1 RT @PSchioppa: Con il 50% dei delegati regionali scelti a grandi elettori per il #Quirinale viste le appartenenze, mai come stiamo facendoÔÇª
# <class 'str'>
# rt pschioppa con il 50 dei delegati regionali scelti a grandi elettori per il quirinale viste le appartenenze mai come stiamo facendoôçª
# ['rt', 'pschioppa', 'con', 'il', '50', 'dei', 'delegati', 'regionali', 'scelti', 'a', 'grandi', 'elettori', 'per', 'il', 'quirinale', 'viste', 'le', 'appartenenze', 'mai', 'come', 'stiamo', 'facendoôçª']
# ['rt', 'pschioppa', '50', 'delegati', 'regionali', 'scelti', 'grandi', 'elettori', 'quirinale', 'viste', 'appartenenze', 'mai', 'facendoôçª']
# --------------------------------------------------
# 2 RT @siamonoitv2000: Corsa al #Quirinale, speciale di #SiamoNoi alle 15.15 su @TV2000it con @giuspaterniti, @PaoloGraldi e @FrancoBechis.
#
# #ÔÇª
# <class 'str'>
# rt siamonoitv2000 corsa al quirinale speciale di siamonoi alle 1515 su tv2000it con giuspaterniti paolograldi e francobechis
#
# ôçª
# ['rt', 'siamonoitv2000', 'corsa', 'al', 'quirinale', 'speciale', 'di', 'siamonoi', 'alle', '1515', 'su', 'tv2000it', 'con', 'giuspaterniti', 'paolograldi', 'e', 'francobechis', 'ôçª']
# ['rt', 'siamonoitv2000', 'corsa', 'quirinale', 'speciale', 'siamonoi', '1515', 'tv2000it', 'giuspaterniti', 'paolograldi', 'francobechis', 'ôçª']
# --------------------------------------------------
# 3 Ô×í´©Å #SiamoNoi
# ÔÅ░ 15.15
# ­ƒô║ @TV2000it
#
# #Quirinale #12gennaio #canale28 #siamonoitv2000 @FrancoBechis @giuspaterniti @PaoloGraldi @ilmessaggeroit @tempoweb @GabriFacondo https://t.co/RXCDpGCiY0
# <class 'str'>
# ô×í´©å siamonoi
# ôå░ 1515
# ­ƒô║ tv2000it
#
# quirinale 12gennaio canale28 siamonoitv2000 francobechis giuspaterniti paolograldi ilmessaggeroit tempoweb gabrifacondo httpstcorxcdpgciy0
# ['ô', 'í', 'å', 'siamonoi', 'ôå', '1515', 'ƒô', 'tv2000it', 'quirinale', '12gennaio', 'canale28', 'siamonoitv2000', 'francobechis', 'giuspaterniti', 'paolograldi', 'ilmessaggeroit', 'tempoweb', 'gabrifacondo', 'httpstcorxcdpgciy0']
# ['ô', 'í', 'å', 'siamonoi', 'ôå', '1515', 'ƒô', 'tv2000it', 'quirinale', '12gennaio', 'canale28', 'siamonoitv2000', 'francobechis', 'giuspaterniti', 'paolograldi', 'ilmessaggeroit', 'tempoweb', 'gabrifacondo', 'httpstcorxcdpgciy0']
# --------------------------------------------------
# 4 Dopo che per mesi #Mattarella ha detto che non ci pensava nemmeno ora ripropongono Mattarella per un secondo incarico.
# Cos├¼, tranquillamente e come se fosse la cosa pi├╣ fattibile del mondo.
# #Quirinale
# <class 'str'>
# dopo che per mesi mattarella ha detto che non ci pensava nemmeno ora ripropongono mattarella per un secondo incarico
# cos├¼ tranquillamente e come se fosse la cosa pi├╣ fattibile del mondo
# quirinale
# ['dopo', 'che', 'per', 'mesi', 'mattarella', 'ha', 'detto', 'che', 'non', 'ci', 'pensava', 'nemmeno', 'ora', 'ripropongono', 'mattarella', 'per', 'un', 'secondo', 'incarico', 'cos', '¼', 'tranquillamente', 'e', 'come', 'se', 'fosse', 'la', 'cosa', 'pi', 'fattibile', 'del', 'mondo', 'quirinale']
# ['dopo', 'mesi', 'mattarella', 'detto', 'pensava', 'nemmeno', 'ora', 'ripropongono', 'mattarella', 'secondo', 'incarico', 'cos', '¼', 'tranquillamente', 'cosa', 'pi', 'fattibile', 'mondo', 'quirinale']
# --------------------------------------------------
# 5 RT @smenichini: Non ci sar├á purtroppo alcun effetto #Sassoli sul voto per il #Quirinale, che non ├¿ un momento per la politica gentile. Per├▓ÔÇª
# <class 'str'>
# rt smenichini non ci sar├á purtroppo alcun effetto sassoli sul voto per il quirinale che non ├¿ un momento per la politica gentile per├▓ôçª
# ['rt', 'smenichini', 'non', 'ci', 'sar', 'á', 'purtroppo', 'alcun', 'effetto', 'sassoli', 'sul', 'voto', 'per', 'il', 'quirinale', 'che', 'non', 'un', 'momento', 'per', 'la', 'politica', 'gentile', 'per', 'ôçª']
# ['rt', 'smenichini', 'sar', 'á', 'purtroppo', 'alcun', 'effetto', 'sassoli', 'voto', 'quirinale', 'momento', 'politica', 'gentile', 'ôçª']
# --------------------------------------------------
# 6 RT @DinoGiarrusso: Immaginatevi se @GiuseppeConteIT fosse andato in #CONFERENZASTAMPA con tre giorni di ritardo, escludendo un quotidiano eÔÇª
# <class 'str'>
# rt dinogiarrusso immaginatevi se giuseppeconteit fosse andato in conferenzastampa con tre giorni di ritardo escludendo un quotidiano eôçª
# ['rt', 'dinogiarrusso', 'immaginatevi', 'se', 'giuseppeconteit', 'fosse', 'andato', 'in', 'conferenzastampa', 'con', 'tre', 'giorni', 'di', 'ritardo', 'escludendo', 'un', 'quotidiano', 'eôçª']
# ['rt', 'dinogiarrusso', 'immaginatevi', 'giuseppeconteit', 'andato', 'conferenzastampa', 'tre', 'giorni', 'ritardo', 'escludendo', 'quotidiano', 'eôçª']
# --------------------------------------------------
# 7 E' fissata per le 16 di oggi pomeriggio la seduta d'Aula dell'Assemblea Regionale Siciliana che elegger├á i tre grandi elettori che dal 24 gennaio prossimo voteranno per il nuovo Presidente della Repubblica.
#  #Ars #Palermo #Quirinale
#
# https://t.co/kOTsCdHde5 https://t.co/elAayM8EYC
# <class 'str'>
# e fissata per le 16 di oggi pomeriggio la seduta daula dellassemblea regionale siciliana che elegger├á i tre grandi elettori che dal 24 gennaio prossimo voteranno per il nuovo presidente della repubblica
#  ars palermo quirinale
#
# httpstcokotscdhde5 httpstcoelaaym8eyc
# ['e', 'fissata', 'per', 'le', '16', 'di', 'oggi', 'pomeriggio', 'la', 'seduta', 'daula', 'dellassemblea', 'regionale', 'siciliana', 'che', 'elegger', 'á', 'i', 'tre', 'grandi', 'elettori', 'che', 'dal', '24', 'gennaio', 'prossimo', 'voteranno', 'per', 'il', 'nuovo', 'presidente', 'della', 'repubblica', 'ars', 'palermo', 'quirinale', 'httpstcokotscdhde5', 'httpstcoelaaym8eyc']
# ['fissata', '16', 'oggi', 'pomeriggio', 'seduta', 'daula', 'dellassemblea', 'regionale', 'siciliana', 'elegger', 'á', 'tre', 'grandi', 'elettori', '24', 'gennaio', 'prossimo', 'voteranno', 'nuovo', 'presidente', 'repubblica', 'ars', 'palermo', 'quirinale', 'httpstcokotscdhde5', 'httpstcoelaaym8eyc']
# --------------------------------------------------
# 8 RT @CCKKI: Dice #Berlusconi: "Se va #Draghi al #Quirinale si va al voto".
# Probabilmente #Mattarella sar├á costretto a disfare i bagagli e feÔÇª
# <class 'str'>
# rt cckki dice berlusconi se va draghi al quirinale si va al voto
# probabilmente mattarella sar├á costretto a disfare i bagagli e feôçª
# ['rt', 'cckki', 'dice', 'berlusconi', 'se', 'va', 'draghi', 'al', 'quirinale', 'si', 'va', 'al', 'voto', 'probabilmente', 'mattarella', 'sar', 'á', 'costretto', 'a', 'disfare', 'i', 'bagagli', 'e', 'feôçª']
# ['rt', 'cckki', 'dice', 'berlusconi', 'va', 'draghi', 'quirinale', 'va', 'voto', 'probabilmente', 'mattarella', 'sar', 'á', 'costretto', 'disfare', 'bagagli', 'feôçª']
# --------------------------------------------------
# 9 Il Corriere stila i possibili nomi per il #Quirinale, ma i vari #noQUIRISILVIO, Prodi, Casini e Cartabia mi fanno venire voglia di andare sotto la finestra di #Mattarella a piangere e gridare non ci lasciare ti prego
# <class 'str'>
# il corriere stila i possibili nomi per il quirinale ma i vari noquirisilvio prodi casini e cartabia mi fanno venire voglia di andare sotto la finestra di mattarella a piangere e gridare non ci lasciare ti prego
# ['il', 'corriere', 'stila', 'i', 'possibili', 'nomi', 'per', 'il', 'quirinale', 'ma', 'i', 'vari', 'noquirisilvio', 'prodi', 'casini', 'e', 'cartabia', 'mi', 'fanno', 'venire', 'voglia', 'di', 'andare', 'sotto', 'la', 'finestra', 'di', 'mattarella', 'a', 'piangere', 'e', 'gridare', 'non', 'ci', 'lasciare', 'ti', 'prego']
# ['corriere', 'stila', 'possibili', 'nomi', 'quirinale', 'vari', 'noquirisilvio', 'prodi', 'casini', 'cartabia', 'venire', 'voglia', 'andare', 'sotto', 'finestra', 'mattarella', 'piangere', 'gridare', 'lasciare', 'prego']
# --------------------------------------------------
# 10 RT @fattoquotidiano: #Quirinale, Cinque Stelle e Pd pensano di non scrivere nulla sulla scheda per le prime tre chiame, per poi andare sulÔÇª
# <class 'str'>
# rt fattoquotidiano quirinale cinque stelle e pd pensano di non scrivere nulla sulla scheda per le prime tre chiame per poi andare sulôçª
# ['rt', 'fattoquotidiano', 'quirinale', 'cinque', 'stelle', 'e', 'pd', 'pensano', 'di', 'non', 'scrivere', 'nulla', 'sulla', 'scheda', 'per', 'le', 'prime', 'tre', 'chiame', 'per', 'poi', 'andare', 'sulôçª']
# ['rt', 'fattoquotidiano', 'quirinale', 'cinque', 'stelle', 'pd', 'pensano', 'scrivere', 'nulla', 'scheda', 'prime', 'tre', 'chiame', 'poi', 'andare', 'sulôçª']
# --------------------------------------------------
# 11 Stefano Folli su @repubblica, quello che molti cittadini pensano #Quirinale https://t.co/iaH4AUDOGT
# <class 'str'>
# stefano folli su repubblica quello che molti cittadini pensano quirinale httpstcoiah4audogt
# ['stefano', 'folli', 'su', 'repubblica', 'quello', 'che', 'molti', 'cittadini', 'pensano', 'quirinale', 'httpstcoiah4audogt']
# ['stefano', 'folli', 'repubblica', 'molti', 'cittadini', 'pensano', 'quirinale', 'httpstcoiah4audogt']
# --------------------------------------------------
# 12 Perle di cinismo &amp; saggezza #Quirinale https://t.co/MfGj7xD0x7
# <class 'str'>
# perle di cinismo amp saggezza quirinale httpstcomfgj7xd0x7
# ['perle', 'di', 'cinismo', 'amp', 'saggezza', 'quirinale', 'httpstcomfgj7xd0x7']
# ['perle', 'cinismo', 'amp', 'saggezza', 'quirinale', 'httpstcomfgj7xd0x7']
# --------------------------------------------------
# 13 Di cose strane sul #totoquirinale ne ho lette parecchie, ma quella secondo cui il centrosinistra non potrebbe dire no a Letizia Moratti, "perch├® figlia di un partigiano" (La Stampa, oggi) le batte davvero tutte #quirinale #elezioniquirinale #presidentedellarepubblica
# <class 'str'>
# di cose strane sul totoquirinale ne ho lette parecchie ma quella secondo cui il centrosinistra non potrebbe dire no a letizia moratti perch├® figlia di un partigiano la stampa oggi le batte davvero tutte quirinale elezioniquirinale presidentedellarepubblica
# ['di', 'cose', 'strane', 'sul', 'totoquirinale', 'ne', 'ho', 'lette', 'parecchie', 'ma', 'quella', 'secondo', 'cui', 'il', 'centrosinistra', 'non', 'potrebbe', 'dire', 'no', 'a', 'letizia', 'moratti', 'perch', 'figlia', 'di', 'un', 'partigiano', 'la', 'stampa', 'oggi', 'le', 'batte', 'davvero', 'tutte', 'quirinale', 'elezioniquirinale', 'presidentedellarepubblica']
# ['cose', 'strane', 'totoquirinale', 'lette', 'parecchie', 'secondo', 'centrosinistra', 'potrebbe', 'dire', 'no', 'letizia', 'moratti', 'perch', 'figlia', 'partigiano', 'stampa', 'oggi', 'batte', 'davvero', 'tutte', 'quirinale', 'elezioniquirinale', 'presidentedellarepubblica']
# --------------------------------------------------
# 14 RT @CCKKI: Dice #Berlusconi: "Se va #Draghi al #Quirinale si va al voto".
# Probabilmente #Mattarella sar├á costretto a disfare i bagagli e feÔÇª
# <class 'str'>
# rt cckki dice berlusconi se va draghi al quirinale si va al voto
# probabilmente mattarella sar├á costretto a disfare i bagagli e feôçª
# ['rt', 'cckki', 'dice', 'berlusconi', 'se', 'va', 'draghi', 'al', 'quirinale', 'si', 'va', 'al', 'voto', 'probabilmente', 'mattarella', 'sar', 'á', 'costretto', 'a', 'disfare', 'i', 'bagagli', 'e', 'feôçª']
# ['rt', 'cckki', 'dice', 'berlusconi', 'va', 'draghi', 'quirinale', 'va', 'voto', 'probabilmente', 'mattarella', 'sar', 'á', 'costretto', 'disfare', 'bagagli', 'feôçª']
# --------------------------------------------------
# 15 RT @Murandrea1: Il #Quirinale ├¿ perno istituzionale, geopolitico, strategico dello Stato italiano.  La forza del Quirinale ├¿ quella di poteÔÇª
# <class 'str'>
# rt murandrea1 il quirinale ├¿ perno istituzionale geopolitico strategico dello stato italiano  la forza del quirinale ├¿ quella di poteôçª
# ['rt', 'murandrea1', 'il', 'quirinale', 'perno', 'istituzionale', 'geopolitico', 'strategico', 'dello', 'stato', 'italiano', 'la', 'forza', 'del', 'quirinale', 'quella', 'di', 'poteôçª']
# ['rt', 'murandrea1', 'quirinale', 'perno', 'istituzionale', 'geopolitico', 'strategico', 'stato', 'italiano', 'forza', 'quirinale', 'poteôçª']
# --------------------------------------------------
# 16 16 arresti a #catania per pizzo e usura.
# Addio a #sassoli. Delirio #novax sui social.
# #Bassetti ÔÇ£Non pubblichiamo pi├╣ il dato dei contagiÔÇØ.
# LÔÇÖARS scegli i grandi elettori per il #quirinale.
# Pronta la task force regionale per il #PNRR
#
# #edicola #primapagina #12gennaio https://t.co/osymboONnD
# <class 'str'>
# 16 arresti a catania per pizzo e usura
# addio a sassoli delirio novax sui social
# bassetti ôç£non pubblichiamo pi├╣ il dato dei contagiôçø
# lôçöars scegli i grandi elettori per il quirinale
# pronta la task force regionale per il pnrr
#
# edicola primapagina 12gennaio httpstcoosymboonnd
# ['16', 'arresti', 'a', 'catania', 'per', 'pizzo', 'e', 'usura', 'addio', 'a', 'sassoli', 'delirio', 'novax', 'sui', 'social', 'bassetti', 'ôç', 'non', 'pubblichiamo', 'pi', 'il', 'dato', 'dei', 'contagiôçø', 'lôçöars', 'scegli', 'i', 'grandi', 'elettori', 'per', 'il', 'quirinale', 'pronta', 'la', 'task', 'force', 'regionale', 'per', 'il', 'pnrr', 'edicola', 'primapagina', '12gennaio', 'httpstcoosymboonnd']
# ['16', 'arresti', 'catania', 'pizzo', 'usura', 'addio', 'sassoli', 'delirio', 'novax', 'social', 'bassetti', 'ôç', 'pubblichiamo', 'pi', 'dato', 'contagiôçø', 'lôçöars', 'scegli', 'grandi', 'elettori', 'quirinale', 'pronta', 'task', 'force', 'regionale', 'pnrr', 'edicola', 'primapagina', '12gennaio', 'httpstcoosymboonnd']
# --------------------------------------------------
# 17 RT @DinoGiarrusso: Immaginatevi se @GiuseppeConteIT fosse andato in #CONFERENZASTAMPA con tre giorni di ritardo, escludendo un quotidiano eÔÇª
# <class 'str'>
# rt dinogiarrusso immaginatevi se giuseppeconteit fosse andato in conferenzastampa con tre giorni di ritardo escludendo un quotidiano eôçª
# ['rt', 'dinogiarrusso', 'immaginatevi', 'se', 'giuseppeconteit', 'fosse', 'andato', 'in', 'conferenzastampa', 'con', 'tre', 'giorni', 'di', 'ritardo', 'escludendo', 'un', 'quotidiano', 'eôçª']
# ['rt', 'dinogiarrusso', 'immaginatevi', 'giuseppeconteit', 'andato', 'conferenzastampa', 'tre', 'giorni', 'ritardo', 'escludendo', 'quotidiano', 'eôçª']
# --------------------------------------------------
# 18 #Berlusconi ├¿ improponibile al #Quirinale. Un condannato in via definitiva e ancora sotto processo come pu├▓ diventare Presidente della Repubblica? Andr├á alla sbarra da imputato come presidente del Consiglio Superiore della Magistratura?
# <class 'str'>
# berlusconi ├¿ improponibile al quirinale un condannato in via definitiva e ancora sotto processo come pu├▓ diventare presidente della repubblica andr├á alla sbarra da imputato come presidente del consiglio superiore della magistratura
# ['berlusconi', 'improponibile', 'al', 'quirinale', 'un', 'condannato', 'in', 'via', 'definitiva', 'e', 'ancora', 'sotto', 'processo', 'come', 'pu', 'diventare', 'presidente', 'della', 'repubblica', 'andr', 'á', 'alla', 'sbarra', 'da', 'imputato', 'come', 'presidente', 'del', 'consiglio', 'superiore', 'della', 'magistratura']
# ['berlusconi', 'improponibile', 'quirinale', 'condannato', 'via', 'definitiva', 'ancora', 'sotto', 'processo', 'pu', 'diventare', 'presidente', 'repubblica', 'andr', 'á', 'sbarra', 'imputato', 'presidente', 'consiglio', 'superiore', 'magistratura']
# --------------------------------------------------
# 19 Quirinale, da oggi Berlusconi ha un voto in pi├╣, Toma: ┬½Per me Silvio Berlusconi sarebbe perfetto┬╗ #Quirinale #Berlusconi #toma https://t.co/GG8McaE19i via @MoliseWeb
# <class 'str'>
# quirinale da oggi berlusconi ha un voto in pi├╣ toma ┬½per me silvio berlusconi sarebbe perfetto┬╗ quirinale berlusconi toma httpstcogg8mcae19i via moliseweb
# ['quirinale', 'da', 'oggi', 'berlusconi', 'ha', 'un', 'voto', 'in', 'pi', 'toma', '½per', 'me', 'silvio', 'berlusconi', 'sarebbe', 'perfetto', 'quirinale', 'berlusconi', 'toma', 'httpstcogg8mcae19i', 'via', 'moliseweb']
# ['quirinale', 'oggi', 'berlusconi', 'voto', 'pi', 'toma', '½per', 'me', 'silvio', 'berlusconi', 'perfetto', 'quirinale', 'berlusconi', 'toma', 'httpstcogg8mcae19i', 'via', 'moliseweb']
# --------------------------------------------------
# 20 RT @fuskiko: Se la notizia ├¿ vera. Domani alla cara avvocatessa, una querela non gliela toglie nessuno. #quirinale chiediamo scuse imm├®diatÔÇª
# <class 'str'>
# rt fuskiko se la notizia ├¿ vera domani alla cara avvocatessa una querela non gliela toglie nessuno quirinale chiediamo scuse imm├®diatôçª
# ['rt', 'fuskiko', 'se', 'la', 'notizia', 'vera', 'domani', 'alla', 'cara', 'avvocatessa', 'una', 'querela', 'non', 'gliela', 'toglie', 'nessuno', 'quirinale', 'chiediamo', 'scuse', 'imm', 'diatôçª']
# ['rt', 'fuskiko', 'notizia', 'vera', 'domani', 'cara', 'avvocatessa', 'querela', 'gliela', 'toglie', 'nessuno', 'quirinale', 'chiediamo', 'scuse', 'imm', 'diatôçª']
# --------------------------------------------------
# 21 RT @fattoquotidiano: #Quirinale, Cinque Stelle e Pd pensano di non scrivere nulla sulla scheda per le prime tre chiame, per poi andare sulÔÇª
# <class 'str'>
# rt fattoquotidiano quirinale cinque stelle e pd pensano di non scrivere nulla sulla scheda per le prime tre chiame per poi andare sulôçª
# ['rt', 'fattoquotidiano', 'quirinale', 'cinque', 'stelle', 'e', 'pd', 'pensano', 'di', 'non', 'scrivere', 'nulla', 'sulla', 'scheda', 'per', 'le', 'prime', 'tre', 'chiame', 'per', 'poi', 'andare', 'sulôçª']
# ['rt', 'fattoquotidiano', 'quirinale', 'cinque', 'stelle', 'pd', 'pensano', 'scrivere', 'nulla', 'scheda', 'prime', 'tre', 'chiame', 'poi', 'andare', 'sulôçª']
# --------------------------------------------------
# 22 RT @CosoSono: #noQUIRISILVIO ­ƒö┤
#
# Cosa si fa per danaro?
#
# Anche eleggere un pregiudicato al #Quirinale ­ƒñ¼
# <class 'str'>
# rt cososono noquirisilvio ­ƒö┤
#
# cosa si fa per danaro
#
# anche eleggere un pregiudicato al quirinale ­ƒñ¼
# ['rt', 'cososono', 'noquirisilvio', 'ƒö', 'cosa', 'si', 'fa', 'per', 'danaro', 'anche', 'eleggere', 'un', 'pregiudicato', 'al', 'quirinale', 'ƒñ¼']
# ['rt', 'cososono', 'noquirisilvio', 'ƒö', 'cosa', 'fa', 'danaro', 'eleggere', 'pregiudicato', 'quirinale', 'ƒñ¼']
# --------------------------------------------------
# 23 RT @fuskiko: Se la notizia ├¿ vera. Domani alla cara avvocatessa, una querela non gliela toglie nessuno. #quirinale chiediamo scuse imm├®diatÔÇª
# <class 'str'>
# rt fuskiko se la notizia ├¿ vera domani alla cara avvocatessa una querela non gliela toglie nessuno quirinale chiediamo scuse imm├®diatôçª
# ['rt', 'fuskiko', 'se', 'la', 'notizia', 'vera', 'domani', 'alla', 'cara', 'avvocatessa', 'una', 'querela', 'non', 'gliela', 'toglie', 'nessuno', 'quirinale', 'chiediamo', 'scuse', 'imm', 'diatôçª']
# ['rt', 'fuskiko', 'notizia', 'vera', 'domani', 'cara', 'avvocatessa', 'querela', 'gliela', 'toglie', 'nessuno', 'quirinale', 'chiediamo', 'scuse', 'imm', 'diatôçª']
# --------------------------------------------------
# 24 RT @CCKKI: Dice #Berlusconi: "Se va #Draghi al #Quirinale si va al voto".
# Probabilmente #Mattarella sar├á costretto a disfare i bagagli e feÔÇª
# <class 'str'>
# rt cckki dice berlusconi se va draghi al quirinale si va al voto
# probabilmente mattarella sar├á costretto a disfare i bagagli e feôçª
# ['rt', 'cckki', 'dice', 'berlusconi', 'se', 'va', 'draghi', 'al', 'quirinale', 'si', 'va', 'al', 'voto', 'probabilmente', 'mattarella', 'sar', 'á', 'costretto', 'a', 'disfare', 'i', 'bagagli', 'e', 'feôçª']
# ['rt', 'cckki', 'dice', 'berlusconi', 'va', 'draghi', 'quirinale', 'va', 'voto', 'probabilmente', 'mattarella', 'sar', 'á', 'costretto', 'disfare', 'bagagli', 'feôçª']
# --------------------------------------------------
# 25 RT @fuskiko: Se la notizia ├¿ vera. Domani alla cara avvocatessa, una querela non gliela toglie nessuno. #quirinale chiediamo scuse imm├®diatÔÇª
# <class 'str'>
# rt fuskiko se la notizia ├¿ vera domani alla cara avvocatessa una querela non gliela toglie nessuno quirinale chiediamo scuse imm├®diatôçª
# ['rt', 'fuskiko', 'se', 'la', 'notizia', 'vera', 'domani', 'alla', 'cara', 'avvocatessa', 'una', 'querela', 'non', 'gliela', 'toglie', 'nessuno', 'quirinale', 'chiediamo', 'scuse', 'imm', 'diatôçª']
# ['rt', 'fuskiko', 'notizia', 'vera', 'domani', 'cara', 'avvocatessa', 'querela', 'gliela', 'toglie', 'nessuno', 'quirinale', 'chiediamo', 'scuse', 'imm', 'diatôçª']
# --------------------------------------------------
# 26 RT @fattoquotidiano: #Quirinale, Cinque Stelle e Pd pensano di non scrivere nulla sulla scheda per le prime tre chiame, per poi andare sulÔÇª
# <class 'str'>
# rt fattoquotidiano quirinale cinque stelle e pd pensano di non scrivere nulla sulla scheda per le prime tre chiame per poi andare sulôçª
# ['rt', 'fattoquotidiano', 'quirinale', 'cinque', 'stelle', 'e', 'pd', 'pensano', 'di', 'non', 'scrivere', 'nulla', 'sulla', 'scheda', 'per', 'le', 'prime', 'tre', 'chiame', 'per', 'poi', 'andare', 'sulôçª']
# ['rt', 'fattoquotidiano', 'quirinale', 'cinque', 'stelle', 'pd', 'pensano', 'scrivere', 'nulla', 'scheda', 'prime', 'tre', 'chiame', 'poi', 'andare', 'sulôçª']
# --------------------------------------------------
# 27 #Quirinale, Cinque Stelle e Pd pensano di non scrivere nulla sulla scheda per le prime tre chiame, per poi andare sul ÔÇ£bisÔÇØ o su Draghi. Conte incontrer├á Salvini [di @lucadecarolis e @WandaMarra] https://t.co/WM4donPLb7
# <class 'str'>
# quirinale cinque stelle e pd pensano di non scrivere nulla sulla scheda per le prime tre chiame per poi andare sul ôç£bisôçø o su draghi conte incontrer├á salvini di lucadecarolis e wandamarra httpstcowm4donplb7
# ['quirinale', 'cinque', 'stelle', 'e', 'pd', 'pensano', 'di', 'non', 'scrivere', 'nulla', 'sulla', 'scheda', 'per', 'le', 'prime', 'tre', 'chiame', 'per', 'poi', 'andare', 'sul', 'ôç', 'bisôçø', 'o', 'su', 'draghi', 'conte', 'incontrer', 'á', 'salvini', 'di', 'lucadecarolis', 'e', 'wandamarra', 'httpstcowm4donplb7']
# ['quirinale', 'cinque', 'stelle', 'pd', 'pensano', 'scrivere', 'nulla', 'scheda', 'prime', 'tre', 'chiame', 'poi', 'andare', 'ôç', 'bisôçø', 'draghi', 'conte', 'incontrer', 'á', 'salvini', 'lucadecarolis', 'wandamarra', 'httpstcowm4donplb7']
# --------------------------------------------------
# 28 RT @armanduplessis: Considerando anche alcune bizzarre ipotesi in campo per il #Quirinale, scrive Folli che "il Paese potrebbe aver bisognoÔÇª
# <class 'str'>
# rt armanduplessis considerando anche alcune bizzarre ipotesi in campo per il quirinale scrive folli che il paese potrebbe aver bisognoôçª
# ['rt', 'armanduplessis', 'considerando', 'anche', 'alcune', 'bizzarre', 'ipotesi', 'in', 'campo', 'per', 'il', 'quirinale', 'scrive', 'folli', 'che', 'il', 'paese', 'potrebbe', 'aver', 'bisognoôçª']
# ['rt', 'armanduplessis', 'considerando', 'alcune', 'bizzarre', 'ipotesi', 'campo', 'quirinale', 'scrive', 'folli', 'paese', 'potrebbe', 'aver', 'bisognoôçª']
# --------------------------------------------------
# 29 RT @smenichini: Non ci sar├á purtroppo alcun effetto #Sassoli sul voto per il #Quirinale, che non ├¿ un momento per la politica gentile. Per├▓ÔÇª
# <class 'str'>
# rt smenichini non ci sar├á purtroppo alcun effetto sassoli sul voto per il quirinale che non ├¿ un momento per la politica gentile per├▓ôçª
# ['rt', 'smenichini', 'non', 'ci', 'sar', 'á', 'purtroppo', 'alcun', 'effetto', 'sassoli', 'sul', 'voto', 'per', 'il', 'quirinale', 'che', 'non', 'un', 'momento', 'per', 'la', 'politica', 'gentile', 'per', 'ôçª']
# ['rt', 'smenichini', 'sar', 'á', 'purtroppo', 'alcun', 'effetto', 'sassoli', 'voto', 'quirinale', 'momento', 'politica', 'gentile', 'ôçª']
# --------------------------------------------------
# 30 RT @maurobiani: #PresidenteDellaRepubblica #Quirinale #Covid
# Corsa.
# Oggi su @repubblica https://t.co/wXMlZQLaoo
# <class 'str'>
# rt maurobiani presidentedellarepubblica quirinale covid
# corsa
# oggi su repubblica httpstcowxmlzqlaoo
# ['rt', 'maurobiani', 'presidentedellarepubblica', 'quirinale', 'covid', 'corsa', 'oggi', 'su', 'repubblica', 'httpstcowxmlzqlaoo']
# ['rt', 'maurobiani', 'presidentedellarepubblica', 'quirinale', 'covid', 'corsa', 'oggi', 'repubblica', 'httpstcowxmlzqlaoo']
# --------------------------------------------------
# 31 RT @LaNotiziaTweet: Draghi sogna il #Quirinale. Ma a Palazzo Chigi ha fallito quasi tutto. A partire da Recovery plan e campagna vaccinale.ÔÇª
# <class 'str'>
# rt lanotiziatweet draghi sogna il quirinale ma a palazzo chigi ha fallito quasi tutto a partire da recovery plan e campagna vaccinaleôçª
# ['rt', 'lanotiziatweet', 'draghi', 'sogna', 'il', 'quirinale', 'ma', 'a', 'palazzo', 'chigi', 'ha', 'fallito', 'quasi', 'tutto', 'a', 'partire', 'da', 'recovery', 'plan', 'e', 'campagna', 'vaccinaleôçª']
# ['rt', 'lanotiziatweet', 'draghi', 'sogna', 'quirinale', 'palazzo', 'chigi', 'fallito', 'quasi', 'partire', 'recovery', 'plan', 'campagna', 'vaccinaleôçª']
# --------------------------------------------------
# 32 RT @maurobiani: #PresidenteDellaRepubblica #Quirinale #Covid
# Corsa.
# Oggi su @repubblica https://t.co/wXMlZQLaoo
# <class 'str'>
# rt maurobiani presidentedellarepubblica quirinale covid
# corsa
# oggi su repubblica httpstcowxmlzqlaoo
# ['rt', 'maurobiani', 'presidentedellarepubblica', 'quirinale', 'covid', 'corsa', 'oggi', 'su', 'repubblica', 'httpstcowxmlzqlaoo']
# ['rt', 'maurobiani', 'presidentedellarepubblica', 'quirinale', 'covid', 'corsa', 'oggi', 'repubblica', 'httpstcowxmlzqlaoo']
# --------------------------------------------------
# 33 12 giorni allÔÇÖalba. #Quirinale
# <class 'str'>
# 12 giorni allôçöalba quirinale
# ['12', 'giorni', 'allôçöalba', 'quirinale']
# ['12', 'giorni', 'allôçöalba', 'quirinale']
# --------------------------------------------------
# 34 RT @LaNotiziaTweet: Draghi sogna il #Quirinale. Ma a Palazzo Chigi ha fallito quasi tutto. A partire da Recovery plan e campagna vaccinale.ÔÇª
# <class 'str'>
# rt lanotiziatweet draghi sogna il quirinale ma a palazzo chigi ha fallito quasi tutto a partire da recovery plan e campagna vaccinaleôçª
# ['rt', 'lanotiziatweet', 'draghi', 'sogna', 'il', 'quirinale', 'ma', 'a', 'palazzo', 'chigi', 'ha', 'fallito', 'quasi', 'tutto', 'a', 'partire', 'da', 'recovery', 'plan', 'e', 'campagna', 'vaccinaleôçª']
# ['rt', 'lanotiziatweet', 'draghi', 'sogna', 'quirinale', 'palazzo', 'chigi', 'fallito', 'quasi', 'partire', 'recovery', 'plan', 'campagna', 'vaccinaleôçª']
# --------------------------------------------------
# 35 RT @maurobiani: #PresidenteDellaRepubblica #Quirinale #Covid
# Corsa.
# Oggi su @repubblica https://t.co/wXMlZQLaoo
# <class 'str'>
# rt maurobiani presidentedellarepubblica quirinale covid
# corsa
# oggi su repubblica httpstcowxmlzqlaoo
# ['rt', 'maurobiani', 'presidentedellarepubblica', 'quirinale', 'covid', 'corsa', 'oggi', 'su', 'repubblica', 'httpstcowxmlzqlaoo']
# ['rt', 'maurobiani', 'presidentedellarepubblica', 'quirinale', 'covid', 'corsa', 'oggi', 'repubblica', 'httpstcowxmlzqlaoo']
# --------------------------------------------------
# 36 RT @thebrightside0: #buonoasapersi­ƒÆí
#
# La buona ed utile informazione ├¿ quella di @DavideGiac su @rtl1025 quando ricorda e sottolinea come l'ÔÇª
# <class 'str'>
# rt thebrightside0 buonoasapersi­ƒæí
#
# la buona ed utile informazione ├¿ quella di davidegiac su rtl1025 quando ricorda e sottolinea come lôçª
# ['rt', 'thebrightside0', 'buonoasapersi', 'ƒæí', 'la', 'buona', 'ed', 'utile', 'informazione', 'quella', 'di', 'davidegiac', 'su', 'rtl1025', 'quando', 'ricorda', 'e', 'sottolinea', 'come', 'lôçª']
# ['rt', 'thebrightside0', 'buonoasapersi', 'ƒæí', 'buona', 'utile', 'informazione', 'davidegiac', 'rtl1025', 'quando', 'ricorda', 'sottolinea', 'lôçª']
# --------------------------------------------------
# 37 #Quirinale Un Mattarella-bis unico, estremo tentativo per un centrosinistra in empasse sul candidato anti-Berlusconi. @domanigiornale illustra il piano Pd-M5S, per @ilfoglio_it Letta non sarebbe troppo entusiasta.
#
# #primapagina  #12gennaio  #FrontPage https://t.co/w4abCq9jmQ
# <class 'str'>
# quirinale un mattarellabis unico estremo tentativo per un centrosinistra in empasse sul candidato antiberlusconi domanigiornale illustra il piano pdm5s per ilfoglioit letta non sarebbe troppo entusiasta
#
# primapagina  12gennaio  frontpage httpstcow4abcq9jmq
# ['quirinale', 'un', 'mattarellabis', 'unico', 'estremo', 'tentativo', 'per', 'un', 'centrosinistra', 'in', 'empasse', 'sul', 'candidato', 'antiberlusconi', 'domanigiornale', 'illustra', 'il', 'piano', 'pdm5s', 'per', 'ilfoglioit', 'letta', 'non', 'sarebbe', 'troppo', 'entusiasta', 'primapagina', '12gennaio', 'frontpage', 'httpstcow4abcq9jmq']
# ['quirinale', 'mattarellabis', 'unico', 'estremo', 'tentativo', 'centrosinistra', 'empasse', 'candidato', 'antiberlusconi', 'domanigiornale', 'illustra', 'piano', 'pdm5s', 'ilfoglioit', 'letta', 'troppo', 'entusiasta', 'primapagina', '12gennaio', 'frontpage', 'httpstcow4abcq9jmq']
# --------------------------------------------------
# 38 @MartaGrande87 si legge sui giornali che una parte dei parlamentari 5stelle, te in primis, appoggia #casini al #Quirinale...spero siano solo fantasie della mente deviata dei giornalisti.....
# <class 'str'>
# martagrande87 si legge sui giornali che una parte dei parlamentari 5stelle te in primis appoggia casini al quirinalespero siano solo fantasie della mente deviata dei giornalisti
# ['martagrande87', 'si', 'legge', 'sui', 'giornali', 'che', 'una', 'parte', 'dei', 'parlamentari', '5stelle', 'te', 'in', 'primis', 'appoggia', 'casini', 'al', 'quirinalespero', 'siano', 'solo', 'fantasie', 'della', 'mente', 'deviata', 'dei', 'giornalisti']
# ['martagrande87', 'legge', 'giornali', 'parte', 'parlamentari', '5stelle', 'te', 'primis', 'appoggia', 'casini', 'quirinalespero', 'solo', 'fantasie', 'mente', 'deviata', 'giornalisti']
# --------------------------------------------------
# 39 RT @maurobiani: #PresidenteDellaRepubblica #Quirinale #Covid
# Corsa.
# Oggi su @repubblica https://t.co/wXMlZQLaoo
# <class 'str'>
# rt maurobiani presidentedellarepubblica quirinale covid
# corsa
# oggi su repubblica httpstcowxmlzqlaoo
# ['rt', 'maurobiani', 'presidentedellarepubblica', 'quirinale', 'covid', 'corsa', 'oggi', 'su', 'repubblica', 'httpstcowxmlzqlaoo']
# ['rt', 'maurobiani', 'presidentedellarepubblica', 'quirinale', 'covid', 'corsa', 'oggi', 'repubblica', 'httpstcowxmlzqlaoo']
# --------------------------------------------------
# 40 RT @qn_lanazione: #Quirinale - Grandi elettori toscani, la Lega non cede il posto https://t.co/wHfZUVkAZx via @qn_lanazione
# <class 'str'>
# rt qnlanazione quirinale  grandi elettori toscani la lega non cede il posto httpstcowhfzuvkazx via qnlanazione
# ['rt', 'qnlanazione', 'quirinale', 'grandi', 'elettori', 'toscani', 'la', 'lega', 'non', 'cede', 'il', 'posto', 'httpstcowhfzuvkazx', 'via', 'qnlanazione']
# ['rt', 'qnlanazione', 'quirinale', 'grandi', 'elettori', 'toscani', 'lega', 'cede', 'posto', 'httpstcowhfzuvkazx', 'via', 'qnlanazione']
# --------------------------------------------------
# 41 ­ƒöÁ ÔÇ£Orientarsi in questa fase non ├¿ semplice, sul #Quirinale ci sono poche certezze e molte incertezze. #Draghi vuole andare al #Colle al 100%ÔÇØ
#
# @claudiocerasa ­ƒÄÖ´©Å
# #nonstopnews
# ­ƒö┤ LIVE ÔûÂ´©Å https://t.co/iDld1y40ul https://t.co/DQK1XtDZAi
# <class 'str'>
# ­ƒöá ôç£orientarsi in questa fase non ├¿ semplice sul quirinale ci sono poche certezze e molte incertezze draghi vuole andare al colle al 100ôçø
#
# claudiocerasa ­ƒäö´©å
# nonstopnews
# ­ƒö┤ live ôûâ´©å httpstcoidld1y40ul httpstcodqk1xtdzai
# ['', 'ƒöá', 'ôç', 'orientarsi', 'in', 'questa', 'fase', 'non', 'semplice', 'sul', 'quirinale', 'ci', 'sono', 'poche', 'certezze', 'e', 'molte', 'incertezze', 'draghi', 'vuole', 'andare', 'al', 'colle', 'al', '100ôçø', 'claudiocerasa', 'ƒäö', 'å', 'nonstopnews', 'ƒö', 'live', 'ôûâ', 'å', 'httpstcoidld1y40ul', 'httpstcodqk1xtdzai']
# ['', 'ƒöá', 'ôç', 'orientarsi', 'fase', 'semplice', 'quirinale', 'poche', 'certezze', 'molte', 'incertezze', 'draghi', 'vuole', 'andare', 'colle', '100ôçø', 'claudiocerasa', 'ƒäö', 'å', 'nonstopnews', 'ƒö', 'live', 'ôûâ', 'å', 'httpstcoidld1y40ul', 'httpstcodqk1xtdzai']
# --------------------------------------------------
# 42 RT @CCKKI: Dice #Berlusconi: "Se va #Draghi al #Quirinale si va al voto".
# Probabilmente #Mattarella sar├á costretto a disfare i bagagli e feÔÇª
# <class 'str'>
# rt cckki dice berlusconi se va draghi al quirinale si va al voto
# probabilmente mattarella sar├á costretto a disfare i bagagli e feôçª
# ['rt', 'cckki', 'dice', 'berlusconi', 'se', 'va', 'draghi', 'al', 'quirinale', 'si', 'va', 'al', 'voto', 'probabilmente', 'mattarella', 'sar', 'á', 'costretto', 'a', 'disfare', 'i', 'bagagli', 'e', 'feôçª']
# ['rt', 'cckki', 'dice', 'berlusconi', 'va', 'draghi', 'quirinale', 'va', 'voto', 'probabilmente', 'mattarella', 'sar', 'á', 'costretto', 'disfare', 'bagagli', 'feôçª']
# --------------------------------------------------
# 43 Rosy Bindi al #Quirinale? ... Io credo ai miracoli. https://t.co/sGg51ffGFP
# <class 'str'>
# rosy bindi al quirinale  io credo ai miracoli httpstcosgg51ffgfp
# ['rosy', 'bindi', 'al', 'quirinale', 'io', 'credo', 'ai', 'miracoli', 'httpstcosgg51ffgfp']
# ['rosy', 'bindi', 'quirinale', 'credo', 'miracoli', 'httpstcosgg51ffgfp']
# --------------------------------------------------
# 44 #Quirinale Sembra che il Pd si appresti ad affossare il buon senso, come per il DdlZan. Alta politica
# <class 'str'>
# quirinale sembra che il pd si appresti ad affossare il buon senso come per il ddlzan alta politica
# ['quirinale', 'sembra', 'che', 'il', 'pd', 'si', 'appresti', 'ad', 'affossare', 'il', 'buon', 'senso', 'come', 'per', 'il', 'ddlzan', 'alta', 'politica']
# ['quirinale', 'sembra', 'pd', 'appresti', 'affossare', 'buon', 'senso', 'ddlzan', 'alta', 'politica']
# --------------------------------------------------
# 45 RT @Lombard5stelle: #Quirinale @dariovioli: "LÔÇÖipotesi che io possa votare Berlusconi non ├¿ semplicemente ridicola fantapolitica, ma unÔÇÖoffÔÇª
# <class 'str'>
# rt lombard5stelle quirinale dariovioli lôçöipotesi che io possa votare berlusconi non ├¿ semplicemente ridicola fantapolitica ma unôçöoffôçª
# ['rt', 'lombard5stelle', 'quirinale', 'dariovioli', 'lôçöipotesi', 'che', 'io', 'possa', 'votare', 'berlusconi', 'non', 'semplicemente', 'ridicola', 'fantapolitica', 'ma', 'unôçöoffôçª']
# ['rt', 'lombard5stelle', 'quirinale', 'dariovioli', 'lôçöipotesi', 'possa', 'votare', 'berlusconi', 'semplicemente', 'ridicola', 'fantapolitica', 'unôçöoffôçª']
# --------------------------------------------------
# 46 RT @LaNotiziaTweet: Draghi sogna il #Quirinale. Ma a Palazzo Chigi ha fallito quasi tutto. A partire da Recovery plan e campagna vaccinale.ÔÇª
# <class 'str'>
# rt lanotiziatweet draghi sogna il quirinale ma a palazzo chigi ha fallito quasi tutto a partire da recovery plan e campagna vaccinaleôçª
# ['rt', 'lanotiziatweet', 'draghi', 'sogna', 'il', 'quirinale', 'ma', 'a', 'palazzo', 'chigi', 'ha', 'fallito', 'quasi', 'tutto', 'a', 'partire', 'da', 'recovery', 'plan', 'e', 'campagna', 'vaccinaleôçª']
# ['rt', 'lanotiziatweet', 'draghi', 'sogna', 'quirinale', 'palazzo', 'chigi', 'fallito', 'quasi', 'partire', 'recovery', 'plan', 'campagna', 'vaccinaleôçª']
# --------------------------------------------------
# 47 RT @DinoGiarrusso: Immaginatevi se @GiuseppeConteIT fosse andato in #CONFERENZASTAMPA con tre giorni di ritardo, escludendo un quotidiano eÔÇª
# <class 'str'>
# rt dinogiarrusso immaginatevi se giuseppeconteit fosse andato in conferenzastampa con tre giorni di ritardo escludendo un quotidiano eôçª
# ['rt', 'dinogiarrusso', 'immaginatevi', 'se', 'giuseppeconteit', 'fosse', 'andato', 'in', 'conferenzastampa', 'con', 'tre', 'giorni', 'di', 'ritardo', 'escludendo', 'un', 'quotidiano', 'eôçª']
# ['rt', 'dinogiarrusso', 'immaginatevi', 'giuseppeconteit', 'andato', 'conferenzastampa', 'tre', 'giorni', 'ritardo', 'escludendo', 'quotidiano', 'eôçª']
# --------------------------------------------------
# 48 RT @GiampieroBiglia: ÔÇ£Lo stop di #Berlusconi a #Draghi :con lui al Colle noi fuori dal governoÔÇØ in una frase lÔÇÖarroganza, spregiudicatezzaÔÇª
# <class 'str'>
# rt giampierobiglia ôç£lo stop di berlusconi a draghi con lui al colle noi fuori dal governoôçø in una frase lôçöarroganza spregiudicatezzaôçª
# ['rt', 'giampierobiglia', 'ôç', 'lo', 'stop', 'di', 'berlusconi', 'a', 'draghi', 'con', 'lui', 'al', 'colle', 'noi', 'fuori', 'dal', 'governoôçø', 'in', 'una', 'frase', 'lôçöarroganza', 'spregiudicatezzaôçª']
# ['rt', 'giampierobiglia', 'ôç', 'stop', 'berlusconi', 'draghi', 'colle', 'fuori', 'governoôçø', 'frase', 'lôçöarroganza', 'spregiudicatezzaôçª']
# --------------------------------------------------
# 49 .@paolomieli: "Vi pare questo il modo di discutere sul Capo dello Stato a 10 giorni dalle votazioni? Proporre di richiamare Mattarella?" #Quirinale
# <class 'str'>
# paolomieli vi pare questo il modo di discutere sul capo dello stato a 10 giorni dalle votazioni proporre di richiamare mattarella quirinale
# ['paolomieli', 'vi', 'pare', 'questo', 'il', 'modo', 'di', 'discutere', 'sul', 'capo', 'dello', 'stato', 'a', '10', 'giorni', 'dalle', 'votazioni', 'proporre', 'di', 'richiamare', 'mattarella', 'quirinale']
# ['paolomieli', 'pare', 'modo', 'discutere', 'capo', 'stato', '10', 'giorni', 'votazioni', 'proporre', 'richiamare', 'mattarella', 'quirinale']
# --------------------------------------------------
# 50 RT @CosoSono: #noQUIRISILVIO ­ƒö┤
#
# Cosa si fa per danaro?
#
# Anche eleggere un pregiudicato al #Quirinale ­ƒñ¼
# <class 'str'>
# rt cososono noquirisilvio ­ƒö┤
#
# cosa si fa per danaro
#
# anche eleggere un pregiudicato al quirinale ­ƒñ¼
# ['rt', 'cososono', 'noquirisilvio', 'ƒö', 'cosa', 'si', 'fa', 'per', 'danaro', 'anche', 'eleggere', 'un', 'pregiudicato', 'al', 'quirinale', 'ƒñ¼']
# ['rt', 'cososono', 'noquirisilvio', 'ƒö', 'cosa', 'fa', 'danaro', 'eleggere', 'pregiudicato', 'quirinale', 'ƒñ¼']
# --------------------------------------------------
# 51 ÔÇ£Sgarbi chiama i parlamentari uno a uno, poi gli passa Berlusconi che augura buon anno e chiede il voto per il #QuirinaleÔÇØ
# E ve la siete presa con Montanari perch├® diceva Repubblica delle Banane
# <class 'str'>
# ôç£sgarbi chiama i parlamentari uno a uno poi gli passa berlusconi che augura buon anno e chiede il voto per il quirinaleôçø
# e ve la siete presa con montanari perch├® diceva repubblica delle banane
# ['ôç', 'sgarbi', 'chiama', 'i', 'parlamentari', 'uno', 'a', 'uno', 'poi', 'gli', 'passa', 'berlusconi', 'che', 'augura', 'buon', 'anno', 'e', 'chiede', 'il', 'voto', 'per', 'il', 'quirinaleôçø', 'e', 've', 'la', 'siete', 'presa', 'con', 'montanari', 'perch', 'diceva', 'repubblica', 'delle', 'banane']
# ['ôç', 'sgarbi', 'chiama', 'parlamentari', 'poi', 'passa', 'berlusconi', 'augura', 'buon', 'anno', 'chiede', 'voto', 'quirinaleôçø', 've', 'presa', 'montanari', 'perch', 'diceva', 'repubblica', 'banane']
# --------------------------------------------------
# 52 @elio_vito Elio, battute a parte, sei uno dei pochi che in questo paese riuscirebbe a mettere  d'accordo dx e sx, ma non hai fatto un pensiero per il #Quirinale. Stanotte ho sognato che diventava presidente della Repubblica Pillon ­ƒÿ¡­ƒÿ¡
# <class 'str'>
# eliovito elio battute a parte sei uno dei pochi che in questo paese riuscirebbe a mettere  daccordo dx e sx ma non hai fatto un pensiero per il quirinale stanotte ho sognato che diventava presidente della repubblica pillon ­ƒÿ¡­ƒÿ¡
# ['eliovito', 'elio', 'battute', 'a', 'parte', 'sei', 'uno', 'dei', 'pochi', 'che', 'in', 'questo', 'paese', 'riuscirebbe', 'a', 'mettere', 'daccordo', 'dx', 'e', 'sx', 'ma', 'non', 'hai', 'fatto', 'un', 'pensiero', 'per', 'il', 'quirinale', 'stanotte', 'ho', 'sognato', 'che', 'diventava', 'presidente', 'della', 'repubblica', 'pillon', 'ƒÿ', 'ƒÿ', '']
# ['eliovito', 'elio', 'battute', 'parte', 'pochi', 'paese', 'riuscirebbe', 'mettere', 'daccordo', 'dx', 'sx', 'fatto', 'pensiero', 'quirinale', 'stanotte', 'sognato', 'diventava', 'presidente', 'repubblica', 'pillon', 'ƒÿ', 'ƒÿ', '']
# --------------------------------------------------
# 53 .@paolomieli: "Dibattito sul #Quirinale svilente, si vede ricomparire il sempre uguale, ora chiedono a #Mattarella di restare ma c'├¿ un solo precedente quello di Napolitano che accett├▓ un secondo mandato ma solo dopo il patatrac delle prime votazioni".
# <class 'str'>
# paolomieli dibattito sul quirinale svilente si vede ricomparire il sempre uguale ora chiedono a mattarella di restare ma c├¿ un solo precedente quello di napolitano che accett├▓ un secondo mandato ma solo dopo il patatrac delle prime votazioni
# ['paolomieli', 'dibattito', 'sul', 'quirinale', 'svilente', 'si', 'vede', 'ricomparire', 'il', 'sempre', 'uguale', 'ora', 'chiedono', 'a', 'mattarella', 'di', 'restare', 'ma', 'c', 'un', 'solo', 'precedente', 'quello', 'di', 'napolitano', 'che', 'accett', 'un', 'secondo', 'mandato', 'ma', 'solo', 'dopo', 'il', 'patatrac', 'delle', 'prime', 'votazioni']
# ['paolomieli', 'dibattito', 'quirinale', 'svilente', 'vede', 'ricomparire', 'sempre', 'uguale', 'ora', 'chiedono', 'mattarella', 'restare', 'solo', 'precedente', 'napolitano', 'accett', 'secondo', 'mandato', 'solo', 'dopo', 'patatrac', 'prime', 'votazioni']
# --------------------------------------------------
# 54 ÔÇ£Immaginate se #mattarella dicesse ho scherzato ├¿ impossibile potrebbe tornare in campo solo di fronte a un disastro conclamato ÔÇ£
# @paolomieli @24Mattino #Quirinale
# <class 'str'>
# ôç£immaginate se mattarella dicesse ho scherzato ├¿ impossibile potrebbe tornare in campo solo di fronte a un disastro conclamato ôç£
# paolomieli 24mattino quirinale
# ['ôç', 'immaginate', 'se', 'mattarella', 'dicesse', 'ho', 'scherzato', 'impossibile', 'potrebbe', 'tornare', 'in', 'campo', 'solo', 'di', 'fronte', 'a', 'un', 'disastro', 'conclamato', 'ôç', 'paolomieli', '24mattino', 'quirinale']
# ['ôç', 'immaginate', 'mattarella', 'dicesse', 'scherzato', 'impossibile', 'potrebbe', 'tornare', 'campo', 'solo', 'fronte', 'disastro', 'conclamato', 'ôç', 'paolomieli', '24mattino', 'quirinale']
# --------------------------------------------------
# 55 RT @OrioliAlberto: Se la #Meloni desidera un patriota al #Quirinale dovrebbe leggere di piu` @AnpiPatria, rivista dell'#ANPI fondata nel 19ÔÇª
# <class 'str'>
# rt oriolialberto se la meloni desidera un patriota al quirinale dovrebbe leggere di piu anpipatria rivista dellanpi fondata nel 19ôçª
# ['rt', 'oriolialberto', 'se', 'la', 'meloni', 'desidera', 'un', 'patriota', 'al', 'quirinale', 'dovrebbe', 'leggere', 'di', 'piu', 'anpipatria', 'rivista', 'dellanpi', 'fondata', 'nel', '19ôçª']
# ['rt', 'oriolialberto', 'meloni', 'desidera', 'patriota', 'quirinale', 'dovrebbe', 'leggere', 'piu', 'anpipatria', 'rivista', 'dellanpi', 'fondata', '19ôçª']
# --------------------------------------------------
# 56 Ci mancava #Bersani e la sua lungimiranza!! Vorrei #MarioDraghi come  #PdR  per i prossimi sette anni (e non fino al 2023, sempre che ci si arrivi). Cio' darebbe peso,  credibilita' e stabilita' al ns Paese! .@matteorenzi  @AzioneCesena  #facciamorete #Quirinale @GiorgiaMeloni https://t.co/i85BInr7wL
# <class 'str'>
# ci mancava bersani e la sua lungimiranza vorrei mariodraghi come  pdr  per i prossimi sette anni e non fino al 2023 sempre che ci si arrivi cio darebbe peso  credibilita e stabilita al ns paese matteorenzi  azionecesena  facciamorete quirinale giorgiameloni httpstcoi85binr7wl
# ['ci', 'mancava', 'bersani', 'e', 'la', 'sua', 'lungimiranza', 'vorrei', 'mariodraghi', 'come', 'pdr', 'per', 'i', 'prossimi', 'sette', 'anni', 'e', 'non', 'fino', 'al', '2023', 'sempre', 'che', 'ci', 'si', 'arrivi', 'cio', 'darebbe', 'peso', 'credibilita', 'e', 'stabilita', 'al', 'ns', 'paese', 'matteorenzi', 'azionecesena', 'facciamorete', 'quirinale', 'giorgiameloni', 'httpstcoi85binr7wl']
# ['mancava', 'bersani', 'lungimiranza', 'vorrei', 'mariodraghi', 'pdr', 'prossimi', 'sette', 'anni', 'fino', '2023', 'sempre', 'arrivi', 'cio', 'darebbe', 'peso', 'credibilita', 'stabilita', 'ns', 'paese', 'matteorenzi', 'azionecesena', 'facciamorete', 'quirinale', 'giorgiameloni', 'httpstcoi85binr7wl']
# --------------------------------------------------
# 57 Negli episodi precedenti....(musichetta) #Quirinale https://t.co/kYI0x6vnCl
# <class 'str'>
# negli episodi precedentimusichetta quirinale httpstcokyi0x6vncl
# ['negli', 'episodi', 'precedentimusichetta', 'quirinale', 'httpstcokyi0x6vncl']
# ['episodi', 'precedentimusichetta', 'quirinale', 'httpstcokyi0x6vncl']
# --------------------------------------------------
# 58 #dimartedi Il segretario del Partito democratico Enrico Letta sul #Quirinale: ÔÇ£Ho notizie di parlamentari del nostro gruppo che hanno ricevuto una telefonata di Berlusconi in questi giorniÔÇØ
#
# Occhio alle sporche manovre.
# <class 'str'>
# dimartedi il segretario del partito democratico enrico letta sul quirinale ôç£ho notizie di parlamentari del nostro gruppo che hanno ricevuto una telefonata di berlusconi in questi giorniôçø
#
# occhio alle sporche manovre
# ['dimartedi', 'il', 'segretario', 'del', 'partito', 'democratico', 'enrico', 'letta', 'sul', 'quirinale', 'ôç', 'ho', 'notizie', 'di', 'parlamentari', 'del', 'nostro', 'gruppo', 'che', 'hanno', 'ricevuto', 'una', 'telefonata', 'di', 'berlusconi', 'in', 'questi', 'giorniôçø', 'occhio', 'alle', 'sporche', 'manovre']
# ['dimartedi', 'segretario', 'partito', 'democratico', 'enrico', 'letta', 'quirinale', 'ôç', 'notizie', 'parlamentari', 'gruppo', 'ricevuto', 'telefonata', 'berlusconi', 'giorniôçø', 'occhio', 'sporche', 'manovre']
# --------------------------------------------------
# 59 Il #Quirinale ├¿ perno istituzionale, geopolitico, strategico dello Stato italiano.  La forza del Quirinale ├¿ quella di poter disegnare la cornice entro cui la vita politico-istituzionale pu├▓ muoversi.
# @diss_ipatio
#
# https://t.co/v0lLp7c8Om
# <class 'str'>
# il quirinale ├¿ perno istituzionale geopolitico strategico dello stato italiano  la forza del quirinale ├¿ quella di poter disegnare la cornice entro cui la vita politicoistituzionale pu├▓ muoversi
# dissipatio
#
# httpstcov0llp7c8om
# ['il', 'quirinale', 'perno', 'istituzionale', 'geopolitico', 'strategico', 'dello', 'stato', 'italiano', 'la', 'forza', 'del', 'quirinale', 'quella', 'di', 'poter', 'disegnare', 'la', 'cornice', 'entro', 'cui', 'la', 'vita', 'politicoistituzionale', 'pu', 'muoversi', 'dissipatio', 'httpstcov0llp7c8om']
# ['quirinale', 'perno', 'istituzionale', 'geopolitico', 'strategico', 'stato', 'italiano', 'forza', 'quirinale', 'poter', 'disegnare', 'cornice', 'entro', 'vita', 'politicoistituzionale', 'pu', 'muoversi', 'dissipatio', 'httpstcov0llp7c8om']
# --------------------------------------------------
# 60 Vi aspettiamo a #Studio24, alle 10:00 su @RaiNews, con i nostri ospiti per parlare di:
#
# #OMS #VarianteOmicron #COVID19 #scuola #universit├á #ricerca #Draghi #Mattarella #Berlusconi #Quirinale #PresidenteDellaRepubblica #Sassoli #Europa
#
# Conduce @GiorgiaRomb https://t.co/dlKuuaKpu6
# <class 'str'>
# vi aspettiamo a studio24 alle 1000 su rainews con i nostri ospiti per parlare di
#
# oms varianteomicron covid19 scuola universit├á ricerca draghi mattarella berlusconi quirinale presidentedellarepubblica sassoli europa
#
# conduce giorgiaromb httpstcodlkuuakpu6
# ['vi', 'aspettiamo', 'a', 'studio24', 'alle', '1000', 'su', 'rainews', 'con', 'i', 'nostri', 'ospiti', 'per', 'parlare', 'di', 'oms', 'varianteomicron', 'covid19', 'scuola', 'universit', 'á', 'ricerca', 'draghi', 'mattarella', 'berlusconi', 'quirinale', 'presidentedellarepubblica', 'sassoli', 'europa', 'conduce', 'giorgiaromb', 'httpstcodlkuuakpu6']
# ['aspettiamo', 'studio24', '1000', 'rainews', 'ospiti', 'parlare', 'oms', 'varianteomicron', 'covid19', 'scuola', 'universit', 'á', 'ricerca', 'draghi', 'mattarella', 'berlusconi', 'quirinale', 'presidentedellarepubblica', 'sassoli', 'europa', 'conduce', 'giorgiaromb', 'httpstcodlkuuakpu6']
# --------------------------------------------------
# 61 #URBANI: ÔÇ£SUL #QUIRINALE #BERLUSCONI APRA GLI OCCHI, NON CI SONO LE ÔÇØ
#
# ÔÇ£DRAGHI MEGLIO A PALAZZO CHIGIÔÇØ
# https://t.co/wyu50PJcUP https://t.co/eB6kQFq6vV
# <class 'str'>
# urbani ôç£sul quirinale berlusconi apra gli occhi non ci sono le ôçø
#
# ôç£draghi meglio a palazzo chigiôçø
# httpstcowyu50pjcup httpstcoeb6kqfq6vv
# ['urbani', 'ôç', 'sul', 'quirinale', 'berlusconi', 'apra', 'gli', 'occhi', 'non', 'ci', 'sono', 'le', 'ôçø', 'ôç', 'draghi', 'meglio', 'a', 'palazzo', 'chigiôçø', 'httpstcowyu50pjcup', 'httpstcoeb6kqfq6vv']
# ['urbani', 'ôç', 'quirinale', 'berlusconi', 'apra', 'occhi', 'ôçø', 'ôç', 'draghi', 'meglio', 'palazzo', 'chigiôçø', 'httpstcowyu50pjcup', 'httpstcoeb6kqfq6vv']
# --------------------------------------------------
# ...
# ['rt', 'ilvetero', 'finalmente', 'candidatura', 'grado', 'mettere', 'dôçöaccordo', 'italiani', 'tutte', 'italiane', 'cristinapresidente', 'subitoôçª']
# --------------------------------------------------
# 478 RT @valy_s: A #Crisanti viene chiesto un parere su #Draghi e #Quirinale:
# ÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á dÔÇª
# <class 'str'>
# rt valys a crisanti viene chiesto un parere su draghi e quirinale
# ôç£├ê stato ôçÿsfortunatoôçö ci ha detto che avremmo avuto lôçöimmunit├á dôçª
# ['rt', 'valys', 'a', 'crisanti', 'viene', 'chiesto', 'un', 'parere', 'su', 'draghi', 'e', 'quirinale', 'ôç', 'ê', 'stato', 'ôçÿsfortunatoôçö', 'ci', 'ha', 'detto', 'che', 'avremmo', 'avuto', 'lôçöimmunit', 'á', 'dôçª']
# ['rt', 'valys', 'crisanti', 'viene', 'chiesto', 'parere', 'draghi', 'quirinale', 'ôç', 'ê', 'stato', 'ôçÿsfortunatoôçö', 'detto', 'lôçöimmunit', 'á', 'dôçª']
# --------------------------------------------------
# 479 RT @DinoGiarrusso: Immaginatevi se @GiuseppeConteIT fosse andato in #CONFERENZASTAMPA con tre giorni di ritardo, escludendo un quotidiano eÔÇª
# <class 'str'>
# rt dinogiarrusso immaginatevi se giuseppeconteit fosse andato in conferenzastampa con tre giorni di ritardo escludendo un quotidiano eôçª
# ['rt', 'dinogiarrusso', 'immaginatevi', 'se', 'giuseppeconteit', 'fosse', 'andato', 'in', 'conferenzastampa', 'con', 'tre', 'giorni', 'di', 'ritardo', 'escludendo', 'un', 'quotidiano', 'eôçª']
# ['rt', 'dinogiarrusso', 'immaginatevi', 'giuseppeconteit', 'andato', 'conferenzastampa', 'tre', 'giorni', 'ritardo', 'escludendo', 'quotidiano', 'eôçª']
# --------------------------------------------------
# 480 RT @LucillaMasini: QUESITO DI GENNAIO
#
# Fra avere Berlusconi Presidente della Repubblica e mangiare un chilo di mÔé¼rda, preferite il guano dÔÇª
# <class 'str'>
# rt lucillamasini quesito di gennaio
#
# fra avere berlusconi presidente della repubblica e mangiare un chilo di môé¼rda preferite il guano dôçª
# ['rt', 'lucillamasini', 'quesito', 'di', 'gennaio', 'fra', 'avere', 'berlusconi', 'presidente', 'della', 'repubblica', 'e', 'mangiare', 'un', 'chilo', 'di', 'môé¼rda', 'preferite', 'il', 'guano', 'dôçª']
# ['rt', 'lucillamasini', 'quesito', 'gennaio', 'fra', 'avere', 'berlusconi', 'presidente', 'repubblica', 'mangiare', 'chilo', 'môé¼rda', 'preferite', 'guano', 'dôçª']
# --------------------------------------------------
# 481 RT @DomaniGiornale: #Berlusconi ├¿ arrivato a #Roma, da dove prover├á il salto al #Quirinale: nonostante i suoi consiglieri lo abbiano cautamÔÇª
# <class 'str'>
# rt domanigiornale berlusconi ├¿ arrivato a roma da dove prover├á il salto al quirinale nonostante i suoi consiglieri lo abbiano cautamôçª
# ['rt', 'domanigiornale', 'berlusconi', 'arrivato', 'a', 'roma', 'da', 'dove', 'prover', 'á', 'il', 'salto', 'al', 'quirinale', 'nonostante', 'i', 'suoi', 'consiglieri', 'lo', 'abbiano', 'cautamôçª']
# ['rt', 'domanigiornale', 'berlusconi', 'arrivato', 'roma', 'prover', 'á', 'salto', 'quirinale', 'nonostante', 'consiglieri', 'cautamôçª']
# --------------------------------------------------
# 482 Il #centrodestra ├¿ diviso su #Berlusconi al #Quirinale. #Draghi resta in pole ma prende quota l'ipotesi di un bis di #Mattarella.
#
# https://t.co/c5kOJPGJ34
# <class 'str'>
# il centrodestra ├¿ diviso su berlusconi al quirinale draghi resta in pole ma prende quota lipotesi di un bis di mattarella
#
# httpstcoc5kojpgj34
# ['il', 'centrodestra', 'diviso', 'su', 'berlusconi', 'al', 'quirinale', 'draghi', 'resta', 'in', 'pole', 'ma', 'prende', 'quota', 'lipotesi', 'di', 'un', 'bis', 'di', 'mattarella', 'httpstcoc5kojpgj34']
# ['centrodestra', 'diviso', 'berlusconi', 'quirinale', 'draghi', 'resta', 'pole', 'prende', 'quota', 'lipotesi', 'bis', 'mattarella', 'httpstcoc5kojpgj34']
# --------------------------------------------------
# 483 RT @NicoFuccaro: Qualcuno ha capito qualcosa di quello che in iperpolitichese sta sostenendo @VeltroniWalter sul #Quirinale? (non che sia dÔÇª
# <class 'str'>
# rt nicofuccaro qualcuno ha capito qualcosa di quello che in iperpolitichese sta sostenendo veltroniwalter sul quirinale non che sia dôçª
# ['rt', 'nicofuccaro', 'qualcuno', 'ha', 'capito', 'qualcosa', 'di', 'quello', 'che', 'in', 'iperpolitichese', 'sta', 'sostenendo', 'veltroniwalter', 'sul', 'quirinale', 'non', 'che', 'sia', 'dôçª']
# ['rt', 'nicofuccaro', 'qualcuno', 'capito', 'qualcosa', 'iperpolitichese', 'sostenendo', 'veltroniwalter', 'quirinale', 'dôçª']
# --------------------------------------------------
# 484 RT @Lombard5stelle: #Quirinale @dariovioli: "LÔÇÖipotesi che io possa votare Berlusconi non ├¿ semplicemente ridicola fantapolitica, ma unÔÇÖoffÔÇª
# <class 'str'>
# rt lombard5stelle quirinale dariovioli lôçöipotesi che io possa votare berlusconi non ├¿ semplicemente ridicola fantapolitica ma unôçöoffôçª
# ['rt', 'lombard5stelle', 'quirinale', 'dariovioli', 'lôçöipotesi', 'che', 'io', 'possa', 'votare', 'berlusconi', 'non', 'semplicemente', 'ridicola', 'fantapolitica', 'ma', 'unôçöoffôçª']
# ['rt', 'lombard5stelle', 'quirinale', 'dariovioli', 'lôçöipotesi', 'possa', 'votare', 'berlusconi', 'semplicemente', 'ridicola', 'fantapolitica', 'unôçöoffôçª']
# --------------------------------------------------
# 485 RT @fabrizio19651: Una minaccia obliqua che  dimostra una volta di pi├╣ che non ha le caratteristiche per fare il #PresidenteDellaRepubblicaÔÇª
# <class 'str'>
# rt fabrizio19651 una minaccia obliqua che  dimostra una volta di pi├╣ che non ha le caratteristiche per fare il presidentedellarepubblicaôçª
# ['rt', 'fabrizio19651', 'una', 'minaccia', 'obliqua', 'che', 'dimostra', 'una', 'volta', 'di', 'pi', 'che', 'non', 'ha', 'le', 'caratteristiche', 'per', 'fare', 'il', 'presidentedellarepubblicaôçª']
# ['rt', 'fabrizio19651', 'minaccia', 'obliqua', 'dimostra', 'volta', 'pi', 'caratteristiche', 'fare', 'presidentedellarepubblicaôçª']
# --------------------------------------------------
# 486 Lo smemorato di Cologno al #Quirinale lo voglio vedere solo in una puntata di @fratellicrozza
# <class 'str'>
# lo smemorato di cologno al quirinale lo voglio vedere solo in una puntata di fratellicrozza
# ['lo', 'smemorato', 'di', 'cologno', 'al', 'quirinale', 'lo', 'voglio', 'vedere', 'solo', 'in', 'una', 'puntata', 'di', 'fratellicrozza']
# ['smemorato', 'cologno', 'quirinale', 'voglio', 'vedere', 'solo', 'puntata', 'fratellicrozza']
# --------------------------------------------------
# 487 RT @S_Giacomoni: #Quirinale. Saranno le regole della #democrazia a scegliere­ƒù│
#
# ­ƒöÁ Sono convinto che #Berlusconi al #Colle e #Draghi al #GovÔÇª
# <class 'str'>
# rt sgiacomoni quirinale saranno le regole della democrazia a scegliere­ƒù│
#
# ­ƒöá sono convinto che berlusconi al colle e draghi al govôçª
# ['rt', 'sgiacomoni', 'quirinale', 'saranno', 'le', 'regole', 'della', 'democrazia', 'a', 'scegliere', 'ƒù', 'ƒöá', 'sono', 'convinto', 'che', 'berlusconi', 'al', 'colle', 'e', 'draghi', 'al', 'govôçª']
# ['rt', 'sgiacomoni', 'quirinale', 'regole', 'democrazia', 'scegliere', 'ƒù', 'ƒöá', 'convinto', 'berlusconi', 'colle', 'draghi', 'govôçª']
# --------------------------------------------------
# 488 RT @valy_s: A #Crisanti viene chiesto un parere su #Draghi e #Quirinale:
# ÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á dÔÇª
# <class 'str'>
# rt valys a crisanti viene chiesto un parere su draghi e quirinale
# ôç£├ê stato ôçÿsfortunatoôçö ci ha detto che avremmo avuto lôçöimmunit├á dôçª
# ['rt', 'valys', 'a', 'crisanti', 'viene', 'chiesto', 'un', 'parere', 'su', 'draghi', 'e', 'quirinale', 'ôç', 'ê', 'stato', 'ôçÿsfortunatoôçö', 'ci', 'ha', 'detto', 'che', 'avremmo', 'avuto', 'lôçöimmunit', 'á', 'dôçª']
# ['rt', 'valys', 'crisanti', 'viene', 'chiesto', 'parere', 'draghi', 'quirinale', 'ôç', 'ê', 'stato', 'ôçÿsfortunatoôçö', 'detto', 'lôçöimmunit', 'á', 'dôçª']
# --------------------------------------------------
# 489 RT @valy_s: A #Crisanti viene chiesto un parere su #Draghi e #Quirinale:
# ÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á dÔÇª
# <class 'str'>
# rt valys a crisanti viene chiesto un parere su draghi e quirinale
# ôç£├ê stato ôçÿsfortunatoôçö ci ha detto che avremmo avuto lôçöimmunit├á dôçª
# ['rt', 'valys', 'a', 'crisanti', 'viene', 'chiesto', 'un', 'parere', 'su', 'draghi', 'e', 'quirinale', 'ôç', 'ê', 'stato', 'ôçÿsfortunatoôçö', 'ci', 'ha', 'detto', 'che', 'avremmo', 'avuto', 'lôçöimmunit', 'á', 'dôçª']
# ['rt', 'valys', 'crisanti', 'viene', 'chiesto', 'parere', 'draghi', 'quirinale', 'ôç', 'ê', 'stato', 'ôçÿsfortunatoôçö', 'detto', 'lôçöimmunit', 'á', 'dôçª']
# --------------------------------------------------
# 490 Quirinale la segreteria Pd decide di non decidere. La candidatura di Berlusconi angoscia Letta -  #Quirinale #segreteria #decide  https://t.co/YHC1UzasAF
# <class 'str'>
# quirinale la segreteria pd decide di non decidere la candidatura di berlusconi angoscia letta   quirinale segreteria decide  httpstcoyhc1uzasaf
# ['quirinale', 'la', 'segreteria', 'pd', 'decide', 'di', 'non', 'decidere', 'la', 'candidatura', 'di', 'berlusconi', 'angoscia', 'letta', 'quirinale', 'segreteria', 'decide', 'httpstcoyhc1uzasaf']
# ['quirinale', 'segreteria', 'pd', 'decide', 'decidere', 'candidatura', 'berlusconi', 'angoscia', 'letta', 'quirinale', 'segreteria', 'decide', 'httpstcoyhc1uzasaf']
# --------------------------------------------------
# 491 Canditati per il #Quirinale -1 https://t.co/grTSJWHtTY
# <class 'str'>
# canditati per il quirinale 1 httpstcogrtsjwhtty
# ['canditati', 'per', 'il', 'quirinale', '1', 'httpstcogrtsjwhtty']
# ['canditati', 'quirinale', '1', 'httpstcogrtsjwhtty']
# --------------------------------------------------
# 492 RT @valy_s: A #Crisanti viene chiesto un parere su #Draghi e #Quirinale:
# ÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á dÔÇª
# <class 'str'>
# rt valys a crisanti viene chiesto un parere su draghi e quirinale
# ôç£├ê stato ôçÿsfortunatoôçö ci ha detto che avremmo avuto lôçöimmunit├á dôçª
# ['rt', 'valys', 'a', 'crisanti', 'viene', 'chiesto', 'un', 'parere', 'su', 'draghi', 'e', 'quirinale', 'ôç', 'ê', 'stato', 'ôçÿsfortunatoôçö', 'ci', 'ha', 'detto', 'che', 'avremmo', 'avuto', 'lôçöimmunit', 'á', 'dôçª']
# ['rt', 'valys', 'crisanti', 'viene', 'chiesto', 'parere', 'draghi', 'quirinale', 'ôç', 'ê', 'stato', 'ôçÿsfortunatoôçö', 'detto', 'lôçöimmunit', 'á', 'dôçª']
# --------------------------------------------------
# 493 RT @valy_s: A #Crisanti viene chiesto un parere su #Draghi e #Quirinale:
# ÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á dÔÇª
# <class 'str'>
# rt valys a crisanti viene chiesto un parere su draghi e quirinale
# ôç£├ê stato ôçÿsfortunatoôçö ci ha detto che avremmo avuto lôçöimmunit├á dôçª
# ['rt', 'valys', 'a', 'crisanti', 'viene', 'chiesto', 'un', 'parere', 'su', 'draghi', 'e', 'quirinale', 'ôç', 'ê', 'stato', 'ôçÿsfortunatoôçö', 'ci', 'ha', 'detto', 'che', 'avremmo', 'avuto', 'lôçöimmunit', 'á', 'dôçª']
# ['rt', 'valys', 'crisanti', 'viene', 'chiesto', 'parere', 'draghi', 'quirinale', 'ôç', 'ê', 'stato', 'ôçÿsfortunatoôçö', 'detto', 'lôçöimmunit', 'á', 'dôçª']
# --------------------------------------------------
# 494 RT @valy_s: A #Crisanti viene chiesto un parere su #Draghi e #Quirinale:
# ÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á dÔÇª
# <class 'str'>
# rt valys a crisanti viene chiesto un parere su draghi e quirinale
# ôç£├ê stato ôçÿsfortunatoôçö ci ha detto che avremmo avuto lôçöimmunit├á dôçª
# ['rt', 'valys', 'a', 'crisanti', 'viene', 'chiesto', 'un', 'parere', 'su', 'draghi', 'e', 'quirinale', 'ôç', 'ê', 'stato', 'ôçÿsfortunatoôçö', 'ci', 'ha', 'detto', 'che', 'avremmo', 'avuto', 'lôçöimmunit', 'á', 'dôçª']
# ['rt', 'valys', 'crisanti', 'viene', 'chiesto', 'parere', 'draghi', 'quirinale', 'ôç', 'ê', 'stato', 'ôçÿsfortunatoôçö', 'detto', 'lôçöimmunit', 'á', 'dôçª']
# --------------------------------------------------
# 495 #Quirinale #Berlusconi #Draghi #PresidenteDellaRepubblica  https://t.co/uoCuFPo59S
# <class 'str'>
# quirinale berlusconi draghi presidentedellarepubblica  httpstcouocufpo59s
# ['quirinale', 'berlusconi', 'draghi', 'presidentedellarepubblica', 'httpstcouocufpo59s']
# ['quirinale', 'berlusconi', 'draghi', 'presidentedellarepubblica', 'httpstcouocufpo59s']
# --------------------------------------------------
# 496 #ottoemezzo Walter Veltroni sulla prossima elezione del Capo dello Stato: "Non possiamo permetterci di perdere in un colpo solo sia #Draghi sia #Mattarella" @VeltroniWalter #quirinale https://t.co/VL1ETJJybt
# <class 'str'>
# ottoemezzo walter veltroni sulla prossima elezione del capo dello stato non possiamo permetterci di perdere in un colpo solo sia draghi sia mattarella veltroniwalter quirinale httpstcovl1etjjybt
# ['ottoemezzo', 'walter', 'veltroni', 'sulla', 'prossima', 'elezione', 'del', 'capo', 'dello', 'stato', 'non', 'possiamo', 'permetterci', 'di', 'perdere', 'in', 'un', 'colpo', 'solo', 'sia', 'draghi', 'sia', 'mattarella', 'veltroniwalter', 'quirinale', 'httpstcovl1etjjybt']
# ['ottoemezzo', 'walter', 'veltroni', 'prossima', 'elezione', 'capo', 'stato', 'possiamo', 'permetterci', 'perdere', 'colpo', 'solo', 'draghi', 'mattarella', 'veltroniwalter', 'quirinale', 'httpstcovl1etjjybt']
# --------------------------------------------------
# 497 A #Crisanti viene chiesto un parere su #Draghi e #Quirinale:
# ÔÇ£├ê stato ÔÇÿsfortunatoÔÇÖ. Ci ha detto che avremmo avuto lÔÇÖimmunit├á di gregge, che il #greenpass ci avrebbe protetto dal contagio e poi ├¿ arrivata #Omicron. Per fortuna ├¿ pi├╣ ÔÇ£leggeraÔÇØÔÇØ
# #ottoemezzo
# <class 'str'>
# a crisanti viene chiesto un parere su draghi e quirinale
# ôç£├ê stato ôçÿsfortunatoôçö ci ha detto che avremmo avuto lôçöimmunit├á di gregge che il greenpass ci avrebbe protetto dal contagio e poi ├¿ arrivata omicron per fortuna ├¿ pi├╣ ôç£leggeraôçøôçø
# ottoemezzo
# ['a', 'crisanti', 'viene', 'chiesto', 'un', 'parere', 'su', 'draghi', 'e', 'quirinale', 'ôç', 'ê', 'stato', 'ôçÿsfortunatoôçö', 'ci', 'ha', 'detto', 'che', 'avremmo', 'avuto', 'lôçöimmunit', 'á', 'di', 'gregge', 'che', 'il', 'greenpass', 'ci', 'avrebbe', 'protetto', 'dal', 'contagio', 'e', 'poi', 'arrivata', 'omicron', 'per', 'fortuna', 'pi', 'ôç', 'leggeraôçøôçø', 'ottoemezzo']
# ['crisanti', 'viene', 'chiesto', 'parere', 'draghi', 'quirinale', 'ôç', 'ê', 'stato', 'ôçÿsfortunatoôçö', 'detto', 'lôçöimmunit', 'á', 'gregge', 'greenpass', 'protetto', 'contagio', 'poi', 'arrivata', 'omicron', 'fortuna', 'pi', 'ôç', 'leggeraôçøôçø', 'ottoemezzo']
# --------------------------------------------------
# 498 RT @AdolfoTasinato: Per il giornale inglese The Guardian in Italia non vige un sistema democratico. #Draghi #Italy #Italia #democrazia #PolÔÇª
# <class 'str'>
# rt adolfotasinato per il giornale inglese the guardian in italia non vige un sistema democratico draghi italy italia democrazia polôçª
# ['rt', 'adolfotasinato', 'per', 'il', 'giornale', 'inglese', 'the', 'guardian', 'in', 'italia', 'non', 'vige', 'un', 'sistema', 'democratico', 'draghi', 'italy', 'italia', 'democrazia', 'polôçª']
# ['rt', 'adolfotasinato', 'giornale', 'inglese', 'the', 'guardian', 'italia', 'vige', 'sistema', 'democratico', 'draghi', 'italy', 'italia', 'democrazia', 'polôçª']
# --------------------------------------------------
# 499 #ottoemezzo #quirinale
# #Crisanti scopri l'intruso
# <class 'str'>
# ottoemezzo quirinale
# crisanti scopri lintruso
# ['ottoemezzo', 'quirinale', 'crisanti', 'scopri', 'lintruso']
# ['ottoemezzo', 'quirinale', 'crisanti', 'scopri', 'lintruso']
# --------------------------------------------------
# 500 Berlusconi al #Quirinale in questo periodo storico non si pu├▓ sopportare #ottoemezzo .
# <class 'str'>
# berlusconi al quirinale in questo periodo storico non si pu├▓ sopportare ottoemezzo
# ['berlusconi', 'al', 'quirinale', 'in', 'questo', 'periodo', 'storico', 'non', 'si', 'pu', 'sopportare', 'ottoemezzo', '']
# ['berlusconi', 'quirinale', 'periodo', 'storico', 'pu', 'sopportare', 'ottoemezzo', '']
# --------------------------------------------------
# 501
# <class 'str'>
#
# ['']
# ['']
# --------------------------------------------------

# %%
lista_token_m2 = []
for lista in token_list:
    li_i = []
    for li in lista: 
        if len(li) > 2: 
            li_i.append(li)
    lista_token_m2.append(li_i)

# %%
lista_token_m2
# Out:
# [['pschioppa',
#   'delegati',
#   'regionali',
#   'scelti',
#   'grandi',
#   'elettori',
#   'quirinale',
#   'viste',
#   'appartenenze',
#   'mai',
#   'facendoôçª'],
#  ['siamonoitv2000',
#   'corsa',
#   'quirinale',
#   'speciale',
#   'siamonoi',
#   '1515',
#   'tv2000it',
#   'giuspaterniti',
#   'paolograldi',
#   'francobechis',
#   'ôçª'],
#  ['siamonoi',
#   '1515',
#   'tv2000it',
#   'quirinale',
#   '12gennaio',
#   'canale28',
#   'siamonoitv2000',
#   'francobechis',
#   'giuspaterniti',
#   'paolograldi',
#   'ilmessaggeroit',
#   'tempoweb',
#   'gabrifacondo',
#   'httpstcorxcdpgciy0'],
#  ['dopo',
#   'mesi',
#   'mattarella',
#   'detto',
#   'pensava',
#   'nemmeno',
#   'ora',
#   'ripropongono',
#   'mattarella',
#   'secondo',
#   'incarico',
#   'cos',
#   'tranquillamente',
#   'cosa',
#   'fattibile',
#   'mondo',
#   'quirinale'],
#  ['smenichini',
#   'sar',
#   'purtroppo',
#   'alcun',
#   'effetto',
#   'sassoli',
#   'voto',
#   'quirinale',
#   'momento',
#   'politica',
#   'gentile',
#   'ôçª'],
#  ['dinogiarrusso',
#   'immaginatevi',
#   'giuseppeconteit',
#   'andato',
#   'conferenzastampa',
#   'tre',
#   'giorni',
#   'ritardo',
#   'escludendo',
#   'quotidiano',
#   'eôçª'],
#  ['fissata',
#   'oggi',
#   'pomeriggio',
#   'seduta',
#   'daula',
#   'dellassemblea',
#   'regionale',
#   'siciliana',
#   'elegger',
#   'tre',
#   'grandi',
#   'elettori',
#   'gennaio',
#   'prossimo',
#   'voteranno',
#   'nuovo',
#   'presidente',
#   'repubblica',
#   'ars',
#   'palermo',
#   'quirinale',
#   'httpstcokotscdhde5',
#   'httpstcoelaaym8eyc'],
#  ['cckki',
#   'dice',
#   'berlusconi',
#   'draghi',
#   'quirinale',
#   'voto',
#   'probabilmente',
#   'mattarella',
#   'sar',
#   'costretto',
#   'disfare',
#   'bagagli',
#   'feôçª'],
#  ['corriere',
#   'stila',
#   'possibili',
#   'nomi',
#   'quirinale',
#   'vari',
#   'noquirisilvio',
#   'prodi',
#   'casini',
#   'cartabia',
#   'venire',
#   'voglia',
#   'andare',
#   'sotto',
#   'finestra',
#   'mattarella',
#   'piangere',
#   'gridare',
#   'lasciare',
#   'prego'],
#  ['fattoquotidiano',
#   'quirinale',
#   'cinque',
#   'stelle',
#   'pensano',
#   'scrivere',
#   'nulla',
#   'scheda',
#   'prime',
#   'tre',
#   'chiame',
#   'poi',
#   'andare',
#   'sulôçª'],
#  ['stefano',
#   'folli',
#   'repubblica',
#   'molti',
#   'cittadini',
#   'pensano',
#   'quirinale',
#   'httpstcoiah4audogt'],
#  ['perle', 'cinismo', 'amp', 'saggezza', 'quirinale', 'httpstcomfgj7xd0x7'],
#  ['cose',
#   'strane',
#   'totoquirinale',
#   'lette',
#   'parecchie',
#   'secondo',
#   'centrosinistra',
#   'potrebbe',
#   'dire',
#   'letizia',
#   'moratti',
#   'perch',
#   'figlia',
#   'partigiano',
#   'stampa',
#   'oggi',
#   'batte',
#   'davvero',
#   'tutte',
#   'quirinale',
#   'elezioniquirinale',
#   'presidentedellarepubblica'],
#  ['cckki',
#   'dice',
#   'berlusconi',
#   'draghi',
#   'quirinale',
#   'voto',
#   'probabilmente',
#   'mattarella',
#   'sar',
#   'costretto',
#   'disfare',
#   'bagagli',
#   'feôçª'],
#  ['murandrea1',
#   'quirinale',
#   'perno',
#   'istituzionale',
#   'geopolitico',
#   'strategico',
#   'stato',
#   'italiano',
#   'forza',
#   'quirinale',
#   'poteôçª'],
#  ['arresti',
#   'catania',
#   'pizzo',
#   'usura',
#   'addio',
#   'sassoli',
#   'delirio',
#   'novax',
#   'social',
#   'bassetti',
#   'pubblichiamo',
#   'dato',
#   'contagiôçø',
#   'lôçöars',
#   'scegli',
#   'grandi',
#   'elettori',
#   'quirinale',
#   'pronta',
#   'task',
#   'force',
#   'regionale',
#   'pnrr',
#   'edicola',
#   'primapagina',
#   '12gennaio',
#   'httpstcoosymboonnd'],
#  ['dinogiarrusso',
#   'immaginatevi',
#   'giuseppeconteit',
#   'andato',
#   'conferenzastampa',
#   'tre',
#   'giorni',
#   'ritardo',
#   'escludendo',
#   'quotidiano',
#   'eôçª'],
#  ['berlusconi',
#   'improponibile',
#   'quirinale',
#   'condannato',
#   'via',
#   'definitiva',
#   'ancora',
#   'sotto',
#   'processo',
#   'diventare',
#   'presidente',
#   'repubblica',
#   'andr',
#   'sbarra',
#   'imputato',
#   'presidente',
#   'consiglio',
#   'superiore',
#   'magistratura'],
#  ['quirinale',
#   'oggi',
#   'berlusconi',
#   'voto',
#   'toma',
#   '½per',
#   'silvio',
#   'berlusconi',
#   'perfetto',
#   'quirinale',
#   'berlusconi',
#   'toma',
#   'httpstcogg8mcae19i',
#   'via',
#   'moliseweb'],
#  ['fuskiko',
#   'notizia',
#   'vera',
#   'domani',
#   'cara',
#   'avvocatessa',
#   'querela',
#   'gliela',
#   'toglie',
#   'nessuno',
#   'quirinale',
#   'chiediamo',
#   'scuse',
#   'imm',
#   'diatôçª'],
#  ['fattoquotidiano',
#   'quirinale',
#   'cinque',
#   'stelle',
#   'pensano',
#   'scrivere',
#   'nulla',
#   'scheda',
#   'prime',
#   'tre',
#   'chiame',
#   'poi',
#   'andare',
#   'sulôçª'],
#  ['cososono',
#   'noquirisilvio',
#   'cosa',
#   'danaro',
#   'eleggere',
#   'pregiudicato',
#   'quirinale',
#   'ƒñ¼'],
#  ['fuskiko',
#   'notizia',
#   'vera',
#   'domani',
#   'cara',
#   'avvocatessa',
#   'querela',
#   'gliela',
#   'toglie',
#   'nessuno',
#   'quirinale',
#   'chiediamo',
#   'scuse',
#   'imm',
#   'diatôçª'],
#  ['cckki',
#   'dice',
#   'berlusconi',
#   'draghi',
#   'quirinale',
#   'voto',
#   'probabilmente',
#   'mattarella',
#   'sar',
#   'costretto',
#   'disfare',
#   'bagagli',
#   'feôçª'],
#  ['fuskiko',
#   'notizia',
#   'vera',
#   'domani',
#   'cara',
#   'avvocatessa',
#   'querela',
#   'gliela',
#   'toglie',
#   'nessuno',
#   'quirinale',
#   'chiediamo',
#   'scuse',
#   'imm',
#   'diatôçª'],
#  ['fattoquotidiano',
#   'quirinale',
#   'cinque',
#   'stelle',
#   'pensano',
#   'scrivere',
#   'nulla',
#   'scheda',
#   'prime',
#   'tre',
#   'chiame',
#   'poi',
#   'andare',
#   'sulôçª'],
#  ['quirinale',
#   'cinque',
#   'stelle',
#   'pensano',
#   'scrivere',
#   'nulla',
#   'scheda',
#   'prime',
#   'tre',
#   'chiame',
#   'poi',
#   'andare',
#   'bisôçø',
#   'draghi',
#   'conte',
#   'incontrer',
#   'salvini',
#   'lucadecarolis',
#   'wandamarra',
#   'httpstcowm4donplb7'],
#  ['armanduplessis',
#   'considerando',
#   'alcune',
#   'bizzarre',
#   'ipotesi',
#   'campo',
#   'quirinale',
#   'scrive',
#   'folli',
#   'paese',
#   'potrebbe',
#   'aver',
#   'bisognoôçª'],
#  ['smenichini',
#   'sar',
#   'purtroppo',
#   'alcun',
#   'effetto',
#   'sassoli',
#   'voto',
#   'quirinale',
#   'momento',
#   'politica',
#   'gentile',
#   'ôçª'],
#  ['maurobiani',
#   'presidentedellarepubblica',
#   'quirinale',
#   'covid',
#   'corsa',
#   'oggi',
#   'repubblica',
#   'httpstcowxmlzqlaoo'],
#  ['lanotiziatweet',
#   'draghi',
#   'sogna',
#   'quirinale',
#   'palazzo',
#   'chigi',
#   'fallito',
#   'quasi',
#   'partire',
#   'recovery',
#   'plan',
#   'campagna',
#   'vaccinaleôçª'],
#  ['maurobiani',
#   'presidentedellarepubblica',
#   'quirinale',
#   'covid',
#   'corsa',
#   'oggi',
#   'repubblica',
#   'httpstcowxmlzqlaoo'],
#  ['giorni', 'allôçöalba', 'quirinale'],
#  ['lanotiziatweet',
#   'draghi',
#   'sogna',
#   'quirinale',
#   'palazzo',
#   'chigi',
#   'fallito',
#   'quasi',
#   'partire',
#   'recovery',
#   'plan',
#   'campagna',
#   'vaccinaleôçª'],
#  ['maurobiani',
#   'presidentedellarepubblica',
#   'quirinale',
#   'covid',
#   'corsa',
#   'oggi',
#   'repubblica',
#   'httpstcowxmlzqlaoo'],
#  ['thebrightside0',
#   'buonoasapersi',
#   'ƒæí',
#   'buona',
#   'utile',
#   'informazione',
#   'davidegiac',
#   'rtl1025',
#   'quando',
#   'ricorda',
#   'sottolinea',
#   'lôçª'],
#  ['quirinale',
#   'mattarellabis',
#   'unico',
#   'estremo',
#   'tentativo',
#   'centrosinistra',
#   'empasse',
#   'candidato',
#   'antiberlusconi',
#   'domanigiornale',
#   'illustra',
#   'piano',
#   'pdm5s',
#   'ilfoglioit',
#   'letta',
#   'troppo',
#   'entusiasta',
#   'primapagina',
#   '12gennaio',
#   'frontpage',
#   'httpstcow4abcq9jmq'],
#  ['martagrande87',
#   'legge',
#   'giornali',
#   'parte',
#   'parlamentari',
#   '5stelle',
#   'primis',
#   'appoggia',
#   'casini',
#   'quirinalespero',
#   'solo',
#   'fantasie',
#   'mente',
#   'deviata',
#   'giornalisti'],
#  ['maurobiani',
#   'presidentedellarepubblica',
#   'quirinale',
#   'covid',
#   'corsa',
#   'oggi',
#   'repubblica',
#   'httpstcowxmlzqlaoo'],
#  ['qnlanazione',
#   'quirinale',
#   'grandi',
#   'elettori',
#   'toscani',
#   'lega',
#   'cede',
#   'posto',
#   'httpstcowhfzuvkazx',
#   'via',
#   'qnlanazione'],
#  ['ƒöá',
#   'orientarsi',
#   'fase',
#   'semplice',
#   'quirinale',
#   'poche',
#   'certezze',
#   'molte',
#   'incertezze',
#   'draghi',
#   'vuole',
#   'andare',
#   'colle',
#   '100ôçø',
#   'claudiocerasa',
#   'ƒäö',
#   'nonstopnews',
#   'live',
#   'ôûâ',
#   'httpstcoidld1y40ul',
#   'httpstcodqk1xtdzai'],
#  ['cckki',
#   'dice',
#   'berlusconi',
#   'draghi',
#   'quirinale',
#   'voto',
#   'probabilmente',
#   'mattarella',
#   'sar',
#   'costretto',
#   'disfare',
#   'bagagli',
#   'feôçª'],
#  ['rosy', 'bindi', 'quirinale', 'credo', 'miracoli', 'httpstcosgg51ffgfp'],
#  ['quirinale',
#   'sembra',
#   'appresti',
#   'affossare',
#   'buon',
#   'senso',
#   'ddlzan',
#   'alta',
#   'politica'],
#  ['lombard5stelle',
#   'quirinale',
#   'dariovioli',
#   'lôçöipotesi',
#   'possa',
#   'votare',
#   'berlusconi',
#   'semplicemente',
#   'ridicola',
#   'fantapolitica',
#   'unôçöoffôçª'],
#  ['lanotiziatweet',
#   'draghi',
#   'sogna',
#   'quirinale',
#   'palazzo',
#   'chigi',
#   'fallito',
#   'quasi',
#   'partire',
#   'recovery',
#   'plan',
#   'campagna',
#   'vaccinaleôçª'],
#  ['dinogiarrusso',
#   'immaginatevi',
#   'giuseppeconteit',
#   'andato',
#   'conferenzastampa',
#   'tre',
#   'giorni',
#   'ritardo',
#   'escludendo',
#   'quotidiano',
#   'eôçª'],
#  ['giampierobiglia',
#   'stop',
#   'berlusconi',
#   'draghi',
#   'colle',
#   'fuori',
#   'governoôçø',
#   'frase',
#   'lôçöarroganza',
#   'spregiudicatezzaôçª'],
#  ['paolomieli',
#   'pare',
#   'modo',
#   'discutere',
#   'capo',
#   'stato',
#   'giorni',
#   'votazioni',
#   'proporre',
#   'richiamare',
#   'mattarella',
#   'quirinale'],
#  ['cososono',
#   'noquirisilvio',
#   'cosa',
#   'danaro',
#   'eleggere',
#   'pregiudicato',
#   'quirinale',
#   'ƒñ¼'],
#  ['sgarbi',
#   'chiama',
#   'parlamentari',
#   'poi',
#   'passa',
#   'berlusconi',
#   'augura',
#   'buon',
#   'anno',
#   'chiede',
#   'voto',
#   'quirinaleôçø',
#   'presa',
#   'montanari',
#   'perch',
#   'diceva',
#   'repubblica',
#   'banane'],
#  ['eliovito',
#   'elio',
#   'battute',
#   'parte',
#   'pochi',
#   'paese',
#   'riuscirebbe',
#   'mettere',
#   'daccordo',
#   'fatto',
#   'pensiero',
#   'quirinale',
#   'stanotte',
#   'sognato',
#   'diventava',
#   'presidente',
#   'repubblica',
#   'pillon'],
#  ['paolomieli',
#   'dibattito',
#   'quirinale',
#   'svilente',
#   'vede',
#   'ricomparire',
#   'sempre',
#   'uguale',
#   'ora',
#   'chiedono',
#   'mattarella',
#   'restare',
#   'solo',
#   'precedente',
#   'napolitano',
#   'accett',
#   'secondo',
#   'mandato',
#   'solo',
#   'dopo',
#   'patatrac',
#   'prime',
#   'votazioni'],
#  ['immaginate',
#   'mattarella',
#   'dicesse',
#   'scherzato',
#   'impossibile',
#   'potrebbe',
#   'tornare',
#   'campo',
#   'solo',
#   'fronte',
#   'disastro',
#   'conclamato',
#   'paolomieli',
#   '24mattino',
#   'quirinale'],
#  ['oriolialberto',
#   'meloni',
#   'desidera',
#   'patriota',
#   'quirinale',
#   'dovrebbe',
#   'leggere',
#   'piu',
#   'anpipatria',
#   'rivista',
#   'dellanpi',
#   'fondata',
#   '19ôçª'],
#  ['mancava',
#   'bersani',
#   'lungimiranza',
#   'vorrei',
#   'mariodraghi',
#   'pdr',
#   'prossimi',
#   'sette',
#   'anni',
#   'fino',
#   '2023',
#   'sempre',
#   'arrivi',
#   'cio',
#   'darebbe',
#   'peso',
#   'credibilita',
#   'stabilita',
#   'paese',
#   'matteorenzi',
#   'azionecesena',
#   'facciamorete',
#   'quirinale',
#   'giorgiameloni',
#   'httpstcoi85binr7wl'],
#  ['episodi', 'precedentimusichetta', 'quirinale', 'httpstcokyi0x6vncl'],
#  ['dimartedi',
#   'segretario',
#   'partito',
#   'democratico',
#   'enrico',
#   'letta',
#   'quirinale',
#   'notizie',
#   'parlamentari',
#   'gruppo',
#   'ricevuto',
#   'telefonata',
#   'berlusconi',
#   'giorniôçø',
#   'occhio',
#   'sporche',
#   'manovre'],
#  ['quirinale',
#   'perno',
#   'istituzionale',
#   'geopolitico',
#   'strategico',
#   'stato',
#   'italiano',
#   'forza',
#   'quirinale',
#   'poter',
#   'disegnare',
#   'cornice',
#   'entro',
#   'vita',
#   'politicoistituzionale',
#   'muoversi',
#   'dissipatio',
#   'httpstcov0llp7c8om'],
#  ['aspettiamo',
#   'studio24',
#   '1000',
#   'rainews',
#   'ospiti',
#   'parlare',
#   'oms',
#   'varianteomicron',
#   'covid19',
#   'scuola',
#   'universit',
#   'ricerca',
#   'draghi',
#   'mattarella',
#   'berlusconi',
#   'quirinale',
#   'presidentedellarepubblica',
#   'sassoli',
#   'europa',
#   'conduce',
#   'giorgiaromb',
#   'httpstcodlkuuakpu6'],
#  ['urbani',
#   'quirinale',
#   'berlusconi',
#   'apra',
#   'occhi',
#   'ôçø',
#   'draghi',
#   'meglio',
#   'palazzo',
#   'chigiôçø',
#   'httpstcowyu50pjcup',
#   'httpstcoeb6kqfq6vv'],
#  ['elezioni',
#   'quirinale',
#   '2022',
#   'possibili',
#   'scenari',
#   'mattarella',
#   'bis',
#   'draghi',
#   'berlusconi',
#   'prodi',
#   'cartabia',
#   'fino',
#   'moratti',
#   'sar',
#   'prossimo',
#   'presidente',
#   'repubblicahttpstcos6czyyzdua'],
#  ['spero',
#   'veramente',
#   'mattarella',
#   'ripensi',
#   'elezionipresidente',
#   'quirinale'],
#  ['gladiatoremassi',
#   'nome',
#   'popolo',
#   'italiano',
#   'chiedo',
#   'meloni',
#   'salvini',
#   'persona',
#   'perbene',
#   'gratteri',
#   'quirinale',
#   'meglôçª'],
#  ['fabvix1971',
#   'sola',
#   'idea',
#   'centrodestra',
#   'possa',
#   'effettivamente',
#   'proporre',
#   'berlusconi',
#   'quirinale',
#   'raccapricciante',
#   'auguro',
#   'côçª'],
#  ['juorno',
#   'quirinale',
#   'sgambetti',
#   'alleati',
#   'delegati',
#   'regionali',
#   'caos',
#   'httpstcoc8rdfxmdbe'],
#  ['juorno',
#   'quirinale',
#   'sgambetti',
#   'alleati',
#   'delegati',
#   'regionali',
#   'caos',
#   'httpstco0sxk4cw7uh'],
#  ['bollettino',
#   'covid',
#   'deve',
#   'essere',
#   'giornaliero',
#   'settimanale',
#   'fatti',
#   'capodanno',
#   'milano',
#   'entrano',
#   'dibattito',
#   'politico',
#   'quirinale',
#   'torna',
#   'voglia',
#   'bis',
#   'mattarella',
#   'riaprire',
#   'pozzi',
#   'gas',
#   'italiani',
#   'giornata',
#   'minuti',
#   '12gennaio',
#   'httpstcoqe5u9of6mh'],
#  ['lanota',
#   'gianka',
#   'modus',
#   'operandi',
#   'sinistraporre',
#   'veti',
#   'altri',
#   'scommettere',
#   'candidatura',
#   'femminile',
#   'colle',
#   'solo',
#   'appartiene',
#   'fronte',
#   'rosso',
#   'quirinale',
#   'httpstcobuxc4acbsq'],
#  ['quirinale',
#   'volevo',
#   'avvisare',
#   'berlusconi',
#   'liberato',
#   'posto',
#   'presidente',
#   'parlamentoeuropeo',
#   '12gennaio',
#   'europa',
#   'europarlamento',
#   'sassoli',
#   'davidsassoli',
#   'addiodavid',
#   'ripdavidsassoli',
#   'presidentedellarepubblica',
#   'noquirisilvio',
#   'buongiorno',
#   'untemaalgiorno'],
#  ['armanduplessis',
#   'considerando',
#   'alcune',
#   'bizzarre',
#   'ipotesi',
#   'campo',
#   'quirinale',
#   'scrive',
#   'folli',
#   'paese',
#   'potrebbe',
#   'aver',
#   'bisognoôçª'],
#  ['quirinale',
#   'perno',
#   'istituzionale',
#   'geopolitico',
#   'strategico',
#   'stato',
#   'italiano',
#   'forza',
#   'quirinale',
#   'poter',
#   'disegnare',
#   'cornice',
#   'entro',
#   'vita',
#   'politicoistituzionale',
#   'muoversi',
#   'potere',
#   'informali',
#   'nominaôçªhttpstcomss06urhro',
#   'httpstcoiainhsuto7'],
#  ['armanduplessis',
#   'considerando',
#   'alcune',
#   'bizzarre',
#   'ipotesi',
#   'campo',
#   'quirinale',
#   'scrive',
#   'folli',
#   'paese',
#   'potrebbe',
#   'aver',
#   'bisognoôçª'],
#  ['considerando',
#   'alcune',
#   'bizzarre',
#   'ipotesi',
#   'campo',
#   'quirinale',
#   'scrive',
#   'folli',
#   'paese',
#   'potrebbe',
#   'aver',
#   'bisogno',
#   'ancora',
#   'mattarella',
#   'nonostante',
#   'personale',
#   'desiderio',
#   'tornare',
#   'vita',
#   'privata',
#   'repubblica'],
#  ['dinogiarrusso',
#   'immaginatevi',
#   'giuseppeconteit',
#   'andato',
#   'conferenzastampa',
#   'tre',
#   'giorni',
#   'ritardo',
#   'escludendo',
#   'quotidiano',
#   'eôçª'],
#  ['dinogiarrusso',
#   'immaginatevi',
#   'giuseppeconteit',
#   'andato',
#   'conferenzastampa',
#   'tre',
#   'giorni',
#   'ritardo',
#   'escludendo',
#   'quotidiano',
#   'eôçª'],
#  ['sola',
#   'idea',
#   'centrodestra',
#   'possa',
#   'effettivamente',
#   'proporre',
#   'berlusconi',
#   'quirinale',
#   'raccapricciante',
#   'auguro',
#   'quel',
#   'nome',
#   'venga',
#   'fatto',
#   'solo',
#   'dargli',
#   'contentino',
#   'poi',
#   'concentri',
#   'qualcuno',
#   'presentabile'],
#  ['elezione',
#   'presidente',
#   'politica',
#   'trovi',
#   'unit',
#   'nellôçöinteresse',
#   'paese',
#   'pasquale',
#   'episcopo',
#   'quirinale',
#   'presidentedellarepubblica',
#   'politica',
#   'httpstcodyrvri5jzm'],
#  ['lanotiziatweet',
#   'draghi',
#   'sogna',
#   'quirinale',
#   'palazzo',
#   'chigi',
#   'fallito',
#   'quasi',
#   'partire',
#   'recovery',
#   'plan',
#   'campagna',
#   'vaccinaleôçª'],
#  ['fuskiko',
#   'notizia',
#   'vera',
#   'domani',
#   'cara',
#   'avvocatessa',
#   'querela',
#   'gliela',
#   'toglie',
#   'nessuno',
#   'quirinale',
#   'chiediamo',
#   'scuse',
#   'imm',
#   'diatôçª'],
#  ['invece',
#   'napolitanoter',
#   'noquirinale',
#   'romanzoquirinale',
#   'presidentedellarepubblica'],
#  ['albertoletizia2',
#   'dopo',
#   'avere',
#   'ascoltato',
#   'letta',
#   'lipotesi',
#   'agghiacciante',
#   'berlusconi',
#   'quirinale',
#   'diventa',
#   'improvvisamente',
#   'realistica'],
#  ['ilfaccendiere',
#   'voci',
#   'sempre',
#   'fitte',
#   'cronisti',
#   'parlamentari',
#   'almeno',
#   'conte',
#   'domande',
#   'fare',
#   'ôçª'],
#  ['corsa',
#   'quirinale',
#   'speciale',
#   'siamonoi',
#   '1515',
#   'tv2000it',
#   'giuspaterniti',
#   'paolograldi',
#   'francobechis',
#   '12gennaio',
#   'mattarella',
#   'canale28',
#   'tempoweb',
#   'ilmessaggeroit',
#   'httpstcoydexo5cr0m'],
#  ['colle',
#   'berlusconi',
#   'rompe',
#   'indugi',
#   'spariglia',
#   'subito',
#   'carte',
#   'httpstcox58rl5pvmq',
#   'mariodraghi',
#   'pensionideiparlamentari',
#   'presidentedellarepubblica',
#   'quirinale',
#   'sergiomattarella',
#   'silvioberlusconi',
#   'httpstcomjw8om0vv8'],
#  ['credo',
#   'fine',
#   'salveremo',
#   'poco',
#   'grazie',
#   'inciuci',
#   'partitocratici',
#   'italioti',
#   'lelezione',
#   'pdr',
#   'creare',
#   'terremoto',
#   'draghi',
#   'vada',
#   'quirinale',
#   'possa',
#   'restare',
#   'palazzochigi',
#   'escluso',
#   'nemmeno',
#   'dimetta',
#   'terza',
#   'opzione'],
#  ['sallisbeth',
#   'cinque',
#   'figure',
#   'femminili',
#   'the',
#   'new',
#   'donna',
#   'quirinale'],
#  ['cbriguglio',
#   'côçö',
#   'spinge',
#   'letta',
#   'chiamata',
#   'allôçöemergenza',
#   'democratica',
#   'denuncia',
#   'caimano',
#   'vuole',
#   'diventare',
#   'capo',
#   'magisôçª'],
#  ['vanessaeffect',
#   'luno',
#   'gennaio',
#   'domanigiornale',
#   'scrivevamo',
#   'rassegna',
#   'rassegna',
#   'capodannoôçª'],
#  ['radioanchio',
#   'poco',
#   'radioanchio',
#   'giorgiozanchini',
#   '12gennaio',
#   'radio1rai',
#   '730',
#   'gestione',
#   'pandemia',
#   'europa',
#   'eva',
#   'polverino',
#   'giorgôçª'],
#  ['comunque',
#   'vero',
#   'segretario',
#   'partito',
#   'mai',
#   'stato',
#   'candidato',
#   'quirinale',
#   'spadolini'],
#  ['fatto',
#   'quirinale',
#   'mai',
#   'andato',
#   'capo',
#   'partito',
#   'significa',
#   'vietato',
#   'costituzione',
#   'berlusconi'],
#  ['dukana2',
#   'travaglio',
#   'draghi',
#   'domande',
#   'quirinale',
#   'roba',
#   'corea',
#   'nord',
#   'fatto',
#   'meglio',
#   'fare',
#   'conferenza',
#   'stamôçª'],
#  ['quirinale',
#   'grandi',
#   'elettori',
#   'toscani',
#   'lega',
#   'cede',
#   'posto',
#   'httpstcowhfzuvkazx',
#   'via',
#   'qnlanazione'],
#  ['pare',
#   'proprio',
#   'minimo',
#   'noquirisilvio',
#   'quirinale',
#   'berlusconi',
#   'conte',
#   'letta',
#   'm5s',
#   'httpstcofor0olukul'],
#  ['xmeridio78',
#   'segnale',
#   'delirio',
#   'onnipotenza',
#   'draghidimettiti',
#   'draghivatteneingalera',
#   'quirinale',
#   'bassetti',
#   'renzifaischifo',
#   'httpsôçª'],
#  ['ultimi',
#   'mesi',
#   'perso',
#   'uomini',
#   'giustidi',
#   'valore',
#   'dott',
#   'ginostrada',
#   'davidsassoli',
#   'uomini',
#   'perbenecapaci',
#   'uomini',
#   'cuore',
#   'grande',
#   'forza',
#   'morale',
#   'rassegno',
#   'pensiero',
#   'farabutto',
#   'quirinale',
#   'scagnozzi',
#   'potere',
#   'lumanit',
#   'deve',
#   'vincere',
#   'sempre'],
#  ['radioanchio',
#   'poco',
#   'radioanchio',
#   'giorgiozanchini',
#   '12gennaio',
#   'radio1rai',
#   '730',
#   'gestione',
#   'pandemia',
#   'europa',
#   'eva',
#   'polverino',
#   'giorgôçª'],
#  ['letta',
#   'grado',
#   'porre',
#   'condizioni',
#   'quirinale',
#   'tanto',
#   'meno',
#   'berlusconi',
#   'ragione'],
#  ['quirinale',
#   'ventuno',
#   'votazioni',
#   'eleggere',
#   'saragat',
#   'lasceltadelpresudente',
#   'ilmattinofoggia',
#   '12gennaio',
#   'presidentedellarepubblica',
#   'httpstcogapzras8lv'],
#  ['barbapapoo',
#   'dalema',
#   'male',
#   'giudice',
#   'talent',
#   'show',
#   'vuol',
#   'essere',
#   'presidente',
#   'repubblica',
#   'quirinale',
#   'httpstôçª'],
#  ['storace', 'conferenzastampa', 'draghi', 'quirinale', 'httpstcol6bqrhgd0g'],
#  ['maurobiani',
#   'presidentedellarepubblica',
#   'quirinale',
#   'covid',
#   'corsa',
#   'oggi',
#   'repubblica',
#   'httpstcowxmlzqlaoo'],
#  ['m5s',
#   'assemblea',
#   'deputati',
#   'quirinale',
#   'dare',
#   'pieno',
#   'mandato',
#   'conteôçø',
#   'montecitorio',
#   'côçö',
#   'chiede',
#   'mattarellabis',
#   'httpstcotzgw4p0jyh'],
#  ['quirinale',
#   'scintille',
#   'regioni',
#   'ásui',
#   'delegati',
#   'beffato',
#   'lombardia',
#   'httpstcotpcay9gdub'],
#  ['quirinale',
#   'salvini',
#   '½berlusconi',
#   'adesso',
#   'sciolga',
#   'riserva',
#   'evoca',
#   'governo',
#   'leader',
#   'politici',
#   'httpstcoglwqyvrkdh'],
#  ['maurobiani',
#   'presidentedellarepubblica',
#   'quirinale',
#   'covid',
#   'corsa',
#   'oggi',
#   'repubblica',
#   'httpstcowxmlzqlaoo'],
#  ['maurobiani',
#   'presidentedellarepubblica',
#   'quirinale',
#   'covid',
#   'corsa',
#   'oggi',
#   'repubblica',
#   'httpstcowxmlzqlaoo'],
#  ['quirinale',
#   'piano',
#   'segreto',
#   'm5s',
#   'mattarella',
#   'bis',
#   'httpstconvsknbrlix'],
#  ['maurobiani',
#   'presidentedellarepubblica',
#   'quirinale',
#   'covid',
#   'corsa',
#   'oggi',
#   'repubblica',
#   'httpstcowxmlzqlaoo'],
#  ['lanotiziatweet',
#   'draghi',
#   'sogna',
#   'quirinale',
#   'palazzo',
#   'chigi',
#   'fallito',
#   'quasi',
#   'partire',
#   'recovery',
#   'plan',
#   'campagna',
#   'vaccinaleôçª'],
#  ['ilfaccendiere',
#   'voci',
#   'sempre',
#   'fitte',
#   'cronisti',
#   'parlamentari',
#   'almeno',
#   'conte',
#   'domande',
#   'fare',
#   'ôçª'],
#  ['quirinale',
#   'letta',
#   '½mattarella',
#   'bis',
#   'massimo',
#   'sbarramento',
#   'antiberlusconi',
#   'httpstco74sgb2z6we'],
#  ['lanotiziatweet',
#   'draghi',
#   'sogna',
#   'quirinale',
#   'palazzo',
#   'chigi',
#   'fallito',
#   'quasi',
#   'partire',
#   'recovery',
#   'plan',
#   'campagna',
#   'vaccinaleôçª'],
#  ['manlantuit',
#   'letta',
#   'dimaterd',
#   'bolla',
#   'improbabile',
#   'maggioranza',
#   'ursula',
#   'salvini',
#   'portaaporta',
#   'esclude',
#   'fuga',
#   'lega',
#   'governoôçª'],
#  ['liberoofficial',
#   'mariodraghi',
#   'traghettare',
#   'paese',
#   'fuori',
#   'pandemia',
#   'potrebbe',
#   'sfilarsi',
#   'corsa',
#   'quirinale',
#   'spingere',
#   'perôçª'],
#  ['dukana2',
#   'travaglio',
#   'draghi',
#   'domande',
#   'quirinale',
#   'roba',
#   'corea',
#   'nord',
#   'fatto',
#   'meglio',
#   'fare',
#   'conferenza',
#   'stamôçª'],
#  ['cbriguglio',
#   'côçö',
#   'spinge',
#   'letta',
#   'chiamata',
#   'allôçöemergenza',
#   'democratica',
#   'denuncia',
#   'caimano',
#   'vuole',
#   'diventare',
#   'capo',
#   'magisôçª'],
#  ['dukana2',
#   'travaglio',
#   'draghi',
#   'domande',
#   'quirinale',
#   'roba',
#   'corea',
#   'nord',
#   'fatto',
#   'meglio',
#   'fare',
#   'conferenza',
#   'stamôçª'],
#  ['maurobiani',
#   'presidentedellarepubblica',
#   'quirinale',
#   'covid',
#   'corsa',
#   'oggi',
#   'repubblica',
#   'httpstcowxmlzqlaoo'],
#  ['malgradotutto',
#   'esiste',
#   'storia',
#   'muta',
#   'diano',
#   'fuoco',
#   'frantumino',
#   'falsifichino',
#   'storia',
#   'uôçª'],
#  ['cav',
#   'armato',
#   'quirinale',
#   'villa',
#   'grande',
#   'conti',
#   'salvini',
#   'sbuffa',
#   'armato',
#   'quirinale',
#   'villa',
#   'grande',
#   'httpstcofru02arzqx'],
#  ['cososono',
#   'noquirisilvio',
#   'cosa',
#   'danaro',
#   'eleggere',
#   'pregiudicato',
#   'quirinale',
#   'ƒñ¼'],
#  ['noquirisilvio',
#   'cosa',
#   'danaro',
#   'eleggere',
#   'pregiudicato',
#   'quirinale',
#   'ƒñ¼',
#   'httpstco3uujejfdl5'],
#  ['maurobiani',
#   'presidentedellarepubblica',
#   'quirinale',
#   'covid',
#   'corsa',
#   'oggi',
#   'repubblica',
#   'httpstcowxmlzqlaoo'],
#  ['albertoletizia2',
#   'dopo',
#   'avere',
#   'ascoltato',
#   'letta',
#   'lipotesi',
#   'agghiacciante',
#   'berlusconi',
#   'quirinale',
#   'diventa',
#   'improvvisamente',
#   'realistica'],
#  ['ilfaccendiere',
#   'voci',
#   'sempre',
#   'fitte',
#   'cronisti',
#   'parlamentari',
#   'almeno',
#   'conte',
#   'domande',
#   'fare',
#   'ôçª'],
#  ['mattarella', 'quirinale', 'httpstcoy2rshlglre'],
#  ['albertoletizia2',
#   'dopo',
#   'avere',
#   'ascoltato',
#   'letta',
#   'lipotesi',
#   'agghiacciante',
#   'berlusconi',
#   'quirinale',
#   'diventa',
#   'improvvisamente',
#   'realistica'],
#  ['ilfaccendiere',
#   'voci',
#   'sempre',
#   'fitte',
#   'cronisti',
#   'parlamentari',
#   'almeno',
#   'conte',
#   'domande',
#   'fare',
#   'ôçª'],
#  ['quirinale',
#   'sorgi',
#   'lastampa',
#   'attacca',
#   'berlusconi',
#   'avverte',
#   'occhio',
#   'torbide',
#   'manovre',
#   'sullelezione',
#   'presidente',
#   'httpstco5m1cxtztxi',
#   'httpstcoakzyzjocgq'],
#  ['dukana2',
#   'travaglio',
#   'draghi',
#   'domande',
#   'quirinale',
#   'roba',
#   'corea',
#   'nord',
#   'fatto',
#   'meglio',
#   'fare',
#   'conferenza',
#   'stamôçª'],
#  ['lucianoghelfi',
#   'salvini',
#   'amato',
#   'parterre',
#   'testa',
#   'quirinale',
#   'forzerei',
#   'mattarella',
#   'fare',
#   'quel',
#   'vuolôçª'],
#  ['carlagommy',
#   'quirinale',
#   'nessun',
#   'evasore',
#   'amico',
#   'evasori',
#   'aspirare',
#   'ricoprire',
#   'massima',
#   'carica',
#   'stato',
#   'dato',
#   'fatto',
#   'noôçª'],
#  ['malgradotutto',
#   'esiste',
#   'storia',
#   'muta',
#   'diano',
#   'fuoco',
#   'frantumino',
#   'falsifichino',
#   'storia',
#   'uôçª'],
#  ['radioanchio',
#   'poco',
#   'radioanchio',
#   'giorgiozanchini',
#   '12gennaio',
#   'radio1rai',
#   '730',
#   'gestione',
#   'pandemia',
#   'europa',
#   'eva',
#   'polverino',
#   'giorgôçª'],
#  ['malgradotutto',
#   'esiste',
#   'storia',
#   'muta',
#   'diano',
#   'fuoco',
#   'frantumino',
#   'falsifichino',
#   'storia',
#   'uôçª'],
#  ['lombard5stelle',
#   'quirinale',
#   'dariovioli',
#   'lôçöipotesi',
#   'possa',
#   'votare',
#   'berlusconi',
#   'semplicemente',
#   'ridicola',
#   'fantapolitica',
#   'unôçöoffôçª'],
#  ['dukana2',
#   'travaglio',
#   'draghi',
#   'domande',
#   'quirinale',
#   'roba',
#   'corea',
#   'nord',
#   'fatto',
#   'meglio',
#   'fare',
#   'conferenza',
#   'stamôçª'],
#  ['maurobiani',
#   'presidentedellarepubblica',
#   'quirinale',
#   'covid',
#   'corsa',
#   'oggi',
#   'repubblica',
#   'httpstcowxmlzqlaoo'],
#  ['travaglio',
#   'draghi',
#   'domande',
#   'quirinale',
#   'roba',
#   'corea',
#   'nord',
#   'fatto',
#   'meglio',
#   'fare',
#   'conferenza',
#   'stampaôçø',
#   'httpstcov75iv9zytf'],
#  ['poco',
#   'radioanchio',
#   'giorgiozanchini',
#   '12gennaio',
#   'radio1rai',
#   '730',
#   'gestione',
#   'pandemia',
#   'europa',
#   'eva',
#   'polverino',
#   'giorgiogilestro',
#   '830',
#   'politica',
#   'quirinalecrippa5stelle',
#   'enricoborghi1',
#   'mandelliandrea',
#   'molinaririk',
#   '905',
#   'caso',
#   'djokovicadrianopanatta',
#   'giorgiamecca',
#   'httpstcowg9soyipre'],
#  ['pschioppa',
#   'delegati',
#   'regionali',
#   'scelti',
#   'grandi',
#   'elettori',
#   'quirinale',
#   'viste',
#   'appartenenze',
#   'mai',
#   'facendoôçª'],
#  ['grand',
#   'jeu',
#   'quirinale',
#   'berlusconi',
#   'croit',
#   'mais',
#   'salvini',
#   'amp',
#   'meloni',
#   'cherchent',
#   'des',
#   'alternatives',
#   'mariodraghi',
#   'reste',
#   'plus',
#   'qualifi',
#   'tous',
#   'amp',
#   'm5s',
#   'travaillent',
#   'maintien',
#   'sergio',
#   'mattarella',
#   'malgr',
#   'refus',
#   'sident',
#   'sortant',
#   'httpstcolpdmyubfqm'],
#  ['apndp',
#   'conduttori',
#   'qualsiasi',
#   'draghi',
#   'perch',
#   'rifiutato',
#   'parlare',
#   'quirinale',
#   'son',
#   'concoôçª'],
#  ['lucianoghelfi',
#   'letta',
#   'centrodestra',
#   'davvero',
#   'presentasse',
#   'berlusconi',
#   'quirinale',
#   'escludo',
#   'rimanga',
#   'fuori',
#   'dallôçöaôçª'],
#  ['albertoletizia2',
#   'dopo',
#   'avere',
#   'ascoltato',
#   'letta',
#   'lipotesi',
#   'agghiacciante',
#   'berlusconi',
#   'quirinale',
#   'diventa',
#   'improvvisamente',
#   'realistica'],
#  ['malgradotutto',
#   'esiste',
#   'storia',
#   'muta',
#   'diano',
#   'fuoco',
#   'frantumino',
#   'falsifichino',
#   'storia',
#   'uôçª'],
#  ['cazzeggiate',
#   'social',
#   'intanto',
#   'berlusconi',
#   'caccia',
#   'voti',
#   'quirinale'],
#  ['maurobiani',
#   'presidentedellarepubblica',
#   'quirinale',
#   'covid',
#   'corsa',
#   'oggi',
#   'repubblica',
#   'httpstcowxmlzqlaoo'],
#  ['valys',
#   'crisanti',
#   'viene',
#   'chiesto',
#   'parere',
#   'draghi',
#   'quirinale',
#   'stato',
#   'ôçÿsfortunatoôçö',
#   'detto',
#   'lôçöimmunit',
#   'dôçª'],
#  ['dinogiarrusso',
#   'immaginatevi',
#   'giuseppeconteit',
#   'andato',
#   'conferenzastampa',
#   'tre',
#   'giorni',
#   'ritardo',
#   'escludendo',
#   'quotidiano',
#   'eôçª'],
#  ['maurobiani',
#   'presidentedellarepubblica',
#   'quirinale',
#   'covid',
#   'corsa',
#   'oggi',
#   'repubblica',
#   'httpstcowxmlzqlaoo'],
#  ['fuskiko',
#   'notizia',
#   'vera',
#   'domani',
#   'cara',
#   'avvocatessa',
#   'querela',
#   'gliela',
#   'toglie',
#   'nessuno',
#   'quirinale',
#   'chiediamo',
#   'scuse',
#   'imm',
#   'diatôçª'],
#  ['juorno',
#   'quirinale',
#   'tensione',
#   'assemblea',
#   'm5s',
#   'indicazioni',
#   'senatori',
#   'httpstcooy2yviwm3t'],
#  ['juorno',
#   'quirinale',
#   'tensione',
#   'assemblea',
#   'm5s',
#   'indicazioni',
#   'senatori',
#   'httpstcos6fyag8drp'],
#  ['lucianoghelfi',
#   'letta',
#   'centrodestra',
#   'davvero',
#   'presentasse',
#   'berlusconi',
#   'quirinale',
#   'escludo',
#   'rimanga',
#   'fuori',
#   'dallôçöaôçª'],
#  ['lombard5stelle',
#   'quirinale',
#   'dariovioli',
#   'lôçöipotesi',
#   'possa',
#   'votare',
#   'berlusconi',
#   'semplicemente',
#   'ridicola',
#   'fantapolitica',
#   'unôçöoffôçª'],
#  ['maurobiani',
#   'presidentedellarepubblica',
#   'quirinale',
#   'covid',
#   'corsa',
#   'oggi',
#   'repubblica',
#   'httpstcowxmlzqlaoo'],
#  ['quirinale',
#   'dario',
#   'violi',
#   'delegati',
#   'regionali',
#   'voter',
#   'berlusconiôçø',
#   'quirinale',
#   'dario',
#   'violi',
#   'delegati',
#   'httpstco9qtxayyi4c'],
#  ['albertoletizia2',
#   'dopo',
#   'avere',
#   'ascoltato',
#   'letta',
#   'lipotesi',
#   'agghiacciante',
#   'berlusconi',
#   'quirinale',
#   'diventa',
#   'improvvisamente',
#   'realistica'],
#  ['apndp',
#   'conduttori',
#   'qualsiasi',
#   'draghi',
#   'perch',
#   'rifiutato',
#   'parlare',
#   'quirinale',
#   'son',
#   'concoôçª'],
#  ['lombard5stelle',
#   'quirinale',
#   'dariovioli',
#   'lôçöipotesi',
#   'possa',
#   'votare',
#   'berlusconi',
#   'semplicemente',
#   'ridicola',
#   'fantapolitica',
#   'unôçöoffôçª'],
#  ['dinogiarrusso',
#   'immaginatevi',
#   'giuseppeconteit',
#   'andato',
#   'conferenzastampa',
#   'tre',
#   'giorni',
#   'ritardo',
#   'escludendo',
#   'quotidiano',
#   'eôçª'],
#  ['cercando',
#   'procedura',
#   'candida',
#   'quirinale',
#   'rifiutano',
#   'candidature',
#   'costituzione',
#   'italiana',
#   'trovo'],
#  ['sabrinaqwerty',
#   'politici',
#   'sceglieresti',
#   'presidente',
#   'repubblica',
#   'fantasia',
#   'quirinale'],
#  ['storace', 'conferenzastampa', 'draghi', 'quirinale', 'httpstcol6bqrhgd0g'],
#  ['stuprando',
#   'quirinale',
#   'pedofilo',
#   'stragista',
#   'silvioberlusconi',
#   'lesbica',
#   'nazista',
#   'marinaberlusconi',
#   'voglion',
#   'far',
#   'tornare',
#   'metodi',
#   'killer',
#   'governi',
#   '20012006',
#   '20082011',
#   'quando',
#   'lassassino',
#   'silvio',
#   'berlusconi',
#   'ordinava',
#   'disarticolare',
#   'morte',
#   'leccava',
#   'paura',
#   'zero',
#   'httpstcorhyd5vjtrz'],
#  ['youtrend',
#   'quirinale',
#   'abruzzo',
#   'liguria',
#   'lombardia',
#   'umbria',
#   'eletto',
#   'rispettivi',
#   'delegati',
#   'vista',
#   'gennaio',
#   'delegôçª'],
#  ['quirinale',
#   'letta',
#   'mattarella',
#   'bis',
#   'massimoôçø',
#   'quirinale',
#   'letta',
#   'mattarella',
#   'httpstcopxypix3lx5',
#   'httpstcoxpsi5xoufw'],
#  ['ilignorante',
#   'troppo',
#   'repentino',
#   'cambio',
#   'narrazione',
#   'centri',
#   'quirinale',
#   'sistemare',
#   'vuole',
#   'zio',
#   'bill',
#   'musso',
#   'fdragôçª'],
#  ['albertoletizia2',
#   'dopo',
#   'avere',
#   'ascoltato',
#   'letta',
#   'lipotesi',
#   'agghiacciante',
#   'berlusconi',
#   'quirinale',
#   'diventa',
#   'improvvisamente',
#   'realistica'],
#  ['killers',
#   'marinaberlusconi',
#   'amp',
#   'silvioberlusconi',
#   'are',
#   'trialsinvestigations',
#   'their',
#   'murder',
#   'imanefadil',
#   'corrupting',
#   'witnesses',
#   'mafia',
#   'ôé¼',
#   'laundering',
#   'done',
#   'sell',
#   'acmilan',
#   'butchering',
#   'heroes',
#   'falcone',
#   'amp',
#   'borsellino',
#   'therefore',
#   'want',
#   'sodomize',
#   'quirinale',
#   'bury',
#   'justice',
#   'jail',
#   'httpstcopfc3up0ely'],
#  ['lanotiziatweet',
#   'paese',
#   'piena',
#   'emergenza',
#   'covid',
#   'draghi',
#   'berlusconi',
#   'lôçöunico',
#   'pensiero',
#   'giochi',
#   'quirinale',
#   'ultiôçª'],
#  ['ilfaccendiere',
#   'voci',
#   'sempre',
#   'fitte',
#   'cronisti',
#   'parlamentari',
#   'almeno',
#   'conte',
#   'domande',
#   'fare',
#   'ôçª'],
#  ['dinogiarrusso',
#   'immaginatevi',
#   'giuseppeconteit',
#   'andato',
#   'conferenzastampa',
#   'tre',
#   'giorni',
#   'ritardo',
#   'escludendo',
#   'quotidiano',
#   'eôçª'],
#  ['catirafaella',
#   'comunque',
#   'finir',
#   'romanzo',
#   'quirinale',
#   'nessuno',
#   'toglier',
#   'testa',
#   'davidsassoli',
#   'stato',
#   'grande',
#   'presôçª'],
#  ['albertoletizia2',
#   'dopo',
#   'avere',
#   'ascoltato',
#   'letta',
#   'lipotesi',
#   'agghiacciante',
#   'berlusconi',
#   'quirinale',
#   'diventa',
#   'improvvisamente',
#   'realistica'],
#  ['chiama', 'problema', 'danno', 'burioni', 'possibile', 'quirinale'],
#  ['apndp',
#   'conduttori',
#   'qualsiasi',
#   'draghi',
#   'perch',
#   'rifiutato',
#   'parlare',
#   'quirinale',
#   'son',
#   'concoôçª'],
#  ['fuskiko',
#   'notizia',
#   'vera',
#   'domani',
#   'cara',
#   'avvocatessa',
#   'querela',
#   'gliela',
#   'toglie',
#   'nessuno',
#   'quirinale',
#   'chiediamo',
#   'scuse',
#   'imm',
#   'diatôçª'],
#  ['lanfrancopalazz',
#   'berlusconi',
#   'roma',
#   'quirinale',
#   'radioradicale',
#   'gasparripdl',
#   'opencamera',
#   'finewss',
#   'senatostampa',
#   'opensenato',
#   'httpsôçª'],
#  ['apndp',
#   'conduttori',
#   'qualsiasi',
#   'draghi',
#   'perch',
#   'rifiutato',
#   'parlare',
#   'quirinale',
#   'son',
#   'concoôçª'],
#  ['apndp',
#   'conduttori',
#   'qualsiasi',
#   'draghi',
#   'perch',
#   'rifiutato',
#   'parlare',
#   'quirinale',
#   'son',
#   'concoôçª'],
#  ['dariosci1',
#   'ultimi',
#   'dieci',
#   'giorni',
#   'credo',
#   'stati',
#   'cruciali',
#   'governo',
#   'draghi',
#   'quirinale',
#   'covid',
#   'contagi',
#   'provvedimenti',
#   'scuolaôçª'],
#  ['fuskiko',
#   'notizia',
#   'vera',
#   'domani',
#   'cara',
#   'avvocatessa',
#   'querela',
#   'gliela',
#   'toglie',
#   'nessuno',
#   'quirinale',
#   'chiediamo',
#   'scuse',
#   'imm',
#   'diatôçª'],
#  ['lombard5stelle',
#   'quirinale',
#   'dariovioli',
#   'lôçöipotesi',
#   'possa',
#   'votare',
#   'berlusconi',
#   'semplicemente',
#   'ridicola',
#   'fantapolitica',
#   'unôçöoffôçª'],
#  ['notizia',
#   'vera',
#   'domani',
#   'cara',
#   'avvocatessa',
#   'querela',
#   'gliela',
#   'toglie',
#   'nessuno',
#   'quirinale',
#   'chiediamo',
#   'scuse',
#   'imm',
#   'diate',
#   'ritiro',
#   'affermazione',
#   'alessiamorani',
#   'poliziapostale',
#   'httpstcova7i9hnmjm'],
#  ['manlantuit',
#   'letta',
#   'dimaterd',
#   'bolla',
#   'improbabile',
#   'maggioranza',
#   'ursula',
#   'salvini',
#   'portaaporta',
#   'esclude',
#   'fuga',
#   'lega',
#   'governoôçª'],
#  ['ilfaccendiere',
#   'voci',
#   'sempre',
#   'fitte',
#   'cronisti',
#   'parlamentari',
#   'almeno',
#   'conte',
#   'domande',
#   'fare',
#   'ôçª'],
#  ['20012006',
#   'chigi',
#   'lassassino',
#   'silvioberlusconi',
#   'incitato',
#   'killer',
#   'marinaberlusconi',
#   'uccidere',
#   'via',
#   'disarticolazioni',
#   'traumatiche',
#   '20082011',
#   'chigi',
#   'stragista',
#   'berlusconi',
#   'esplodon',
#   'omicidi',
#   'stato',
#   'aldrovandi',
#   'cucchi',
#   'andr',
#   'quirinale',
#   'uccider',
#   'migliaia',
#   'httpstcot3yzfpzgdd'],
#  ['lombard5stelle',
#   'quirinale',
#   'dariovioli',
#   'lôçöipotesi',
#   'possa',
#   'votare',
#   'berlusconi',
#   'semplicemente',
#   'ridicola',
#   'fantapolitica',
#   'unôçöoffôçª'],
#  ['dinogiarrusso',
#   'immaginatevi',
#   'giuseppeconteit',
#   'andato',
#   'conferenzastampa',
#   'tre',
#   'giorni',
#   'ritardo',
#   'escludendo',
#   'quotidiano',
#   'eôçª'],
#  ['esiste',
#   'storia',
#   'muta',
#   'diano',
#   'fuoco',
#   'frantumino',
#   'falsifichino',
#   'storia',
#   'umana',
#   'rifiuta',
#   'tacereôçø',
#   'edoardogaleano',
#   '12gennaio',
#   'falcone',
#   'borsellino',
#   'quirinale',
#   'berlusconi',
#   'httpstcoackxtmhv0s'],
#  ['albertoletizia2',
#   'dopo',
#   'avere',
#   'ascoltato',
#   'letta',
#   'lipotesi',
#   'agghiacciante',
#   'berlusconi',
#   'quirinale',
#   'diventa',
#   'improvvisamente',
#   'realistica'],
#  ['piccolo',
#   'sforzo',
#   'fate',
#   'quirinale',
#   'unadonna',
#   'sanremo2022',
#   'httpstco4phvsnepmf'],
#  ['dice',
#   'berlusconi',
#   'draghi',
#   'quirinale',
#   'voto',
#   'probabilmente',
#   'mattarella',
#   'sar',
#   'costretto',
#   'disfare',
#   'bagagli',
#   'fermarsi',
#   'altri',
#   'due',
#   'anni',
#   'quirinale',
#   'tanto',
#   'ormai',
#   'strappo',
#   'costituzione',
#   'stato',
#   'preoccupa'],
#  ['letta',
#   'dimaterd',
#   'bolla',
#   'improbabile',
#   'maggioranza',
#   'ursula',
#   'salvini',
#   'portaaporta',
#   'esclude',
#   'fuga',
#   'lega',
#   'governo',
#   'letta',
#   'usa',
#   'formula',
#   'patto',
#   'governo',
#   'salvini',
#   'natura',
#   'governo',
#   'disaccordo',
#   'quirinale',
#   'sintonia',
#   'dopo',
#   'httpstcotmp3ssdp2e'],
#  ['dariosci1',
#   'ultimi',
#   'dieci',
#   'giorni',
#   'credo',
#   'stati',
#   'cruciali',
#   'governo',
#   'draghi',
#   'quirinale',
#   'covid',
#   'contagi',
#   'provvedimenti',
#   'scuolaôçª'],
#  ['chiave',
#   'dellenigma',
#   'palazzo',
#   'chigi',
#   'quirinale',
#   'presidentedellarepubblica',
#   'pnrr',
#   'dimartedi'],
#  ['ultimi',
#   'dieci',
#   'giorni',
#   'credo',
#   'stati',
#   'cruciali',
#   'governo',
#   'draghi',
#   'quirinale',
#   'covid',
#   'contagi',
#   'provvedimenti',
#   'scuola',
#   'trasporti',
#   'ospedali',
#   'pervenuti',
#   'lotte',
#   'maggioranza',
#   'riesplodono',
#   'contagi',
#   'sar',
#   'dura',
#   'scelta',
#   'quirinale',
#   'lineanotte'],
#  ['diario',
#   'quirinale6',
#   'franco',
#   'frattini',
#   'lôçöasso',
#   'manica',
#   'centrodestra',
#   'httpstcontxq2ym6aq',
#   'via',
#   'ilmiogiornale',
#   'quirinale'],
#  ['draghi',
#   'ieri',
#   'arroccato',
#   'oggi',
#   'partito',
#   'riposizionamento',
#   'stampa',
#   'tigg',
#   'virologi',
#   'amp',
#   'lôçöex',
#   'mida',
#   'ormai',
#   'epigono',
#   'giuseppi',
#   'cambier',
#   'registro',
#   'solo',
#   'dopo',
#   'quirinale',
#   'chigi',
#   'vedremo',
#   'draghivattene',
#   'speranzadimettiti'],
#  ['apndp',
#   'conduttori',
#   'qualsiasi',
#   'draghi',
#   'perch',
#   'rifiutato',
#   'parlare',
#   'quirinale',
#   'son',
#   'concoôçª'],
#  ['eccole',
#   'italiani',
#   'trovi',
#   'strada',
#   'frega',
#   'niente',
#   'quirinale',
#   'presidentielle2022',
#   'presidentedellarepubblica',
#   'presidente',
#   'italia',
#   'italy',
#   'italie',
#   'italien',
#   'italian',
#   'italiano',
#   'italiana',
#   'httpstcokdbl0zbudt'],
#  ['dinogiarrusso',
#   'immaginatevi',
#   'giuseppeconteit',
#   'andato',
#   'conferenzastampa',
#   'tre',
#   'giorni',
#   'ritardo',
#   'escludendo',
#   'quotidiano',
#   'eôçª'],
#  ['claramutsc', 'visto', 'frega', 'niente', 'italia', 'tema', 'quirinale'],
#  ['lascito',
#   'politico',
#   'sassoli',
#   'spagna',
#   'declassa',
#   'covid',
#   'emergenza',
#   'influenza',
#   'piani',
#   'quirinale',
#   'puntata',
#   'stasera',
#   'domaniôçø',
#   'rassegna',
#   'stampa',
#   'rai',
#   'news',
#   'rainews',
#   'httpstco5c7uzlzp9y',
#   'httpstco4ymingotnh'],
#  ['spostiamo', 'vicenda', 'quirinale', 'floris', 'dimarted'],
#  ['berlusconi',
#   'roma',
#   'quirinale',
#   'radioradicale',
#   'gasparripdl',
#   'opencamera',
#   'finewss',
#   'senatostampa',
#   'opensenato',
#   'httpstcoggvfip01kk'],
#  ['ilfaccendiere',
#   'voci',
#   'sempre',
#   'fitte',
#   'cronisti',
#   'parlamentari',
#   'almeno',
#   'conte',
#   'domande',
#   'fare',
#   'ôçª'],
#  ['blackouttotale',
#   'eleggiamolo',
#   'presidente',
#   'repubblica',
#   'miserabile',
#   'buffone',
#   'quirinale',
#   'berlusconi',
#   'httpstco7gyôçª'],
#  ['giuliomarini2',
#   'palazzochigi',
#   'comunque',
#   'articolo',
#   'apologetico',
#   'grande',
#   'decisore',
#   'benissimo',
#   'ovunque',
#   'mentre',
#   'invece',
#   'distruggendo',
#   'paese',
#   'divisivo',
#   'pdc',
#   'oso',
#   'immaginarlo',
#   'quirinale'],
#  ['pera',
#   'frattini',
#   'casellati',
#   'moratti',
#   'amato',
#   'cartabia',
#   'ricambio',
#   'dopo',
#   'anni',
#   'presidenti',
#   'cultura',
#   'sinistra',
#   'declassamento',
#   'quirinale',
#   'penosi',
#   'punto',
#   'draghi',
#   'salvini',
#   'portaaporta'],
#  ['blackouttotale',
#   'eleggiamolo',
#   'presidente',
#   'repubblica',
#   'miserabile',
#   'buffone',
#   'quirinale',
#   'berlusconi',
#   'httpstco7gyôçª'],
#  ['lombard5stelle',
#   'quirinale',
#   'dariovioli',
#   'lôçöipotesi',
#   'possa',
#   'votare',
#   'berlusconi',
#   'semplicemente',
#   'ridicola',
#   'fantapolitica',
#   'unôçöoffôçª'],
#  ['mthmwarrior',
#   'la7tv',
#   'maleôüë',
#   'forzaitalia',
#   'forse',
#   'alleati',
#   'governoôøô',
#   'ƒÿü',
#   'berlusconi',
#   'chiede',
#   'appoggio',
#   'perôçª'],
#  ['quirinale',
#   'scontro',
#   'delegato',
#   'lombardia',
#   'centrodestra',
#   'vota',
#   'candidato',
#   'm5s',
#   'radioradicale',
#   'rampi',
#   'httpstco9lkxna59ob'],
#  ['apndp',
#   'conduttori',
#   'qualsiasi',
#   'draghi',
#   'perch',
#   'rifiutato',
#   'parlare',
#   'quirinale',
#   'son',
#   'concoôçª'],
#  ['la7tv',
#   'maleôüë',
#   'forzaitalia',
#   'forse',
#   'alleati',
#   'governoôøô',
#   'ƒÿü',
#   'berlusconi',
#   'chiede',
#   'appoggio',
#   'perch',
#   'ottenerlo',
#   'quirinale'],
#  ['gerriliu5',
#   'nonsonpago1',
#   'maurobiani',
#   'espressonline',
#   'blobrai3',
#   'quirinale'],
#  ['plpetrillo',
#   'sottoscrivo',
#   'pensiero',
#   'clementif',
#   'permanente',
#   'cultura',
#   'rinvio',
#   'tipica',
#   'paese',
#   'permei',
#   'voto',
#   'pôçª'],
#  ['tempoweb',
#   'ritratto',
#   'pietrangelo',
#   'buttafuoco',
#   'draghi',
#   'morto',
#   'insegna',
#   'piangere',
#   'quirinale',
#   'governo',
#   'rete4',
#   'staseraitalia',
#   'ôçª'],
#  ['presidentedellarepubblica',
#   'quirinale',
#   'covid19',
#   'maurobiani',
#   'httpstcotnmhbyv4vo'],
#  ['vuole',
#   'berlusconi',
#   'quirinale',
#   'lultimo',
#   'tassello',
#   'manca',
#   'distruzione',
#   'voglio',
#   'godermela',
#   'diretta',
#   'lounge',
#   'httpstcots7pmcdgnk'],
#  ['quirinale',
#   'candidato',
#   'centrodestra',
#   'alto',
#   'profilo',
#   'dice',
#   'salvini',
#   'cilindro',
#   'lennesima',
#   'volta',
#   'tira',
#   'fuori',
#   'nome',
#   'berlusconi',
#   'politico',
#   'alto',
#   'profilo',
#   'spettacolo',
#   'mamifacciailpiacere',
#   'portaaporta',
#   'noquirisilvio'],
#  ['nonsonpago1', 'maurobiani', 'espressonline', 'blobrai3', 'quirinale'],
#  ['dimartedi',
#   'italiani',
#   'frega',
#   'niente',
#   'quirinale',
#   'presidentedellarepubblica',
#   'presidente',
#   'democrazia',
#   'dopo',
#   'parliamo',
#   'serve',
#   'scuola',
#   'aperte',
#   'perche',
#   'supergreenpass',
#   'megagreenpass',
#   'greenpass',
#   'senza',
#   'senza',
#   'italia',
#   'italy'],
#  ['nonsonpago1',
#   'maurobiani',
#   'taglioalto',
#   'presidentedellarepubblica',
#   'quirinale',
#   'berlusconi',
#   'scavare',
#   'baratro',
#   'settimana',
#   'espreôçª'],
#  ['isamazon',
#   'jokervilma',
#   'sonostefanoit',
#   'ilconteit',
#   'gio2020gio',
#   'napolitanoida',
#   'giuno55',
#   'apatrignan',
#   'mspagna',
#   'idanapolitano5',
#   'fabrixl3ill',
#   'lucabottazzi',
#   'ferrandomau',
#   'aprigli2occhi',
#   'anteo17',
#   'antoniodibari85',
#   'vivdany',
#   'gladiatoremassi',
#   'giannimagini',
#   'primaopoitorna',
#   'parentesi',
#   'draghi',
#   'presidente',
#   'consiglio',
#   'piace',
#   'm5s',
#   'conte',
#   'quirinale',
#   'httpstcoamxxsmaa2e'],
#  ['ilfaccendiere',
#   'voci',
#   'sempre',
#   'fitte',
#   'cronisti',
#   'parlamentari',
#   'almeno',
#   'conte',
#   'domande',
#   'fare',
#   'ôçª'],
#  ['liberoofficial',
#   'credere',
#   'matteosalvini',
#   'poter',
#   'scegliere',
#   'prossimo',
#   'capo',
#   'stato',
#   'trappola',
#   'due',
#   'tavoli',
#   'pdôçª'],
#  ['ierogamos',
#   'giorgiameloni',
#   'quirinale',
#   'meloni',
#   'fase',
#   'fare',
#   'diversamente',
#   'ben',
#   'sapendo',
#   'tanto',
#   'berlusconi',
#   'avr',
#   'mai',
#   'voti',
#   'necessari',
#   'letto',
#   'lintervista',
#   'uffpost',
#   'urbani',
#   'consiglia',
#   'cav',
#   'ritirarsi',
#   'corsa',
#   'quirinale'],
#  ['draghi',
#   'governo',
#   'quirinale',
#   'rebus',
#   'senza',
#   'soluzione',
#   'forse',
#   'forzaitalia',
#   'giorgiameloni',
#   'governo',
#   'italiaviva',
#   'lega',
#   'mariodraghi',
#   'matteorenzi',
#   'matteosalvini',
#   'quirinale',
#   'silvioberlusconi',
#   'httpstcorgpsqdfp6r',
#   'httpstco3vaowosir5'],
#  ['quirinale',
#   'nodo',
#   'berlusconi',
#   'complica',
#   'trattativa',
#   'salvini',
#   'evoca',
#   'governo',
#   'dentro',
#   'leader',
#   'quirinale',
#   'berlusconi',
#   'complica',
#   'httpstco9zrfjcevi2'],
#  ['jacopoat',
#   'qui',
#   'ricordarvi',
#   'berlusconi',
#   'quirinale',
#   'soltanto',
#   'auspicabile',
#   'ineluttabile',
#   'accettatelo',
#   'sapete',
#   'doôçª'],
#  ['ilignorante',
#   'troppo',
#   'repentino',
#   'cambio',
#   'narrazione',
#   'centri',
#   'quirinale',
#   'sistemare',
#   'vuole',
#   'zio',
#   'bill',
#   'musso',
#   'fdragôçª'],
#  ['lôçöintervista',
#   'la7tv',
#   'dato',
#   'lôçöidea',
#   'enricoletta',
#   'molto',
#   'responsabile',
#   'lôçöaccenno',
#   'lôçöappello',
#   'tuttavia',
#   'ribellione',
#   'parlamentari',
#   'forzaitalia',
#   'allôçöipotesi',
#   'berlusconi',
#   'candidato',
#   'quirinale',
#   'cos',
#   '¼ôçªaltro',
#   'vietnam',
#   'presidentedellarepubblica',
#   'httpstcoo8gfztbvfm'],
#  ['portaaporta',
#   'porco',
#   'politico',
#   'berlusconi',
#   'fatto',
#   'volte',
#   'premier',
#   'riconosciuto',
#   'livello',
#   'internazionale',
#   'sinistrasic',
#   'dire',
#   'andare',
#   'quirinale',
#   'httpstcod7gscr5bak'],
#  ['romanzo',
#   'quirinale',
#   'comincia',
#   'entrare',
#   'vivo',
#   'oggi',
#   'carte',
#   'eccetto',
#   'tutte',
#   'coperte',
#   'basandosi',
#   'esclusivamente',
#   'percentuali',
#   'aula',
#   'poco',
#   'pochissimo',
#   'spazio',
#   'manovre',
#   'partitiche',
#   'tema',
#   'bipartisan',
#   'esce',
#   'fuori',
#   'sol',
#   'nome',
#   'pierferdinando',
#   'casini',
#   'dimartedi'],
#  ['ilignorante',
#   'troppo',
#   'repentino',
#   'cambio',
#   'narrazione',
#   'centri',
#   'quirinale',
#   'sistemare',
#   'vuole',
#   'zio',
#   'bill',
#   'musso',
#   'fdragôçª'],
#  ['ilfaccendiere',
#   'voci',
#   'sempre',
#   'fitte',
#   'cronisti',
#   'parlamentari',
#   'almeno',
#   'conte',
#   'domande',
#   'fare',
#   'ôçª'],
#  ['primo',
#   'trapiantato',
#   'cuore',
#   'maiale',
#   'ora',
#   'candidato',
#   'presidenza',
#   'repubblica',
#   'quirinale',
#   'presidentedellarepubblica'],
#  ['tempoweb',
#   'timori',
#   'formazione',
#   'nuovo',
#   'governo',
#   'impossibile',
#   'vada',
#   'elezioni',
#   'terrorizza',
#   'm5s',
#   'ecco',
#   'perch',
#   'voglioôçª'],
#  ['vincepastore',
#   'candidatura',
#   'silvio',
#   'berlusconi',
#   'quirinale',
#   'detto',
#   'ornella',
#   'vanoni',
#   'fattoquotidiano',
#   'intervistata',
#   'ôçª'],
#  ['mostro15119736',
#   'cose',
#   'giornali',
#   'spagnoli',
#   'scrivono',
#   'italiani',
#   'coraggio',
#   'dire',
#   'palacio',
#   'quirinale',
#   'eôçª'],
#  ['fotte',
#   'cazzo',
#   'nessuno',
#   'siccome',
#   'iniziando',
#   'fare',
#   'serio',
#   'caso',
#   'quirisilvio',
#   'programmando',
#   'trasloco',
#   'spagna',
#   'portogallo',
#   'scherzo',
#   'intollerabile',
#   'vergognerei',
#   'nazione',
#   'dimartedi',
#   'cartabianca',
#   'berlusconi',
#   'quirinale'],
#  ['albertoletizia2',
#   'dopo',
#   'avere',
#   'ascoltato',
#   'letta',
#   'lipotesi',
#   'agghiacciante',
#   'berlusconi',
#   'quirinale',
#   'diventa',
#   'improvvisamente',
#   'realistica'],
#  ['m5s',
#   'assemblea',
#   'deputati',
#   'quirinale',
#   'dare',
#   'pieno',
#   'mandato',
#   'conteôçø',
#   'montecitorio',
#   'côçö',
#   'chiede',
#   'mattarellabis',
#   'assemblea',
#   'deputati',
#   'quirinale',
#   'httpstcolwbw3tywet'],
#  ['tommybrain',
#   'quirinale',
#   'dimartedi',
#   'cartabianca',
#   'fuoridalcoro',
#   'attenzione',
#   'passare',
#   'padella',
#   'draghi',
#   'brace',
#   'berlusconi',
#   'noquirisilvio',
#   'httpstcoojix2nlkwr'],
#  ['tgrraimolise',
#   'quirinale',
#   'ecco',
#   'grandielettori',
#   'molise',
#   'httpstcoodlj36co2y'],
#  ['quirinale',
#   'salvini',
#   'meglio',
#   'draghi',
#   'continuasse',
#   'premierôçø',
#   'ôçô',
#   'libero',
#   'quotidiano',
#   'quirinale',
#   'salvini',
#   'draghi',
#   'continuasse',
#   'premier',
#   'libero',
#   'quotidiano',
#   'httpstcocd0c2qt2o9'],
#  ['quirinale',
#   'meloni',
#   'draghi',
#   'chiarisca',
#   'candidato',
#   'noôçø',
#   'ôçô',
#   'libero',
#   'quotidiano',
#   'quirinale',
#   'meloni',
#   'draghi',
#   'chiarisca',
#   'candidato',
#   'libero',
#   'quotidiano',
#   'httpstcowgk168inme'],
#  ['sole24ore',
#   'berlusconi',
#   'pregiudicato',
#   'evasionefiscale',
#   'nonch',
#   'amico',
#   'corrotti',
#   'mafiosi',
#   'altroch',
#   'quirinale'],
#  ['laspettava',
#   'allora',
#   'tempi',
#   'enricostaisereno',
#   'imparato',
#   'nulla',
#   'letta',
#   'berlusconi',
#   'quirinale',
#   'draghi',
#   'mattarella',
#   'httpstcoonszrlqipz'],
#  ['la7tv',
#   'mattarella',
#   'detto',
#   'noooooooo',
#   'tonti',
#   'cosa',
#   'quirinale',
#   'dimartedi'],
#  ['ilfaccendiere',
#   'voci',
#   'sempre',
#   'fitte',
#   'cronisti',
#   'parlamentari',
#   'almeno',
#   'conte',
#   'domande',
#   'fare',
#   'ôçª'],
#  ['berlusconi',
#   'carte',
#   'regola',
#   'aspirare',
#   'quirinale',
#   'dellesito',
#   'finale',
#   'avr',
#   'diritto',
#   'farlo',
#   'lagitazione',
#   'espressa',
#   'taluni',
#   'dimartedi',
#   'altro',
#   'uninsofferenza',
#   'democrazia'],
#  ['lôçöuscita',
#   'ieri',
#   'berlusconi',
#   'totalmente',
#   'sproporzionata',
#   'enricoletta',
#   'crede',
#   'pistola',
#   'scaricaôçø',
#   'belpietro',
#   'brutta',
#   'espressione',
#   'lôçöha',
#   'detta',
#   'leiôçøreplica',
#   'segretario',
#   'dimartedi',
#   'dimartedi',
#   'quirinale'],
#  ['alberoandronico',
#   'alberoandronico',
#   'fotografia',
#   'poesia',
#   'narrativa',
#   'cortometraggi',
#   'pittura',
#   'dialetto',
#   'video',
#   'videopoesie',
#   'httpstco0qkôçª'],
#  ['alberoandronico',
#   'alberoandronico',
#   'fotografia',
#   'poesia',
#   'narrativa',
#   'cortometraggi',
#   'pittura',
#   'dialetto',
#   'video',
#   'videopoesie',
#   'httpstco0qkôçª'],
#  ['alberoandronico',
# ...
#   'meglio',
#   'berlusconi',
#   'vallanzasca',
#   'quirinale',
#   'berlusconi',
#   'noquirisilvio'],
#  ['thewatcherpost',
#   'ƒùô',
#   'largo',
#   'chigi',
#   'gennaio',
#   'ore',
#   '845',
#   'torna',
#   'rassegna',
#   'stampa',
#   'thewatcherpost',
#   'condotta',
#   'pierotatafiore',
#   'luci',
#   'puntôçª'],
#  ['maurobiani',
#   'presidentedellarepubblica',
#   'quirinale',
#   'covid',
#   'corsa',
#   'oggi',
#   'repubblica',
#   'httpstcowxmlzqlaoo'],
#  ['youtrend',
#   'quirinale',
#   'abruzzo',
#   'liguria',
#   'lombardia',
#   'umbria',
#   'eletto',
#   'rispettivi',
#   'delegati',
#   'vista',
#   'gennaio',
#   'delegôçª'],
#  ['dimartedi',
#   'travaglio',
#   'draghi',
#   'governo',
#   'tenere',
#   'insieme',
#   'larga',
#   'maggioranza',
#   'invece',
#   'tentare',
#   'fuga',
#   'verso',
#   'quirinaleôçø',
#   'vorremo',
#   'mica',
#   'privarci',
#   'cotanto',
#   'salvatore',
#   'patria',
#   'draghi',
#   'governodeimigliori'],
#  ['apndp',
#   'conduttori',
#   'qualsiasi',
#   'draghi',
#   'perch',
#   'rifiutato',
#   'parlare',
#   'quirinale',
#   'son',
#   'concoôçª'],
#  ['la7tv',
#   'ottoemezzo',
#   'walter',
#   'veltroni',
#   'candidatura',
#   'silvio',
#   'berlusconi',
#   'quirinale',
#   'soprattutto',
#   'volta',
#   'vista',
#   'situazioôçª'],
#  ['presidente',
#   'repubblica',
#   'scelto',
#   'segreto',
#   'enna',
#   'mafia',
#   'metodo',
#   'quirinale'],
#  ['liberoofficial',
#   'quirinale',
#   'elezione',
#   'rinviabile',
#   'deve',
#   'essere',
#   'foza',
#   'presenza',
#   'sabinocassese',
#   'spiega',
#   'dribblarôçª'],
#  ['troppo',
#   'repentino',
#   'cambio',
#   'narrazione',
#   'centri',
#   'quirinale',
#   'sistemare',
#   'vuole',
#   'zio',
#   'bill',
#   'musso',
#   'fdragoni',
#   'quirinale',
#   'draghibugiardo',
#   'speranzadimettiti',
#   'httpstcogzp8rulj2w'],
#  ['dimartedi',
#   'presidentedellarepubblica',
#   'governodeipeggiori',
#   'novax',
#   'nogreenpassobbligatorio',
#   'amo',
#   'governodeimigliori',
#   'travaglio',
#   'cerca',
#   'demolire',
#   'ogni',
#   'costo',
#   'draghi',
#   'porta',
#   'dritti',
#   'berlusconi',
#   'quirinale',
#   'poi'],
#  ['expoitalyonline',
#   'calenda',
#   'rilancia',
#   'cartabia',
#   'proposta',
#   'ministra',
#   'cartabia',
#   'persona',
#   'grande',
#   'qualit',
#   'presidente',
#   'delôçª'],
#  ['uomini',
#   'servono',
#   'momenti',
#   'crisi',
#   'quirinale',
#   'lancio',
#   'candidatura',
#   'carcarlopravettonipresidente',
#   'httpstcooxmdxb1e3k'],
#  ['apndp',
#   'conduttori',
#   'qualsiasi',
#   'draghi',
#   'perch',
#   'rifiutato',
#   'parlare',
#   'quirinale',
#   'son',
#   'concoôçª'],
#  ['catirafaella',
#   'comunque',
#   'finir',
#   'romanzo',
#   'quirinale',
#   'nessuno',
#   'toglier',
#   'testa',
#   'davidsassoli',
#   'stato',
#   'grande',
#   'presôçª'],
#  ['segnale',
#   'delirio',
#   'onnipotenza',
#   'draghidimettiti',
#   'draghivatteneingalera',
#   'quirinale',
#   'bassetti',
#   'renzifaischifo',
#   'httpstcov0z724xbnz'],
#  ['maurobiani',
#   'presidentedellarepubblica',
#   'quirinale',
#   'covid',
#   'corsa',
#   'oggi',
#   'repubblica',
#   'httpstcowxmlzqlaoo'],
#  ['lucianoghelfi',
#   'salvini',
#   'amato',
#   'parterre',
#   'testa',
#   'quirinale',
#   'forzerei',
#   'mattarella',
#   'fare',
#   'quel',
#   'vuolôçª'],
#  ['valys',
#   'crisanti',
#   'viene',
#   'chiesto',
#   'parere',
#   'draghi',
#   'quirinale',
#   'stato',
#   'ôçÿsfortunatoôçö',
#   'detto',
#   'lôçöimmunit',
#   'dôçª'],
#  ['apndp',
#   'conduttori',
#   'qualsiasi',
#   'draghi',
#   'perch',
#   'rifiutato',
#   'parlare',
#   'quirinale',
#   'son',
#   'concoôçª'],
#  ['apndp',
#   'conduttori',
#   'qualsiasi',
#   'draghi',
#   'perch',
#   'rifiutato',
#   'parlare',
#   'quirinale',
#   'son',
#   'concoôçª'],
#  ['marta',
#   'cartabia',
#   'presidente',
#   'repubblica',
#   'quirinale',
#   'httpstcomp0gvqnx7s'],
#  ['valys',
#   'crisanti',
#   'viene',
#   'chiesto',
#   'parere',
#   'draghi',
#   'quirinale',
#   'stato',
#   'ôçÿsfortunatoôçö',
#   'detto',
#   'lôçöimmunit',
#   'dôçª'],
#  ['liberoofficial',
#   'quirinale',
#   'elezione',
#   'rinviabile',
#   'deve',
#   'essere',
#   'foza',
#   'presenza',
#   'sabinocassese',
#   'spiega',
#   'dribblarôçª'],
#  ['maurobiani',
#   'presidentedellarepubblica',
#   'quirinale',
#   'covid',
#   'corsa',
#   'oggi',
#   'repubblica',
#   'httpstcowxmlzqlaoo'],
#  ['valys',
#   'crisanti',
#   'viene',
#   'chiesto',
#   'parere',
#   'draghi',
#   'quirinale',
#   'stato',
#   'ôçÿsfortunatoôçö',
#   'detto',
#   'lôçöimmunit',
#   'dôçª'],
#  ['eib63',
#   'direpuntoit',
#   'sola',
#   'ipotesi',
#   'berlusconi',
#   'quirinale',
#   'offende',
#   'decine',
#   'milioni',
#   'italianiôçø',
#   'antonio',
#   'scurati',
#   'quirinale',
#   'berlôçª'],
#  ['maurobiani',
#   'presidentedellarepubblica',
#   'quirinale',
#   'covid',
#   'corsa',
#   'oggi',
#   'repubblica',
#   'httpstcowxmlzqlaoo'],
#  ['valys',
#   'crisanti',
#   'viene',
#   'chiesto',
#   'parere',
#   'draghi',
#   'quirinale',
#   'stato',
#   'ôçÿsfortunatoôçö',
#   'detto',
#   'lôçöimmunit',
#   'dôçª'],
#  ['liberoofficial',
#   'mariodraghi',
#   'traghettare',
#   'paese',
#   'fuori',
#   'pandemia',
#   'potrebbe',
#   'sfilarsi',
#   'corsa',
#   'quirinale',
#   'spingere',
#   'perôçª'],
#  ['dinogiarrusso',
#   'immaginatevi',
#   'giuseppeconteit',
#   'andato',
#   'conferenzastampa',
#   'tre',
#   'giorni',
#   'ritardo',
#   'escludendo',
#   'quotidiano',
#   'eôçª'],
#  ['la7tv',
#   'ottoemezzo',
#   'walter',
#   'veltroni',
#   'prossima',
#   'elezione',
#   'capo',
#   'stato',
#   'possiamo',
#   'permetterci',
#   'perdere',
#   'colpo',
#   'soloôçª'],
#  ['maurobiani',
#   'presidentedellarepubblica',
#   'quirinale',
#   'covid',
#   'corsa',
#   'oggi',
#   'repubblica',
#   'httpstcowxmlzqlaoo'],
#  ['valys',
#   'crisanti',
#   'viene',
#   'chiesto',
#   'parere',
#   'draghi',
#   'quirinale',
#   'stato',
#   'ôçÿsfortunatoôçö',
#   'detto',
#   'lôçöimmunit',
#   'dôçª'],
#  ['valys',
#   'crisanti',
#   'viene',
#   'chiesto',
#   'parere',
#   'draghi',
#   'quirinale',
#   'stato',
#   'ôçÿsfortunatoôçö',
#   'detto',
#   'lôçöimmunit',
#   'dôçª'],
#  ['concordo',
#   'enricoletta',
#   'mattarella',
#   'bis',
#   'massimo',
#   'bisogna',
#   'assolutamente',
#   'rispettare',
#   'volont',
#   'presidente',
#   'dimartedi',
#   'quirinale'],
#  ['direpuntoit',
#   'sola',
#   'ipotesi',
#   'berlusconi',
#   'quirinale',
#   'offende',
#   'decine',
#   'milioni',
#   'italianiôçø',
#   'antonio',
#   'scurati',
#   'quirinale',
#   'berlusconi'],
#  ['dinogiarrusso',
#   'immaginatevi',
#   'giuseppeconteit',
#   'andato',
#   'conferenzastampa',
#   'tre',
#   'giorni',
#   'ritardo',
#   'escludendo',
#   'quotidiano',
#   'eôçª'],
#  ['lucianoghelfi',
#   'salvini',
#   'amato',
#   'parterre',
#   'testa',
#   'quirinale',
#   'forzerei',
#   'mattarella',
#   'fare',
#   'quel',
#   'vuolôçª'],
#  ['salvini',
#   'amato',
#   'parterre',
#   'testa',
#   'quirinale',
#   'forzerei',
#   'mattarella',
#   'fare',
#   'quel',
#   'vuole',
#   'serve',
#   'tavolo',
#   'leader',
#   'senza',
#   'veti'],
#  ['valys',
#   'crisanti',
#   'viene',
#   'chiesto',
#   'parere',
#   'draghi',
#   'quirinale',
#   'stato',
#   'ôçÿsfortunatoôçö',
#   'detto',
#   'lôçöimmunit',
#   'dôçª'],
#  ['lercionotizie',
#   'breakingnews',
#   'quirinale',
#   'riunione',
#   'segreta',
#   'centrodestra',
#   'centrosinistra',
#   'sala',
#   'bingo',
#   'bufalotta',
#   'roma'],
#  ['lanotiziatweet',
#   'paese',
#   'piena',
#   'emergenza',
#   'covid',
#   'draghi',
#   'berlusconi',
#   'lôçöunico',
#   'pensiero',
#   'giochi',
#   'quirinale',
#   'ultiôçª'],
#  ['liberoofficial',
#   'quirinale',
#   'elezione',
#   'rinviabile',
#   'deve',
#   'essere',
#   'foza',
#   'presenza',
#   'sabinocassese',
#   'spiega',
#   'dribblarôçª'],
#  ['ottoemezzo',
#   'walter',
#   'veltroni',
#   'candidatura',
#   'silvio',
#   'berlusconi',
#   'quirinale',
#   'soprattutto',
#   'volta',
#   'vista',
#   'situazione',
#   'drammatica',
#   'versiamo',
#   'necessario',
#   'trovare',
#   'persona',
#   'lautorevolezza',
#   'internazionale',
#   'httpstco81h4tuos6g'],
#  ['valys',
#   'crisanti',
#   'viene',
#   'chiesto',
#   'parere',
#   'draghi',
#   'quirinale',
#   'stato',
#   'ôçÿsfortunatoôçö',
#   'detto',
#   'lôçöimmunit',
#   'dôçª'],
#  ['quirinale',
#   'elezione',
#   'rinviabile',
#   'deve',
#   'essere',
#   'foza',
#   'presenza',
#   'sabinocassese',
#   'spiega',
#   'dribblare',
#   'covid',
#   'httpstcoiwsdtwl7rz',
#   'httpstcom9i3pglji9'],
#  ['floris', '2022', 'anno', 'berlusconi', 'quirinale'],
#  ['vedo', 'difficile', 'enricoletta', 'berlusconi', 'quirinale'],
#  ['berlusconi',
#   'quando',
#   'giovanemeno',
#   'rincoglionitovedeva',
#   'comunisti',
#   'dappertuttochiss',
#   'cosa',
#   'vedr',
#   'ora',
#   'candidato',
#   'quirinale'],
#  ['abituato',
#   'esser',
#   'criticato',
#   'contraddetto',
#   'pbuttafuoco',
#   'staseraitalia',
#   'staseraitalia',
#   'draghi',
#   'risposte',
#   'chiaro',
#   'pensierino',
#   'quirinale'],
#  ['letta',
#   'dimartedi',
#   'vedo',
#   'difficile',
#   'berlusconi',
#   'quirinale',
#   'httpstcotdzklmbooe'],
#  ['maurobiani',
#   'presidentedellarepubblica',
#   'quirinale',
#   'covid',
#   'corsa',
#   'oggi',
#   'repubblica',
#   'httpstcowxmlzqlaoo'],
#  ['apndp',
#   'conduttori',
#   'qualsiasi',
#   'draghi',
#   'perch',
#   'rifiutato',
#   'parlare',
#   'quirinale',
#   'son',
#   'concoôçª'],
#  ['regliguria',
#   'giovannitoti',
#   'cuoreeconomico',
#   'esg89group',
#   'quirinale',
#   'httpstcoy2ozl16j0d'],
#  ['berlusconi',
#   'sar',
#   'áôçö',
#   'eletto',
#   'quirinale',
#   'quasi',
#   'sicuramente',
#   'daraôçö',
#   'lôçöamnistia',
#   'amici',
#   'criminali',
#   'dellutri',
#   'previti',
#   'fedeôçª',
#   'vergogna'],
#  ['carta73',
#   'qualche',
#   'giorno',
#   'ragionava',
#   'amici',
#   'discutendo',
#   'politica',
#   'speravamo',
#   'vederti',
#   'salire',
#   'colle',
#   'salito',
#   'moltoôçª'],
#  ['tempoweb',
#   'colloquio',
#   'draghisalvini',
#   'senato',
#   'spinta',
#   'lega',
#   'resti',
#   'governo',
#   'côçö',
#   'bisogno',
#   'confusioneôçø',
#   'quirinale',
#   '1ôçª'],
#  ['tempoweb',
#   'colloquio',
#   'draghisalvini',
#   'senato',
#   'spinta',
#   'lega',
#   'resti',
#   'governo',
#   'côçö',
#   'bisogno',
#   'confusioneôçø',
#   'quirinale',
#   '1ôçª'],
#  ['mica',
#   'vero',
#   'draghi',
#   'diventando',
#   'presidente',
#   'repubblica',
#   'lascerebbe',
#   'palazzo',
#   'chigi',
#   'smonterebbe',
#   'pezzo',
#   'pezzo',
#   'poi',
#   'ricostruirselo',
#   'dentro',
#   'quirinale',
#   'quirinale'],
#  ['apndp',
#   'conduttori',
#   'qualsiasi',
#   'draghi',
#   'perch',
#   'rifiutato',
#   'parlare',
#   'quirinale',
#   'son',
#   'concoôçª'],
#  ['lanotiziatweet',
#   'paese',
#   'piena',
#   'emergenza',
#   'covid',
#   'draghi',
#   'berlusconi',
#   'lôçöunico',
#   'pensiero',
#   'giochi',
#   'quirinale',
#   'ultiôçª'],
#  ['maurobiani',
#   'presidentedellarepubblica',
#   'quirinale',
#   'covid',
#   'corsa',
#   'oggi',
#   'repubblica',
#   'httpstcowxmlzqlaoo'],
#  ['ottoemezzo',
#   'walter',
#   'veltroni',
#   'possibile',
#   'elezione',
#   'draghi',
#   'quirinale',
#   'condizione',
#   'proseguire',
#   'lazione',
#   'dellesecutivo',
#   'condizione',
#   'politica',
#   'partiti',
#   'devono',
#   'sfilare',
#   'base',
#   'proprie',
#   'convenienze',
#   'httpstcomoddvxrth6'],
#  ['fabrizio19651',
#   'minaccia',
#   'obliqua',
#   'dimostra',
#   'volta',
#   'caratteristiche',
#   'fare',
#   'presidentedellarepubblicaôçª'],
#  ['colloquio',
#   'draghisalvini',
#   'senato',
#   'spinta',
#   'lega',
#   'resti',
#   'governo',
#   'côçö',
#   'bisogno',
#   'confusioneôçø',
#   'quirinale',
#   '11gennaio',
#   'iltempoquotidiano',
#   'httpstcoueb5mlvect',
#   'httpstcozdc6tgcdht'],
#  ['ivanscalfarotto', 'riflessioni', 'quirinale', 'httpstcoxlzfov8f3o'],
#  ['lanotiziatweet',
#   'draghi',
#   'sogna',
#   'quirinale',
#   'palazzo',
#   'chigi',
#   'fallito',
#   'quasi',
#   'partire',
#   'recovery',
#   'plan',
#   'campagna',
#   'vaccinaleôçª'],
#  ['ricordo',
#   'primo',
#   'presidente',
#   'repubblica',
#   'enrico',
#   'nicola',
#   'ôçªche',
#   'comanda',
#   'mai',
#   'cosi',
#   'bene',
#   'quando',
#   'obbedisce',
#   'propria',
#   'coscienza',
#   'leadership',
#   'quirinale',
#   'httpstcospiowjr9hl'],
#  ['apndp',
#   'conduttori',
#   'qualsiasi',
#   'draghi',
#   'perch',
#   'rifiutato',
#   'parlare',
#   'quirinale',
#   'son',
#   'concoôçª'],
#  ['ƒæç',
#   'quirinale',
#   'presidentedellarepubblica',
#   'donnaalquirinale',
#   'toscana',
#   'siena',
#   'bohemien',
#   'radicalchic',
#   'cattocomunisti',
#   'cattocomunismo',
#   'httpstcoc5yrlqifhe',
#   'httpstcosxgblkacqt'],
#  ['dinogiarrusso',
#   'immaginatevi',
#   'giuseppeconteit',
#   'andato',
#   'conferenzastampa',
#   'tre',
#   'giorni',
#   'ritardo',
#   'escludendo',
#   'quotidiano',
#   'eôçª'],
#  ['valys',
#   'crisanti',
#   'viene',
#   'chiesto',
#   'parere',
#   'draghi',
#   'quirinale',
#   'stato',
#   'ôçÿsfortunatoôçö',
#   'detto',
#   'lôçöimmunit',
#   'dôçª'],
#  ['ivanscalfarotto', 'riflessioni', 'quirinale', 'httpstcoxlzfov8f3o'],
#  ['piacerebbe',
#   'draghi',
#   'decidesse',
#   'levarsi',
#   'piedi',
#   'altro',
#   'quirinale',
#   'ottoemezzo'],
#  ['apndp',
#   'conduttori',
#   'qualsiasi',
#   'draghi',
#   'perch',
#   'rifiutato',
#   'parlare',
#   'quirinale',
#   'son',
#   'concoôçª'],
#  ['ilvetero',
#   'finalmente',
#   'candidatura',
#   'grado',
#   'mettere',
#   'dôçöaccordo',
#   'italiani',
#   'tutte',
#   'italiane',
#   'cristinapresidente',
#   'subitoôçª'],
#  ['valys',
#   'crisanti',
#   'viene',
#   'chiesto',
#   'parere',
#   'draghi',
#   'quirinale',
#   'stato',
#   'ôçÿsfortunatoôçö',
#   'detto',
#   'lôçöimmunit',
#   'dôçª'],
#  ['dinogiarrusso',
#   'immaginatevi',
#   'giuseppeconteit',
#   'andato',
#   'conferenzastampa',
#   'tre',
#   'giorni',
#   'ritardo',
#   'escludendo',
#   'quotidiano',
#   'eôçª'],
#  ['lucillamasini',
#   'quesito',
#   'gennaio',
#   'fra',
#   'avere',
#   'berlusconi',
#   'presidente',
#   'repubblica',
#   'mangiare',
#   'chilo',
#   'môé¼rda',
#   'preferite',
#   'guano',
#   'dôçª'],
#  ['domanigiornale',
#   'berlusconi',
#   'arrivato',
#   'roma',
#   'prover',
#   'salto',
#   'quirinale',
#   'nonostante',
#   'consiglieri',
#   'cautamôçª'],
#  ['centrodestra',
#   'diviso',
#   'berlusconi',
#   'quirinale',
#   'draghi',
#   'resta',
#   'pole',
#   'prende',
#   'quota',
#   'lipotesi',
#   'bis',
#   'mattarella',
#   'httpstcoc5kojpgj34'],
#  ['nicofuccaro',
#   'qualcuno',
#   'capito',
#   'qualcosa',
#   'iperpolitichese',
#   'sostenendo',
#   'veltroniwalter',
#   'quirinale',
#   'dôçª'],
#  ['lombard5stelle',
#   'quirinale',
#   'dariovioli',
#   'lôçöipotesi',
#   'possa',
#   'votare',
#   'berlusconi',
#   'semplicemente',
#   'ridicola',
#   'fantapolitica',
#   'unôçöoffôçª'],
#  ['fabrizio19651',
#   'minaccia',
#   'obliqua',
#   'dimostra',
#   'volta',
#   'caratteristiche',
#   'fare',
#   'presidentedellarepubblicaôçª'],
#  ['smemorato',
#   'cologno',
#   'quirinale',
#   'voglio',
#   'vedere',
#   'solo',
#   'puntata',
#   'fratellicrozza'],
#  ['sgiacomoni',
#   'quirinale',
#   'regole',
#   'democrazia',
#   'scegliere',
#   'ƒöá',
#   'convinto',
#   'berlusconi',
#   'colle',
#   'draghi',
#   'govôçª'],
#  ['valys',
#   'crisanti',
#   'viene',
#   'chiesto',
#   'parere',
#   'draghi',
#   'quirinale',
#   'stato',
#   'ôçÿsfortunatoôçö',
#   'detto',
#   'lôçöimmunit',
#   'dôçª'],
#  ['valys',
#   'crisanti',
#   'viene',
#   'chiesto',
#   'parere',
#   'draghi',
#   'quirinale',
#   'stato',
#   'ôçÿsfortunatoôçö',
#   'detto',
#   'lôçöimmunit',
#   'dôçª'],
#  ['quirinale',
#   'segreteria',
#   'decide',
#   'decidere',
#   'candidatura',
#   'berlusconi',
#   'angoscia',
#   'letta',
#   'quirinale',
#   'segreteria',
#   'decide',
#   'httpstcoyhc1uzasaf'],
#  ['canditati', 'quirinale', 'httpstcogrtsjwhtty'],
#  ['valys',
#   'crisanti',
#   'viene',
#   'chiesto',
#   'parere',
#   'draghi',
#   'quirinale',
#   'stato',
#   'ôçÿsfortunatoôçö',
#   'detto',
#   'lôçöimmunit',
#   'dôçª'],
#  ['valys',
#   'crisanti',
#   'viene',
#   'chiesto',
#   'parere',
#   'draghi',
#   'quirinale',
#   'stato',
#   'ôçÿsfortunatoôçö',
#   'detto',
#   'lôçöimmunit',
#   'dôçª'],
#  ['valys',
#   'crisanti',
#   'viene',
#   'chiesto',
#   'parere',
#   'draghi',
#   'quirinale',
#   'stato',
#   'ôçÿsfortunatoôçö',
#   'detto',
#   'lôçöimmunit',
#   'dôçª'],
#  ['quirinale',
#   'berlusconi',
#   'draghi',
#   'presidentedellarepubblica',
#   'httpstcouocufpo59s'],
#  ['ottoemezzo',
#   'walter',
#   'veltroni',
#   'prossima',
#   'elezione',
#   'capo',
#   'stato',
#   'possiamo',
#   'permetterci',
#   'perdere',
#   'colpo',
#   'solo',
#   'draghi',
#   'mattarella',
#   'veltroniwalter',
#   'quirinale',
#   'httpstcovl1etjjybt'],
#  ['crisanti',
#   'viene',
#   'chiesto',
#   'parere',
#   'draghi',
#   'quirinale',
#   'stato',
#   'ôçÿsfortunatoôçö',
#   'detto',
#   'lôçöimmunit',
#   'gregge',
#   'greenpass',
#   'protetto',
#   'contagio',
#   'poi',
#   'arrivata',
#   'omicron',
#   'fortuna',
#   'leggeraôçøôçø',
#   'ottoemezzo'],
#  ['adolfotasinato',
#   'giornale',
#   'inglese',
#   'the',
#   'guardian',
#   'italia',
#   'vige',
#   'sistema',
#   'democratico',
#   'draghi',
#   'italy',
#   'italia',
#   'democrazia',
#   'polôçª'],
#  ['ottoemezzo', 'quirinale', 'crisanti', 'scopri', 'lintruso'],
#  ['berlusconi', 'quirinale', 'periodo', 'storico', 'sopportare', 'ottoemezzo'],
#  []]

# %%
flatten_list = sum(lista_token_m2, [])

# %%
flatten_list
# Out:
# ['pschioppa',
#  'delegati',
#  'regionali',
#  'scelti',
#  'grandi',
#  'elettori',
#  'quirinale',
#  'viste',
#  'appartenenze',
#  'mai',
#  'facendoôçª',
#  'siamonoitv2000',
#  'corsa',
#  'quirinale',
#  'speciale',
#  'siamonoi',
#  '1515',
#  'tv2000it',
#  'giuspaterniti',
#  'paolograldi',
#  'francobechis',
#  'ôçª',
#  'siamonoi',
#  '1515',
#  'tv2000it',
#  'quirinale',
#  '12gennaio',
#  'canale28',
#  'siamonoitv2000',
#  'francobechis',
#  'giuspaterniti',
#  'paolograldi',
#  'ilmessaggeroit',
#  'tempoweb',
#  'gabrifacondo',
#  'httpstcorxcdpgciy0',
#  'dopo',
#  'mesi',
#  'mattarella',
#  'detto',
#  'pensava',
#  'nemmeno',
#  'ora',
#  'ripropongono',
#  'mattarella',
#  'secondo',
#  'incarico',
#  'cos',
#  'tranquillamente',
#  'cosa',
#  'fattibile',
#  'mondo',
#  'quirinale',
#  'smenichini',
#  'sar',
#  'purtroppo',
#  'alcun',
#  'effetto',
#  'sassoli',
#  'voto',
#  'quirinale',
#  'momento',
#  'politica',
#  'gentile',
#  'ôçª',
#  'dinogiarrusso',
#  'immaginatevi',
#  'giuseppeconteit',
#  'andato',
#  'conferenzastampa',
#  'tre',
#  'giorni',
#  'ritardo',
#  'escludendo',
#  'quotidiano',
#  'eôçª',
#  'fissata',
#  'oggi',
#  'pomeriggio',
#  'seduta',
#  'daula',
#  'dellassemblea',
#  'regionale',
#  'siciliana',
#  'elegger',
#  'tre',
#  'grandi',
#  'elettori',
#  'gennaio',
#  'prossimo',
#  'voteranno',
#  'nuovo',
#  'presidente',
#  'repubblica',
#  'ars',
#  'palermo',
#  'quirinale',
#  'httpstcokotscdhde5',
#  'httpstcoelaaym8eyc',
#  'cckki',
#  'dice',
#  'berlusconi',
#  'draghi',
#  'quirinale',
#  'voto',
#  'probabilmente',
#  'mattarella',
#  'sar',
#  'costretto',
#  'disfare',
#  'bagagli',
#  'feôçª',
#  'corriere',
#  'stila',
#  'possibili',
#  'nomi',
#  'quirinale',
#  'vari',
#  'noquirisilvio',
#  'prodi',
#  'casini',
#  'cartabia',
#  'venire',
#  'voglia',
#  'andare',
#  'sotto',
#  'finestra',
#  'mattarella',
#  'piangere',
#  'gridare',
#  'lasciare',
#  'prego',
#  'fattoquotidiano',
#  'quirinale',
#  'cinque',
#  'stelle',
#  'pensano',
#  'scrivere',
#  'nulla',
#  'scheda',
#  'prime',
#  'tre',
#  'chiame',
#  'poi',
#  'andare',
#  'sulôçª',
#  'stefano',
#  'folli',
#  'repubblica',
#  'molti',
#  'cittadini',
#  'pensano',
#  'quirinale',
#  'httpstcoiah4audogt',
#  'perle',
#  'cinismo',
#  'amp',
#  'saggezza',
#  'quirinale',
#  'httpstcomfgj7xd0x7',
#  'cose',
#  'strane',
#  'totoquirinale',
#  'lette',
#  'parecchie',
#  'secondo',
#  'centrosinistra',
#  'potrebbe',
#  'dire',
#  'letizia',
#  'moratti',
#  'perch',
#  'figlia',
#  'partigiano',
#  'stampa',
#  'oggi',
#  'batte',
#  'davvero',
#  'tutte',
#  'quirinale',
#  'elezioniquirinale',
#  'presidentedellarepubblica',
#  'cckki',
#  'dice',
#  'berlusconi',
#  'draghi',
#  'quirinale',
#  'voto',
#  'probabilmente',
#  'mattarella',
#  'sar',
#  'costretto',
#  'disfare',
#  'bagagli',
#  'feôçª',
#  'murandrea1',
#  'quirinale',
#  'perno',
#  'istituzionale',
#  'geopolitico',
#  'strategico',
#  'stato',
#  'italiano',
#  'forza',
#  'quirinale',
#  'poteôçª',
#  'arresti',
#  'catania',
#  'pizzo',
#  'usura',
#  'addio',
#  'sassoli',
#  'delirio',
#  'novax',
#  'social',
#  'bassetti',
#  'pubblichiamo',
#  'dato',
#  'contagiôçø',
#  'lôçöars',
#  'scegli',
#  'grandi',
#  'elettori',
#  'quirinale',
#  'pronta',
#  'task',
#  'force',
#  'regionale',
#  'pnrr',
#  'edicola',
#  'primapagina',
#  '12gennaio',
#  'httpstcoosymboonnd',
#  'dinogiarrusso',
#  'immaginatevi',
#  'giuseppeconteit',
#  'andato',
#  'conferenzastampa',
#  'tre',
#  'giorni',
#  'ritardo',
#  'escludendo',
#  'quotidiano',
#  'eôçª',
#  'berlusconi',
#  'improponibile',
#  'quirinale',
#  'condannato',
#  'via',
#  'definitiva',
#  'ancora',
#  'sotto',
#  'processo',
#  'diventare',
#  'presidente',
#  'repubblica',
#  'andr',
#  'sbarra',
#  'imputato',
#  'presidente',
#  'consiglio',
#  'superiore',
#  'magistratura',
#  'quirinale',
#  'oggi',
#  'berlusconi',
#  'voto',
#  'toma',
#  '½per',
#  'silvio',
#  'berlusconi',
#  'perfetto',
#  'quirinale',
#  'berlusconi',
#  'toma',
#  'httpstcogg8mcae19i',
#  'via',
#  'moliseweb',
#  'fuskiko',
#  'notizia',
#  'vera',
#  'domani',
#  'cara',
#  'avvocatessa',
#  'querela',
#  'gliela',
#  'toglie',
#  'nessuno',
#  'quirinale',
#  'chiediamo',
#  'scuse',
#  'imm',
#  'diatôçª',
#  'fattoquotidiano',
#  'quirinale',
#  'cinque',
#  'stelle',
#  'pensano',
#  'scrivere',
#  'nulla',
#  'scheda',
#  'prime',
#  'tre',
#  'chiame',
#  'poi',
#  'andare',
#  'sulôçª',
#  'cososono',
#  'noquirisilvio',
#  'cosa',
#  'danaro',
#  'eleggere',
#  'pregiudicato',
#  'quirinale',
#  'ƒñ¼',
#  'fuskiko',
#  'notizia',
#  'vera',
#  'domani',
#  'cara',
#  'avvocatessa',
#  'querela',
#  'gliela',
#  'toglie',
#  'nessuno',
#  'quirinale',
#  'chiediamo',
#  'scuse',
#  'imm',
#  'diatôçª',
#  'cckki',
#  'dice',
#  'berlusconi',
#  'draghi',
#  'quirinale',
#  'voto',
#  'probabilmente',
#  'mattarella',
#  'sar',
#  'costretto',
#  'disfare',
#  'bagagli',
#  'feôçª',
#  'fuskiko',
#  'notizia',
#  'vera',
#  'domani',
#  'cara',
#  'avvocatessa',
#  'querela',
#  'gliela',
#  'toglie',
#  'nessuno',
#  'quirinale',
#  'chiediamo',
#  'scuse',
#  'imm',
#  'diatôçª',
#  'fattoquotidiano',
#  'quirinale',
#  'cinque',
#  'stelle',
#  'pensano',
#  'scrivere',
#  'nulla',
#  'scheda',
#  'prime',
#  'tre',
#  'chiame',
#  'poi',
#  'andare',
#  'sulôçª',
#  'quirinale',
#  'cinque',
#  'stelle',
#  'pensano',
#  'scrivere',
#  'nulla',
#  'scheda',
#  'prime',
#  'tre',
#  'chiame',
#  'poi',
#  'andare',
#  'bisôçø',
#  'draghi',
#  'conte',
#  'incontrer',
#  'salvini',
#  'lucadecarolis',
#  'wandamarra',
#  'httpstcowm4donplb7',
#  'armanduplessis',
#  'considerando',
#  'alcune',
#  'bizzarre',
#  'ipotesi',
#  'campo',
#  'quirinale',
#  'scrive',
#  'folli',
#  'paese',
#  'potrebbe',
#  'aver',
#  'bisognoôçª',
#  'smenichini',
#  'sar',
#  'purtroppo',
#  'alcun',
#  'effetto',
#  'sassoli',
#  'voto',
#  'quirinale',
#  'momento',
#  'politica',
#  'gentile',
#  'ôçª',
#  'maurobiani',
#  'presidentedellarepubblica',
#  'quirinale',
#  'covid',
#  'corsa',
#  'oggi',
#  'repubblica',
#  'httpstcowxmlzqlaoo',
#  'lanotiziatweet',
#  'draghi',
#  'sogna',
#  'quirinale',
#  'palazzo',
#  'chigi',
#  'fallito',
#  'quasi',
#  'partire',
#  'recovery',
#  'plan',
#  'campagna',
#  'vaccinaleôçª',
#  'maurobiani',
#  'presidentedellarepubblica',
#  'quirinale',
#  'covid',
#  'corsa',
#  'oggi',
#  'repubblica',
#  'httpstcowxmlzqlaoo',
#  'giorni',
#  'allôçöalba',
#  'quirinale',
#  'lanotiziatweet',
#  'draghi',
#  'sogna',
#  'quirinale',
#  'palazzo',
#  'chigi',
#  'fallito',
#  'quasi',
#  'partire',
#  'recovery',
#  'plan',
#  'campagna',
#  'vaccinaleôçª',
#  'maurobiani',
#  'presidentedellarepubblica',
#  'quirinale',
#  'covid',
#  'corsa',
#  'oggi',
#  'repubblica',
#  'httpstcowxmlzqlaoo',
#  'thebrightside0',
#  'buonoasapersi',
#  'ƒæí',
#  'buona',
#  'utile',
#  'informazione',
#  'davidegiac',
#  'rtl1025',
#  'quando',
#  'ricorda',
#  'sottolinea',
#  'lôçª',
#  'quirinale',
#  'mattarellabis',
#  'unico',
#  'estremo',
#  'tentativo',
#  'centrosinistra',
#  'empasse',
#  'candidato',
#  'antiberlusconi',
#  'domanigiornale',
#  'illustra',
#  'piano',
#  'pdm5s',
#  'ilfoglioit',
#  'letta',
#  'troppo',
#  'entusiasta',
#  'primapagina',
#  '12gennaio',
#  'frontpage',
#  'httpstcow4abcq9jmq',
#  'martagrande87',
#  'legge',
#  'giornali',
#  'parte',
#  'parlamentari',
#  '5stelle',
#  'primis',
#  'appoggia',
#  'casini',
#  'quirinalespero',
#  'solo',
#  'fantasie',
#  'mente',
#  'deviata',
#  'giornalisti',
#  'maurobiani',
#  'presidentedellarepubblica',
#  'quirinale',
#  'covid',
#  'corsa',
#  'oggi',
#  'repubblica',
#  'httpstcowxmlzqlaoo',
#  'qnlanazione',
#  'quirinale',
#  'grandi',
#  'elettori',
#  'toscani',
#  'lega',
#  'cede',
#  'posto',
#  'httpstcowhfzuvkazx',
#  'via',
#  'qnlanazione',
#  'ƒöá',
#  'orientarsi',
#  'fase',
#  'semplice',
#  'quirinale',
#  'poche',
#  'certezze',
#  'molte',
#  'incertezze',
#  'draghi',
#  'vuole',
#  'andare',
#  'colle',
#  '100ôçø',
#  'claudiocerasa',
#  'ƒäö',
#  'nonstopnews',
#  'live',
#  'ôûâ',
#  'httpstcoidld1y40ul',
#  'httpstcodqk1xtdzai',
#  'cckki',
#  'dice',
#  'berlusconi',
#  'draghi',
#  'quirinale',
#  'voto',
#  'probabilmente',
#  'mattarella',
#  'sar',
#  'costretto',
#  'disfare',
#  'bagagli',
#  'feôçª',
#  'rosy',
#  'bindi',
#  'quirinale',
#  'credo',
#  'miracoli',
#  'httpstcosgg51ffgfp',
#  'quirinale',
#  'sembra',
#  'appresti',
#  'affossare',
#  'buon',
#  'senso',
#  'ddlzan',
#  'alta',
#  'politica',
#  'lombard5stelle',
#  'quirinale',
#  'dariovioli',
#  'lôçöipotesi',
#  'possa',
#  'votare',
#  'berlusconi',
#  'semplicemente',
#  'ridicola',
#  'fantapolitica',
#  'unôçöoffôçª',
#  'lanotiziatweet',
#  'draghi',
#  'sogna',
#  'quirinale',
#  'palazzo',
#  'chigi',
#  'fallito',
#  'quasi',
#  'partire',
#  'recovery',
#  'plan',
#  'campagna',
#  'vaccinaleôçª',
#  'dinogiarrusso',
#  'immaginatevi',
#  'giuseppeconteit',
#  'andato',
#  'conferenzastampa',
#  'tre',
#  'giorni',
#  'ritardo',
#  'escludendo',
#  'quotidiano',
#  'eôçª',
#  'giampierobiglia',
#  'stop',
#  'berlusconi',
#  'draghi',
#  'colle',
#  'fuori',
#  'governoôçø',
#  'frase',
#  'lôçöarroganza',
#  'spregiudicatezzaôçª',
#  'paolomieli',
#  'pare',
#  'modo',
#  'discutere',
#  'capo',
#  'stato',
#  'giorni',
#  'votazioni',
#  'proporre',
#  'richiamare',
#  'mattarella',
#  'quirinale',
#  'cososono',
#  'noquirisilvio',
#  'cosa',
#  'danaro',
#  'eleggere',
#  'pregiudicato',
#  'quirinale',
#  'ƒñ¼',
#  'sgarbi',
#  'chiama',
#  'parlamentari',
#  'poi',
#  'passa',
#  'berlusconi',
#  'augura',
#  'buon',
#  'anno',
#  'chiede',
#  'voto',
#  'quirinaleôçø',
#  'presa',
#  'montanari',
#  'perch',
#  'diceva',
#  'repubblica',
#  'banane',
#  'eliovito',
#  'elio',
#  'battute',
#  'parte',
#  'pochi',
#  'paese',
#  'riuscirebbe',
#  'mettere',
#  'daccordo',
#  'fatto',
#  'pensiero',
#  'quirinale',
#  'stanotte',
#  'sognato',
#  'diventava',
#  'presidente',
#  'repubblica',
#  'pillon',
#  'paolomieli',
#  'dibattito',
#  'quirinale',
#  'svilente',
#  'vede',
#  'ricomparire',
#  'sempre',
#  'uguale',
#  'ora',
#  'chiedono',
#  'mattarella',
#  'restare',
#  'solo',
#  'precedente',
#  'napolitano',
#  'accett',
#  'secondo',
#  'mandato',
#  'solo',
#  'dopo',
#  'patatrac',
#  'prime',
#  'votazioni',
#  'immaginate',
#  'mattarella',
#  'dicesse',
#  'scherzato',
#  'impossibile',
#  'potrebbe',
#  'tornare',
#  'campo',
#  'solo',
#  'fronte',
#  'disastro',
#  'conclamato',
#  'paolomieli',
#  '24mattino',
#  'quirinale',
#  'oriolialberto',
#  'meloni',
#  'desidera',
#  'patriota',
#  'quirinale',
#  'dovrebbe',
#  'leggere',
#  'piu',
#  'anpipatria',
#  'rivista',
#  'dellanpi',
#  'fondata',
#  '19ôçª',
#  'mancava',
#  'bersani',
#  'lungimiranza',
#  'vorrei',
#  'mariodraghi',
#  'pdr',
#  'prossimi',
#  'sette',
#  'anni',
#  'fino',
#  '2023',
#  'sempre',
#  'arrivi',
#  'cio',
#  'darebbe',
#  'peso',
#  'credibilita',
#  'stabilita',
#  'paese',
#  'matteorenzi',
#  'azionecesena',
#  'facciamorete',
#  'quirinale',
#  'giorgiameloni',
#  'httpstcoi85binr7wl',
#  'episodi',
#  'precedentimusichetta',
#  'quirinale',
#  'httpstcokyi0x6vncl',
#  'dimartedi',
#  'segretario',
#  'partito',
#  'democratico',
#  'enrico',
#  'letta',
#  'quirinale',
#  'notizie',
#  'parlamentari',
#  'gruppo',
#  'ricevuto',
#  'telefonata',
#  'berlusconi',
#  'giorniôçø',
#  'occhio',
#  'sporche',
#  'manovre',
#  'quirinale',
#  'perno',
#  'istituzionale',
#  'geopolitico',
#  'strategico',
#  'stato',
#  'italiano',
#  'forza',
#  'quirinale',
#  'poter',
#  'disegnare',
#  'cornice',
#  'entro',
#  'vita',
#  'politicoistituzionale',
#  'muoversi',
#  'dissipatio',
#  'httpstcov0llp7c8om',
#  'aspettiamo',
#  'studio24',
#  '1000',
#  'rainews',
#  'ospiti',
#  'parlare',
#  'oms',
#  'varianteomicron',
#  'covid19',
#  'scuola',
#  'universit',
#  'ricerca',
#  'draghi',
#  'mattarella',
#  'berlusconi',
#  'quirinale',
#  'presidentedellarepubblica',
#  'sassoli',
#  'europa',
#  'conduce',
#  'giorgiaromb',
#  'httpstcodlkuuakpu6',
#  'urbani',
#  'quirinale',
#  'berlusconi',
#  'apra',
#  'occhi',
#  'ôçø',
#  'draghi',
#  'meglio',
#  'palazzo',
#  'chigiôçø',
#  'httpstcowyu50pjcup',
#  'httpstcoeb6kqfq6vv',
#  'elezioni',
#  'quirinale',
#  '2022',
#  'possibili',
#  'scenari',
#  'mattarella',
#  'bis',
#  'draghi',
#  'berlusconi',
#  'prodi',
#  'cartabia',
#  'fino',
#  'moratti',
#  'sar',
#  'prossimo',
#  'presidente',
#  'repubblicahttpstcos6czyyzdua',
#  'spero',
#  'veramente',
#  'mattarella',
#  'ripensi',
#  'elezionipresidente',
#  'quirinale',
#  'gladiatoremassi',
#  'nome',
#  'popolo',
#  'italiano',
#  'chiedo',
#  'meloni',
#  'salvini',
#  'persona',
#  'perbene',
#  'gratteri',
#  'quirinale',
#  'meglôçª',
#  'fabvix1971',
#  'sola',
#  'idea',
#  'centrodestra',
#  'possa',
#  'effettivamente',
#  'proporre',
#  'berlusconi',
#  'quirinale',
#  'raccapricciante',
#  'auguro',
#  'côçª',
#  'juorno',
#  'quirinale',
#  'sgambetti',
#  'alleati',
#  'delegati',
#  'regionali',
#  'caos',
#  'httpstcoc8rdfxmdbe',
#  'juorno',
#  'quirinale',
#  'sgambetti',
#  'alleati',
#  'delegati',
#  'regionali',
#  'caos',
#  'httpstco0sxk4cw7uh',
#  'bollettino',
#  'covid',
#  'deve',
#  'essere',
#  'giornaliero',
#  'settimanale',
#  'fatti',
#  'capodanno',
#  'milano',
#  'entrano',
#  'dibattito',
#  'politico',
#  'quirinale',
#  'torna',
#  'voglia',
#  'bis',
#  'mattarella',
#  'riaprire',
#  'pozzi',
#  'gas',
#  'italiani',
#  'giornata',
#  'minuti',
#  '12gennaio',
#  'httpstcoqe5u9of6mh',
#  'lanota',
#  'gianka',
#  'modus',
#  'operandi',
#  'sinistraporre',
#  'veti',
#  'altri',
#  'scommettere',
#  'candidatura',
#  'femminile',
#  'colle',
#  'solo',
#  'appartiene',
#  'fronte',
#  'rosso',
#  'quirinale',
#  'httpstcobuxc4acbsq',
#  'quirinale',
#  'volevo',
#  'avvisare',
#  'berlusconi',
#  'liberato',
#  'posto',
#  'presidente',
#  'parlamentoeuropeo',
#  '12gennaio',
#  'europa',
#  'europarlamento',
#  'sassoli',
#  'davidsassoli',
#  'addiodavid',
#  'ripdavidsassoli',
#  'presidentedellarepubblica',
#  'noquirisilvio',
#  'buongiorno',
#  'untemaalgiorno',
#  'armanduplessis',
#  'considerando',
#  'alcune',
#  'bizzarre',
#  'ipotesi',
#  'campo',
#  'quirinale',
#  'scrive',
#  'folli',
#  'paese',
#  'potrebbe',
#  'aver',
#  'bisognoôçª',
#  'quirinale',
#  'perno',
#  'istituzionale',
#  'geopolitico',
#  'strategico',
#  'stato',
#  'italiano',
#  'forza',
#  'quirinale',
#  'poter',
#  'disegnare',
#  'cornice',
#  'entro',
#  'vita',
#  'politicoistituzionale',
#  'muoversi',
#  'potere',
#  'informali',
#  'nominaôçªhttpstcomss06urhro',
#  'httpstcoiainhsuto7',
#  'armanduplessis',
#  'considerando',
#  'alcune',
#  'bizzarre',
#  'ipotesi',
#  'campo',
#  'quirinale',
#  ...]

# %%
text_wordcloud = "".join(flatten_list)

# %%
wordcloud_grahics = WordCloud(collocations = False).generate(text_wordcloud)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-4f3641311a92> in <module>
# ----> 1 wordcloud_grahics = WordCloud(collocations = False).generate(text_wordcloud)
#
# NameError: name 'WordCloud' is not defined
