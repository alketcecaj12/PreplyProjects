# %%
import pandas as pd

# %%
data = pd.read_csv("data/big_five_scores.txt")

# %%
data
# Out:
#         case_id     country  age  sex  agreeable_score  extraversion_score  \
# 0             1  South Afri   24    1         0.753333            0.496667
# 1             3          UK   24    2         0.733333            0.680000
# 2             4         USA   36    2         0.880000            0.770000
# 3             5          UK   19    1         0.690000            0.616667
# 4             6          UK   17    1         0.600000            0.713333
# ...         ...         ...  ...  ...              ...                 ...
# 307308   334156         USA   22    2         0.750000            0.556667
# 307309   334157         USA   22    1         0.600000            0.620000
# 307310   334158         USA   22    2         0.820000            0.716667
# 307311   334160    Slovakia   36    1         0.516667            0.670000
# 307312   334161   Australia   35    2         0.866667            0.900000
#
#         openness_score  conscientiousness_score  neuroticism_score
# ...

# %%
data.corr()
# Out:
#                           case_id       age       sex  agreeable_score  \
# case_id                  1.000000 -0.018642 -0.053404         0.029784
# age                     -0.018642  1.000000 -0.002110         0.170754
# sex                     -0.053404 -0.002110  1.000000         0.226898
# agreeable_score          0.029784  0.170754  0.226898         1.000000
# extraversion_score       0.014258 -0.133600  0.078299         0.063388
# openness_score          -0.079521  0.018875  0.099388         0.160516
# conscientiousness_score  0.089970  0.265693  0.044886         0.314205
# neuroticism_score       -0.098343 -0.124734  0.196449        -0.169137
#
#                          extraversion_score  openness_score  \
# case_id                            0.014258       -0.079521
# age                               -0.133600        0.018875
# sex                                0.078299        0.099388
# agreeable_score                    0.063388        0.160516
# ...

# %%
gbc = data.groupby(by= ['country'])

# %%
for i, k in gbc : 
    print(i, len(k))
# Out:
# Afghanista 624
# Albania 527
# Algeria 360
# Andorra 167
# Angola 97
# Anguilla 83
# Antarctica 74
# Antigua 36
# Arabian Gu 32
# Argentina 235
# Armenia 40
# Aruba 23
# Australia 10400
# Austria 223
# Azerbaijan 47
# Bahamas 83
# Bahrain 42
# Bangladesh 63
# Barbados 57
# Belarus 33
# Belgium 663
# Belize 26
# Benin 7
# Bermuda 35
# Bhutan 13
# Bolivia 33
# Borneo 11
# Bosnia Her 77
# Botswana 10
# Bouvet Isl 3
# Brazil 661
# British In 21
# British Vi 60
# Brunei 22
# Bulgaria 176
# Burkina Fa 6
# Burma 6
# Burma(Myan 18
# Burundi 7
# Cambodia 19
# Cameroon 26
# Canada 21798
# Cape Verde 66
# Cayman Isl 63
# Central Af 19
# Chad 8
# Chile 81
# China 915
# Christmas 3
# Cocos (Kee 4
# Columbia 209
# Comoros 4
# Congo 6
# Cook Islan 5
# Costa Rica 75
# Croatia 307
# Cuba 76
# Cyprus 77
# Czech Repu 108
# Denmark 614
# Djibouti 5
# Dominica 10
# Dominican 75
# East Timor 2
# Ecuador 56
# Egypt 286
# El Salvado 47
# Equatorial 1
# Eritrea 4
# Estonia 189
# Ethiopia 27
# Faeroe Isl 8
# ...
